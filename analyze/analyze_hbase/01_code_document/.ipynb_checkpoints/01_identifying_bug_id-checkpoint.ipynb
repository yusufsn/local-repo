# %%
import os, glob, json, csv, subprocess, sys, re
from urllib.request import urlopen
from itertools import chain
import urllib.request
from pprint import pprint
from bs4 import BeautifulSoup
from git import *
from subprocess import Popen, PIPE
from os import path
from collections import Counter
import pandas as pd
import plotly.graph_objs as go
import plotly
from plotly.offline import plot, init_notebook_mode, iplot
import itertools

# %matplotlib inline

# %% [markdown]
# # Defining directories

# %%
userhome = os.path.expanduser('~')
repository = userhome + r'/different-diff/dataset/hbase/'
analyze_dir = userhome + r'/different-diff/analyze/analyze_hbase/'

# %% [markdown]
# # Defining git command function

# %%
def execute_command(cmd, work_dir):
    """Executes a shell command in a subprocess, waiting until it has completed.
    :param cmd: Command to execute.
    :param work_dir: Working directory path.
    """
    pipe = subprocess.Popen(cmd, shell=True, cwd=work_dir, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    (out, error) = pipe.communicate()
    return out, error
    pipe.wait()

# %% [markdown]
# # Finding log messages containing bug

# %%
#Applying git command to find commit log messages containing words of bugs, fix, defect or patch
words = ['bug', 'fix', 'defect', 'patch']
logs = []
for n, word in enumerate(words):
    git_cmd = "git log --all --grep='" + word + "' --oneline"
    log = (str(execute_command(git_cmd, repository)).replace("b'",'').replace('b"','').replace('(','',1).replace("\\'","'").split("\\n"))[:-1]

    logs.append(log)

com_logs = [item for sublist in logs for item in sublist]
com_logs
# Out:
# ['acbdb86bb4 HBASE-20169 NPE when calling HBTU.shutdownMiniCluster',
#  '0b44b13609 HBASE-20169 NPE when calling HBTU.shutdownMiniCluster',
#  'fabb1d97cc HBASE-20169 NPE when calling HBTU.shutdownMiniCluster',
#  'd0e55429b3 HBASE-20178 [AMv2] Throw exception if hostile environment',
#  'abdc7b25d4 HBASE-20178 [AMv2] Throw exception if hostile environment',
#  '63ce0c0733 HBASE-20178 [AMv2] Throw exception if hostile environment',
#  '81bf068b2f HBASE-20078 MultiByteBuff : bug in reading primitives when individual buffers are too small.',
#  '7bd39250e7 HBASE-20078 MultiByteBuff : bug in reading primitives when individual buffers are too small.',
#  'e83ac38d68 HBASE-20078 MultiByteBuff : bug in reading primitives when individual buffers are too small.',
#  'd4e0fc74d4 HBASE-20082 Fix findbugs errors only on master which are introduced by HBASE-19397',
#  '39c8acfed6 HBASE-15151 ensure findbugs check runs in nightly tests on all branches.',
#  '27642614b4 HBASE-15151 ensure findbugs check runs in nightly tests on all branches.',
#  'c9bcc0b9b1 HBASE-20082 Fix findbugs errors only on master which are introduced by HBASE-19397',
#  'f89a1f7d7a HBASE-20121 Fix findbugs warning for RestoreTablesClient',
#  '5f238440ac HBASE-15151 ensure findbugs check runs in nightly tests on all branches.',
#  'a9bbaca7c9 HBASE-15151 ensure findbugs check runs in nightly tests on all branches.',
#  '915a6865c0 HBASE-15151 ensure findbugs check runs in nightly tests on all branches.',
#  '01746c72ab HBASE-15151 ensure findbugs check runs in nightly tests on all branches.',
#  '383b7cc592 HBASE-15151 ensure findbugs check runs in nightly tests on all branches.',
#  '5b64de45ed HBASE-20110 Findbugs in zk and mr caused nightly #409 branch-2 to fail',
#  '03f9cb89a6 HBASE-20110 Findbugs in zk and mr caused nightly #409 branch-2 to fail',
#  '5317ca92bc HBASE-20069 fix existing findbugs errors in hbase-server; ADDENDUM Address review Revert of the revert, i.e. reapply. Thought this had broken the build but it was a bad nightly. Putting it back.',
#  '07eae00ec1 Revert "HBASE-20069 fix existing findbugs errors in hbase-server; ADDENDUM Address review"',
#  'd272ac908c HBASE-20069 fix existing findbugs errors in hbase-server; ADDENDUM Address review',
#  '43d661b008 HBASE-20069 fix existing findbugs errors in hbase-server; ADDENDUM Address review',
#  'b11e506664 HBASE-20069 fix existing findbugs errors in hbase-server',
#  '44544c7db0 HBASE-20069 fix existing findbugs errors in hbase-server',
#  'ef02762dd8 HBASE-20083 Fix findbugs error for ReplicationSyncUp',
#  '2beda62a10 HBASE-20083 Fix findbugs error for ReplicationSyncUp',
#  '8c74d177f6 HBASE-20082 Fix findbugs errors only on master which are introduced by HBASE-19397',
#  'af804a586b HBASE-19930: Fixing the bug, in the rare case when there is a merge into CCM and the one of the old segments has a big cell allocated on-heap and it needs to be copied to the MSLAB',
#  '07e93458fe HBASE-19930: Fixing the bug, in the rare case when there is a merge into CCM and the one of the old segments has a big cell allocated on-heap and it needs to be copied to the MSLAB',
#  '89baad5bbe     HBASE-19940 TestMetaShutdownHandler flakey; ADDENDUM: yet more debug',
#  '001f9cc5ea     HBASE-19940 TestMetaShutdownHandler flakey; ADDENDUM: yet more debug',
#  '590bee78dc HBASE-19940 TestMetaShutdownHandler flakey; ADDENDUM: more debug',
#  'ca6b37d63c HBASE-19940 TestMetaShutdownHandler flakey; ADDENDUM: more debug',
#  '9f2149f171 HBASE-19840 Flakey TestMetaWithReplicas; ADDENDUM Adding debug',
#  'a1600c1490 HBASE-19840 Flakey TestMetaWithReplicas; ADDENDUM Adding debug',
#  'c245bd5c03 HBASE-19837 Flakey TestRegionLoad; ADDENDUM Report more often and wait less time on change (also add some debug on TestMetaShutdown test)',
#  '29016bc100 HBASE-19837 Flakey TestRegionLoad; ADDENDUM Report more often and wait less time on change (also add some debug on TestMetaShutdown test)',
#  '30a7e4a35c HBASE-19554 reenable TestDLSAsyncFSWAL/TestDLSFSHLog for debugging',
#  '88d6e06a1f HBASE-19554 reenable TestDLSAsyncFSWAL/TestDLSFSHLog for debugging',
#  '811afad103 HBASE-19915 Create merged/ daughter region/s with initial state CLOSED from MetaTableAccessor#splitRegion()/ mergeRegions()',
#  'fdbc843516 HBASE-19915 Create merged/ daughter region/s with initial state CLOSED from MetaTableAccessor#splitRegion()/ mergeRegions()',
#  '34c6c99041 HBASE-19811 Fix findbugs and error-prone warnings in hbase-server (branch-2) - addendum',
#  '27d73dec8a HBASE-19811 Fix findbugs and error-prone warnings in hbase-server (branch-2) - addendum',
#  '72f4e98ed1 HBASE-19846 Fix findbugs and error-prone warnings in hbase-rest (branch-2)',
#  'aeffca497b HBASE-19846 Fix findbugs and error-prone warnings in hbase-rest (branch-2)',
#  '130da9d18b HBASE-19860 Run branch-2 nightly job more frequently to help with flaky tests debugging',
#  'f5779855c6 HBASE-19845 Fix findbugs and error-prone warnings in hbase-rsgroup (branch-2)',
#  'b20b45e4e8 HBASE-19845 Fix findbugs and error-prone warnings in hbase-rsgroup',
#  'd589b72382 HBASE-19847 Fix findbugs and error-prone warnings in hbase-thrift (branch-2)',
#  '8977aae430 HBASE-19847 Fix findbugs and error-prone warnings in hbase-thrift (branch-2)',
#  '93a182f286 HBASE-19811 Fix findbugs and error-prone warnings in hbase-server (branch-2)',
#  'b1269ec57f HBASE-19811 Fix findbugs and error-prone warnings in hbase-server (branch-2)',
#  'd49357f265 HBASE-19840 Flakey TestMetaWithReplicas',
#  '1e5fc1ed63 HBASE-19840 Flakey TestMetaWithReplicas',
#  'c60359959c HBASE-19837 Flakey TestRegionLoad',
#  'd4ffee2023 HBASE-19837 Flakey TestRegionLoad',
#  'b44be75bd1 HBASE-19837 Flakey TestRegionLoad',
#  'f3c563fc00 HBASE-19837 Flakey TestRegionLoad',
#  '13547d53eb HBASE-19815 Flakey TestAssignmentManager.testAssignWithRandExec (Part Two).',
#  '581fabe7b2 HBASE-19815 Flakey TestAssignmentManager.testAssignWithRandExec (Part Two).',
#  '4676d4bf4a HBASE-19810 Fix findbugs and error-prone warnings in hbase-metrics (branch-2)',
#  'c1a8dc09d6 HBASE-19810 Fix findbugs and error-prone warnings in hbase-metrics (branch-2)',
#  '0561312bc4 HBASE-19809 Fix findbugs and error-prone warnings in hbase-procedure (branch-2)',
#  'c269e63a07 HBASE-19809 Fix findbugs and error-prone warnings in hbase-procedure (branch-2)',
#  '4ddfecac56 HBASE-19787 Fix or disable tests broken in branch-2 so can cut beta-1',
#  '026f535a77 HBASE-19787 Fix or disable tests broken in branch-2 so can cut beta-1',
#  'c799b0e69b HBASE-19694 The initialization order for a fresh cluster is incorrect Addendum. Adds in a missing line that helps debugging.',
#  'd8271b0361 HBASE-19694 The initialization order for a fresh cluster is incorrect Addendum. Adds in a missing line that helps debugging.',
#  '97dc7d87cd HBASE-19654 Remove misleading and chatty debug message in ReplicationLogCleaner',
#  'd8ef30c5e1 HBASE-19654 Remove misleading and chatty debug message in ReplicationLogCleaner',
#  'bcacdeb212 HBASE-19491 Improvements to Nighly runs: Fixes findbugs tests, Exclude flaky tests from master.',
#  '605d92e3c1 HBASE-19491 Improvements to Nighly runs: Fixes findbugs tests, Exclude flaky tests from master.',
#  'b0b4eb2177 HBASE-19491 Improvements to Nighly runs: Fixes findbugs tests, Exclude flaky tests from master.',
#  '85211b1b5b HBASE-19491 Improvements to Nighly runs: Fixes findbugs tests, Exclude flaky tests from master.',
#  '0a31209f91 HBASE-19491 Improvements to Nighly runs: Fixes findbugs tests, Exclude flaky tests from master.',
#  '90ac3c93c9 HBASE-19491 Improvements to Nighly runs: Fixes findbugs tests, Exclude flaky tests from master.',
#  'dc5ec061b5 HBASE-19491 Improvements to Nighly runs: Fixes findbugs tests, Exclude flaky tests from master.',
#  '4fad3d96c9 HBASE-19554 For debug: Modify HTU.waitUntilAllRegionsAssigned to handle the case where we do not have entries for the given table',
#  '084e324fb9 HBASE-19554 For debug: Modify HTU.waitUntilAllRegionsAssigned to handle the case where we do not have entries for the given table',
#  '4c2b2b3e6a HBASE-19497 Fix findbugs and error-prone warnings in hbase-common (branch-2) Signed-off-by: Apekshit Sharma <appy@apache.org>',
#  'f9f869f60a HBASE-19497 Fix findbugs and error-prone warnings in hbase-common (branch-2) Signed-off-by: Apekshit Sharma <appy@apache.org>',
#  '2043c337d8 HBASE-19498 Fix findbugs and error-prone warnings in hbase-client (branch-2)',
#  '59529a78f0 HBASE-19498 Fix findbugs and error-prone warnings in hbase-client (branch-2)',
#  'e8ba7b2320 HBASE-19457 Debugging flaky TestTruncateTableProcedure',
#  '7092b814bd HBASE-19457 Debugging flaky TestTruncateTableProcedure',
#  'a70b9b5e94 HBASE-19454 Debugging TestDistributedLogSplitting#testThreeRSAbort',
#  '033e64a8b1 HBASE-19454 Debugging TestDistributedLogSplitting#testThreeRSAbort',
#  '9d481b1c43 HBASE-19239 (addendum) Fix findbugs and error-prone warnings (branch-1)',
#  'ed9c8b1cfe HBASE-19239 (addendum) Fix findbugs and error-prone warnings (branch-1)',
#  'd32ba0977f HBASE-19386 Enable Arm64 unaligned support for HBase',
#  'ddbff4fd87 HBASE-19386 Enable Arm64 unaligned support for HBase',
#  '96e63ac7b8 HBASE-19319 Fix bug in synchronizing over ProcedureEvent',
#  'f886716617 HBASE-19319 Fix bug in synchronizing over ProcedureEvent',
#  '0f888cbcf3 HBASE-19239 Fix findbugs and error-prone issues',
#  'b2fa185f85 HBASE-19239 Fix findbugs and error-prone issues',
#  'f6e93520ba HBASE-19239 Fix findbugs and error-prone issues',
#  '3436ed957c HBASE-19239 Fix findbugs and error-prone issues',
#  'e95f94a72d HBASE-19239 Fix findbugs and error-prone issues',
#  'd80d3fa454 HBASE-19239 Fix findbugs and error-prone issues',
#  '357b3dbc3e HBASE-19239 Fix findbugs and error-prone issues',
#  '24feb1ab75 HBASE-19239 Fix findbugs and error-prone issues',
#  '5b7411290b HBASE-19239 Fix findbugs and error-prone issues',
#  'f856cbf414 HBASE-19239 Fix findbugs and error-prone issues',
#  'b9475d3e75 HBASE-19239 Fix findbugs and error-prone issues',
#  '108ea30e3d HBASE-19239 Fix findbugs and error-prone issues',
#  'daf1fc6f1f HBASE-19239 Fix findbugs and error-prone issues',
#  'ca186f9349 HBASE-19239 Fix findbugs and error-prone issues',
#  '1a5e95ae98 HBASE-19239 Fix findbugs and error-prone issues',
#  '3444059a20 HBASE-19239 Fix findbugs and error-prone issues',
#  'c179d5144f HBASE-19239 Fix findbugs and error-prone issues',
#  '2d579a4140 HBASE-19239 Fix findbugs and error-prone issues',
#  '6ceb4a4f41 HBASE-16290 Dump summary of callQueue content; can help debugging',
#  '7cdfbde37d HBASE-16290 Dump summary of callQueue content; can help debugging',
#  '6765f5e203 HBASE-18350 RSGroups are broken under AMv2',
#  '41cc9a125f HBASE-18350 RSGroups are broken under AMv2',
#  '08dff49620 HBASE-18960 A few bug fixes and minor improvements around batchMutate',
#  'e1941aa6d1 HBASE-18960 A few bug fixes and minor improvements around batchMutate',
#  'c4497c37d5 HBASE-18929 Hbase backup command doesn\\xe2\\x80\\x99t show debug option to enable backup in debug mode (Amit Kabra)',
#  '1ff90d3b4b HBASE-18929 Hbase backup command doesn\\xe2\\x80\\x99t show debug option to enable backup in debug mode (Amit Kabra)',
#  "ede916af5a Amend HBASE-18830 TestCanaryTool does not check Canary monitor's error code",
#  "91e1f834bf Amend HBASE-18830 TestCanaryTool does not check Canary monitor's error code",
#  "f391fc44df Amend HBASE-18830 TestCanaryTool does not check Canary monitor's error code",
#  "3abc0458e9 Amend HBASE-18830 TestCanaryTool does not check Canary monitor's error code",
#  '68ec2a9da0 HBASE-18375: Fix the bug where the pool chunks from ChunkCreator are deallocated and not returned to pool, because there is no reference to them',
#  '43c4bc5761 HBASE-18723 [pom cleanup] Do a pass with dependency:analyze; remove unused and explicity list the dependencies we exploit',
#  'fb537fe736 HBASE-18723 [pom cleanup] Do a pass with dependency:analyze; remove unused and explicity list the dependencies we exploit',
#  '75a6b36849 HBASE-18375: Fix the bug where the pool chunks from ChunkCreator are deallocated and not returned to pool, because there is no reference to them',
#  '97877df172 HBASE-18315 Eliminate the findbugs warnings for hbase-rest',
#  'bb8c3ac035 HBASE-18315 Eliminate the findbugs warnings for hbase-rest',
#  '781272c37f HBASE-18315 Eliminate the findbugs warnings for hbase-rest',
#  '8b6cf09869 HBASE-18315 Eliminate the findbugs warnings for hbase-rest',
#  '4376233e2a HBASE-18315 Eliminate the findbugs warnings for hbase-rest',
#  '18d29e4794 HBASE-18315 Eliminate the findbugs warnings for hbase-rest',
#  '7db088b4be HBASE-18308 Eliminate the findbugs warnings for hbase-server',
#  '8aabbdb3ed HBASE-18308 Eliminate the findbugs warnings for hbase-server',
#  '68e9f2173b HBASE-18308 Eliminate the findbugs warnings for hbase-server',
#  '2da5b432a1 HBASE-18308 Eliminate the findbugs warnings for hbase-server',
#  '594f892c02 HBASE-18308 Eliminate the findbugs warnings for hbase-server',
#  '3574757f74 HBASE-18308 Eliminate the findbugs warnings for hbase-server',
#  'ea0062fa54 HBASE-18376 Add debug logs to hbase-personality.sh to make it possible to debug this issue.',
#  '4bd5f03d22 HBASE-18365 Eliminate the findbugs warnings for hbase-common',
#  'b1e128fd76 HBASE-18365 Eliminate the findbugs warnings for hbase-common',
#  '0616811fab HBASE-18365 Eliminate the findbugs warnings for hbase-common',
#  '1b8fb0a8d8 HBASE-18365 Eliminate the findbugs warnings for hbase-common',
#  '9daac09f6e HBASE-18365 Eliminate the findbugs warnings for hbase-common',
#  'cf636e50b9 HBASE-18365 Eliminate the findbugs warnings for hbase-common',
#  'd11b5d1fd5 HBASE-18268 Eliminate the findbugs warnings for hbase-client',
#  'a84de33129 HBASE-18268 Eliminate the findbugs warnings for hbase-client',
#  '4ad8ae3db5 HBASE-18268 Eliminate the findbugs warnings for hbase-client',
#  '8eaad67866 HBASE-18268 Eliminate the findbugs warnings for hbase-client',
#  'ca5d8c40b7 HBASE-18268 Eliminate the findbugs warnings for hbase-client',
#  'cc4301ca08 HBASE-18268 Eliminate the findbugs warnings for hbase-client',
#  '29ec749363 HBASE-18314 Eliminate the findbugs warnings for hbase-examples',
#  '8b63eb6fc6 HBASE-18314 Eliminate the findbugs warnings for hbase-examples',
#  'b222a41c1f HBASE-18293 Only add the spotbugs dependency when jdk8 is active',
#  'a4dfc669f1 HBASE-18293 Only add the spotbugs dependency when jdk8 is active',
#  'eacbdb061e HBASE-18264 Update pom plugins',
#  'f2731fc241 HBASE-18264 Update pom plugins',
#  "d627c6f288 HBASE-18293 remove spotbugs on branch-1.1 since it doesn't support jdk8",
#  'b49390922e HBASE-18293 Only add the spotbugs dependency when jdk8 is active',
#  '8c37b912ac HBASE-18293 Only add the spotbugs dependency when jdk8 is active',
#  '0d4245c99e HBASE-18293 Only add the spotbugs dependency when jdk8 is active',
#  '0357c2266a HBASE-18254 ServerCrashProcedure checks and waits for meta initialized, instead should check and wait for meta loaded',
#  '7cc458e129 HBASE-18254 ServerCrashProcedure checks and waits for meta initialized, instead should check and wait for meta loaded',
#  '0936f1f2bd HBASE-17954 Switched findbugs implementation to spotbugs',
#  'a8874eb7eb HBASE-17954 Switched findbugs implementation to spotbugs',
#  'a7d824bf13 HBASE-17954 Switched findbugs implementation to spotbugs',
#  '13f670057f HBASE-17954 Switched findbugs implementation to spotbugs',
#  '8b0ae5d1ae HBASE-17954 Switched findbugs implementation to spotbugs',
#  '298454e8a7 HBASE-17954 Switched findbugs implementation to spotbugs',
#  '3975bbd008 HBASE-14614 Procedure v2 - Core Assignment Manager (Matteo Bertozzi) Move to a new AssignmentManager, one that describes Assignment using a State Machine built on top of ProcedureV2 facility.',
#  'e76e8eb8e1 HBASE-14614 Procedure v2 - Core Assignment Manager (Matteo Bertozzi) Move to a new AssignmentManager, one that describes Assignment using a State Machine built on top of ProcedureV2 facility.',
#  'dc1065a85d HBASE-14614 Procedure v2 - Core Assignment Manager (Matteo Bertozzi) Move to a new AssignmentManager, one that describes Assignment using a State Machine built on top of ProcedureV2 facility.',
#  '841bb00655 HBASE-18044 Fix bug in report-flakies.py where if counter is set outside for loop, it cannot be overwritten inside loop.',
#  'cb4fac1d18 HBASE-17765 Reviving the merge of the compacting pipeline',
#  '046d4e183b Revert "Reviving the merge of the compacting pipeline: making the limit on the number of the segments in the pipeline configurable, adding merge test, fixing bug in sizes counting"',
#  'c77e2135db Reviving the merge of the compacting pipeline: making the limit on the number of the segments in the pipeline configurable, adding merge test, fixing bug in sizes counting',
#  'f45d261902 HBASE-15484 Correct the semantic of batch and partial - amend to fix bug and revise the JavaDoc for related APIs.',
#  'b635414e83 HBASE-15484 Correct the semantic of batch and partial - amend to fix bug and revise the JavaDoc for related APIs.',
#  "c725d4d334 HBASE-17538 HDFS.setStoragePolicy() logs errors on local fs Policy is set in a number of places each with its own 'implementation'.",
#  '69ce5967fd HBASE-17373: Fixing bug in moving segments from compaction pipeline to snapshot',
#  'a5ee36d937 HBASE-17326 Fix findbugs warning in BufferedMutatorParams Fix above and the other hbase-server findbugs complaint about null-check Addendum to fix complaint out of BMParams#clone. Added CN_IDIOM_NO_SUPER_CALL handling.',
#  'c3ce02d592 HBASE-17326 Fix findbugs warning in BufferedMutatorParams Fix above and the other hbase-server findbugs complaint about null-check',
#  '8d62d9a0d5 HBASE-16940 Address review of "Backup/Restore (HBASE-7912, HBASE-14030, HBASE-14123) mega patch" posted on RB - fix findbugs warnings (Vladimir Rodionov)',
#  '8152234539 HBASE-16904 ADDENDUM cleanup of snapshot related changes for fs redo.',
#  '87f74bcaab HBASE-17006 Give name to existing threads. Having thread names in logs and thread dumps greatly improve debugability. This patch is simply adding the names to the threads we spawn.',
#  '90c29888c4 HBASE-17006 Give name to existing threads. Having thread names in logs and thread dumps greatly improve debugability. This patch is simply adding the names to the threads we spawn.',
#  '326ecc32fd HBASE-17006 Give name to existing threads. Having thread names in logs and thread dumps greatly improve debugability. This patch is simply adding the names to the threads we spawn.',
#  '3dc95c0e67 HBASE-17006 Give name to existing threads. Having thread names in logs and thread dumps greatly improve debugability. This patch is simply adding the names to the threads we spawn.',
#  '51ba7cfde3 HBASE-17006 Give name to existing threads. Having thread names in logs and thread dumps greatly improve debugability. This patch is simply adding the names to the threads we spawn.',
#  'bb0fc6b602 HBASE-17006 Give name to existing threads. Having thread names in logs and thread dumps greatly improve debugability. This patch is simply adding the names to the threads we spawn.',
#  '281bf9a222 HBASE-17014 Added clearly marked log messages for start and shutdown of services HMaster, HRegionServer, ThriftServer, RESTServer. Also changed the log level for RPCServer responder starting log message to debug.',
#  'a969f8d790 HBASE-16969 RegionCoprocessorServiceExec should override the toString() for debugging (ChiaPing Tsai)',
#  'fe47ec81f9 HBASE-16969 RegionCoprocessorServiceExec should override the toString() for debugging (ChiaPing Tsai)',
#  'bbe88d942e HBASE-16944 Fix findbugs warning in hbase-server HRegion UL_UNRELEASED_LOCK',
#  '9dd28f2a94 HBASE-16881 Address findbugs warnings for backup mega patch',
#  '0d40a52ee8 Revert "Revert "HBASE-16698 Performance issue: handlers stuck waiting for CountDownLatch inside WALKey#getWriteEntry under high writing workload; ADDENDUM. Fix findbugs""',
#  'f555b5be9c Revert "HBASE-16698 Performance issue: handlers stuck waiting for CountDownLatch inside WALKey#getWriteEntry under high writing workload; ADDENDUM. Fix findbugs" Premature commit. Revert while discussion ongoing',
#  'e1923b7c0c HBASE-16698 Performance issue: handlers stuck waiting for CountDownLatch inside WALKey#getWriteEntry under high writing workload; ADDENDUM. Fix findbugs',
#  '8c4b09dfba HBASE-16624 Fix MVCC DeSerialization bug in the HFileScannerImpl',
#  '5a1b3a548e HBASE-16535 Use regex to exclude generated classes for findbugs',
#  '4de27ee312 HBASE-16535 Use regex to exclude generated classes for findbugs',
#  'c25c36274f HBASE-16535 Use regex to exclude generated classes for findbugs',
#  '3c5d01c3e4 HBASE-16535 Use regex to exclude generated classes for findbugs',
#  '966aeb06a8 HBASE-16535 Use regex to exclude generated classes for findbugs',
#  '1da0a48f6b HBASE-16535 Use regex to exclude generated classes for findbugs',
#  'c11923d8aa HBASE-16456 Fix findbugs warnings in hbase-rsgroup module (Guangxu Cheng)',
#  "741d0a4511 HBASE-16430 Fix RegionServer Group's bug when moving multiple tables (Guangxu Cheng)",
#  "ad16676f92 Fix RegionServer Group's bug when moving multiple tables (Guangxu Cheng)",
#  '45bb6180a3 REVERT of revert of "HBASE-16308 Contain protobuf references Gather up the pb references into a few locations only rather than have pb references distributed all about the code base." This is a revert of a revert; i.e. we are adding back the change only adding back with fixes for the broken unit test; was a real issue on a test that went in just at same time as this commit; I was getting a new nonce on each retry rather than getting one for the mutation.',
#  'bbc427028c HBASE-16321 ensure no findbugs-jsr305',
#  'ca5e1a5771 HBASE-16321 ensure no findbugs-jsr305',
#  '7b91c136b2 HBASE-16321 ensure no findbugs-jsr305',
#  'bf12fe6788 HBASE-16321 ensure no findbugs-jsr305',
#  'a5f98c3f9e HBASE-16321 ensure no findbugs-jsr305',
#  '60b79e2daa HBASE-16321 ensure no findbugs-jsr305',
#  'af6ebcd1a2 HBASE-16355 Invalid hbase-common test-jar dependency scope',
#  '737e063240 HBASE-16355 Invalid hbase-common test-jar dependency scope',
#  '544dc1e558 HBASE-16355 Invalid hbase-common test-jar dependency scope',
#  'dfc9616aea HBASE-16317 revert all ESAPI changes',
#  '01215db07a HBASE-16317 revert all ESAPI changes',
#  '92b2973b62 HBASE-16317 revert all ESAPI changes',
#  '209b6f74c7 HBASE-16317 revert all ESAPI changes',
#  '8b3385bd36 HBASE-16317 revert all ESAPI changes',
#  'e5d0d48580 HBASE-15115 Fix findbugs complaints in hbase-client',
#  'fb9a64816d HBASE-16180 Fix ST_WRITE_TO_STATIC_FROM_INSTANCE_METHOD findbugs introduced by parent',
#  '11c59d9ddf HBASE-16180 Fix ST_WRITE_TO_STATIC_FROM_INSTANCE_METHOD findbugs introduced by parent',
#  '78ef0513b4 HBASE-16180 Fix ST_WRITE_TO_STATIC_FROM_INSTANCE_METHOD findbugs introduced by parent',
#  '1ac755e40d HBASE-16180 Fix ST_WRITE_TO_STATIC_FROM_INSTANCE_METHOD findbugs introduced by parent',
#  '2d6cdfb10a HBASE-16180 Fix ST_WRITE_TO_STATIC_FROM_INSTANCE_METHOD findbugs introduced by parent',
#  '4421fdf981 HBASE-16066 Resolve RpC_REPEATED_CONDITIONAL_TEST findbugs warnings in HMaster, addendum to HBASE-15467',
#  "c2b4c6f637 HBASE-15965 - Testing by executing a command will cover the exact path users will trigger, so its better then directly calling library functions in tests. Changing the tests to use @shell.command(:<command>, args) to execute them like it's a command coming from shell.",
#  "15c03fd1c9 HBASE-15965 - Testing by executing a command will cover the exact path users will trigger, so its better then directly calling library functions in tests. Changing the tests to use @shell.command(:<command>, args) to execute them like it's a command coming from shell.",
#  '6d0e8b2a91 Revert "HBASE-15949 Cleanup TestRegionServerMetrics." This change passes on master but fails on branch-1. Will try to debug.',
#  'eb64cd9dd1 HBASE-15917 Addendum. Fix bug in report-flakies.py where hanging tests are not being added to flaky list. (Apekshit) ADDENDUM #2!',
#  '4abc602e3b HBASE-15912. REST module has 2 extent warnings in findbugs.',
#  'c47511baa7 HBASE-15828 fix extant findbug NM_SAME_SIMPLE_NAME_AS_INTERFACE in Future',
#  'ac31ceb835 HBASE-15794 Fix Findbugs instanceof always true issue in MultiServerCallable',
#  'a3e77bf366 HBASE-15720 Print row locks at the debug dump page, addendum',
#  'bf13941592 HBASE-15720 Print row locks at the debug dump page; addendum',
#  '716ca48a74 HBASE-15720 Print row locks at the debug dump page',
#  'a837182b79 HBASE-15720 Print row locks at the debug dump page',
#  '1c92d02b00 HBASE-15720 Print row locks at the debug dump page',
#  '92eec53829 HBASE-15720 Print row locks at the debug dump page',
#  '710ad4a168 HBASE-15720 Print row locks at the debug dump page',
#  '5f5cdaae9a HBASE-15720 Print row locks at the debug dump page',
#  'e8b37422c3 HBASE-15720 Print row locks at the debug dump page',
#  'b3e71d4644 HBASE-15434 [findbugs] Exclude scala generated source and protobuf generated code in hbase-spark module',
#  'fe7bcf58d9 HBASE-15291 Revert due to the bug Haitao discovered',
#  'dc4bdb9928 HBASE-15291 Revert due to the bug Haitao discovered',
#  'd74f99fbc1 HBASE-15291 Revert due to the bug Haitao discovered',
#  '77c3c61b34 HBASE-15291 Revert due to the bug Haitao discovered',
#  'edc5ab5af9 HBASE-15291 Revert due to the bug Haitao discovered',
#  '41c04ee685 HBASE-15181 Addendum fixes findbugs warning (Clara Xiong)',
#  'ab2904c7d7 HBASE-15181 Addendum fixes findbugs warning (Clara Xiong)',
#  '231a5807b4 HBASE-15181 Addendum fixes findbugs warning (Clara Xiong)',
#  'bab8d1527b HBASE-15181 Addendum fixes findbugs warning (Clara Xiong)',
#  '29ce46a67f HBASE-15122 Servlets generate XSS_REQUEST_PARAMETER_TO_SERVLET_WRITER findbugs warnings (Samir Ahmic)',
#  '3733223e40 HBASE-15122 Servlets generate XSS_REQUEST_PARAMETER_TO_SERVLET_WRITER findbugs warnings (Samir Ahmic)',
#  'a6f53600dd HBASE-15122 Servlets generate XSS_REQUEST_PARAMETER_TO_SERVLET_WRITER findbugs warnings (Samir Ahmic)',
#  'f280c45956 HBASE-15122 Servlets generate XSS_REQUEST_PARAMETER_TO_SERVLET_WRITER findbugs warnings (Samir Ahmic)',
#  '68b300173f HBASE-15122 Servlets generate XSS_REQUEST_PARAMETER_TO_SERVLET_WRITER findbugs warnings (Samir Ahmic)',
#  'a975408b7c HBASE-15253 Small bug in CellUtil.matchingRow(Cell, byte[]) (Ram)',
#  '52355ab1de HBASE-15148 Resolve IS2_INCONSISTENT_SYNC findbugs warning in AuthenticationTokenSecretManager (Yu Li)',
#  '6f6cd661d5     HBASE-15238 HFileReaderV2 prefetch overreaches; runs off the end of the data',
#  'b6328eb803 HBASE-15238 HFileReaderV2 prefetch overreaches; runs off the end of the data',
#  'd82ae42126 Revert "HBASE-15122 Servlets generate XSS_REQUEST_PARAMETER_TO_SERVLET_WRITER findbugs warnings (Samir Ahmic)" Revert mistaken commit.',
#  'efc7a0d347 HBASE-15122 Servlets generate XSS_REQUEST_PARAMETER_TO_SERVLET_WRITER findbugs warnings (Samir Ahmic)',
#  'f4d9597e1e  HBASE-15210 Undo aggressive load balancer logging at tens of lines per millisecond; ADDENDUM changing LOG.debug to LOG.trace -- noticed by matteo',
#  '846a2f31c1  HBASE-15210 Undo aggressive load balancer logging at tens of lines per millisecond; ADDENDUM changing LOG.debug to LOG.trace -- noticed by matteo',
#  '0e36afd2d0  HBASE-15210 Undo aggressive load balancer logging at tens of lines per millisecond; ADDENDUM changing LOG.debug to LOG.trace -- noticed by matteo',
#  '2cc48e039d HBASE-15158 HBASE-15158 Preamble 1 of 2: fix findbugs, add javadoc, change Region#getReadpoint to #getReadPoint, and some util',
#  "9955118995 HBASE-15195 Don't run findbugs on hbase-it; it has nothing in src/main/java",
#  'cd920940b7 HBASE-15148 Resolve IS2_INCONSISTENT_SYNC findbugs warning in AuthenticationTokenSecretManager (Yu Li)',
#  '37d15e05d8 HBASE-15148 Resolve IS2_INCONSISTENT_SYNC findbugs warning in AuthenticationTokenSecretManager (Yu Li)',
#  'f9e69b51e1 HBASE-15148 Resolve IS2_INCONSISTENT_SYNC findbugs warning in AuthenticationTokenSecretManager (Yu Li)',
#  '4fb7babad9 HBASE-15106 Procedure v2 - Procedure Queue pass Procedure for better debuggability',
#  '7d7a2d8712 HBASE-15106 Procedure v2 - Procedure Queue pass Procedure for better debuggability',
#  '713c6b5b1e HBASE-15106 Procedure v2 - Procedure Queue pass Procedure for better debuggability',
#  'b9450687ce  HBASE-15118 Fix findbugs complaint in hbase-server; ADDENDUM TO FIX TestImportTsv',
#  'c4bcaa3f65 HBASE-15118 Fix findbugs complaint in hbase-server',
#  'd6654ea7ea HBASE-15118 Fix findbugs complaint in hbase-server',
#  '9bf26f46d1 HBASE-15118 Fix findbugs complaint in hbase-server',
#  '5a280c9fd6 HBASE-15115 Fix findbugs complaints in hbase-client',
#  'd9fd87d5a8 HBASE-15115 Fix findbugs complaints in hbase-client',
#  '76bce77326 HBASE-15115 Fix findbugs complaints in hbase-client',
#  'cb17c7a97a HBASE-15117 Resolve ICAST findbugs warnings in current codes (Yu Li)',
#  'ab0651ed2b HBASE-15087 Fix hbase-common findbugs complaints',
#  '546adefcd6 HBASE-15087 Fix hbase-common findbugs complaints',
#  '83c506d9d4 HBASE-15087 Fix hbase-common findbugs complaints',
#  '894ce84b83 HBASE-15027 - Findbug fix (addendum)',
#  '0cfd893e12 HBASE-14355 Scan different TimeRange for each column family - fixing memstore bug',
#  '9a11c025f2 HBASE-14355 Scan different TimeRange for each column family - fixing memstore bug',
#  '0d72849581 HBASE-14355 Scan different TimeRange for each column family - fixing memstore bug',
#  'b3e40e4257 HBASE-14343 Fix debug message in SimpleRegionNormalizer for small regions (Lars Francke)',
#  '6f21cfbf27 HBASE-14343 Fix debug message in SimpleRegionNormalizer for small regions (Lars Francke)',
#  '6875e6d4d4 HBASE-14343 Fix debug message in SimpleRegionNormalizer for small regions (Lars Francke)',
#  'e41f6c934b HBASE-14547 Add more debug/trace to zk-procedure',
#  '86b505c224 HBASE-14547 Add more debug/trace to zk-procedure',
#  'dd955fa417 HBASE-14547 Add more debug/trace to zk-procedure',
#  '17829bbb54 HBASE-14100 Fix high priority findbugs warnings',
#  'ca57ef2cf2 HBASE-14100 Fix high priority findbugs warnings',
#  '12f6470bf3 HBASE-14100 Fix high priority findbugs warnings',
#  '257df19cc3 HBASE-14100 Fix high priority findbugs warnings',
#  '4936766d1a HBASE-13930 Exclude Findbugs packages from shaded jars',
#  '3af21f154b HBASE-13930 Exclude Findbugs packages from shaded jars',
#  '854d27350d HBASE-13930 Exclude Findbugs packages from shaded jars',
#  '7dbb2e6977 HBASE-13930 Exclude Findbugs packages from shaded jars',
#  '84a50393ee HBASE-13888 Fix refill bug from HBASE-13686 (Guanghao Zhang)',
#  'e8821d1806 HBASE-13888 Fix refill bug from HBASE-13686 (Guanghao Zhang)',
#  '49700460da HBASE-13888 Fix refill bug from HBASE-13686 (Guanghao Zhang)',
#  '9ee184b673 HBASE-13760 Cleanup Findbugs keySet iterator warnings. (Gabor Liptak)',
#  '7f2b33dbbf HBASE-13071 synchronous scanner -- cache size-in-bytes bug fix',
#  '3352585160 HBASE-13677 changed RecoverableZooKeeper logs about retries from info and warn to debug',
#  '00636cc998 HBASE-13677 changed RecoverableZooKeeper logs about retries from info and warn to debug',
#  'a1c94c0bdf HBASE-13677 changed RecoverableZooKeeper logs about retries from info and warn to debug',
#  '586a60606e HBASE-13132 Improve RemoveColumn action debug message',
#  '5688ab4fa2 HBASE-13528 A bug on selecting compaction pool (Shuaifeng Zhou)',
#  '5b8f70d368 HBASE-13528 A bug on selecting compaction pool (Shuaifeng Zhou)',
#  '93fce057a3 HBASE-13528 A bug on selecting compaction pool (Shuaifeng Zhou)',
#  '42ad845032 HBASE-13528 A bug on selecting compaction pool (Shuaifeng Zhou)',
#  'e1cb405adc HBASE-13528 A bug on selecting compaction pool (Shuaifeng Zhou)',
#  'ced0e324a1 HBASE-13262 Observe ScanResponse.moreResults in ClientScanner.',
#  '20189c258c HBASE-13262 Observe ScanResponse.moreResults in ClientScanner.',
#  'b0116398ff HBASE-13262 Observe ScanResponse.moreResults in ClientScanner.',
#  '1abf3aa0fd HBASE-13262 Observe ScanResponse.moreResults in ClientScanner.',
#  '69f6a2e7b4 HBASE-13334 FindBugs should create precise report for new bugs introduced (addendum)',
#  '948a6a63e8 HBASE-13334 FindBugs should create precise report for new bugs introduced',
#  '6e9ded51fb HBASE-13310 Fix high priority findbugs warnings',
#  '9c83fa7b52 HBASE-13167 The check for balancerCutoffTime is buggy (Mikhail Antonov)',
#  'd590f87ef4 HBASE-7126 Document how to report security bugs',
#  '5bd27af8b0 Fixed bug in publication script',
#  'd66f88134c HBASE-13132 Improve RemoveColumn action debug message',
#  '7dd6a203c7 HBASE-13132 Improve RemoveColumn action debug message',
#  '309e124a57 HBASE-13123 - Minor bug in ROW bloom filter (Ram)',
#  'c4acac561c HBASE-13138 Clean up TestMasterObserver (debug, trying to figure why fails)',
#  'b9f8616177 HBASE-13138 Clean up TestMasterObserver (debug, trying to figure why fails)',
#  'd2e64032c6 HBASE-13132 Improve RemoveColumn action debug message',
#  'b3ebca633a HBASE-13132 Improve RemoveColumn action debug message',
#  'bd8544f662 HBASE-13123 - Minor bug in ROW bloom filter (Ram)',
#  '9c3cbdcd05 HBASE-13123 - Minor bug in ROW bloom filter (Ram):w',
#  '4fb6f91cba HBASE-13123 - Minor bug in ROW bloom filter (Ram)',
#  '3216b8b6e3 HBASE-12985 Javadoc warning and findbugs fixes to get us green again',
#  'b3d8a8843c HBASE-12985 Javadoc warning and findbugs fixes to get us green again',
#  'eea9873cef HBASE-12985 Javadoc warning and findbugs fixes to get us green again',
#  'd0e4fb6ae3 HBASE-12548. Improve debuggability of IntegrationTestTimeBoundedRequestsWithRegionReplicas.',
#  '6314063e74 HBASE-12270 A bug in the bucket cache, with cache blocks on write enabled (Liu Shaohui)',
#  '4083306c3d HBASE-12711 Fix new findbugs warnings in hbase-thrift module (Srikanth)',
#  '9b25e850df Revert "HBASE-12270 A bug in the bucket cache, with cache blocks on write enabled (Liu Shaohui)" Reverting since this is failing often on 0.98 branch',
#  'bb7074b3d8 Revert "HBASE-12270 A bug in the bucket cache, with cache blocks on write enabled (Liu Shaohui) -- ADDENDUM" Revert for now since it is failing often on 0.98',
#  '0256cdd1b4 HBASE-12716 A bug in RegionSplitter.UniformSplit algorithm (Weichen Ye)',
#  '74f303ba24 HBASE-12716 A bug in RegionSplitter.UniformSplit algorithm (Weichen Ye)',
#  '99acd66a95 HBASE-12270 A bug in the bucket cache, with cache blocks on write enabled (Liu Shaohui) -- ADDENDUM',
#  '809de6ae1c HBASE-12270 A bug in the bucket cache, with cache blocks on write enabled (Liu Shaohui)',
#  'dd566e0347 HBASE-12270 A bug in the bucket cache, with cache blocks on write enabled (Liu Shaohui)',
#  '2ff16e532b HBASE-12270 A bug in the bucket cache, with cache blocks on write enabled (Liu Shaohui)',
#  '305267b8e2 HBASE-12270 A bug in the bucket cache, with cache blocks on write enabled (Liu Shaohui)',
#  '882f4c9761 HBASE-12716 A bug in RegionSplitter.UniformSplit algorithm (Weichen Ye)',
#  'fbdaf62bf8 HBASE-12716 A bug in RegionSplitter.UniformSplit algorithm (Weichen Ye)',
#  '3021c060bd HBASE-12711 Fix new findbugs warnings in hbase-thrift module (Srikanth)',
#  'd436559378 HBASE-12711 Fix new findbugs warnings in hbase-thrift module (Srikanth)',
#  'ca0c1774c9 HBASE-12548. Improve debuggability of IntegrationTestTimeBoundedRequestsWithRegionReplicas',
#  '5cc0714840 HBASE-12559 Addendum fixes findbugs warnings',
#  '0df5ed2ca6 HBASE-12550 Check all storefiles are referenced before splitting',
#  '860ddd2c22 HBASE-12550 Check all storefiles are referenced before splitting',
#  '339fd6bdca HBASE-12550 Check all storefiles are referenced before splitting',
#  '42cbdea76d HBASE-12541 Add misc debug logging to hanging tests in TestHCM and TestBaseLoadBalancer -- ADDENDUM; add waitForNoRegionInTransition from HTU in master branch',
#  'bfda57d4f2 HBASE-12541 Add misc debug logging to hanging tests in TestHCM and TestBaseLoadBalancer',
#  'c5690b1be3 HBASE-12541 Add misc debug logging to hanging tests in TestHCM and TestBaseLoadBalancer',
#  '5563105d16 HBASE-12472 Improve debuggability of IntegrationTestBulkLoad',
#  '390d4acf0d HBASE-12472 Improve debuggability of IntegrationTestBulkLoad',
#  '42c03460e4 HBASE-12472 Improve debuggability of IntegrationTestBulkLoad',
#  '9ea80f8f11 HBASE-12488 Small bug in publish_hbase_website.sh script',
#  'a28a90eefb HBASE-12198 Fix the bug of not updating location cache',
#  'c61f233dfd HBASE-12198 Fix the bug of not updating location cache',
#  '3c1fbd2ddf HBASE-12198 Fix the bug of not updating location cache',
#  'e5ecfb9440 HBASE-12104 Some optimization and bugfix for HTableMultiplexer (Yi Deng)',
#  '073ca6a516 HBASE-12104 Some optimization and bugfix for HTableMultiplexer (Yi Deng)',
#  'bc4f25ff45 HBASE-12104 Some optimization and bugfix for HTableMultiplexer (Yi Deng)',
#  "9f33edab0e HBASE-12145 Fix javadoc and findbugs so new folks aren't freaked when they see them",
#  "43301167db HBASE-12145 Fix javadoc and findbugs so new folks aren't freaked when they see them",
#  '3b8d80d5f9 HBASE-12086 Fix bug of HTableMultipliexer',
#  'a01f1f8ef9 HBASE-12086 Fix bug of HTableMultipliexer',
#  '78d532e5f3 HBASE-12086 Fix bug of HTableMultipliexer',
#  '74c7169252 HBASE-11662 shell should properly handle long form --debug.',
#  '6a7f923c0d HBASE-11662 shell should properly handle long form --debug.',
#  '41ecb18c20 HBASE-11662 shell should properly handle long form --debug.',
#  'aca2462ce3 HBASE-4744 enable test that log roll fails after split start.',
#  "d5640c1024 [master] add more information in exception thrown from Store's constructor",
#  '45883c6bd1 [HBASE-11258] Pull in Integration Tests from open source 0.96/trunk',
#  '8f76956cc6 [HBASE-9704] Fix TableServers.isNetworkException()',
#  '9f96d91b2e HBASE-11261 Addendum to remove an unneeded debug message',
#  '2a20143f72 HBASE-11514 Fix findbugs warnings in blockcache',
#  '96dcd67f56 HBASE-11514 Fix findbugs warnings in blockcache',
#  '8d62d85864 HBASE-11463 (findbugs) HE: Class defines equals() and uses Object.hashCode() (Mike Drob)',
#  '6da1a485fc HBASE-11463 (findbugs) HE: Class defines equals() and uses Object.hashCode()',
#  '8f6e04c446 Add some debug and echo around findbugs generations',
#  'a181dff8e0 HBASE-11413 [findbugs] RV: Negating the result of compareTo()/compare() (Mike Drob)',
#  '1b2a05c944 HBASE-11413 [findbugs] RV: Negating the result of compareTo()/compare() (Mike Drob)',
#  '9ff90931dc HBASE-11413 [findbugs] RV: Negating the result of compareTo()/compare() (Mike Drob)',
#  '4053868e72 HBASE-11203 Clean up javadoc and findbugs warnings in trunk',
#  'fdf2d11e86 [master] Fix RPC compression bug for titan',
#  '52591973cb [master] Let HLogPrettyPrinter output real timestamp value',
#  '0296547aa2 [HBASE-11021] HBaseFsck Fix for Table Hole Reporting',
#  'bbfbee0c76 [master] Fix the problem of scanning over stopRow',
#  '1ae68a2bbd [Master] Fix TestRegionChecker',
#  'd928cfe843 [HBASE-10709] Fix the bug of rejecting exception in HTableClientScanner when too many scanner running at the same time.',
#  'a8da435a58 [master] Fix bugs in MemStoreFlusher',
#  'c8ea643074 [HBASE-10901] Fix TestHRegionClose unstable bug',
#  '6a1b347964 [HBASE-10893] Fixing critical bug in FastDiffDeltaEncoder',
#  'd7582304d9 [master] Fix bug in TableServers.prefetchRegionCache that fails TestHTable',
#  '54175f554a [HBASE-10808] Forward porting Leases and Histogram bug fixes to trunk.',
#  '4487333e5e HBASE-10840 Fix findbug warn induced by HBASE-10569.(Anoop)',
#  "6d6327b477 HBASE-10656 high-scale-lib's Counter depends on Oracle (Sun) JRE, and also has some bug",
#  "a1a5f57bff HBASE-10656 high-scale-lib's Counter depends on Oracle (Sun) JRE, and also has some bug",
#  '1426ba05ac [HBASE-7099][89-fb] Debugging why compaction hook is not populating kvsConverted, but populates bytesSaved',
#  'a11781eae8 HBASE-10624 Fix 2 new findbugs warnings introduced by HBASE-10598',
#  '66f01155fe HBASE-10624 Fix 2 new findbugs warnings introduced by HBASE-10598',
#  'bc9834426a HBASE-10624 Fix 2 new findbugs warnings introduced by HBASE-10598',
#  'ce1e3b6c77 HBASE-10624 Fix 2 new findbugs warnings introduced by HBASE-10598',
#  '2e28ec44c8 [HBASE-10647] Fix the bug of not decrease from size in updateColumnValue when removing the old columns.',
#  '93d11d6efb [HBASE-10450] Fix the Thrift test cases',
#  '72cabe8b2b [HBASE-9896] Fix the end row bug in the TableInputFormatBase',
#  '59c2b2bb09 HBASE-10452 Fix potential bugs in exception handlers (Ding Yuan)',
#  'f1ad5cb938 HBASE-10452 Fix potential bugs in exception handlers (Ding Yuan)',
#  '75aaf88b1b [master] Let HRegion get correct flushable size from each Store',
#  'b3b3d0ddff HBASE-10446 Backup master gives Error 500 for debug dump',
#  '48e8a694dd [HBASE-10027] Adding an E2E test case.',
#  'b5d161c513 HBASE-10397 Fix findbugs introduced from HBASE-9426.',
#  'a8670eb5b7 [master] Add 2 extra options to debug replication issue',
#  'a1e54b2b00 HBASE-10239. Improve determinism and debugability of TestAccessController',
#  '5123e92213 HBASE-10239. Improve determinism and debugability of TestAccessController',
#  '54fedebeb9 HBASE-10116 Addendum: fix findbugs warning',
#  '529e41d727 HBASE-10116 Addendum: fix findbugs warning',
#  '2124f4054d HBASE-10116 Addendum: fix findbugs warning',
#  '8970eddf22 HBASE-10134 Fix findbug warning in VisibilityController',
#  'a28881da2d HBASE-10134 Fix findbug warning in VisibilityController',
#  '13e9eda3e7 HBASE-9856 Fix some findbugs Performance Warnings',
#  '22f54af029 HBASE-10011 Fix some findbugs in the client - addendum: set OK_FINDBUGS_WARNINGS=89',
#  '8c0078d175 HBASE-10023 Fix/Suppress all the 10 findbug warnings under hbase-common (Liang Xie)',
#  '100cfded38 HBASE-10011 Fix some findbugs in the client',
#  '35cea57fe5 HBASE-10011 Fix some findbugs in the client',
#  'eb48f4dc8e [HBASE-9972] Make HBase export metrics to JMX by default, instead of to NullContext',
#  'ecb4b1017c HBASE-9921 stripe compaction - findbugs and javadoc issues, some improvements',
#  '45a337446e HBASE-9920 Revert: total findbugs warning is higher than 87, leading to false-positive',
#  'bf2144fe60 HBASE-9003 Remove the jamon generated classes from the findbugs analysis',
#  '5478e5a82e [master] Fix bug in TimestampsFilter that returns deleted KeyValue under certain circumstance',
#  '24e4df74ea [0.89-fb] [ HBASE-7517] Add server name to PFFE Exceptions',
#  '0c9f543e1c HBASE-9238 bug in Mutation::getFamilyMap',
#  '7773da0cb4 HBASE-9232 Fix javadoc warning and a few findbugs items',
#  '58ee2bbf24 HBASE-9232 Fix javadoc warning and a few findbugs items',
#  '2c80ed63b0 HBASE-9158 Serious bug in cyclic replication',
#  '852bb0c21f [master]exclude classes in jacoco and findbugs reports',
#  'e7657c930b HBASE-9158 Serious bug in cyclic replication',
#  'bd3acd05d4 HBASE-9158 Serious bug in cyclic replication',
#  '3bc9e2c95c HBASE-9158 Serious bug in cyclic replication',
#  '54aab0e3c0 [HBASE-8307] Fix a bug in Histogram class.',
#  'cea837fa8f HBASE-9085 Integration Tests fails because of bug in teardown phase where the cluster state is not being restored properly. (gautam)',
#  'ee48ceb820 HBASE-9085 Integration Tests fails because of bug in teardown phase where the cluster state is not being restored properly. (gautam)',
#  '08235fca23 HBASE-9085 Integration Tests fails because of bug in teardown phase where the cluster state is not being restored properly. (gautam)',
#  'dc71a9b104 [master]Make findbugs happy',
#  '415e06f7a1 [HBASE-8467] Logging Failed nodes list to a new file every time, plus a small bug fix',
#  'd390841912 HBASE-8919  TestReplicationQueueFailover (and Compressed) can fail because the recovered queue             gets stuck on ClosedByInterruptException (first try, getting more debug)',
#  '299b39532b HBASE-8919  TestReplicationQueueFailover (and Compressed) can fail because the recovered queue             gets stuck on ClosedByInterruptException (first try, getting more debug)',
#  '9ccf16db51 HBASE-8798 Fix a minor bug in shell command with clone_snapshot table error',
#  '98060a04ac [HBASE-8500] Fixes Minor bug in RollingRestart',
#  '8cbe3e2e2b [0.89-fb] [master] Allow regionServerReport to run with shorter RPC timeouts.',
#  '68b1e5c512 [HBASE-8500] Adds a RollingRestart utility for a region server',
#  'c44bf173e4 [0.89-fb] [master] handle rootRegion close correctly',
#  '7a3ad000ee [HBASE-5263] Change the logging to trace in HFileWriterV2 for cacheCurrentBlockForCompaction',
#  '77df789608 HBASE-7817: Suggested JDWP debug options in hbase-env.sh are wrong (Vasu Mariyala)',
#  'ff3ae92d1f HBASE-7817: Suggested JDWP debug options in hbase-env.sh are wrong (Vasu Mariyala)',
#  '5ca140fe2f HBASE-7817: Suggested JDWP debug options in hbase-env.sh are wrong (Vasu Mariyala)',
#  '24736e83bb HBASE-8062 Replace HBaseFsck.debugLsr() in TestFlushSnapshotFromClient with FSUtils.logFileSystemState()',
#  '7181fa35a3 HBASE-8062 Replace HBaseFsck.debugLsr() in TestFlushSnapshotFromClient with FSUtils.logFileSystemState()',
#  '448f2f7902 HBASE-8067 TestHFileArchiving.testArchiveOnTableDelete sometimes fails',
#  '986c9fbed6 HBASE-8067 TestHFileArchiving.testArchiveOnTableDelete sometimes fails -- more debug',
#  'a79a77aa02 HBASE-8225 [replication] minor code bug when registering ReplicationLogCleaner (Jerry He)',
#  'a96672bec6 HBASE-8225 [replication] minor code bug when registering ReplicationLogCleaner (Jerry He)',
#  '0bc9187d46 HBASE-8225 [replication] minor code bug when registering ReplicationLogCleaner (Jerry He)',
#  '635949147f [0.89-fb] [HBASE-8216] Enable the serverManager to respect the config change for Power failures',
#  '3b4b9b3c7a HBASE-7878 add debug log for recoverLease timeout',
#  '152ec1cc7f HBASE-7587. Fix two findbugs warnings in RowResource (Jean-Marc Spaggiari)',
#  '69cbc81e5c [0.89-fb] [HBASE-7517] Improve the PFFE mechanism such that (i) Ensure that if a thread gets the AtomicBoolean for a single server, it will not be stopped to get the AtomicBoolean for a different server. (ii) PFFE is only thrown for threads that are not a',
#  '008aa92991 HBASE-8101 Cleanup: findbugs and javadoc warning fixes as well as making it illegal passing null row to Put/Delete, etc.',
#  '466902ffde HBASE-8101 Cleanup: findbugs and javadoc warning fixes as well as making it illegal passing null row to Put/Delete, etc.',
#  '90eaac74d5 HBASE-8067 TestHFileArchiving.testArchiveOnTableDelete sometimes fails -- more debug',
#  '95e4f53090 HBASE-8067 TestHFileArchiving.testArchiveOnTableDelete sometimes fails -- more debug',
#  'ca1a0ea654 HBASE-7966 ACL tests fail on trunk (flaky) -- Some debug log',
#  '27dd86e0a0 HBASE-7966 ACL tests fail on trunk (flaky) -- Some debug log',
#  '539ff195e8 HBASE-7878 add debug log for recoverLease timeout',
#  '1e414a4413 HBASE-7547 Fix findbugs warnings in snapshot classes (Ted Yu)',
#  'c9b3e9b2da HBASE-7354 Snapshot Info/Debug Tool (Matteo Bertozzi)',
#  '1d330c9478 HBASE-7699 Replace LOG.info() with LOG.debug() in FSUtils.listStatus()',
#  'a3f0aea354 HBASE-7682 Replace HRegion custom File-System debug, with FSUtils.logFileSystemState()',
#  'b33f042ea2 [HBASE-7276] bug in TestRegionServerMetrics.testNumReadsAndWrites',
#  'f60b8246e7 HBASE-7588 Fix two findbugs warning in MemStoreFlusher; REAPPLIED',
#  'c3e140cd14 HBASE-7588 Fix two findbugs warning in MemStoreFlusher; REVERTED',
#  '3b345cd684 HBASE-7588 Fix two findbugs warning in MemStoreFlusher',
#  'b96d60d659 HBASE-7601 Fix 8 remaining EQ findbug warnings from hbase-server.',
#  'f39aac876d [HBASE-6967][89-fb] Bugfix for dynamic loading in Store',
#  '28b79e1214 HBASE-7595 Fix one findbug warning in ReplicationSourceManager',
#  '05934d7405 HBASE-7587. Fix two findbugs warnings in RowResource (Jean-Marc Spaggiari)',
#  'bda467aeca HBASE-7587. Fix two findbugs warnings in RowResource (Jean-Marc Spaggiari)',
#  '5c8c3d0a8c HBASE-7586 Fix two findbugs warnings to get our count down to the tolerated number again',
#  '6b97306c1e HBASE-7512 Document the findbugs library annotation',
#  '4e0af48fe4 HBASE-7508 Fix simple findbugs',
#  'c739366d73 [HBASE-7491] testBatchedUpload test cases more deterministic',
#  '4409ba741c HBASE-7443 More findbugs fixes - addendum - fix compilation error',
#  '92c98a76d1 HBASE-7443 More findbugs fixes',
#  '9fac4877d3 HBASE-5598 Analyse and fix the findbugs reporting by QA and add invalid bugs into findbugs-excludeFilter file',
#  '289ab6b87c [HBASE-7275] Fix two bugs in HBase based on findBugs report',
#  'ca9d748276 [HBASE-7193] Print the detail exceptions info from the RetriesExhaustedException',
#  'a1ebb191e7 [0.89-fb] [master] Fix a race condition that might cause unassigned regions.',
#  "094e8d4420 HBASE-3925 Make Shell's -d and debug cmd behave the same",
# ...
#  '2bbcc5a122 HADOOP-1528 HClient for multiple tables (phase 1)',
#  '07657c40e9 HADOOP-1528 HClient for multiple tables (phase 1)',
#  '5f850fcee4 HADOOP-1516 HClient fails to readjust when ROOT or META redeployed on new region server',
#  '1baaf3f03a HADOOP-1516 HClient fails to readjust when ROOT or META redeployed on new region server',
#  "8c14bab2c4 HADOOP-1581 HBASE: Un-openable tablename bug Change format of region names from TABLENAME_STARTROW_ENDROW-RANDOMID to TABLENAME,STARTROW,ENDROW-RANDOMID. Makes it so lone table name will sort before any region of said table. M src/contrib/hbase/src/test/hbase-site.xml   (hbase.client.retries.number): Removed. Wasdefault value for this property.   (hbase.master.meta.thread.rescanfrequency, hbase.server.thread.wakefrequency,    hbase.regionserver.handler.count): Add values that are less than   default so unit tests are even more responsive (and finished quicker). M src/contrib/hbase/src/test/org/apache/hadoop/hbase/TestToString.java   Change test so it expects region info name that has ',' delimiters   rather than '_' delimiters. M src/contrib/hbase/src/test/org/apache/hadoop/hbase/TestTable.java   Rename testTable as testCreateTable.   (testTableNameClash): Test for this issue. M src/contrib/hbase/src/java/org/apache/hadoop/hbase/HRegionInfo.java   Change format of region names so delimiter is ',' rather than '_'.",
#  "c9fb78e342 HADOOP-1581 HBASE: Un-openable tablename bug Change format of region names from TABLENAME_STARTROW_ENDROW-RANDOMID to TABLENAME,STARTROW,ENDROW-RANDOMID. Makes it so lone table name will sort before any region of said table. M src/contrib/hbase/src/test/hbase-site.xml   (hbase.client.retries.number): Removed. Wasdefault value for this property.   (hbase.master.meta.thread.rescanfrequency, hbase.server.thread.wakefrequency,    hbase.regionserver.handler.count): Add values that are less than   default so unit tests are even more responsive (and finished quicker). M src/contrib/hbase/src/test/org/apache/hadoop/hbase/TestToString.java   Change test so it expects region info name that has ',' delimiters   rather than '_' delimiters. M src/contrib/hbase/src/test/org/apache/hadoop/hbase/TestTable.java   Rename testTable as testCreateTable.   (testTableNameClash): Test for this issue. M src/contrib/hbase/src/java/org/apache/hadoop/hbase/HRegionInfo.java   Change format of region names so delimiter is ',' rather than '_'.",
#  "14dd64dace HADOOP-1574 Concurrent creates of a table named 'X' all succeed M src/contrib/hbase/src/test/org/apache/hadoop/hbase/TestTable.java     (testTable): Add checking of actual exceptions thrown and     assertions that we are getting right behavior.  Add a test     that has ten clients concurrently trying to create same table. M src/contrib/hbase/src/java/org/apache/hadoop/hbase/HClient.java     javadoc edit. Fix debug message that could give impression     table was found when it wasn't. M src/contrib/hbase/src/java/org/apache/hadoop/hbase/HTableDescriptor.java     Added comment on table nameing. M src/contrib/hbase/src/java/org/apache/hadoop/hbase/HMaster.java     (createTable): Refactored. Bulk moved to a private override.     Changed how check for existance is done. M rc/contrib/hbase/src/java/org/apache/hadoop/hbase/HRegionInfo.java     (getTableNameFromRegionName): Utility method added. A src/contrib/hbase/src/java/org/apache/hadoop/hbase/TableExistsException.java     Added.",
#  "406ddd051f HADOOP-1574 Concurrent creates of a table named 'X' all succeed M src/contrib/hbase/src/test/org/apache/hadoop/hbase/TestTable.java     (testTable): Add checking of actual exceptions thrown and     assertions that we are getting right behavior.  Add a test     that has ten clients concurrently trying to create same table. M src/contrib/hbase/src/java/org/apache/hadoop/hbase/HClient.java     javadoc edit. Fix debug message that could give impression     table was found when it wasn't. M src/contrib/hbase/src/java/org/apache/hadoop/hbase/HTableDescriptor.java     Added comment on table nameing. M src/contrib/hbase/src/java/org/apache/hadoop/hbase/HMaster.java     (createTable): Refactored. Bulk moved to a private override.     Changed how check for existance is done. M rc/contrib/hbase/src/java/org/apache/hadoop/hbase/HRegionInfo.java     (getTableNameFromRegionName): Utility method added. A src/contrib/hbase/src/java/org/apache/hadoop/hbase/TableExistsException.java     Added.",
#  '19099c98b1 HADOOP-1420, HADOOP-1423. Findbugs changes, remove reference to removed class HLocking that broke main build.',
#  'c9c9841aac HADOOP-1420, HADOOP-1423. Findbugs changes, remove reference to removed class HLocking that broke main build.',
#  'e4bfce1367 Revert "HBASE-19504 Add TimeRange support into checkAndMutate; ADDENDUM to fix failing unit test" Revert in favor of HBASE-20272',
#  'a6debe4845 Revert "HBASE-19504 Add TimeRange support into checkAndMutate; ADDENDUM to fix failing unit test" Reverting an addendum in favor of patch at HBASE-20272.',
#  'f06bcc7df1 HBASE-19504 Add TimeRange support into checkAndMutate; ADDENDUM to fix failing unit test',
#  '5da92ce352 HBASE-19504 Add TimeRange support into checkAndMutate; ADDENDUM to fix failing unit test',
#  'f346a144b9 HBASE-20116 addendum fix javadoc and also a simple optimization',
#  '51a35aafcd [HBASE-20141] Fix TooManyFiles exception when RefreshingChannels',
#  '009295a3a6 [HBASE-20141] Fix TooManyFiles exception when RefreshingChannels',
#  '10a7b5ea15 [HBASE-20141] Fix TooManyFiles exception when RefreshingChannels',
#  '6bf967adfb [HBASE-20141] Fix TooManyFiles exception when RefreshingChannels',
#  'aaa90d8069 [HBASE-20141] Fix TooManyFiles exception when RefreshingChannels',
#  'd0e55429b3 HBASE-20178 [AMv2] Throw exception if hostile environment',
#  'abdc7b25d4 HBASE-20178 [AMv2] Throw exception if hostile environment',
#  '63ce0c0733 HBASE-20178 [AMv2] Throw exception if hostile environment',
#  'b16e03c130 HBASE-17165 Make use of retry setting in LoadIncrementalHFiles & fix test',
#  '527ca10e98 HBASE-17165 Make use of retry setting in LoadIncrementalHFiles & fix test',
#  'a9d9fa35a2 HBASE-17165 Make use of retry setting in LoadIncrementalHFiles & fix test',
#  '72c3d27bf6 HBASE-20173 [AMv2] DisableTableProcedure concurrent to ServerCrashProcedure can deadlock',
#  '655592fc93 HBASE-20173 [AMv2] DisableTableProcedure concurrent to ServerCrashProcedure can deadlock',
#  '260ee0da60 HBASE-20173 [AMv2] DisableTableProcedure concurrent to ServerCrashProcedure can deadlock',
#  '756cccecff HBASE-19598 Addendum fix typo',
#  '016cf0c64b HBASE-19598 Fix TestAssignmentManagerMetrics flaky test',
#  "0d58092c06 HBASE-20106 [api compliance chacker] Fix Bug Where Branch Isn't Found",
#  "ecc4c87ef3 HBASE-20106 [api compliance chacker] Fix Bug Where Branch Isn't Found",
#  "1181dab14d HBASE-20106 [api compliance chacker] Fix Bug Where Branch Isn't Found",
#  "0cd89ed653 HBASE-20106 [api compliance chacker] Fix Bug Where Branch Isn't Found",
#  "2f3632a2a4 HBASE-20106 [api compliance chacker] Fix Bug Where Branch Isn't Found",
#  "96ebab748f HBASE-20106 [api compliance chacker] Fix Bug Where Branch Isn't Found",
#  '5317ca92bc HBASE-20069 fix existing findbugs errors in hbase-server; ADDENDUM Address review Revert of the revert, i.e. reapply. Thought this had broken the build but it was a bad nightly. Putting it back.',
#  '07eae00ec1 Revert "HBASE-20069 fix existing findbugs errors in hbase-server; ADDENDUM Address review"',
#  'd272ac908c HBASE-20069 fix existing findbugs errors in hbase-server; ADDENDUM Address review',
#  '43d661b008 HBASE-20069 fix existing findbugs errors in hbase-server; ADDENDUM Address review',
#  'b11e506664 HBASE-20069 fix existing findbugs errors in hbase-server',
#  '44544c7db0 HBASE-20069 fix existing findbugs errors in hbase-server',
#  '569f16ea2c HBASE-19391 Calling HRegion#initializeRegionInternals from a region replica can still re-create a region directory; ADDEDNDUM to fix TestRegionOpen failure',
#  '3434e99e6c HBASE-20044 TestClientClusterStatus is flakey" Revert "Revert "HBASE-2004 TestClientClusterStatus is flakey"" This is a revert of a revert, i.e. a reapplication, just so I can fix the JIRA number.',
#  '3d2e9e2125 Revert "HBASE-2004 TestClientClusterStatus is flakey" Revert to fix JIRA number; should be 20044.',
#  '1db1474591 HBASE-20044 TestClientClusterStatus is flakey" Revert "Revert "HBASE-2004 TestClientClusterStatus is flakey"" This is a revert of a revert, i.e. a reapplication, just so I can fix the JIRA number.',
#  '6796b8e21f Revert "HBASE-2004 TestClientClusterStatus is flakey" Revert to fix JIRA number; should be 20044.',
#  'cadc2efd12 HBASE-19391 Calling HRegion#initializeRegionInternals from a region replica can still re-create a region directory; ADDEDNDUM to fix TestRegionOpen failure',
#  '11af33af2a HBASE-19391 Calling HRegion#initializeRegionInternals from a region replica can still re-create a region directory; ADDEDNDUM to fix TestRegionOpen failure',
#  '38a97b87e6 HBASE-19391 Calling HRegion#initializeRegionInternals from a region replica can still re-create a region directory; ADDEDNDUM to fix TestRegionOpen failure',
#  "8d26736bc2 HBASE-19116 Currently the tail of hfiles with CellComparator* classname makes it so hbase1 can't open hbase2 written hfiles; fix",
#  "8a3b4cdc67 HBASE-19116 Currently the tail of hfiles with CellComparator* classname makes it so hbase1 can't open hbase2 written hfiles; fix",
#  '1ae64ccee0 HBASE-19972 Should rethrow the RetriesExhaustedWithDetailsException when failed to apply the batch in ReplicationSink; ADDENDUM to fix TestReplicationSink',
#  '00f8877323 HBASE-19972 Should rethrow the RetriesExhaustedWithDetailsException when failed to apply the batch in ReplicationSink; ADDENDUM to fix TestReplicationSink',
#  '67b69fb2c7 HBASE-16060 1.x clients cannot access table state talking to 2.0 cluster',
#  'c7473df2c3 HBASE-16060 1.x clients cannot access table state talking to 2.0 cluster',
#  '6519b98ac3 Revert "HBASE-19919 Tidying up logging"',
#  '2e2e7845ab HBASE-19840 Flakey TestMetaWithReplicas; ADDENDUM to fix Checksyte',
#  '0b9a0dc951 HBASE-19840 Flakey TestMetaWithReplicas; ADDENDUM to fix Checksyte',
#  '7cbb70945a HBASE-19840 Flakey TestMetaWithReplicas; ADDENDUM to fix Checksyte',
#  'f8295a810d HBASE-19862 addendum: Checkstyle fixes, remove unused imports and variables. Add @Rule for timeout.',
#  '1beb687f4e HBASE-19862 addendum: Checkstyle fixes, remove unused imports and variables. Add @Rule for timeout.',
#  '4ddfecac56 HBASE-19787 Fix or disable tests broken in branch-2 so can cut beta-1',
#  '026f535a77 HBASE-19787 Fix or disable tests broken in branch-2 so can cut beta-1',
#  'd0aff98a67 HBASE-19694 The initialization order for a fresh cluster is incorrect',
#  '1a11fc92b1 HBASE-19694 The initialization order for a fresh cluster is incorrect',
#  'a7f9668c33 HBASE-19753 Miscellany of fixes for hbase-zookeeper tests to make them more robust',
#  'a917a4e796 HBASE-19753 Miscellany of fixes for hbase-zookeeper tests to make them more robust',
#  '8118d5de4e HBASE-19734 Fix IntegrationTestReplication and related impl changes',
#  'efa911f56f HBASE-19734 Fix IntegrationTestReplication and related impl changes',
#  'b31b386f7f HBASE-19483 Add proper privilege check for rsgroup commands addendum fixes unit test',
#  'f0d0501d55 HBASE-19483 Add proper privilege check for rsgroup commands addendum fixes unit test',
#  'ce80e8e38f HBASE-19651 Remove LimitInputStream; AMENDMENT: fix compile',
#  'e7da907c3c Revert "HBASE-19651 Remove LimitInputStream"',
#  '76580fa991 HBASE-19675 Miscellaneous HStore Class Improvements.',
#  'a47afc84cd HBASE-19675 Miscellaneous HStore Class Improvements.',
#  'b3f353cd3c HBASE-19552 ADDENDUM fix shaded lib check',
#  'd4aeba89f4 HBASE-19552 ADDENDUM fix shaded lib check',
#  'c89cfd3406 HBASE--17248 fix javadoc in SimpleRegionNormalizer',
#  '37bf54a516 HBASE--17248 fix javadoc in SimpleRegionNormalizer',
#  'a82f89bd3c HBASE-10092 Addendum fix TestAssignProcedure and TestWALEntrySinkFilter',
#  '00b0288c96 HBASE-10092 Addendum fix TestAssignProcedure and TestWALEntrySinkFilter',
#  'c811d7f965 HBASE-19542 fix TestSafemodeBringsDownMaster',
#  '0a5ef1ed88 HBASE-19542 fix TestSafemodeBringsDownMaster',
#  'db5bfedd2d HBASE-18970 fix hbase shell reading interactive input (Amit Virmani)',
#  'e67a67d444 HBASE-18970 fix hbase shell reading interactive input (Amit Virmani)',
#  '6a3af2e52b HBASE-18430 fixed typo',
#  '5cf0e62a55 HBASE-18404 fixed typo in acid semantics',
#  'd53430b5f7 HBASE-18335 configuration guide fixes',
#  '3c1d4a5d47 HBASE-18311 fix formatting in quickstart',
#  '721b9576d8 HBASE-17839 fixed missing column in table 1 from section "Data Model" of the ref guide.',
#  '9acfb8ae67  HBASE-19122 Suspect methods on Cell to be deprecated; ADDENDUM2 to fix     more compile error',
#  'e343b0c3e3  HBASE-19122 Suspect methods on Cell to be deprecated; ADDENDUM2 to fix     more compile error',
#  'b7268cafac HBASE-19122 Suspect methods on Cell to be deprecated; ADDENDUM to fix compile error',
#  '6a9b1480c1 HBASE-19122 Suspect methods on Cell to be deprecated; ADDENDUM to fix compile error',
#  '988ea870ed HBASE-18309 (addendum) fix NPE in LogCleaner',
#  '1ca2d10299 HBASE-18309 (addendum) fix NPE in LogCleaner',
#  '672c440b9f HBASE-18946 Stochastic load balancer assigns replica regions to the same RS',
#  '010012cbcb HBASE-18946 Stochastic load balancer assigns replica regions to the same RS',
#  'cb4bbea0f1 HBASE-19287 Revert "Revert "master hangs forever if RecoverMeta send assign meta region request to target server fail""',
#  'd1fb987265 HBASE-19287 Revert "Revert "master hangs forever if RecoverMeta send assign meta region request to target server fail""',
#  'fb6625fdd9 HBASE-19508 ReadOnlyConfiguration throws exception if any Configuration in current context calls addDefautlResource; ADDENDUM -- fix license',
#  'd28e126b29 HBASE-19508 ReadOnlyConfiguration throws exception if any Configuration in current context calls addDefautlResource; ADDENDUM -- fix license',
#  'b2f9b7bc19 HBASE-19023 Replace hbase-server with hbase-mapreduce for HBase and MapReduce chapter',
#  'eabad8a91c HBASE-19023 Replace hbase-server with hbase-mapreduce for HBase and MapReduce chapter',
#  'b9f1f5a17c HBASE-18112 (addendum) fix the out-of-bounds index',
#  'ebd8841e0e HBASE-18112 (addendum) fix the out-of-bounds index',
#  "2f7a6f21eb HBASE-18233 We shouldn't wait for readlock in doMiniBatchMutation in case of deadlock (Allan Yang)",
#  "6c490625aa HBASE-18233 We shouldn't wait for readlock in doMiniBatchMutation in case of deadlock (Allan Yang)",
#  "9f102b293f HBASE-18233 We shouldn't wait for readlock in doMiniBatchMutation in case of deadlock (Allan Yang)",
#  "e1d6950381 HBASE-18233 We shouldn't wait for readlock in doMiniBatchMutation in case of deadlock (Allan Yang)",
#  '8b6f305ac7 HBASE-19342 fix TestTableBasedReplicationSourceManagerImpl#testRemovePeerMetricsCleanup',
#  'b75510284f HBASE-19342 fix TestTableBasedReplicationSourceManagerImpl#testRemovePeerMetricsCleanup',
#  '7c1c370f2f HBASE-18601 Update Htrace to 4.2 (addendum)',
#  '95e4f059a3 HBASE-18601 Update Htrace to 4.2 (addendum)',
#  '24feb1ab75 HBASE-19239 Fix findbugs and error-prone issues',
#  'ca186f9349 HBASE-19239 Fix findbugs and error-prone issues',
#  'e063b231da HBASE-18357 Enable disabled tests in TestHCM that were disabled by Proc-V2 AM in HBASE-14614',
#  '3a4655019d HBASE-18357 Enable disabled tests in TestHCM that were disabled by Proc-V2 AM in HBASE-14614',
#  "72ba5c294e HBASE-19246 Trivial fix in findHangingTests.py to make it not stop on finding 'bad string'.",
#  "41f6bf6b89 HBASE-19246 Trivial fix in findHangingTests.py to make it not stop on finding 'bad string'.",
#  '110f2db756 HBASE-19195 error-prone fixes for client, mr, and server',
#  '027ef60a75 HBASE-19195 error-prone fixes for client, mr, and server',
#  ...]

# %%
#separating the commit id and the log messages
commit = []
for xx in range(0,len(com_logs)):
    tmp = []
    comm = com_logs[xx].split()
    word = ' '.join(comm[1:])
    tmp.extend([comm[0],word])
    commit.append(tmp)

for item in commit:
    print (item)
# Out:
# ['acbdb86bb4', 'HBASE-20169 NPE when calling HBTU.shutdownMiniCluster']
# ['0b44b13609', 'HBASE-20169 NPE when calling HBTU.shutdownMiniCluster']
# ['fabb1d97cc', 'HBASE-20169 NPE when calling HBTU.shutdownMiniCluster']
# ['d0e55429b3', 'HBASE-20178 [AMv2] Throw exception if hostile environment']
# ['abdc7b25d4', 'HBASE-20178 [AMv2] Throw exception if hostile environment']
# ['63ce0c0733', 'HBASE-20178 [AMv2] Throw exception if hostile environment']
# ['81bf068b2f', 'HBASE-20078 MultiByteBuff : bug in reading primitives when individual buffers are too small.']
# ['7bd39250e7', 'HBASE-20078 MultiByteBuff : bug in reading primitives when individual buffers are too small.']
# ['e83ac38d68', 'HBASE-20078 MultiByteBuff : bug in reading primitives when individual buffers are too small.']
# ['d4e0fc74d4', 'HBASE-20082 Fix findbugs errors only on master which are introduced by HBASE-19397']
# ['39c8acfed6', 'HBASE-15151 ensure findbugs check runs in nightly tests on all branches.']
# ['27642614b4', 'HBASE-15151 ensure findbugs check runs in nightly tests on all branches.']
# ['c9bcc0b9b1', 'HBASE-20082 Fix findbugs errors only on master which are introduced by HBASE-19397']
# ['f89a1f7d7a', 'HBASE-20121 Fix findbugs warning for RestoreTablesClient']
# ['5f238440ac', 'HBASE-15151 ensure findbugs check runs in nightly tests on all branches.']
# ['a9bbaca7c9', 'HBASE-15151 ensure findbugs check runs in nightly tests on all branches.']
# ['915a6865c0', 'HBASE-15151 ensure findbugs check runs in nightly tests on all branches.']
# ['01746c72ab', 'HBASE-15151 ensure findbugs check runs in nightly tests on all branches.']
# ['383b7cc592', 'HBASE-15151 ensure findbugs check runs in nightly tests on all branches.']
# ['5b64de45ed', 'HBASE-20110 Findbugs in zk and mr caused nightly #409 branch-2 to fail']
# ['03f9cb89a6', 'HBASE-20110 Findbugs in zk and mr caused nightly #409 branch-2 to fail']
# ['5317ca92bc', 'HBASE-20069 fix existing findbugs errors in hbase-server; ADDENDUM Address review Revert of the revert, i.e. reapply. Thought this had broken the build but it was a bad nightly. Putting it back.']
# ['07eae00ec1', 'Revert "HBASE-20069 fix existing findbugs errors in hbase-server; ADDENDUM Address review"']
# ['d272ac908c', 'HBASE-20069 fix existing findbugs errors in hbase-server; ADDENDUM Address review']
# ['43d661b008', 'HBASE-20069 fix existing findbugs errors in hbase-server; ADDENDUM Address review']
# ['b11e506664', 'HBASE-20069 fix existing findbugs errors in hbase-server']
# ['44544c7db0', 'HBASE-20069 fix existing findbugs errors in hbase-server']
# ['ef02762dd8', 'HBASE-20083 Fix findbugs error for ReplicationSyncUp']
# ['2beda62a10', 'HBASE-20083 Fix findbugs error for ReplicationSyncUp']
# ['8c74d177f6', 'HBASE-20082 Fix findbugs errors only on master which are introduced by HBASE-19397']
# ['af804a586b', 'HBASE-19930: Fixing the bug, in the rare case when there is a merge into CCM and the one of the old segments has a big cell allocated on-heap and it needs to be copied to the MSLAB']
# ['07e93458fe', 'HBASE-19930: Fixing the bug, in the rare case when there is a merge into CCM and the one of the old segments has a big cell allocated on-heap and it needs to be copied to the MSLAB']
# ['89baad5bbe', 'HBASE-19940 TestMetaShutdownHandler flakey; ADDENDUM: yet more debug']
# ['001f9cc5ea', 'HBASE-19940 TestMetaShutdownHandler flakey; ADDENDUM: yet more debug']
# ['590bee78dc', 'HBASE-19940 TestMetaShutdownHandler flakey; ADDENDUM: more debug']
# ['ca6b37d63c', 'HBASE-19940 TestMetaShutdownHandler flakey; ADDENDUM: more debug']
# ['9f2149f171', 'HBASE-19840 Flakey TestMetaWithReplicas; ADDENDUM Adding debug']
# ['a1600c1490', 'HBASE-19840 Flakey TestMetaWithReplicas; ADDENDUM Adding debug']
# ['c245bd5c03', 'HBASE-19837 Flakey TestRegionLoad; ADDENDUM Report more often and wait less time on change (also add some debug on TestMetaShutdown test)']
# ['29016bc100', 'HBASE-19837 Flakey TestRegionLoad; ADDENDUM Report more often and wait less time on change (also add some debug on TestMetaShutdown test)']
# ['30a7e4a35c', 'HBASE-19554 reenable TestDLSAsyncFSWAL/TestDLSFSHLog for debugging']
# ['88d6e06a1f', 'HBASE-19554 reenable TestDLSAsyncFSWAL/TestDLSFSHLog for debugging']
# ['811afad103', 'HBASE-19915 Create merged/ daughter region/s with initial state CLOSED from MetaTableAccessor#splitRegion()/ mergeRegions()']
# ['fdbc843516', 'HBASE-19915 Create merged/ daughter region/s with initial state CLOSED from MetaTableAccessor#splitRegion()/ mergeRegions()']
# ['34c6c99041', 'HBASE-19811 Fix findbugs and error-prone warnings in hbase-server (branch-2) - addendum']
# ['27d73dec8a', 'HBASE-19811 Fix findbugs and error-prone warnings in hbase-server (branch-2) - addendum']
# ['72f4e98ed1', 'HBASE-19846 Fix findbugs and error-prone warnings in hbase-rest (branch-2)']
# ['aeffca497b', 'HBASE-19846 Fix findbugs and error-prone warnings in hbase-rest (branch-2)']
# ['130da9d18b', 'HBASE-19860 Run branch-2 nightly job more frequently to help with flaky tests debugging']
# ['f5779855c6', 'HBASE-19845 Fix findbugs and error-prone warnings in hbase-rsgroup (branch-2)']
# ['b20b45e4e8', 'HBASE-19845 Fix findbugs and error-prone warnings in hbase-rsgroup']
# ['d589b72382', 'HBASE-19847 Fix findbugs and error-prone warnings in hbase-thrift (branch-2)']
# ['8977aae430', 'HBASE-19847 Fix findbugs and error-prone warnings in hbase-thrift (branch-2)']
# ['93a182f286', 'HBASE-19811 Fix findbugs and error-prone warnings in hbase-server (branch-2)']
# ['b1269ec57f', 'HBASE-19811 Fix findbugs and error-prone warnings in hbase-server (branch-2)']
# ['d49357f265', 'HBASE-19840 Flakey TestMetaWithReplicas']
# ['1e5fc1ed63', 'HBASE-19840 Flakey TestMetaWithReplicas']
# ['c60359959c', 'HBASE-19837 Flakey TestRegionLoad']
# ['d4ffee2023', 'HBASE-19837 Flakey TestRegionLoad']
# ['b44be75bd1', 'HBASE-19837 Flakey TestRegionLoad']
# ['f3c563fc00', 'HBASE-19837 Flakey TestRegionLoad']
# ['13547d53eb', 'HBASE-19815 Flakey TestAssignmentManager.testAssignWithRandExec (Part Two).']
# ['581fabe7b2', 'HBASE-19815 Flakey TestAssignmentManager.testAssignWithRandExec (Part Two).']
# ['4676d4bf4a', 'HBASE-19810 Fix findbugs and error-prone warnings in hbase-metrics (branch-2)']
# ['c1a8dc09d6', 'HBASE-19810 Fix findbugs and error-prone warnings in hbase-metrics (branch-2)']
# ['0561312bc4', 'HBASE-19809 Fix findbugs and error-prone warnings in hbase-procedure (branch-2)']
# ['c269e63a07', 'HBASE-19809 Fix findbugs and error-prone warnings in hbase-procedure (branch-2)']
# ['4ddfecac56', 'HBASE-19787 Fix or disable tests broken in branch-2 so can cut beta-1']
# ['026f535a77', 'HBASE-19787 Fix or disable tests broken in branch-2 so can cut beta-1']
# ['c799b0e69b', 'HBASE-19694 The initialization order for a fresh cluster is incorrect Addendum. Adds in a missing line that helps debugging.']
# ['d8271b0361', 'HBASE-19694 The initialization order for a fresh cluster is incorrect Addendum. Adds in a missing line that helps debugging.']
# ['97dc7d87cd', 'HBASE-19654 Remove misleading and chatty debug message in ReplicationLogCleaner']
# ['d8ef30c5e1', 'HBASE-19654 Remove misleading and chatty debug message in ReplicationLogCleaner']
# ['bcacdeb212', 'HBASE-19491 Improvements to Nighly runs: Fixes findbugs tests, Exclude flaky tests from master.']
# ['605d92e3c1', 'HBASE-19491 Improvements to Nighly runs: Fixes findbugs tests, Exclude flaky tests from master.']
# ['b0b4eb2177', 'HBASE-19491 Improvements to Nighly runs: Fixes findbugs tests, Exclude flaky tests from master.']
# ['85211b1b5b', 'HBASE-19491 Improvements to Nighly runs: Fixes findbugs tests, Exclude flaky tests from master.']
# ['0a31209f91', 'HBASE-19491 Improvements to Nighly runs: Fixes findbugs tests, Exclude flaky tests from master.']
# ['90ac3c93c9', 'HBASE-19491 Improvements to Nighly runs: Fixes findbugs tests, Exclude flaky tests from master.']
# ['dc5ec061b5', 'HBASE-19491 Improvements to Nighly runs: Fixes findbugs tests, Exclude flaky tests from master.']
# ['4fad3d96c9', 'HBASE-19554 For debug: Modify HTU.waitUntilAllRegionsAssigned to handle the case where we do not have entries for the given table']
# ['084e324fb9', 'HBASE-19554 For debug: Modify HTU.waitUntilAllRegionsAssigned to handle the case where we do not have entries for the given table']
# ['4c2b2b3e6a', 'HBASE-19497 Fix findbugs and error-prone warnings in hbase-common (branch-2) Signed-off-by: Apekshit Sharma <appy@apache.org>']
# ['f9f869f60a', 'HBASE-19497 Fix findbugs and error-prone warnings in hbase-common (branch-2) Signed-off-by: Apekshit Sharma <appy@apache.org>']
# ['2043c337d8', 'HBASE-19498 Fix findbugs and error-prone warnings in hbase-client (branch-2)']
# ['59529a78f0', 'HBASE-19498 Fix findbugs and error-prone warnings in hbase-client (branch-2)']
# ['e8ba7b2320', 'HBASE-19457 Debugging flaky TestTruncateTableProcedure']
# ['7092b814bd', 'HBASE-19457 Debugging flaky TestTruncateTableProcedure']
# ['a70b9b5e94', 'HBASE-19454 Debugging TestDistributedLogSplitting#testThreeRSAbort']
# ['033e64a8b1', 'HBASE-19454 Debugging TestDistributedLogSplitting#testThreeRSAbort']
# ['9d481b1c43', 'HBASE-19239 (addendum) Fix findbugs and error-prone warnings (branch-1)']
# ['ed9c8b1cfe', 'HBASE-19239 (addendum) Fix findbugs and error-prone warnings (branch-1)']
# ['d32ba0977f', 'HBASE-19386 Enable Arm64 unaligned support for HBase']
# ['ddbff4fd87', 'HBASE-19386 Enable Arm64 unaligned support for HBase']
# ['96e63ac7b8', 'HBASE-19319 Fix bug in synchronizing over ProcedureEvent']
# ['f886716617', 'HBASE-19319 Fix bug in synchronizing over ProcedureEvent']
# ['0f888cbcf3', 'HBASE-19239 Fix findbugs and error-prone issues']
# ['b2fa185f85', 'HBASE-19239 Fix findbugs and error-prone issues']
# ['f6e93520ba', 'HBASE-19239 Fix findbugs and error-prone issues']
# ['3436ed957c', 'HBASE-19239 Fix findbugs and error-prone issues']
# ['e95f94a72d', 'HBASE-19239 Fix findbugs and error-prone issues']
# ['d80d3fa454', 'HBASE-19239 Fix findbugs and error-prone issues']
# ['357b3dbc3e', 'HBASE-19239 Fix findbugs and error-prone issues']
# ['24feb1ab75', 'HBASE-19239 Fix findbugs and error-prone issues']
# ['5b7411290b', 'HBASE-19239 Fix findbugs and error-prone issues']
# ['f856cbf414', 'HBASE-19239 Fix findbugs and error-prone issues']
# ['b9475d3e75', 'HBASE-19239 Fix findbugs and error-prone issues']
# ['108ea30e3d', 'HBASE-19239 Fix findbugs and error-prone issues']
# ['daf1fc6f1f', 'HBASE-19239 Fix findbugs and error-prone issues']
# ['ca186f9349', 'HBASE-19239 Fix findbugs and error-prone issues']
# ['1a5e95ae98', 'HBASE-19239 Fix findbugs and error-prone issues']
# ['3444059a20', 'HBASE-19239 Fix findbugs and error-prone issues']
# ['c179d5144f', 'HBASE-19239 Fix findbugs and error-prone issues']
# ['2d579a4140', 'HBASE-19239 Fix findbugs and error-prone issues']
# ['6ceb4a4f41', 'HBASE-16290 Dump summary of callQueue content; can help debugging']
# ['7cdfbde37d', 'HBASE-16290 Dump summary of callQueue content; can help debugging']
# ['6765f5e203', 'HBASE-18350 RSGroups are broken under AMv2']
# ['41cc9a125f', 'HBASE-18350 RSGroups are broken under AMv2']
# ['08dff49620', 'HBASE-18960 A few bug fixes and minor improvements around batchMutate']
# ['e1941aa6d1', 'HBASE-18960 A few bug fixes and minor improvements around batchMutate']
# ['c4497c37d5', 'HBASE-18929 Hbase backup command doesn\\xe2\\x80\\x99t show debug option to enable backup in debug mode (Amit Kabra)']
# ['1ff90d3b4b', 'HBASE-18929 Hbase backup command doesn\\xe2\\x80\\x99t show debug option to enable backup in debug mode (Amit Kabra)']
# ['ede916af5a', "Amend HBASE-18830 TestCanaryTool does not check Canary monitor's error code"]
# ['91e1f834bf', "Amend HBASE-18830 TestCanaryTool does not check Canary monitor's error code"]
# ['f391fc44df', "Amend HBASE-18830 TestCanaryTool does not check Canary monitor's error code"]
# ['3abc0458e9', "Amend HBASE-18830 TestCanaryTool does not check Canary monitor's error code"]
# ['68ec2a9da0', 'HBASE-18375: Fix the bug where the pool chunks from ChunkCreator are deallocated and not returned to pool, because there is no reference to them']
# ['43c4bc5761', 'HBASE-18723 [pom cleanup] Do a pass with dependency:analyze; remove unused and explicity list the dependencies we exploit']
# ['fb537fe736', 'HBASE-18723 [pom cleanup] Do a pass with dependency:analyze; remove unused and explicity list the dependencies we exploit']
# ['75a6b36849', 'HBASE-18375: Fix the bug where the pool chunks from ChunkCreator are deallocated and not returned to pool, because there is no reference to them']
# ['97877df172', 'HBASE-18315 Eliminate the findbugs warnings for hbase-rest']
# ['bb8c3ac035', 'HBASE-18315 Eliminate the findbugs warnings for hbase-rest']
# ['781272c37f', 'HBASE-18315 Eliminate the findbugs warnings for hbase-rest']
# ['8b6cf09869', 'HBASE-18315 Eliminate the findbugs warnings for hbase-rest']
# ['4376233e2a', 'HBASE-18315 Eliminate the findbugs warnings for hbase-rest']
# ['18d29e4794', 'HBASE-18315 Eliminate the findbugs warnings for hbase-rest']
# ['7db088b4be', 'HBASE-18308 Eliminate the findbugs warnings for hbase-server']
# ['8aabbdb3ed', 'HBASE-18308 Eliminate the findbugs warnings for hbase-server']
# ['68e9f2173b', 'HBASE-18308 Eliminate the findbugs warnings for hbase-server']
# ['2da5b432a1', 'HBASE-18308 Eliminate the findbugs warnings for hbase-server']
# ['594f892c02', 'HBASE-18308 Eliminate the findbugs warnings for hbase-server']
# ['3574757f74', 'HBASE-18308 Eliminate the findbugs warnings for hbase-server']
# ['ea0062fa54', 'HBASE-18376 Add debug logs to hbase-personality.sh to make it possible to debug this issue.']
# ['4bd5f03d22', 'HBASE-18365 Eliminate the findbugs warnings for hbase-common']
# ['b1e128fd76', 'HBASE-18365 Eliminate the findbugs warnings for hbase-common']
# ['0616811fab', 'HBASE-18365 Eliminate the findbugs warnings for hbase-common']
# ['1b8fb0a8d8', 'HBASE-18365 Eliminate the findbugs warnings for hbase-common']
# ['9daac09f6e', 'HBASE-18365 Eliminate the findbugs warnings for hbase-common']
# ['cf636e50b9', 'HBASE-18365 Eliminate the findbugs warnings for hbase-common']
# ['d11b5d1fd5', 'HBASE-18268 Eliminate the findbugs warnings for hbase-client']
# ['a84de33129', 'HBASE-18268 Eliminate the findbugs warnings for hbase-client']
# ['4ad8ae3db5', 'HBASE-18268 Eliminate the findbugs warnings for hbase-client']
# ['8eaad67866', 'HBASE-18268 Eliminate the findbugs warnings for hbase-client']
# ['ca5d8c40b7', 'HBASE-18268 Eliminate the findbugs warnings for hbase-client']
# ['cc4301ca08', 'HBASE-18268 Eliminate the findbugs warnings for hbase-client']
# ['29ec749363', 'HBASE-18314 Eliminate the findbugs warnings for hbase-examples']
# ['8b63eb6fc6', 'HBASE-18314 Eliminate the findbugs warnings for hbase-examples']
# ['b222a41c1f', 'HBASE-18293 Only add the spotbugs dependency when jdk8 is active']
# ['a4dfc669f1', 'HBASE-18293 Only add the spotbugs dependency when jdk8 is active']
# ['eacbdb061e', 'HBASE-18264 Update pom plugins']
# ['f2731fc241', 'HBASE-18264 Update pom plugins']
# ['d627c6f288', "HBASE-18293 remove spotbugs on branch-1.1 since it doesn't support jdk8"]
# ['b49390922e', 'HBASE-18293 Only add the spotbugs dependency when jdk8 is active']
# ['8c37b912ac', 'HBASE-18293 Only add the spotbugs dependency when jdk8 is active']
# ['0d4245c99e', 'HBASE-18293 Only add the spotbugs dependency when jdk8 is active']
# ['0357c2266a', 'HBASE-18254 ServerCrashProcedure checks and waits for meta initialized, instead should check and wait for meta loaded']
# ['7cc458e129', 'HBASE-18254 ServerCrashProcedure checks and waits for meta initialized, instead should check and wait for meta loaded']
# ['0936f1f2bd', 'HBASE-17954 Switched findbugs implementation to spotbugs']
# ['a8874eb7eb', 'HBASE-17954 Switched findbugs implementation to spotbugs']
# ['a7d824bf13', 'HBASE-17954 Switched findbugs implementation to spotbugs']
# ['13f670057f', 'HBASE-17954 Switched findbugs implementation to spotbugs']
# ['8b0ae5d1ae', 'HBASE-17954 Switched findbugs implementation to spotbugs']
# ['298454e8a7', 'HBASE-17954 Switched findbugs implementation to spotbugs']
# ['3975bbd008', 'HBASE-14614 Procedure v2 - Core Assignment Manager (Matteo Bertozzi) Move to a new AssignmentManager, one that describes Assignment using a State Machine built on top of ProcedureV2 facility.']
# ['e76e8eb8e1', 'HBASE-14614 Procedure v2 - Core Assignment Manager (Matteo Bertozzi) Move to a new AssignmentManager, one that describes Assignment using a State Machine built on top of ProcedureV2 facility.']
# ['dc1065a85d', 'HBASE-14614 Procedure v2 - Core Assignment Manager (Matteo Bertozzi) Move to a new AssignmentManager, one that describes Assignment using a State Machine built on top of ProcedureV2 facility.']
# ['841bb00655', 'HBASE-18044 Fix bug in report-flakies.py where if counter is set outside for loop, it cannot be overwritten inside loop.']
# ['cb4fac1d18', 'HBASE-17765 Reviving the merge of the compacting pipeline']
# ['046d4e183b', 'Revert "Reviving the merge of the compacting pipeline: making the limit on the number of the segments in the pipeline configurable, adding merge test, fixing bug in sizes counting"']
# ['c77e2135db', 'Reviving the merge of the compacting pipeline: making the limit on the number of the segments in the pipeline configurable, adding merge test, fixing bug in sizes counting']
# ['f45d261902', 'HBASE-15484 Correct the semantic of batch and partial - amend to fix bug and revise the JavaDoc for related APIs.']
# ['b635414e83', 'HBASE-15484 Correct the semantic of batch and partial - amend to fix bug and revise the JavaDoc for related APIs.']
# ['c725d4d334', "HBASE-17538 HDFS.setStoragePolicy() logs errors on local fs Policy is set in a number of places each with its own 'implementation'."]
# ['69ce5967fd', 'HBASE-17373: Fixing bug in moving segments from compaction pipeline to snapshot']
# ['a5ee36d937', 'HBASE-17326 Fix findbugs warning in BufferedMutatorParams Fix above and the other hbase-server findbugs complaint about null-check Addendum to fix complaint out of BMParams#clone. Added CN_IDIOM_NO_SUPER_CALL handling.']
# ['c3ce02d592', 'HBASE-17326 Fix findbugs warning in BufferedMutatorParams Fix above and the other hbase-server findbugs complaint about null-check']
# ['8d62d9a0d5', 'HBASE-16940 Address review of "Backup/Restore (HBASE-7912, HBASE-14030, HBASE-14123) mega patch" posted on RB - fix findbugs warnings (Vladimir Rodionov)']
# ['8152234539', 'HBASE-16904 ADDENDUM cleanup of snapshot related changes for fs redo.']
# ['87f74bcaab', 'HBASE-17006 Give name to existing threads. Having thread names in logs and thread dumps greatly improve debugability. This patch is simply adding the names to the threads we spawn.']
# ['90c29888c4', 'HBASE-17006 Give name to existing threads. Having thread names in logs and thread dumps greatly improve debugability. This patch is simply adding the names to the threads we spawn.']
# ['326ecc32fd', 'HBASE-17006 Give name to existing threads. Having thread names in logs and thread dumps greatly improve debugability. This patch is simply adding the names to the threads we spawn.']
# ['3dc95c0e67', 'HBASE-17006 Give name to existing threads. Having thread names in logs and thread dumps greatly improve debugability. This patch is simply adding the names to the threads we spawn.']
# ['51ba7cfde3', 'HBASE-17006 Give name to existing threads. Having thread names in logs and thread dumps greatly improve debugability. This patch is simply adding the names to the threads we spawn.']
# ['bb0fc6b602', 'HBASE-17006 Give name to existing threads. Having thread names in logs and thread dumps greatly improve debugability. This patch is simply adding the names to the threads we spawn.']
# ['281bf9a222', 'HBASE-17014 Added clearly marked log messages for start and shutdown of services HMaster, HRegionServer, ThriftServer, RESTServer. Also changed the log level for RPCServer responder starting log message to debug.']
# ['a969f8d790', 'HBASE-16969 RegionCoprocessorServiceExec should override the toString() for debugging (ChiaPing Tsai)']
# ['fe47ec81f9', 'HBASE-16969 RegionCoprocessorServiceExec should override the toString() for debugging (ChiaPing Tsai)']
# ['bbe88d942e', 'HBASE-16944 Fix findbugs warning in hbase-server HRegion UL_UNRELEASED_LOCK']
# ['9dd28f2a94', 'HBASE-16881 Address findbugs warnings for backup mega patch']
# ['0d40a52ee8', 'Revert "Revert "HBASE-16698 Performance issue: handlers stuck waiting for CountDownLatch inside WALKey#getWriteEntry under high writing workload; ADDENDUM. Fix findbugs""']
# ['f555b5be9c', 'Revert "HBASE-16698 Performance issue: handlers stuck waiting for CountDownLatch inside WALKey#getWriteEntry under high writing workload; ADDENDUM. Fix findbugs" Premature commit. Revert while discussion ongoing']
# ['e1923b7c0c', 'HBASE-16698 Performance issue: handlers stuck waiting for CountDownLatch inside WALKey#getWriteEntry under high writing workload; ADDENDUM. Fix findbugs']
# ['8c4b09dfba', 'HBASE-16624 Fix MVCC DeSerialization bug in the HFileScannerImpl']
# ['5a1b3a548e', 'HBASE-16535 Use regex to exclude generated classes for findbugs']
# ['4de27ee312', 'HBASE-16535 Use regex to exclude generated classes for findbugs']
# ['c25c36274f', 'HBASE-16535 Use regex to exclude generated classes for findbugs']
# ['3c5d01c3e4', 'HBASE-16535 Use regex to exclude generated classes for findbugs']
# ['966aeb06a8', 'HBASE-16535 Use regex to exclude generated classes for findbugs']
# ['1da0a48f6b', 'HBASE-16535 Use regex to exclude generated classes for findbugs']
# ['c11923d8aa', 'HBASE-16456 Fix findbugs warnings in hbase-rsgroup module (Guangxu Cheng)']
# ['741d0a4511', "HBASE-16430 Fix RegionServer Group's bug when moving multiple tables (Guangxu Cheng)"]
# ['ad16676f92', "Fix RegionServer Group's bug when moving multiple tables (Guangxu Cheng)"]
# ['45bb6180a3', 'REVERT of revert of "HBASE-16308 Contain protobuf references Gather up the pb references into a few locations only rather than have pb references distributed all about the code base." This is a revert of a revert; i.e. we are adding back the change only adding back with fixes for the broken unit test; was a real issue on a test that went in just at same time as this commit; I was getting a new nonce on each retry rather than getting one for the mutation.']
# ['bbc427028c', 'HBASE-16321 ensure no findbugs-jsr305']
# ['ca5e1a5771', 'HBASE-16321 ensure no findbugs-jsr305']
# ['7b91c136b2', 'HBASE-16321 ensure no findbugs-jsr305']
# ['bf12fe6788', 'HBASE-16321 ensure no findbugs-jsr305']
# ['a5f98c3f9e', 'HBASE-16321 ensure no findbugs-jsr305']
# ['60b79e2daa', 'HBASE-16321 ensure no findbugs-jsr305']
# ['af6ebcd1a2', 'HBASE-16355 Invalid hbase-common test-jar dependency scope']
# ['737e063240', 'HBASE-16355 Invalid hbase-common test-jar dependency scope']
# ['544dc1e558', 'HBASE-16355 Invalid hbase-common test-jar dependency scope']
# ['dfc9616aea', 'HBASE-16317 revert all ESAPI changes']
# ['01215db07a', 'HBASE-16317 revert all ESAPI changes']
# ['92b2973b62', 'HBASE-16317 revert all ESAPI changes']
# ['209b6f74c7', 'HBASE-16317 revert all ESAPI changes']
# ['8b3385bd36', 'HBASE-16317 revert all ESAPI changes']
# ['e5d0d48580', 'HBASE-15115 Fix findbugs complaints in hbase-client']
# ['fb9a64816d', 'HBASE-16180 Fix ST_WRITE_TO_STATIC_FROM_INSTANCE_METHOD findbugs introduced by parent']
# ['11c59d9ddf', 'HBASE-16180 Fix ST_WRITE_TO_STATIC_FROM_INSTANCE_METHOD findbugs introduced by parent']
# ['78ef0513b4', 'HBASE-16180 Fix ST_WRITE_TO_STATIC_FROM_INSTANCE_METHOD findbugs introduced by parent']
# ['1ac755e40d', 'HBASE-16180 Fix ST_WRITE_TO_STATIC_FROM_INSTANCE_METHOD findbugs introduced by parent']
# ['2d6cdfb10a', 'HBASE-16180 Fix ST_WRITE_TO_STATIC_FROM_INSTANCE_METHOD findbugs introduced by parent']
# ['4421fdf981', 'HBASE-16066 Resolve RpC_REPEATED_CONDITIONAL_TEST findbugs warnings in HMaster, addendum to HBASE-15467']
# ['c2b4c6f637', "HBASE-15965 - Testing by executing a command will cover the exact path users will trigger, so its better then directly calling library functions in tests. Changing the tests to use @shell.command(:<command>, args) to execute them like it's a command coming from shell."]
# ['15c03fd1c9', "HBASE-15965 - Testing by executing a command will cover the exact path users will trigger, so its better then directly calling library functions in tests. Changing the tests to use @shell.command(:<command>, args) to execute them like it's a command coming from shell."]
# ['6d0e8b2a91', 'Revert "HBASE-15949 Cleanup TestRegionServerMetrics." This change passes on master but fails on branch-1. Will try to debug.']
# ['eb64cd9dd1', 'HBASE-15917 Addendum. Fix bug in report-flakies.py where hanging tests are not being added to flaky list. (Apekshit) ADDENDUM #2!']
# ['4abc602e3b', 'HBASE-15912. REST module has 2 extent warnings in findbugs.']
# ['c47511baa7', 'HBASE-15828 fix extant findbug NM_SAME_SIMPLE_NAME_AS_INTERFACE in Future']
# ['ac31ceb835', 'HBASE-15794 Fix Findbugs instanceof always true issue in MultiServerCallable']
# ['a3e77bf366', 'HBASE-15720 Print row locks at the debug dump page, addendum']
# ['bf13941592', 'HBASE-15720 Print row locks at the debug dump page; addendum']
# ['716ca48a74', 'HBASE-15720 Print row locks at the debug dump page']
# ['a837182b79', 'HBASE-15720 Print row locks at the debug dump page']
# ['1c92d02b00', 'HBASE-15720 Print row locks at the debug dump page']
# ['92eec53829', 'HBASE-15720 Print row locks at the debug dump page']
# ['710ad4a168', 'HBASE-15720 Print row locks at the debug dump page']
# ['5f5cdaae9a', 'HBASE-15720 Print row locks at the debug dump page']
# ['e8b37422c3', 'HBASE-15720 Print row locks at the debug dump page']
# ['b3e71d4644', 'HBASE-15434 [findbugs] Exclude scala generated source and protobuf generated code in hbase-spark module']
# ['fe7bcf58d9', 'HBASE-15291 Revert due to the bug Haitao discovered']
# ['dc4bdb9928', 'HBASE-15291 Revert due to the bug Haitao discovered']
# ['d74f99fbc1', 'HBASE-15291 Revert due to the bug Haitao discovered']
# ['77c3c61b34', 'HBASE-15291 Revert due to the bug Haitao discovered']
# ['edc5ab5af9', 'HBASE-15291 Revert due to the bug Haitao discovered']
# ['41c04ee685', 'HBASE-15181 Addendum fixes findbugs warning (Clara Xiong)']
# ['ab2904c7d7', 'HBASE-15181 Addendum fixes findbugs warning (Clara Xiong)']
# ['231a5807b4', 'HBASE-15181 Addendum fixes findbugs warning (Clara Xiong)']
# ['bab8d1527b', 'HBASE-15181 Addendum fixes findbugs warning (Clara Xiong)']
# ['29ce46a67f', 'HBASE-15122 Servlets generate XSS_REQUEST_PARAMETER_TO_SERVLET_WRITER findbugs warnings (Samir Ahmic)']
# ['3733223e40', 'HBASE-15122 Servlets generate XSS_REQUEST_PARAMETER_TO_SERVLET_WRITER findbugs warnings (Samir Ahmic)']
# ['a6f53600dd', 'HBASE-15122 Servlets generate XSS_REQUEST_PARAMETER_TO_SERVLET_WRITER findbugs warnings (Samir Ahmic)']
# ['f280c45956', 'HBASE-15122 Servlets generate XSS_REQUEST_PARAMETER_TO_SERVLET_WRITER findbugs warnings (Samir Ahmic)']
# ['68b300173f', 'HBASE-15122 Servlets generate XSS_REQUEST_PARAMETER_TO_SERVLET_WRITER findbugs warnings (Samir Ahmic)']
# ['a975408b7c', 'HBASE-15253 Small bug in CellUtil.matchingRow(Cell, byte[]) (Ram)']
# ['52355ab1de', 'HBASE-15148 Resolve IS2_INCONSISTENT_SYNC findbugs warning in AuthenticationTokenSecretManager (Yu Li)']
# ['6f6cd661d5', 'HBASE-15238 HFileReaderV2 prefetch overreaches; runs off the end of the data']
# ['b6328eb803', 'HBASE-15238 HFileReaderV2 prefetch overreaches; runs off the end of the data']
# ['d82ae42126', 'Revert "HBASE-15122 Servlets generate XSS_REQUEST_PARAMETER_TO_SERVLET_WRITER findbugs warnings (Samir Ahmic)" Revert mistaken commit.']
# ['efc7a0d347', 'HBASE-15122 Servlets generate XSS_REQUEST_PARAMETER_TO_SERVLET_WRITER findbugs warnings (Samir Ahmic)']
# ['f4d9597e1e', 'HBASE-15210 Undo aggressive load balancer logging at tens of lines per millisecond; ADDENDUM changing LOG.debug to LOG.trace -- noticed by matteo']
# ['846a2f31c1', 'HBASE-15210 Undo aggressive load balancer logging at tens of lines per millisecond; ADDENDUM changing LOG.debug to LOG.trace -- noticed by matteo']
# ['0e36afd2d0', 'HBASE-15210 Undo aggressive load balancer logging at tens of lines per millisecond; ADDENDUM changing LOG.debug to LOG.trace -- noticed by matteo']
# ['2cc48e039d', 'HBASE-15158 HBASE-15158 Preamble 1 of 2: fix findbugs, add javadoc, change Region#getReadpoint to #getReadPoint, and some util']
# ['9955118995', "HBASE-15195 Don't run findbugs on hbase-it; it has nothing in src/main/java"]
# ['cd920940b7', 'HBASE-15148 Resolve IS2_INCONSISTENT_SYNC findbugs warning in AuthenticationTokenSecretManager (Yu Li)']
# ['37d15e05d8', 'HBASE-15148 Resolve IS2_INCONSISTENT_SYNC findbugs warning in AuthenticationTokenSecretManager (Yu Li)']
# ['f9e69b51e1', 'HBASE-15148 Resolve IS2_INCONSISTENT_SYNC findbugs warning in AuthenticationTokenSecretManager (Yu Li)']
# ['4fb7babad9', 'HBASE-15106 Procedure v2 - Procedure Queue pass Procedure for better debuggability']
# ['7d7a2d8712', 'HBASE-15106 Procedure v2 - Procedure Queue pass Procedure for better debuggability']
# ['713c6b5b1e', 'HBASE-15106 Procedure v2 - Procedure Queue pass Procedure for better debuggability']
# ['b9450687ce', 'HBASE-15118 Fix findbugs complaint in hbase-server; ADDENDUM TO FIX TestImportTsv']
# ['c4bcaa3f65', 'HBASE-15118 Fix findbugs complaint in hbase-server']
# ['d6654ea7ea', 'HBASE-15118 Fix findbugs complaint in hbase-server']
# ['9bf26f46d1', 'HBASE-15118 Fix findbugs complaint in hbase-server']
# ['5a280c9fd6', 'HBASE-15115 Fix findbugs complaints in hbase-client']
# ['d9fd87d5a8', 'HBASE-15115 Fix findbugs complaints in hbase-client']
# ['76bce77326', 'HBASE-15115 Fix findbugs complaints in hbase-client']
# ['cb17c7a97a', 'HBASE-15117 Resolve ICAST findbugs warnings in current codes (Yu Li)']
# ['ab0651ed2b', 'HBASE-15087 Fix hbase-common findbugs complaints']
# ['546adefcd6', 'HBASE-15087 Fix hbase-common findbugs complaints']
# ['83c506d9d4', 'HBASE-15087 Fix hbase-common findbugs complaints']
# ['894ce84b83', 'HBASE-15027 - Findbug fix (addendum)']
# ['0cfd893e12', 'HBASE-14355 Scan different TimeRange for each column family - fixing memstore bug']
# ['9a11c025f2', 'HBASE-14355 Scan different TimeRange for each column family - fixing memstore bug']
# ['0d72849581', 'HBASE-14355 Scan different TimeRange for each column family - fixing memstore bug']
# ['b3e40e4257', 'HBASE-14343 Fix debug message in SimpleRegionNormalizer for small regions (Lars Francke)']
# ['6f21cfbf27', 'HBASE-14343 Fix debug message in SimpleRegionNormalizer for small regions (Lars Francke)']
# ['6875e6d4d4', 'HBASE-14343 Fix debug message in SimpleRegionNormalizer for small regions (Lars Francke)']
# ['e41f6c934b', 'HBASE-14547 Add more debug/trace to zk-procedure']
# ['86b505c224', 'HBASE-14547 Add more debug/trace to zk-procedure']
# ['dd955fa417', 'HBASE-14547 Add more debug/trace to zk-procedure']
# ['17829bbb54', 'HBASE-14100 Fix high priority findbugs warnings']
# ['ca57ef2cf2', 'HBASE-14100 Fix high priority findbugs warnings']
# ['12f6470bf3', 'HBASE-14100 Fix high priority findbugs warnings']
# ['257df19cc3', 'HBASE-14100 Fix high priority findbugs warnings']
# ['4936766d1a', 'HBASE-13930 Exclude Findbugs packages from shaded jars']
# ['3af21f154b', 'HBASE-13930 Exclude Findbugs packages from shaded jars']
# ['854d27350d', 'HBASE-13930 Exclude Findbugs packages from shaded jars']
# ['7dbb2e6977', 'HBASE-13930 Exclude Findbugs packages from shaded jars']
# ['84a50393ee', 'HBASE-13888 Fix refill bug from HBASE-13686 (Guanghao Zhang)']
# ['e8821d1806', 'HBASE-13888 Fix refill bug from HBASE-13686 (Guanghao Zhang)']
# ['49700460da', 'HBASE-13888 Fix refill bug from HBASE-13686 (Guanghao Zhang)']
# ['9ee184b673', 'HBASE-13760 Cleanup Findbugs keySet iterator warnings. (Gabor Liptak)']
# ['7f2b33dbbf', 'HBASE-13071 synchronous scanner -- cache size-in-bytes bug fix']
# ['3352585160', 'HBASE-13677 changed RecoverableZooKeeper logs about retries from info and warn to debug']
# ['00636cc998', 'HBASE-13677 changed RecoverableZooKeeper logs about retries from info and warn to debug']
# ['a1c94c0bdf', 'HBASE-13677 changed RecoverableZooKeeper logs about retries from info and warn to debug']
# ['586a60606e', 'HBASE-13132 Improve RemoveColumn action debug message']
# ['5688ab4fa2', 'HBASE-13528 A bug on selecting compaction pool (Shuaifeng Zhou)']
# ['5b8f70d368', 'HBASE-13528 A bug on selecting compaction pool (Shuaifeng Zhou)']
# ['93fce057a3', 'HBASE-13528 A bug on selecting compaction pool (Shuaifeng Zhou)']
# ['42ad845032', 'HBASE-13528 A bug on selecting compaction pool (Shuaifeng Zhou)']
# ['e1cb405adc', 'HBASE-13528 A bug on selecting compaction pool (Shuaifeng Zhou)']
# ['ced0e324a1', 'HBASE-13262 Observe ScanResponse.moreResults in ClientScanner.']
# ['20189c258c', 'HBASE-13262 Observe ScanResponse.moreResults in ClientScanner.']
# ['b0116398ff', 'HBASE-13262 Observe ScanResponse.moreResults in ClientScanner.']
# ['1abf3aa0fd', 'HBASE-13262 Observe ScanResponse.moreResults in ClientScanner.']
# ['69f6a2e7b4', 'HBASE-13334 FindBugs should create precise report for new bugs introduced (addendum)']
# ['948a6a63e8', 'HBASE-13334 FindBugs should create precise report for new bugs introduced']
# ['6e9ded51fb', 'HBASE-13310 Fix high priority findbugs warnings']
# ['9c83fa7b52', 'HBASE-13167 The check for balancerCutoffTime is buggy (Mikhail Antonov)']
# ['d590f87ef4', 'HBASE-7126 Document how to report security bugs']
# ['5bd27af8b0', 'Fixed bug in publication script']
# ['d66f88134c', 'HBASE-13132 Improve RemoveColumn action debug message']
# ['7dd6a203c7', 'HBASE-13132 Improve RemoveColumn action debug message']
# ['309e124a57', 'HBASE-13123 - Minor bug in ROW bloom filter (Ram)']
# ['c4acac561c', 'HBASE-13138 Clean up TestMasterObserver (debug, trying to figure why fails)']
# ['b9f8616177', 'HBASE-13138 Clean up TestMasterObserver (debug, trying to figure why fails)']
# ['d2e64032c6', 'HBASE-13132 Improve RemoveColumn action debug message']
# ['b3ebca633a', 'HBASE-13132 Improve RemoveColumn action debug message']
# ['bd8544f662', 'HBASE-13123 - Minor bug in ROW bloom filter (Ram)']
# ['9c3cbdcd05', 'HBASE-13123 - Minor bug in ROW bloom filter (Ram):w']
# ['4fb6f91cba', 'HBASE-13123 - Minor bug in ROW bloom filter (Ram)']
# ['3216b8b6e3', 'HBASE-12985 Javadoc warning and findbugs fixes to get us green again']
# ['b3d8a8843c', 'HBASE-12985 Javadoc warning and findbugs fixes to get us green again']
# ['eea9873cef', 'HBASE-12985 Javadoc warning and findbugs fixes to get us green again']
# ['d0e4fb6ae3', 'HBASE-12548. Improve debuggability of IntegrationTestTimeBoundedRequestsWithRegionReplicas.']
# ['6314063e74', 'HBASE-12270 A bug in the bucket cache, with cache blocks on write enabled (Liu Shaohui)']
# ['4083306c3d', 'HBASE-12711 Fix new findbugs warnings in hbase-thrift module (Srikanth)']
# ['9b25e850df', 'Revert "HBASE-12270 A bug in the bucket cache, with cache blocks on write enabled (Liu Shaohui)" Reverting since this is failing often on 0.98 branch']
# ['bb7074b3d8', 'Revert "HBASE-12270 A bug in the bucket cache, with cache blocks on write enabled (Liu Shaohui) -- ADDENDUM" Revert for now since it is failing often on 0.98']
# ['0256cdd1b4', 'HBASE-12716 A bug in RegionSplitter.UniformSplit algorithm (Weichen Ye)']
# ['74f303ba24', 'HBASE-12716 A bug in RegionSplitter.UniformSplit algorithm (Weichen Ye)']
# ['99acd66a95', 'HBASE-12270 A bug in the bucket cache, with cache blocks on write enabled (Liu Shaohui) -- ADDENDUM']
# ['809de6ae1c', 'HBASE-12270 A bug in the bucket cache, with cache blocks on write enabled (Liu Shaohui)']
# ['dd566e0347', 'HBASE-12270 A bug in the bucket cache, with cache blocks on write enabled (Liu Shaohui)']
# ['2ff16e532b', 'HBASE-12270 A bug in the bucket cache, with cache blocks on write enabled (Liu Shaohui)']
# ['305267b8e2', 'HBASE-12270 A bug in the bucket cache, with cache blocks on write enabled (Liu Shaohui)']
# ['882f4c9761', 'HBASE-12716 A bug in RegionSplitter.UniformSplit algorithm (Weichen Ye)']
# ['fbdaf62bf8', 'HBASE-12716 A bug in RegionSplitter.UniformSplit algorithm (Weichen Ye)']
# ['3021c060bd', 'HBASE-12711 Fix new findbugs warnings in hbase-thrift module (Srikanth)']
# ['d436559378', 'HBASE-12711 Fix new findbugs warnings in hbase-thrift module (Srikanth)']
# ['ca0c1774c9', 'HBASE-12548. Improve debuggability of IntegrationTestTimeBoundedRequestsWithRegionReplicas']
# ['5cc0714840', 'HBASE-12559 Addendum fixes findbugs warnings']
# ['0df5ed2ca6', 'HBASE-12550 Check all storefiles are referenced before splitting']
# ['860ddd2c22', 'HBASE-12550 Check all storefiles are referenced before splitting']
# ['339fd6bdca', 'HBASE-12550 Check all storefiles are referenced before splitting']
# ['42cbdea76d', 'HBASE-12541 Add misc debug logging to hanging tests in TestHCM and TestBaseLoadBalancer -- ADDENDUM; add waitForNoRegionInTransition from HTU in master branch']
# ['bfda57d4f2', 'HBASE-12541 Add misc debug logging to hanging tests in TestHCM and TestBaseLoadBalancer']
# ['c5690b1be3', 'HBASE-12541 Add misc debug logging to hanging tests in TestHCM and TestBaseLoadBalancer']
# ['5563105d16', 'HBASE-12472 Improve debuggability of IntegrationTestBulkLoad']
# ['390d4acf0d', 'HBASE-12472 Improve debuggability of IntegrationTestBulkLoad']
# ['42c03460e4', 'HBASE-12472 Improve debuggability of IntegrationTestBulkLoad']
# ['9ea80f8f11', 'HBASE-12488 Small bug in publish_hbase_website.sh script']
# ['a28a90eefb', 'HBASE-12198 Fix the bug of not updating location cache']
# ['c61f233dfd', 'HBASE-12198 Fix the bug of not updating location cache']
# ['3c1fbd2ddf', 'HBASE-12198 Fix the bug of not updating location cache']
# ['e5ecfb9440', 'HBASE-12104 Some optimization and bugfix for HTableMultiplexer (Yi Deng)']
# ['073ca6a516', 'HBASE-12104 Some optimization and bugfix for HTableMultiplexer (Yi Deng)']
# ['bc4f25ff45', 'HBASE-12104 Some optimization and bugfix for HTableMultiplexer (Yi Deng)']
# ['9f33edab0e', "HBASE-12145 Fix javadoc and findbugs so new folks aren't freaked when they see them"]
# ['43301167db', "HBASE-12145 Fix javadoc and findbugs so new folks aren't freaked when they see them"]
# ['3b8d80d5f9', 'HBASE-12086 Fix bug of HTableMultipliexer']
# ['a01f1f8ef9', 'HBASE-12086 Fix bug of HTableMultipliexer']
# ['78d532e5f3', 'HBASE-12086 Fix bug of HTableMultipliexer']
# ['74c7169252', 'HBASE-11662 shell should properly handle long form --debug.']
# ['6a7f923c0d', 'HBASE-11662 shell should properly handle long form --debug.']
# ['41ecb18c20', 'HBASE-11662 shell should properly handle long form --debug.']
# ['aca2462ce3', 'HBASE-4744 enable test that log roll fails after split start.']
# ['d5640c1024', "[master] add more information in exception thrown from Store's constructor"]
# ['45883c6bd1', '[HBASE-11258] Pull in Integration Tests from open source 0.96/trunk']
# ['8f76956cc6', '[HBASE-9704] Fix TableServers.isNetworkException()']
# ['9f96d91b2e', 'HBASE-11261 Addendum to remove an unneeded debug message']
# ['2a20143f72', 'HBASE-11514 Fix findbugs warnings in blockcache']
# ['96dcd67f56', 'HBASE-11514 Fix findbugs warnings in blockcache']
# ['8d62d85864', 'HBASE-11463 (findbugs) HE: Class defines equals() and uses Object.hashCode() (Mike Drob)']
# ['6da1a485fc', 'HBASE-11463 (findbugs) HE: Class defines equals() and uses Object.hashCode()']
# ['8f6e04c446', 'Add some debug and echo around findbugs generations']
# ['a181dff8e0', 'HBASE-11413 [findbugs] RV: Negating the result of compareTo()/compare() (Mike Drob)']
# ['1b2a05c944', 'HBASE-11413 [findbugs] RV: Negating the result of compareTo()/compare() (Mike Drob)']
# ['9ff90931dc', 'HBASE-11413 [findbugs] RV: Negating the result of compareTo()/compare() (Mike Drob)']
# ['4053868e72', 'HBASE-11203 Clean up javadoc and findbugs warnings in trunk']
# ['fdf2d11e86', '[master] Fix RPC compression bug for titan']
# ['52591973cb', '[master] Let HLogPrettyPrinter output real timestamp value']
# ['0296547aa2', '[HBASE-11021] HBaseFsck Fix for Table Hole Reporting']
# ['bbfbee0c76', '[master] Fix the problem of scanning over stopRow']
# ['1ae68a2bbd', '[Master] Fix TestRegionChecker']
# ['d928cfe843', '[HBASE-10709] Fix the bug of rejecting exception in HTableClientScanner when too many scanner running at the same time.']
# ['a8da435a58', '[master] Fix bugs in MemStoreFlusher']
# ['c8ea643074', '[HBASE-10901] Fix TestHRegionClose unstable bug']
# ['6a1b347964', '[HBASE-10893] Fixing critical bug in FastDiffDeltaEncoder']
# ['d7582304d9', '[master] Fix bug in TableServers.prefetchRegionCache that fails TestHTable']
# ['54175f554a', '[HBASE-10808] Forward porting Leases and Histogram bug fixes to trunk.']
# ['4487333e5e', 'HBASE-10840 Fix findbug warn induced by HBASE-10569.(Anoop)']
# ['6d6327b477', "HBASE-10656 high-scale-lib's Counter depends on Oracle (Sun) JRE, and also has some bug"]
# ['a1a5f57bff', "HBASE-10656 high-scale-lib's Counter depends on Oracle (Sun) JRE, and also has some bug"]
# ['1426ba05ac', '[HBASE-7099][89-fb] Debugging why compaction hook is not populating kvsConverted, but populates bytesSaved']
# ['a11781eae8', 'HBASE-10624 Fix 2 new findbugs warnings introduced by HBASE-10598']
# ['66f01155fe', 'HBASE-10624 Fix 2 new findbugs warnings introduced by HBASE-10598']
# ['bc9834426a', 'HBASE-10624 Fix 2 new findbugs warnings introduced by HBASE-10598']
# ['ce1e3b6c77', 'HBASE-10624 Fix 2 new findbugs warnings introduced by HBASE-10598']
# ['2e28ec44c8', '[HBASE-10647] Fix the bug of not decrease from size in updateColumnValue when removing the old columns.']
# ['93d11d6efb', '[HBASE-10450] Fix the Thrift test cases']
# ['72cabe8b2b', '[HBASE-9896] Fix the end row bug in the TableInputFormatBase']
# ['59c2b2bb09', 'HBASE-10452 Fix potential bugs in exception handlers (Ding Yuan)']
# ['f1ad5cb938', 'HBASE-10452 Fix potential bugs in exception handlers (Ding Yuan)']
# ['75aaf88b1b', '[master] Let HRegion get correct flushable size from each Store']
# ['b3b3d0ddff', 'HBASE-10446 Backup master gives Error 500 for debug dump']
# ['48e8a694dd', '[HBASE-10027] Adding an E2E test case.']
# ['b5d161c513', 'HBASE-10397 Fix findbugs introduced from HBASE-9426.']
# ['a8670eb5b7', '[master] Add 2 extra options to debug replication issue']
# ['a1e54b2b00', 'HBASE-10239. Improve determinism and debugability of TestAccessController']
# ['5123e92213', 'HBASE-10239. Improve determinism and debugability of TestAccessController']
# ['54fedebeb9', 'HBASE-10116 Addendum: fix findbugs warning']
# ['529e41d727', 'HBASE-10116 Addendum: fix findbugs warning']
# ['2124f4054d', 'HBASE-10116 Addendum: fix findbugs warning']
# ['8970eddf22', 'HBASE-10134 Fix findbug warning in VisibilityController']
# ['a28881da2d', 'HBASE-10134 Fix findbug warning in VisibilityController']
# ['13e9eda3e7', 'HBASE-9856 Fix some findbugs Performance Warnings']
# ['22f54af029', 'HBASE-10011 Fix some findbugs in the client - addendum: set OK_FINDBUGS_WARNINGS=89']
# ['8c0078d175', 'HBASE-10023 Fix/Suppress all the 10 findbug warnings under hbase-common (Liang Xie)']
# ['100cfded38', 'HBASE-10011 Fix some findbugs in the client']
# ['35cea57fe5', 'HBASE-10011 Fix some findbugs in the client']
# ['eb48f4dc8e', '[HBASE-9972] Make HBase export metrics to JMX by default, instead of to NullContext']
# ['ecb4b1017c', 'HBASE-9921 stripe compaction - findbugs and javadoc issues, some improvements']
# ['45a337446e', 'HBASE-9920 Revert: total findbugs warning is higher than 87, leading to false-positive']
# ['bf2144fe60', 'HBASE-9003 Remove the jamon generated classes from the findbugs analysis']
# ['5478e5a82e', '[master] Fix bug in TimestampsFilter that returns deleted KeyValue under certain circumstance']
# ['24e4df74ea', '[0.89-fb] [ HBASE-7517] Add server name to PFFE Exceptions']
# ['0c9f543e1c', 'HBASE-9238 bug in Mutation::getFamilyMap']
# ['7773da0cb4', 'HBASE-9232 Fix javadoc warning and a few findbugs items']
# ['58ee2bbf24', 'HBASE-9232 Fix javadoc warning and a few findbugs items']
# ['2c80ed63b0', 'HBASE-9158 Serious bug in cyclic replication']
# ['852bb0c21f', '[master]exclude classes in jacoco and findbugs reports']
# ['e7657c930b', 'HBASE-9158 Serious bug in cyclic replication']
# ['bd3acd05d4', 'HBASE-9158 Serious bug in cyclic replication']
# ['3bc9e2c95c', 'HBASE-9158 Serious bug in cyclic replication']
# ['54aab0e3c0', '[HBASE-8307] Fix a bug in Histogram class.']
# ['cea837fa8f', 'HBASE-9085 Integration Tests fails because of bug in teardown phase where the cluster state is not being restored properly. (gautam)']
# ['ee48ceb820', 'HBASE-9085 Integration Tests fails because of bug in teardown phase where the cluster state is not being restored properly. (gautam)']
# ['08235fca23', 'HBASE-9085 Integration Tests fails because of bug in teardown phase where the cluster state is not being restored properly. (gautam)']
# ['dc71a9b104', '[master]Make findbugs happy']
# ['415e06f7a1', '[HBASE-8467] Logging Failed nodes list to a new file every time, plus a small bug fix']
# ['d390841912', 'HBASE-8919 TestReplicationQueueFailover (and Compressed) can fail because the recovered queue gets stuck on ClosedByInterruptException (first try, getting more debug)']
# ['299b39532b', 'HBASE-8919 TestReplicationQueueFailover (and Compressed) can fail because the recovered queue gets stuck on ClosedByInterruptException (first try, getting more debug)']
# ['9ccf16db51', 'HBASE-8798 Fix a minor bug in shell command with clone_snapshot table error']
# ['98060a04ac', '[HBASE-8500] Fixes Minor bug in RollingRestart']
# ['8cbe3e2e2b', '[0.89-fb] [master] Allow regionServerReport to run with shorter RPC timeouts.']
# ['68b1e5c512', '[HBASE-8500] Adds a RollingRestart utility for a region server']
# ['c44bf173e4', '[0.89-fb] [master] handle rootRegion close correctly']
# ['7a3ad000ee', '[HBASE-5263] Change the logging to trace in HFileWriterV2 for cacheCurrentBlockForCompaction']
# ['77df789608', 'HBASE-7817: Suggested JDWP debug options in hbase-env.sh are wrong (Vasu Mariyala)']
# ['ff3ae92d1f', 'HBASE-7817: Suggested JDWP debug options in hbase-env.sh are wrong (Vasu Mariyala)']
# ['5ca140fe2f', 'HBASE-7817: Suggested JDWP debug options in hbase-env.sh are wrong (Vasu Mariyala)']
# ['24736e83bb', 'HBASE-8062 Replace HBaseFsck.debugLsr() in TestFlushSnapshotFromClient with FSUtils.logFileSystemState()']
# ['7181fa35a3', 'HBASE-8062 Replace HBaseFsck.debugLsr() in TestFlushSnapshotFromClient with FSUtils.logFileSystemState()']
# ['448f2f7902', 'HBASE-8067 TestHFileArchiving.testArchiveOnTableDelete sometimes fails']
# ['986c9fbed6', 'HBASE-8067 TestHFileArchiving.testArchiveOnTableDelete sometimes fails -- more debug']
# ['a79a77aa02', 'HBASE-8225 [replication] minor code bug when registering ReplicationLogCleaner (Jerry He)']
# ['a96672bec6', 'HBASE-8225 [replication] minor code bug when registering ReplicationLogCleaner (Jerry He)']
# ['0bc9187d46', 'HBASE-8225 [replication] minor code bug when registering ReplicationLogCleaner (Jerry He)']
# ['635949147f', '[0.89-fb] [HBASE-8216] Enable the serverManager to respect the config change for Power failures']
# ['3b4b9b3c7a', 'HBASE-7878 add debug log for recoverLease timeout']
# ['152ec1cc7f', 'HBASE-7587. Fix two findbugs warnings in RowResource (Jean-Marc Spaggiari)']
# ['69cbc81e5c', '[0.89-fb] [HBASE-7517] Improve the PFFE mechanism such that (i) Ensure that if a thread gets the AtomicBoolean for a single server, it will not be stopped to get the AtomicBoolean for a different server. (ii) PFFE is only thrown for threads that are not a']
# ['008aa92991', 'HBASE-8101 Cleanup: findbugs and javadoc warning fixes as well as making it illegal passing null row to Put/Delete, etc.']
# ['466902ffde', 'HBASE-8101 Cleanup: findbugs and javadoc warning fixes as well as making it illegal passing null row to Put/Delete, etc.']
# ['90eaac74d5', 'HBASE-8067 TestHFileArchiving.testArchiveOnTableDelete sometimes fails -- more debug']
# ['95e4f53090', 'HBASE-8067 TestHFileArchiving.testArchiveOnTableDelete sometimes fails -- more debug']
# ['ca1a0ea654', 'HBASE-7966 ACL tests fail on trunk (flaky) -- Some debug log']
# ['27dd86e0a0', 'HBASE-7966 ACL tests fail on trunk (flaky) -- Some debug log']
# ['539ff195e8', 'HBASE-7878 add debug log for recoverLease timeout']
# ['1e414a4413', 'HBASE-7547 Fix findbugs warnings in snapshot classes (Ted Yu)']
# ['c9b3e9b2da', 'HBASE-7354 Snapshot Info/Debug Tool (Matteo Bertozzi)']
# ['1d330c9478', 'HBASE-7699 Replace LOG.info() with LOG.debug() in FSUtils.listStatus()']
# ['a3f0aea354', 'HBASE-7682 Replace HRegion custom File-System debug, with FSUtils.logFileSystemState()']
# ['b33f042ea2', '[HBASE-7276] bug in TestRegionServerMetrics.testNumReadsAndWrites']
# ['f60b8246e7', 'HBASE-7588 Fix two findbugs warning in MemStoreFlusher; REAPPLIED']
# ...
# ['5148146daf', 'HBASE-1938 Make in-memory table scanning faster ; reverted 20110726_1938_MemStore.patch till we figure why it seems to slow tests']
# ['1c6c7b85a3', 'HBASE-1938 Make in-memory table scanning faster ; reverted 20110726_1938_MemStore.patch till we figure why it seems to slow tests']
# ['edf2b7901a', 'HBASE-3904 Reapply patch v6 for TRUNK with addendum']
# ['d37e6eb390', 'HBASE-3904 Reapply patch v6 for TRUNK with addendum']
# ['de919df41a', 'HBASE-3904 Revert patch v6 from TRUNK']
# ['04e89f8ae4', 'HBASE-3904 Revert patch v6 from TRUNK']
# ['ce20845951', "HBASE-3821 'NOT flushing memstore for region' keep on printing for half an hour; I missed a change from this patch"]
# ['0641df92c5', 'Fix broke build; add amendment to hbase-3708 patch spotted by Ted Yu']
# ['7ad1b11e4d', 'Fix broke build; add amendment to hbase-3708 patch spotted by Ted Yu']
# ['9bf60eb011', 'HBASE-3647 Distinguish read and write request count in region -- reversed the patch because missing a file']
# ['bb027e97e1', 'HBASE-3647 Distinguish read and write request count in region -- reversed the patch because missing a file']
# ['371f963359', 'HBASE-3647 Distinguish read and write request count in region -- reversed the patch because missing a file']
# ['bf21c08839', 'HBASE-3647 Distinguish read and write request count in region -- reversed the patch because missing a file']
# ['c222e2b486', 'HBASE-3711 - amend patch to fix compilation error']
# ['0229f2b4f6', 'HBASE-3711 - amend patch to fix compilation error']
# ['ab6dfa0751', 'HBASE-3455. Amend patch - forgot to add TestMemStoreLAB.java']
# ['b1a82279a1', 'HBASE-3311 Addendum patch on HBASE-3298 broke build']
# ['5441eaa83d', 'HBASE-3311 Addendum patch on HBASE-3298 broke build']
# ['ce3139a30e', 'HBASE-3311 Addendum patch on HBASE-3298 broke build']
# ['0f27ee880c', 'HBASE-3114 Test up on hudson are leaking zookeeper ensemble']
# ['13d8b4fdad', 'HBASE-3114 Test up on hudson are leaking zookeeper ensemble']
# ['924f28e5c3', 'HBASE-3098 TestMetaReaderEditor is broken in TRUNK; hangs; part2 of the patch']
# ['9ebe296b7f', 'HBASE-3098 TestMetaReaderEditor is broken in TRUNK; hangs; part2 of the patch']
# ['74542880d7', 'CLOUDERA-BUILD. HBase running on secure hadoop, temporary patch.']
# ['cec5868f8d', "HBASE-2467. Concurrent flushers in HLog sync using HDFS-895 (JD's v3 patch)"]
# ['b70e4b83c1', 'HBASE-3063 TestThriftServer failing in TRUNK; trying this patch to see if it helps']
# ['937ede3133', 'HBASE-3063 TestThriftServer failing in TRUNK; trying this patch to see if it helps']
# ['1c2775af44', "HBASE-3008 Memstore.updateColumnValue passes wrong flag to heapSizeChange HBASE-3035 Bandaid for HBASE-2990 HBASE-2643 Figure how to deal with eof splitting logs HBASE-2941 port HADOOP-6713 - threading scalability for RPC reads - to HBase HBASE-3006 Reading compressed HFile blocks causes way too many DFS RPC calls severly impacting performance HBASE-2989 [replication] RSM won't cleanup after locking if 0 peers HBASE-2992 [replication] MalformedObjectNameException in ReplicationMetrics HBASE-3034 Revert the regions assignment part of HBASE-2694 (and pals) for 0.89 HBASE-3033 [replication] ReplicationSink.replicateEntries improvements HBASE-2997 Performance fixes - profiler driven HBASE-2889 Tool to look at HLogs -- parse and tail -f (patch #2 only)"]
# ['4e64653921', "HBASE-3008 Memstore.updateColumnValue passes wrong flag to heapSizeChange HBASE-3035 Bandaid for HBASE-2990 HBASE-2643 Figure how to deal with eof splitting logs HBASE-2941 port HADOOP-6713 - threading scalability for RPC reads - to HBase HBASE-3006 Reading compressed HFile blocks causes way too many DFS RPC calls severly impacting performance HBASE-2989 [replication] RSM won't cleanup after locking if 0 peers HBASE-2992 [replication] MalformedObjectNameException in ReplicationMetrics HBASE-3034 Revert the regions assignment part of HBASE-2694 (and pals) for 0.89 HBASE-3033 [replication] ReplicationSink.replicateEntries improvements HBASE-2997 Performance fixes - profiler driven HBASE-2889 Tool to look at HLogs -- parse and tail -f (patch #2 only)"]
# ['1d58b8a3bf', 'HBASE-2870 Add Backup CLI Option to HMaster; repair of damage done to this patch by 2692 master rewrite']
# ['1d7279c140', 'HBASE-2870 Add Backup CLI Option to HMaster; repair of damage done to this patch by 2692 master rewrite']
# ['f521309532', 'HBASE-2692 Master rewrite and cleanup for 0.90']
# ['be4c32c28d', 'HBASE-2692 Master rewrite and cleanup for 0.90']
# ['8164552e35', "Fixup of 'Getting Started' to point at CHANGES.txt of 0.20-append to get list of patches"]
# ['4684743292', "Fixup of 'Getting Started' to point at CHANGES.txt of 0.20-append to get list of patches"]
# ['edf052f87a', 'HBASE-2835 Update hadoop jar to head of branch-0.20-append to catch three added patches']
# ['dafd64e13b', 'HBASE-2835 Update hadoop jar to head of branch-0.20-append to catch three added patches']
# ['6a132e92c0', "HBASE-2344 InfoServer and hence HBase Master doesn't fully start if you have HADOOP-6151 patch"]
# ['7cd91ad2ee', 'Amend documentation around hdfs-630 recommended patch']
# ['538841b788', 'Amend documentation around hdfs-630 recommended patch']
# ['394c64ddcc', 'HBASE-1977 Add ts and allow setting VERSIONS when scanning in shell; back out a piece of this patch... we already had timestamp']
# ['947b62178d', 'HBASE-1977 Add ts and allow setting VERSIONS when scanning in shell; back out a piece of this patch... we already had timestamp']
# ['741d967228', 'HBASE-1859 Misc shell fixes patch']
# ['6d0dddcc00', 'HBASE-1859 Misc shell fixes patch']
# ['41558cf59d', 'HBASE-1859 Misc shell fixes patch']
# ['61e7bc7fcf', "HBASE-1818 HFile code review and refinement -- reversing patch... doesn't pass tests"]
# ['0593245163', "HBASE-1818 HFile code review and refinement -- reversing patch... doesn't pass tests"]
# ['7ce8627988', 'undo accidental mis-application of patch hunk']
# ['a6e48260bb', 'add missing hunk from patch to HBaseRPC.java']
# ['bf9ac84827', 'HBASE-1058 Prevent runaway compactions; patch 1058-2-v1']
# ['1f900dca17', 'HBASE-1058 Prevent runaway compactions; patch 1058-2-v1']
# ['816225f395', 'HBASE-1058 Prevent runaway compactions; patch 1058-2-v1']
# ['24d739c305', 'HBASE-1318 Thrift server doesnt know about atomicIncrement -- undoing this commit because it mistakenly included hbase-1336 patch']
# ['f1bc7a2592', 'HBASE-1318 Thrift server doesnt know about atomicIncrement -- undoing this commit because it mistakenly included hbase-1336 patch']
# ['20cab11400', 'HBASE-1229 Apply HADOOP-5369 to HBase MapFile -- Latest version of Ben patch']
# ['4872cd1ab1', 'HBASE-1155 - commit patched Hadoop jars, add patches to SequenceFile and HLog']
# ['8b53dd0396', 'HBASE-1121 Cluster confused about where -ROOT- is. This patch fixes "re-finding" the root region.']
# ['efe5944279', 'HBASE-1121 Cluster confused about where -ROOT- is. This patch fixes "re-finding" the root region.']
# ['127491e583', 'HBASE-1098 IllegalStateException: Cannot set a region to be closed it it was not already marked as closing; debugging patch']
# ['8836adbf52', 'HBASE-1098 IllegalStateException: Cannot set a region to be closed it it was not already marked as closing; debugging patch']
# ['e0e6435f1c', 'merge up to latest trunk (rev 729349) plus patch for 1062']
# ['9d0c0d2449', "merge up to trunk (rev 728460), plus jimk's patch for 543"]
# ['f78f944026', 'HBASE-984 Fix javadoc warnings This is probably the first of several patches to fix javadoc warnings. Jira issue will remain open until we create the release candidate.']
# ['963c1104dd', 'HBASE-984 Fix javadoc warnings This is probably the first of several patches to fix javadoc warnings. Jira issue will remain open until we create the release candidate.']
# ['5e3815484c', 'HBASE-919 Master and Region Server need to provide root region location if they are using HTable']
# ['a1a9372d19', 'HBASE-919 Master and Region Server need to provide root region location if they are using HTable']
# ['681367f310', 'HBASE-826 Add in rest of hbase-826 -- missed HStore edits; remove method patch added twice']
# ['4456a8f5cf', "HBASE-808,809 MAX_VERSIONS not respected, and Deletall doesn't and inserts; fix misapplication of patch"]
# ['aabc02c44b', "HBASE-808,809 MAX_VERSIONS not respected, and Deletall doesn't and inserts; fix misapplication of patch"]
# ['4c2a6f66f1', "HBASE-808,809 MAX_VERSIONS not respected, and Deletall doesn't and inserts; fix misapplication of patch"]
# ['20165cc25c', 'HBASE-798 Add missing classes: UnknownRowLockException and RowLock which were present in previous versions of the patches for this issue, but not in the version that was committed. Also fix a number of compilation problems that were introduced by patch.']
# ['5fe6a36e1c', 'HBASE-798 Add missing classes: UnknownRowLockException and RowLock which were present in previous versions of the patches for this issue, but not in the version that was committed. Also fix a number of compilation problems that were introduced by patch.']
# ['165e2ed915', 'Fix deadlock caused by HBASE-790 patch']
# ['a9aef2181d', 'Fix deadlock caused by HBASE-790 patch']
# ['92bd62bf58', 'Fix overlogging; part of HBASE-792 patch']
# ['e2a146d694', 'Fix overlogging; part of HBASE-792 patch']
# ['80fa33698f', 'HBASE-613 Timestamp-anchored scanning fails to find all records HBASE-681 NPE in Memcache']
# ['f02a98da07', 'HBASE-613 Timestamp-anchored scanning fails to find all records HBASE-681 NPE in Memcache']
# ['99fc06705d', "HBASE-23 Fix bug introduced by my edits of JDC's patch"]
# ['1336a981e2', "HBASE-23 Fix bug introduced by my edits of JDC's patch"]
# ['cffa3a254e', 'HBASE-586 HRegion runs HStore memcache snapshotting -- fix it so only HStore knows about workings of memcache']
# ['32ce612048', 'HBASE-586 HRegion runs HStore memcache snapshotting -- fix it so only HStore knows about workings of memcache']
# ['da595915a9', 'HBASE-500 Regionserver stuck on exit']
# ['a00fd30d8a', 'HBASE-554 Added attribution for patch. Thanks Clint and thanks David for testing it!']
# ['f15048d4d0', 'HBASE-505 Region assignments should never time out so long as the region server reports that it is processing the open request']
# ['b104b3235b', 'HBASE-505 Region assignments should never time out so long as the region server reports that it is processing the open request']
# ['90e3cb13ca', 'HBASE-505 Region assignments should never time out so long as the region server reports that it is processing the open request']
# ['0f6c5e0ae8', 'HBASE-418 Move HMaster and related classes into master package Part 2 (Previous patch moved these classes but turns out new version also had changes in them -- adding these now).']
# ['559cda0ad0', 'HBASE-418 Move HMaster and related classes into master package Part 2 (Previous patch moved these classes but turns out new version also had changes in them -- adding these now).']
# ['bfce24ce25', 'HBASE-35 Fix javadoc warnings introduced by patch']
# ['4cf6763f2c', 'HBASE-35 Fix javadoc warnings introduced by patch']
# ['9a88155bf0', '2008/02/04 HBase is now a subproject of Hadoop. The first HBase release as a subproject will be release 0.1.0 which will be equivalent to the version of HBase included in Hadoop 0.16.0. In order to accomplish this, the HBase portion of HBASE-288 (formerly HADOOP-1398) has been backed out. Once 0.1.0 is frozen (depending mostly on changes to infrastructure due to becoming a sub project instead of a contrib project), this patch will re-appear on HBase trunk.']
# ['5c866c070e', '2008/02/04 HBase is now a subproject of Hadoop. The first HBase release as a subproject will be release 0.1.0 which will be equivalent to the version of HBase included in Hadoop 0.16.0. In order to accomplish this, the HBase portion of HBASE-288 (formerly HADOOP-1398) has been backed out. Once 0.1.0 is frozen (depending mostly on changes to infrastructure due to becoming a sub project instead of a contrib project), this patch will re-appear on HBase trunk.']
# ['7d09aec4f8', 'HADOOP-2598 Remove chatty debug logging from 2443 patch']
# ['7724b6beb6', 'HADOOP-2598 Remove chatty debug logging from 2443 patch']
# ['470b3a3200', 'HADOOP-2389 Provide multiple language bindings for HBase (Thrift) Actual code (first commit added thrift lib so this patch would build).']
# ['f8e3bf044b', 'HADOOP-2389 Provide multiple language bindings for HBase (Thrift) Actual code (first commit added thrift lib so this patch would build).']
# ['db34c56319', 'HADOOP-2389 Provide multiple language bindings for HBase (Thrift) Added thrift jar in advance so HADOOP-2389 patch will build on hudson.']
# ['9e67e34aa8', 'HADOOP-2389 Provide multiple language bindings for HBase (Thrift) Added thrift jar in advance so HADOOP-2389 patch will build on hudson.']
# ['3ac4baf9b6', "HADOOP-1550 No means of deleting a'row' I forgot to add this file when I commited patch for HADOOP-1550"]
# ['c56b69a806', "HADOOP-1550 No means of deleting a'row' I forgot to add this file when I commited patch for HADOOP-1550"]
# ['b9abf5c728', 'HADOOP-2289 Useless efforts of looking for the non-existant table in select command. FIx javadoc warning introduced by commit of HADOOP-2289 patch (odd -- it got a +1 on javadoc from hudson). M CreateCommand.java']
# ['84dac79e48', 'HADOOP-2289 Useless efforts of looking for the non-existant table in select command. FIx javadoc warning introduced by commit of HADOOP-2289 patch (odd -- it got a +1 on javadoc from hudson). M CreateCommand.java']
# ['8a5b3da292', 'HADOOP-2139 (phase 1) Increase parallelism in region servers']
# ['37a9e4f121', 'HADOOP-2139 (phase 1) Increase parallelism in region servers']
# ['e92a4023d5', 'HADOOP-2083 TestTableIndex failed in patch build #970 and #956']
# ['55e348b2f6', 'HADOOP-2083 TestTableIndex failed in patch build #970 and #956']
# ['920c6b2021', 'HADOOP-2029 TestLogRolling fails too often in patch and nightlies 3rd commit against this issue.']
# ['f8ae1ba85c', 'HADOOP-2029 TestLogRolling fails too often in patch and nightlies 3rd commit against this issue.']
# ['8faa2ea9c6', 'HADOOP-2038 TestCleanRegionServerExit failed in patch build #927']
# ['7736858d5a', 'HADOOP-2038 TestCleanRegionServerExit failed in patch build #927']
# ['8b387823be', 'HADOOP-2029 TestLogRolling fails too often in patch and nightlies This is second commit against this issue.']
# ['fd2d121ca5', 'HADOOP-2029 TestLogRolling fails too often in patch and nightlies This is second commit against this issue.']
# ['642dd4294e', 'HADOOP-2029 TestLogRolling fails too often in patch and nightlies']
# ['087723eb64', 'HADOOP-2029 TestLogRolling fails too often in patch and nightlies']
# ['c9f105acd5', 'HADOOP-2017 TestRegionServerAbort failure in patch build #903 and nightly #266']
# ['5874e836e3', 'HADOOP-2017 TestRegionServerAbort failure in patch build #903 and nightly #266']
# ['af8131b86d', 'HADOOP-1990 Regression test instability affects nightly and patch builds']
# ['3d3f78e4eb', 'HADOOP-1990 Regression test instability affects nightly and patch builds']
# ['6aab1c914f', 'HADOOP-1913 Build a Lucene index on an HBase table AM lucene-core-2.2.0.jar Add jar dependency needed by patch about to be submitted to hudson.']
# ['e54c5d199c', 'HADOOP-1913 Build a Lucene index on an HBase table AM lucene-core-2.2.0.jar Add jar dependency needed by patch about to be submitted to hudson.']
# ['6f42c1f60f', 'HADOOP-1375 a simple parser for hbase A lib/jline-0.9.91.jar Add required library before trying hadoop-1375 against hudson (patch will fail if this lib is not in place first).']
# ['9f7127b2a0', 'HADOOP-1375 a simple parser for hbase A lib/jline-0.9.91.jar Add required library before trying hadoop-1375 against hudson (patch will fail if this lib is not in place first).']
# ['a6b7be60d6', 'Hadoop-1384']
# ['9ed00df9d0', 'Hadoop-1384']
# ['ec9a568764', 'HADOOP-1282. Omnibus HBase patch. Improved tests and configuration. Contributed by Jim Kellerman.']
# ['3c98f70cc6', 'HADOOP-1282. Omnibus HBase patch. Improved tests and configuration. Contributed by Jim Kellerman.']

# %% [markdown]
# # Capturing bug ids

# %%
#Capturing bug ids which are identified as bug links in the log messages
commitbugs = []
buglinks = []

for xx in range(0,len(com_logs)):
    tmp = []
    comm = com_logs[xx].split()
    splitres = (str(comm[1:]))
    letter = re.findall(r"HBASE+[-][0-9]+", splitres)
    if letter != []:
        commitbugs.extend(letter)
    else:
        pass

commitbugs = set(commitbugs)
for p,q in enumerate(commitbugs):
    buglinks.append(q)
buglinks = sorted(buglinks, reverse=True)
print (buglinks)
print ("\nNumber of bug id: " + str(len(buglinks)))
# Out:
# ['HBASE-9991', 'HBASE-998', 'HBASE-9972', 'HBASE-9971', 'HBASE-9961', 'HBASE-9958', 'HBASE-9930', 'HBASE-9921', 'HBASE-9920', 'HBASE-9914', 'HBASE-9908', 'HBASE-9896', 'HBASE-9893', 'HBASE-987', 'HBASE-9856', 'HBASE-985', 'HBASE-9843', 'HBASE-984', 'HBASE-9836', 'HBASE-9815', 'HBASE-9786', 'HBASE-9778', 'HBASE-977', 'HBASE-9747', 'HBASE-9745', 'HBASE-9704', 'HBASE-9703', 'HBASE-9698', 'HBASE-968', 'HBASE-9658', 'HBASE-9639', 'HBASE-9534', 'HBASE-9519', 'HBASE-9426', 'HBASE-9415', 'HBASE-9342', 'HBASE-930', 'HBASE-9295', 'HBASE-927', 'HBASE-9238', 'HBASE-9232', 'HBASE-9219', 'HBASE-921', 'HBASE-9205', 'HBASE-919', 'HBASE-9165', 'HBASE-9164', 'HBASE-9158', 'HBASE-9151', 'HBASE-9128', 'HBASE-9115', 'HBASE-9114', 'HBASE-9102', 'HBASE-9085', 'HBASE-9075', 'HBASE-9064', 'HBASE-9061', 'HBASE-9029', 'HBASE-9003', 'HBASE-9001', 'HBASE-9000', 'HBASE-8960', 'HBASE-8942', 'HBASE-8934', 'HBASE-8930', 'HBASE-8919', 'HBASE-8917', 'HBASE-887', 'HBASE-8856', 'HBASE-883', 'HBASE-881', 'HBASE-8809', 'HBASE-8798', 'HBASE-8767', 'HBASE-8706', 'HBASE-8703', 'HBASE-8685', 'HBASE-8664', 'HBASE-8657', 'HBASE-8627', 'HBASE-8615', 'HBASE-8569', 'HBASE-8557', 'HBASE-8556', 'HBASE-8552', 'HBASE-8543', 'HBASE-8532', 'HBASE-8521', 'HBASE-8519', 'HBASE-8500', 'HBASE-8467', 'HBASE-8409', 'HBASE-8381', 'HBASE-8372', 'HBASE-8347', 'HBASE-834', 'HBASE-8320', 'HBASE-8307', 'HBASE-830', 'HBASE-826', 'HBASE-8259', 'HBASE-8228', 'HBASE-8225', 'HBASE-8223', 'HBASE-8216', 'HBASE-8207', 'HBASE-8206', 'HBASE-8185', 'HBASE-8125', 'HBASE-8119', 'HBASE-8114', 'HBASE-8111', 'HBASE-811', 'HBASE-8101', 'HBASE-8085', 'HBASE-808', 'HBASE-8067', 'HBASE-8062', 'HBASE-8059', 'HBASE-8058', 'HBASE-8050', 'HBASE-8044', 'HBASE-803', 'HBASE-798', 'HBASE-7967', 'HBASE-7966', 'HBASE-7953', 'HBASE-7939', 'HBASE-7936', 'HBASE-7930', 'HBASE-7929', 'HBASE-7920', 'HBASE-792', 'HBASE-7914', 'HBASE-7912', 'HBASE-7910', 'HBASE-790', 'HBASE-7878', 'HBASE-7852', 'HBASE-785', 'HBASE-7823', 'HBASE-7817', 'HBASE-7801', 'HBASE-7770', 'HBASE-7748', 'HBASE-7725', 'HBASE-7703', 'HBASE-7699', 'HBASE-7682', 'HBASE-7669', 'HBASE-7662', 'HBASE-7601', 'HBASE-7595', 'HBASE-7588', 'HBASE-7587', 'HBASE-7586', 'HBASE-7547', 'HBASE-7521', 'HBASE-7517', 'HBASE-7512', 'HBASE-7508', 'HBASE-7491', 'HBASE-7443', 'HBASE-7435', 'HBASE-7427', 'HBASE-7417', 'HBASE-7416', 'HBASE-7390', 'HBASE-7360', 'HBASE-7354', 'HBASE-7349', 'HBASE-7276', 'HBASE-7275', 'HBASE-7213', 'HBASE-7198', 'HBASE-7193', 'HBASE-7162', 'HBASE-7126', 'HBASE-7110', 'HBASE-7106', 'HBASE-7099', 'HBASE-7083', 'HBASE-7036', 'HBASE-7002', 'HBASE-7', 'HBASE-6991', 'HBASE-6980', 'HBASE-697', 'HBASE-6967', 'HBASE-6943', 'HBASE-6928', 'HBASE-6923', 'HBASE-6921', 'HBASE-6920', 'HBASE-6918', 'HBASE-6890', 'HBASE-6871', 'HBASE-6870', 'HBASE-6858', 'HBASE-6852', 'HBASE-6848', 'HBASE-6846', 'HBASE-6838', 'HBASE-681', 'HBASE-6807', 'HBASE-6786', 'HBASE-6775', 'HBASE-6770', 'HBASE-6748', 'HBASE-6741', 'HBASE-6728', 'HBASE-6710', 'HBASE-6697', 'HBASE-6672', 'HBASE-6643', 'HBASE-6629', 'HBASE-6619', 'HBASE-6590', 'HBASE-6583', 'HBASE-656', 'HBASE-6508', 'HBASE-650', 'HBASE-649', 'HBASE-6460', 'HBASE-6421', 'HBASE-6405', 'HBASE-6389', 'HBASE-6388', 'HBASE-6377', 'HBASE-6368', 'HBASE-6363', 'HBASE-6340', 'HBASE-6330', 'HBASE-6284', 'HBASE-6276', 'HBASE-6260', 'HBASE-6215', 'HBASE-6200', 'HBASE-6181', 'HBASE-6170', 'HBASE-6164', 'HBASE-6138', 'HBASE-613', 'HBASE-6123', 'HBASE-6121', 'HBASE-6112', 'HBASE-6110', 'HBASE-6088', 'HBASE-6064', 'HBASE-6060', 'HBASE-6059', 'HBASE-6005', 'HBASE-6004', 'HBASE-5974', 'HBASE-5919', 'HBASE-588', 'HBASE-5869', 'HBASE-586', 'HBASE-5825', 'HBASE-5824', 'HBASE-5809', 'HBASE-5805', 'HBASE-5799', 'HBASE-5781', 'HBASE-5763', 'HBASE-5760', 'HBASE-576', 'HBASE-5744', 'HBASE-5743', 'HBASE-5730', 'HBASE-5727', 'HBASE-5700', 'HBASE-5684', 'HBASE-5654', 'HBASE-5653', 'HBASE-5652', 'HBASE-5645', 'HBASE-5644', 'HBASE-5642', 'HBASE-5611', 'HBASE-5598', 'HBASE-5597', 'HBASE-5596', 'HBASE-5584', 'HBASE-5577', 'HBASE-5567', 'HBASE-5566', 'HBASE-5562', 'H ...
#
# Number of bug id: 1205

# %%
#Synchronizing the bug link with the bug report from JIRA ITS database
errorlinks = []
id_type = []
for a,b in enumerate(buglinks):
    link = "https://issues.apache.org/jira/browse/" + b
    sys.stdout.write("\r%i " %(a+1) + "Extracting: " + b)
    sys.stdout.flush()
    try:
        page = urllib.request.urlopen(link)
        soup = BeautifulSoup(page, 'html.parser')
        types = soup.find('span', attrs={'id':'type-val'}).text.replace("\n",'').replace(" ",'').split(",")
        types = sorted(types)
        types.insert(0, b)
        id_type.append(types)
    except:
        errorlinks.append(b)

print("\nExtraction has been completed.")
# Out:
# 1205 Extracting: HBASE-10004
# Extraction has been completed.

# %%
#Finding out if there were any error from the sync process above
type_of_id = id_type
errorlinks
# Out:
# ['HBASE-9778', 'HBASE-3015', 'HBASE-15195', 'HBASE-15118']

# %%
#Resync for the error bug ids identified
error_links = []
for a,b in enumerate(errorlinks):
    link = "https://issues.apache.org/jira/browse/" + b
    sys.stdout.write("\r%i " %(a+1) + "Extracting: " + b)
    sys.stdout.flush()
    try:
        page = urllib.request.urlopen(link)
        soup = BeautifulSoup(page, 'html.parser')
        types = soup.find('span', attrs={'id':'type-val'}).text.replace("\n",'').replace(" ",'').split(",")
        types = sorted(types)
        types.insert(0, b)
        type_of_id.append(types)
    except:
        error_links.append(b)
# Out:
# 4 Extracting: HBASE-15118

# %%
error_links
# Out:
# []

# %%
bug_links = []
for d, types in enumerate (type_of_id):
    if types[1] == 'Bug':
        bug_links.append(types[0])

print ("Number of bug id: " + str(len(bug_links)))
print (bug_links)
# Out:
# Number of bug id: 624
# ['HBASE-9971', 'HBASE-9961', 'HBASE-9958', 'HBASE-9908', 'HBASE-9893', 'HBASE-9856', 'HBASE-985', 'HBASE-9843', 'HBASE-984', 'HBASE-9786', 'HBASE-977', 'HBASE-9747', 'HBASE-9745', 'HBASE-9704', 'HBASE-9698', 'HBASE-968', 'HBASE-9639', 'HBASE-9534', 'HBASE-9519', 'HBASE-9415', 'HBASE-930', 'HBASE-927', 'HBASE-9238', 'HBASE-9232', 'HBASE-9219', 'HBASE-9205', 'HBASE-9164', 'HBASE-9158', 'HBASE-9151', 'HBASE-9115', 'HBASE-9114', 'HBASE-9085', 'HBASE-9003', 'HBASE-9001', 'HBASE-8942', 'HBASE-8930', 'HBASE-8919', 'HBASE-8917', 'HBASE-8856', 'HBASE-881', 'HBASE-8798', 'HBASE-8706', 'HBASE-8664', 'HBASE-8627', 'HBASE-8615', 'HBASE-8532', 'HBASE-8521', 'HBASE-8519', 'HBASE-8500', 'HBASE-8467', 'HBASE-830', 'HBASE-826', 'HBASE-8259', 'HBASE-8225', 'HBASE-8223', 'HBASE-8216', 'HBASE-8207', 'HBASE-8206', 'HBASE-8125', 'HBASE-8119', 'HBASE-8111', 'HBASE-811', 'HBASE-8085', 'HBASE-808', 'HBASE-8067', 'HBASE-8062', 'HBASE-8058', 'HBASE-8050', 'HBASE-8044', 'HBASE-7966', 'HBASE-7953', 'HBASE-7920', 'HBASE-792', 'HBASE-7914', 'HBASE-790', 'HBASE-7878', 'HBASE-7852', 'HBASE-7817', 'HBASE-7725', 'HBASE-7682', 'HBASE-7669', 'HBASE-7601', 'HBASE-7595', 'HBASE-7588', 'HBASE-7587', 'HBASE-7586', 'HBASE-7521', 'HBASE-7517', 'HBASE-7508', 'HBASE-7491', 'HBASE-7443', 'HBASE-7435', 'HBASE-7417', 'HBASE-7390', 'HBASE-7275', 'HBASE-7198', 'HBASE-7083', 'HBASE-7002', 'HBASE-6991', 'HBASE-697', 'HBASE-6943', 'HBASE-6928', 'HBASE-6920', 'HBASE-6918', 'HBASE-6871', 'HBASE-6858', 'HBASE-6846', 'HBASE-6838', 'HBASE-681', 'HBASE-6748', 'HBASE-6741', 'HBASE-6728', 'HBASE-6710', 'HBASE-6697', 'HBASE-6619', 'HBASE-6590', 'HBASE-6583', 'HBASE-656', 'HBASE-649', 'HBASE-6460', 'HBASE-6421', 'HBASE-6389', 'HBASE-6388', 'HBASE-6377', 'HBASE-6368', 'HBASE-6340', 'HBASE-6284', 'HBASE-6276', 'HBASE-6200', 'HBASE-6164', 'HBASE-6138', 'HBASE-613', 'HBASE-6123', 'HBASE-6121', 'HBASE-6112', 'HBASE-6110', 'HBASE-6088', 'HBASE-6060', 'HBASE-6059', 'HBASE-5974', 'HBASE-5919', 'HBASE-588', 'HBASE-586', 'HBASE-5825', 'HBASE-5824', 'HBASE-5805', 'HBASE-5799', 'HBASE-5781', 'HBASE-5763', 'HBASE-5744', 'HBASE-5743', 'HBASE-5730', 'HBASE-5727', 'HBASE-5700', 'HBASE-5611', 'HBASE-5598', 'HBASE-5597', 'HBASE-5596', 'HBASE-5567', 'HBASE-5566', 'HBASE-5562', 'HBASE-554', 'HBASE-552', 'HBASE-5499', 'HBASE-5470', 'HBASE-5437', 'HBASE-5387', 'HBASE-532', 'HBASE-5286', 'HBASE-5204', 'HBASE-5137', 'HBASE-5104', 'HBASE-5085', 'HBASE-5081', 'HBASE-5077', 'HBASE-505', 'HBASE-5029', 'HBASE-501', 'HBASE-500', 'HBASE-4997', 'HBASE-4927', 'HBASE-4890', 'HBASE-4883', 'HBASE-4823', 'HBASE-4799', 'HBASE-4758', 'HBASE-4722', 'HBASE-4686', 'HBASE-4645', 'HBASE-4589', 'HBASE-4540', 'HBASE-4539', 'HBASE-4531', 'HBASE-4505', 'HBASE-4400', 'HBASE-4367', 'HBASE-4350', 'HBASE-4153', 'HBASE-4150', 'HBASE-4149', 'HBASE-4138', 'HBASE-4078', 'HBASE-4075', 'HBASE-4020', 'HBASE-4005', 'HBASE-3987', 'HBASE-3979', 'HBASE-3939', 'HBASE-3912', 'HBASE-3904', 'HBASE-3872', 'HBASE-3832', 'HBASE-3821', 'HBASE-3819', 'HBASE-3813', 'HBASE-3793', 'HBASE-3762', 'HBASE-3750', 'HBASE-3741', 'HBASE-3708', 'HBASE-3690', 'HBASE-3674', 'HBASE-3671', 'HBASE-3669', 'HBASE-3636', 'HBASE-3627', 'HBASE-3622', 'HBASE-3515', 'HBASE-3481', 'HBASE-3421', 'HBASE-3416', 'HBASE-3374', 'HBASE-3337', 'HBASE-3315', 'HBASE-3311', 'HBASE-3298', 'HBASE-3275', 'HBASE-3264', 'HBASE-3241', 'HBASE-3239', 'HBASE-3232', 'HBASE-3199', 'HBASE-3183', 'HBASE-3179', 'HBASE-3159', 'HBASE-3114', 'HBASE-3113', 'HBASE-3111', 'HBASE-3110', 'HBASE-3100', 'HBASE-3098', 'HBASE-3081', 'HBASE-3074', 'HBASE-3073', 'HBASE-3065', 'HBASE-3063', 'HBASE-3060', 'HBASE-3039', 'HBASE-3038', 'HBASE-3008', 'HBASE-3006', 'HBASE-2997', 'HBASE-2992', 'HBASE-2990', 'HBASE-2989', 'HBASE-2985', 'HBASE-2944', 'HBASE-2941', 'HBASE-2928', 'HBASE-2927', 'HBASE-2889', 'HBASE-288', 'HBASE-2815', 'HBASE-2806', 'HBASE-2781', 'HBASE-2763', 'HBASE-2755', 'HBASE-2740', 'HBASE-2703', 'HBASE-2669', 'HBASE-2643', 'HBASE-2616', 'HBASE-2606', 'HBASE-2581', 'HBASE-2562', 'HBASE-2558', 'HBASE-2513', 'HBASE-2 ...

# %%
with open (analyze_dir + "01_code_document/txt_files/candidate_bug_links.txt", mode="wt", encoding="utf-8") as myfile:
    myfile.write('\n'.join(bug_links))
print ("File candidate_bug_links.txt has been created")
# Out:
# File candidate_bug_links.txt has been created

# %% [markdown]
# # Extracting logs related to bug links

# %%
com_log = []
for no, bug_link in enumerate(bug_links):
    sys.stdout.write("\r%i " %(no+1) + "Extracting bug id: " + bug_link)
    sys.stdout.flush()
    git_cmd = "git log --all --oneline | grep -w '" + bug_link + "'"
    temp = (str(execute_command(git_cmd, repository)).replace("b'",'').replace('b"','').replace('(','',1).split("\\n"))[:-1]

    com_log.append(temp)

print ("\n")
for item in com_log:
    print(item)
# Out:
# 624 Extracting bug id: HBASE-15195
#
# ['8a6291a896 HBASE-9971 Port part of HBASE-9958 to 0.94 - change lock scope in locateRegion (original patch by Nicolas Liochon)']
# ['1e7fdb06b2 HBASE-9961 [WINDOWS] Multicast should bind to local address. ADDENDUM to fix javadoc warning', '560f000424 HBASE-9961 [WINDOWS] Multicast should bind to local address. ADDENDUM to fix javadoc warning', 'e5946ba799 HBASE-9961 [WINDOWS] Multicast should bind to local address', '18e018b3d9 HBASE-9961 [WINDOWS] Multicast should bind to local address']
# ['8a6291a896 HBASE-9971 Port part of HBASE-9958 to 0.94 - change lock scope in locateRegion (original patch by Nicolas Liochon)', '4b84160b37 HBASE-9958 Remove some array copy, change lock scope in locateRegion', 'c5a3048fec HBASE-9958 Remove some array copy, change lock scope in locateRegion']
# ['f224e4721f HBASE-9908 [WINDOWS] Fix filesystem / classloader related unit tests - ADDENDUM patch to fix TestImportTsv', '16b799dae5 HBASE-9908 [WINDOWS] Fix filesystem / classloader related unit tests - ADDENDUM patch to fix TestImportTsv', '61120fb62c HBASE-9908 [WINDOWS] Fix filesystem / classloader related unit tests', 'ff78f217fa HBASE-9908 [WINDOWS] Fix filesystem / classloader related unit tests']
# ['c5fc5b993e HBASE-9893 Incorrect assert condition in OrderedBytes decoding', 'da89846cf7 HBASE-9893 Incorrect assert condition in OrderedBytes decoding']
# ['13e9eda3e7 HBASE-9856 Fix some findbugs Performance Warnings']
# ['e3659aa246 HBASE-985 fix javadoc warnings', '894c99bdb3 HBASE-985 fix javadoc warnings']
# ['6dd52d7ed3 HBASE-9843 Various fixes in client code', '53bb2f6be7 HBASE-9843 Various fixes in client code']
# ['f78f944026 HBASE-984   Fix javadoc warnings This is probably the first of several patches to fix javadoc warnings. Jira issue will remain open until we create the release candidate.', '963c1104dd HBASE-984   Fix javadoc warnings This is probably the first of several patches to fix javadoc warnings. Jira issue will remain open until we create the release candidate.']
# ['230cb08611 HBASE-9786 hbck -metaonly incorrectly reports inconsistent regions after HBASE-9698 fix', '6d0eade8b6 HBASE-9786 hbck -metaonly incorrectly reports inconsistent regions after HBASE-9698 fix']
# ['5418547132 HBASE-977 Arcane HStoreKey comparator bug', '1b49c9b6c4 HBASE-977 Arcane HStoreKey comparator bug']
# ['201c67a7d8 HBASE-9747 added test (Aditya Kishore)', '3f496372bf HBASE-9747 added test (Aditya Kishore)', 'b4df85d6b0 HBASE-9747 added test (Aditya Kishore)', 'fc15e1ae39 HBASE-9747 PrefixFilter with OR condition gives wrong results (Aditya Kishore)', 'a2a3071256 HBASE-9747 PrefixFilter with OR condition gives wrong results (Aditya Kishore)', 'e7dfc21d4f HBASE-9747 PrefixFilter with OR condition gives wrong results (Aditya Kishore)']
# ['3d37252a32 HBASE-11496 HBASE-9745 broke cygwin CLASSPATH translation (Dave Latham)', '24f150ebbc HBASE-11496 HBASE-9745 broke cygwin CLASSPATH translation (Dave Latham)', '0bd53be747 HBASE-11496 HBASE-9745 broke cygwin CLASSPATH translation (Dave Latham)', '86033abef2 HBASE-11496 HBASE-9745 broke cygwin CLASSPATH translation (Dave Latham)', 'd289eecd2f HBASE-11496 HBASE-9745 broke cygwin CLASSPATH translation (Dave Latham)', '8aec79e00c HBASE-9745 Append HBASE_CLASSPATH to end of Java classpath and use another env var for prefix (Aditya Kishore)', 'bcdd3eba60 HBASE-9745 Append HBASE_CLASSPATH to end of Java classpath and use another env var for prefix', 'ffeb4ab1e3 HBASE-9745 Append HBASE_CLASSPATH to end of Java classpath and use another env var for prefix']
# ['5ff5311da2 [HBASE-9704] HLog profiling will fail to work.', 'abbf77d9cb [HBASE-9704] Fix TestHLog', 'bd01833201 [HBASE-9704] Fix regression from https://phabricator.fb.com/D1363451', '2d7c39e50c [HBASE-9704] Fix TestDrainRegionServer#testDrainAndUndrain', 'a270d1c0a6 [HBASE-9704] Fix TestAdmin#forceSplit', '045ee401b3 [HBASE-9704] Deleting all connections while closing the test utility', '8f76956cc6 [HBASE-9704] Fix TableServers.isNetworkException()', '54b2f547c9 [HBASE-9704] Fixing HTable not being AutoCloseable on Bellatrix', '84ee3d54d4 [HBASE-9704] Optimize tableExists in HBaseAdmin', '94184eb5f8 [HBASE-9704] Create a copy of the conf in ClientLocalScanner since we are modifying it', '90c7d0d614 [HBASE-9704] Set caching in TableServers.testTableOnlineState to the value set in the scan.', 'e475dca13d [HBASE-9704] Fail the client creation if it fails for more than rpcTimeout', 'db972590c6 [HBASE-9704] Catch NPE from TableServers.translateException in batchGet', 'e216445124 [HBASE-9704] Revert the part increment table id in https://phabricator.fb.com/D1291992', 'dcfd369293 [HBASE-9704] RowLockID being positive is not guarenteed in the code; Removing the assert.', 'ccc03f50f5 [HBASE-9704] Do not retry on Hadoop port on exceptions while creating a thrift client', 'ff5a191a7b [HBASE-9704] Increasing the timeout on TestChangingEncoding#testCrazyRandomChanges', '3b95287866 [HBASE-9704] Fix TestRegionFavoredNodes by setting dfs.permissions to false.', '29a28aa05c [HBASE-9704] Fix the namenode port to fix FixTestHLog', 'e6b3951c4d [HBASE-9704] Return Empty string in case when the conf property is non existent on the server', '7d38a444b3 [HBASE-9704] Fix the HTableClientScanner when the scan is done and the region is done.', '1d351abceb [HBASE-9704] Tag TestClientLocalScanner#testLocalScannerWithHardlinks as unstable.', '920e6f1ea5 [HBASE-9704] Handle Call object properly on serverside', '1aa35bf423 [HBASE-9704] Un-tag TestFromClientSide.testResultLimits()']
# ['230cb08611 HBASE-9786 hbck -metaonly incorrectly reports inconsistent regions after HBASE-9698 fix', '6d0eade8b6 HBASE-9786 hbck -metaonly incorrectly reports inconsistent regions after HBASE-9698 fix', '36e4fe8a37 HBASE-9698 HBCK does not handle tables with no regions left', 'a07ef888e1 HBASE-9698 HBCK does not handle tables with no regions left']
# ['ae27a2bc3f Back-out HBASE-968 ... already fixed-- thanks to Do\\xc4\\x9facan G\\xc3\\xbcney', 'bf17c35a8f Back-out HBASE-968 ... already fixed-- thanks to Do\\xc4\\x9facan G\\xc3\\xbcney', 'c18a713726 HBASE-968 ArrayIndexOutOfBoundsException from Cell iterator()', 'f609ddabbc HBASE-968 ArrayIndexOutOfBoundsException from Cell iterator()']
# ['91508fd564 HBASE-9639 SecureBulkLoad dispatches file load requests to all Regions', '00927d1438 HBASE-9639 SecureBulkLoad dispatches file load requests to all Regions']
# ['9f11a9d6b6 HBASE-9658: Addendum to HBASE-9534 to fix 0.96', '5e36c8e6dd HBASE-9534: Short-Circuit Coprocessor HTable access when on the same server (Jesse)', '4793668c1d HBASE-9534: Short-Circuit Coprocessor HTable access when on the same server', '69e56e387d HBASE-9534: Short-Circuit Coprocessor HTable access when on the same server', '6bc48464ca HBASE-9534: Short-Circuit Coprocessor HTable access when on the same server']
# ['29909882ea HBASE-9519 fix NPE in EncodedScannerV2.getFirstKeyInBlock()']
# ['de186bdb7b HBASE-9415  In rpcServer, replicationQueue is initialized with the max queue size instead of the max queue lenght - fix bad commit', 'd0cce3f48d HBASE-9415  In rpcServer, replicationQueue is initialized with the max queue size instead of the max queue lenght', 'd50125a745 HBASE-9415  In rpcServer, replicationQueue is initialized with the max queue size instead of the max queue lenght']
# ["029b37eade HBASE-1132 Can't append to HLog, can't roll log, infinite cycle (another spin on HBASE-930)", "c3c1c8ddbc HBASE-1132 Can't append to HLog, can't roll log, infinite cycle (another spin on HBASE-930)", 'a0cffd6f12 HBASE-930 RegionServer stuck: HLog: Could not append. Requesting close of log java.io.IOException: Could not get block locations. Aborting...; WRONG - not a  java 1.6ism', '50ad3e6d12 HBASE-930 RegionServer stuck: HLog: Could not append. Requesting close of log java.io.IOException: Could not get block locations. Aborting...; WRONG - not a  java 1.6ism', '44b55114b4 HBASE-930 RegionServer stuck: HLog: Could not append. Requesting close of log java.io.IOException: Could not get block locations. Aborting...; WRONG - not a  java 1.6ism', 'f84bf5c8a1 HBASE-930 RegionServer stuck: HLog: Could not append. Requesting close of log java.io.IOException: Could not get block locations. Aborting...; WRONG - not a  java 1.6ism', 'ca07a6f30b HBASE-930 RegionServer stuck: HLog: Could not append. Requesting close of log java.io.IOException: Could not get block locations. Aborting...; WRONG - not a  java 1.6ism', 'a1a6b437e0 HBASE-930 RegionServer stuck: HLog: Could not append. Requesting close of log java.io.IOException: Could not get block locations. Aborting...; WRONG - not a  java 1.6ism', '1f66d54b5d HBASE-930 RegionServer stuck: HLog: Could not append. Requesting close of log java.io.IOException: Could not get block locations. Aborting...; fix java 1.6ism', '8dcc95d790 HBASE-930 RegionServer stuck: HLog: Could not append. Requesting close of log java.io.IOException: Could not get block locations. Aborting...', 'f69423a1d9 HBASE-930 RegionServer stuck: HLog: Could not append. Requesting close of log java.io.IOException: Could not get block locations. Aborting...', '3de18d1763 HBASE-930 RegionServer stuck: HLog: Could not append. Requesting close of log java.io.IOException: Could not get block locations. Aborting...', '06d1a00f83 HBASE-930 RegionServer stuck: HLog: Could not append. Requesting close of log java.io.IOException: Could not get block locations. Aborting...']
# ["cfb9cb2946 HBASE-927   We don't recover if HRS hosting -ROOT-/.META. goes down - (back port from trunk)", "838b238999 HBASE-927   We don't recover if HRS hosting -ROOT-/.META. goes down - (fix bug in createTable which caused tests to fail)", "55d0467c75 HBASE-927   We don't recover if HRS hosting -ROOT-/.META. goes down - (fix bug in createTable which caused tests to fail)", "78165487d9 HBASE-927   We don't recover if HRS hosting -ROOT-/.META. goes down", "9950dd24de HBASE-927   We don't recover if HRS hosting -ROOT-/.META. goes down", '69cbc5d27c HBASE-927 - reverting change to HRegionServer', '748842b131 HBASE-927 - reverting change to HRegionServer', "400e183da5 HBASE-927   We don't recover if HRS hosting -ROOT-/.META. goes down Rather than just check once if we know the root region location, check every time in case it changes.", "ad707c4f60 HBASE-927   We don't recover if HRS hosting -ROOT-/.META. goes down Rather than just check once if we know the root region location, check every time in case it changes."]
# ['0c9f543e1c HBASE-9238 bug in Mutation::getFamilyMap']
# ['7773da0cb4 HBASE-9232 Fix javadoc warning and a few findbugs items', '58ee2bbf24 HBASE-9232 Fix javadoc warning and a few findbugs items']
# ['8a9f332ac0 [HBASE-9219] Fix TestMergeMeta and TestMergeTable']
# ['48c1e7aff3 HBASE-9205 fix javadoc violations', 'f651b6a820 HBASE-9205 fix javadoc violations']
# ['4dd82c9b1c HBASE-9164 Convert List<? extends Cell> anti pattern to List<Cell> pattern', 'd7d0398713 HBASE-9164 Convert List<? extends Cell> anti pattern to List<Cell> pattern']
# ['2c80ed63b0 HBASE-9158 Serious bug in cyclic replication', 'e7657c930b HBASE-9158 Serious bug in cyclic replication', 'bd3acd05d4 HBASE-9158 Serious bug in cyclic replication', '3bc9e2c95c HBASE-9158 Serious bug in cyclic replication']
# ['87c2b88576 HBASE-9151 HBCK cannot fix when meta server znode deleted, this can happen if all region servers stopped and there are no logs to split.', '57a307487f HBASE-9151 HBCK cannot fix when meta server znode deleted, this can happen if all region servers stopped and there are no logs to split.', '8d7ed731a9 HBASE-9151 HBCK cannot fix when meta server znode deleted, this can happen if all region servers stopped and there are no logs to split.']
# ['dc795cca20 HBASE-9115 Addendum (Ted and Lars)', 'd272cf1727 HBASE-9115 Addendum for server side fix (Ted Yu and Lars)', '2036dbb763 HBASE-9115 Addendum for server side fix (Ted Yu and Lars)', 'dfb7778d1a HBASE-9115 HTableInterface.append operation may overwrites values (Ted Yu)', 'b77483f695 HBASE-9115 HTableInterface.append operation may overwrites values (Ted Yu)', '5b89721c1e HBASE-9115 HTableInterface.append operation may overwrites values (Ted Yu)']
# ['9f592ea0b4 [HBASE-9114] Fix TestChangingEncoding']
# ['cea837fa8f HBASE-9085 Integration Tests fails because of bug in teardown phase where the cluster state is not being restored properly. (gautam)', 'ee48ceb820 HBASE-9085 Integration Tests fails because of bug in teardown phase where the cluster state is not being restored properly. (gautam)', '08235fca23 HBASE-9085 Integration Tests fails because of bug in teardown phase where the cluster state is not being restored properly. (gautam)']
# ['b2d1b154bb HBASE-9003 TableMapReduceUtil should not rely on org.apache.hadoop.util.JarFinder#getJar (Esteban Gutierrez)', 'a71dd16a70 HBASE-9003 TableMapReduceUtil should not rely on org.apache.hadoop.util.JarFinder#getJar (Esteban Gutierrez)', 'bf2144fe60 HBASE-9003 Remove the jamon generated classes from the findbugs analysis']
# ['d06aa724b0 HBASE-9001 Add a toString in HTable, fix a log in AssignmentManager', 'ff84a7ae16 HBASE-9001 Add a toString in HTable, fix a log in AssignmentManager', '5dc4727113 HBASE-9001 TestThriftServerCmdLine.testRunThriftServer[0] failed', '2fb6b8b7f3 HBASE-9001 TestThriftServerCmdLine.testRunThriftServer[0] failed']
# ['f14f42ec5b HBASE-8942 DFS errors during a read operation (get/scan), may cause write outliers; REVERT', '5f47f7b6a8 HBASE-8942 DFS errors during a read operation (get/scan), may cause write outliers', '8d3133aa0f HBASE-8942 DFS errors during a read operation (get/scan), may cause write outliers', 'e97a20f8b1 HBASE-8942 DFS errors during a read operation (get/scan), may cause write outliers (Amitanand Aiyer)', 'a30d3f5c23 HBASE-8942 DFS errors during a read operation (get/scan), may cause write outliers', 'b0c406da07 HBASE-8942 DFS errors during a read operation (get/scan), may cause write outliers', '45e7540347 [HBASE-8942] [0.89-fb] fix write outliers caused by errors in DFSClient.read()']
# ['e15deb5cf1 HBASE-8930 REAPPLY with testfix', 'df4784be5a HBASE-8930 REAPPLY with testfix', 'da4167c42b HBASE-8930 REAPPLY with testfix', '6905ddc2e1 HBASE-8930 REVERT due to test issues', '30eb01f496 HBASE-8930 REVERT due to test issues', '633369205f HBASE-8930 REVERT due to test issues', '41b9c58f96 HBASE-8930 Filter evaluates KVs outside requested columns (Vasu Mariyala)', '4f05fc60d5 HBASE-8930 Filter evaluates KVs outside requested columns (Vasu Mariyala)', '813f88a482 HBASE-8930 Add missing file', 'ee1562dace HBASE-8930 Filter evaluates KVs outside requested columns (Vasu Mariyala)']
# ['d390841912 HBASE-8919  TestReplicationQueueFailover (and Compressed) can fail because the recovered queue             gets stuck on ClosedByInterruptException (first try, getting more debug)', '299b39532b HBASE-8919  TestReplicationQueueFailover (and Compressed) can fail because the recovered queue             gets stuck on ClosedByInterruptException (first try, getting more debug)']
# ['da3e3046ad HBASE-8917 Minor cleanup and fixes for POM']
# ['6c43cd988b HBASE-8856 Crash when attempting split with DelimitedKeyPrefixRegionSplitPolicy (Robert Dyer)', 'afca885131 HBASE-8856 Crash when attempting split with DelimitedKeyPrefixRegionSplitPolicy (Robert Dyer)']
# ['428e685b75 HBASE-881   Fixed bug when Master tries to reassign split or offline regions from a dead server', '16a2c45780 HBASE-881   Fixed bug when Master tries to reassign split or offline regions from a dead server', '87102ae59b HBASE-881   Fixed bug when Master tries to reassign split or offline regions from a dead server']
# ['9ccf16db51 HBASE-8798 Fix a minor bug in shell command with clone_snapshot table error']
# ['bcf89528dc HBASE-9029 Backport HBASE-8706 Some improvement in snapshot to 0.94 (Jerry He, original patch by Matteo)', '8bb177d37f HBASE-8706 Some improvement in snapshot', '9763240f35 HBASE-8706 Some improvement in snapshot (binlijin)', 'ba8801c2ff HBASE-8706 Some improvement in snapshot (binlijin)']
# ['ed65f9bb6e HBASE-8664 Small fix ups for memory size outputs in UI', 'd6becac229 HBASE-8664 Small fix ups for memory size outputs in UI']
# ['f73a68178f HBASE-8627 HBCK can not fix meta not assigned issue', '2581ebb0b2 HBASE-8627 HBCK can not fix meta not assigned issue']
# ['dc716a9005 HBASE-9061 Put back TestReplicationKillMasterRSCompressed when fixed over in HBASE-8615 (Ted Yu)', '4ec30df08f HBASE-9061 Put back TestReplicationKillMasterRSCompressed when fixed over in HBASE-8615 (Ted Yu)', '8bdcbb67ff HBASE-8615 HLog Compression may fail due to Hadoop fs input stream returning partial bytes', '1236068fd0 HBASE-8615 HLog Compression may fail due to Hadoop fs input stream returning partial bytes']
# ['2eec2f340a HBASE-8532 [Webui] Bootstrap based webui compatibility for IE and also fix some page format issues', '93fab309db HBASE-8532 [Webui] Bootstrap based webui compatibility for IE and also fix some page format issues']
# ['f2d10f4e9e HBASE-8521 Addendum - test fix (Jean-Marc Spaggiari)', '49de0f9133 HBASE-8521 Cells cannot be overwritten with bulk loaded HFiles (Jean-Marc Spaggiari)']
# ['20c4b8a685 HBASE-10555 Backport HBASE-8519 to 0.94, Backup master will never come up if primary master dies during initialization (Jingcheng Du, original patch by Jerry He)', 'ad6292f86e HBASE-8519 Backup master will never come up if primary master dies during initialization', 'bc4992c0f8 HBASE-8519  Backup master will never come up if primary master dies during initialization             (Jerry He via JD)', 'f729fcd4ec HBASE-8519  Backup master will never come up if primary master dies during initialization             (Jerry He via JD)']
# ['b0a03df607 [HBASE-8500] Add an option to move the region to a random region server', '0744c27fc8 [HBASE-8500] Fix Rolling Restart to handle scenarios where RegionServer and Master are using different versions of HRegionInfo', 'e8b80ba94c [HBASE-10699] Reduce unnecessary object allocation related to ArrayList [HBASE-10699] Fix the building problem. [HBASE-10698] Updating the HBase.thrift file to work with Thrift2 C++ client [HBASE-10709] ClientScanner with prefetching [HBASE-9930] Fix TestPerRequestProfiling [HBASE-8500] Provide a drain only option to rolling_restart [master] Add a param for hbck to decide whether to clear meta entry for unassigned region', 'd2cfd53dc3 [HBASE-8500] Adding success message to Rolling Restart script and bailing out in case region movement fails', '0b6039a650 [HBASE-8500] Separates out the test case to make it more reliable', '98060a04ac [HBASE-8500] Fixes Minor bug in RollingRestart', '1977527c57 [HBASE-8500] Minor change in the script to skip restart verification if we are told to just drain and stop or clear the regionserver from blacklist', 'c45f2f28f9 [HBASE-8500] Add option to only drain and stop the region server', '04bbd5eaf7 [HBASE-8500] Minor Changes in RollingRestart + a basic wrapper around the utility', '68b1e5c512 [HBASE-8500] Adds a RollingRestart utility for a region server']
# ['415e06f7a1 [HBASE-8467] Logging Failed nodes list to a new file every time, plus a small bug fix', '2e44f61062 [HBASE-8467] Adds an option to blacklist a server for RollingRestart']
# ['986f364d03 HBASE-830 Debugging HCM.locateRegionInMeta is painful', '1fb69ec11a HBASE-830 Debugging HCM.locateRegionInMeta is painful', '9b62798b11 HBASE-830 Debugging HCM.locateRegionInMeta is painful']
# ['19c87a375d HBASE-826 fix xml error in hbase-default.xml', 'ec8aeab847 HBASE-826 fix xml error in hbase-default.xml', '4dc9c3642c HBASE-826 fix xml error in hbase-default.xml', '681367f310 HBASE-826 Add in rest of hbase-826 -- missed HStore edits; remove method patch added twice', '79d463d658 HBASE-826 Add in rest of hbase-826 -- missed HStore edits', 'ed648b7327 HBASE-826 delete table followed by recreation results in honked table', 'd1adcf1629 HBASE-826 delete table followed by recreation results in honked table', '7627490bea HBASE-826 delete table followed by recreation results in honked table']
# ['b9c3497b8b HBASE-8259 Snapshot backport in 0.94.6 breaks rolling restarts', '8af84cb46d HBASE-8259 Snapshot backport in 0.94.6 breaks rolling restarts (J-D) + CHANGES.txt and pom.xml', 'ca669156cf HBASE-8259 Snapshot backport in 0.94.6 breaks rolling restarts (J-D) + CHANGES.txt and pom.xml', 'a34f3a364f Emergence fix for HBASE-8259', 'fff96309a6 Emergence fix for HBASE-8259', '0c47666dee HBASE-8259 Snapshot backport in 0.94.6 breaks rolling restarts']
# ['a79a77aa02 HBASE-8225 [replication] minor code bug when registering ReplicationLogCleaner (Jerry He)', 'a96672bec6 HBASE-8225 [replication] minor code bug when registering ReplicationLogCleaner (Jerry He)', '0bc9187d46 HBASE-8225 [replication] minor code bug when registering ReplicationLogCleaner (Jerry He)']
# ['6605c597bd [HBASE-8223] Fixes race condition between append and close in HLog']
# ['635949147f [0.89-fb] [HBASE-8216] Enable the serverManager to respect the config change for Power failures']
# ['9e02c52762 HBASE-8207 Replication could have data loss when machine name contains hyphen "-" (Jeffrey)', '92d5967a86 HBASE-9154. [0.92] Backport HBASE-8207 Replication could have data loss when machine name contains hyphen - (Jeffrey)', "7e26d32349 HBASE-8207 Don\\'t use hdfs append during lease recovery", "ac97504dc5 HBASE-8207 Don\\'t use hdfs append during lease recovery", '6930ff607f HBASE-8207 Addendum fixes the typo in extractDeadServersFromZNodeString()', 'aa851e3b7a HBASE-8207 Addendum fixes the typo in extractDeadServersFromZNodeString()', 'c5a16ef24c HBASE-8207 Addendum fixes the typo in extractDeadServersFromZNodeString()', '542b8dcc1f HBASE-8207 Replication could have data loss when machine name contains hyphen "-" (Jeffrey)', '9087f50a5f HBASE-8207 Replication could have data loss when machine name contains hyphen "-" (Jeffrey)', '1babc2abbc HBASE-8207 Replication could have data loss when machine name contains hyphen "-" (Jeffrey)']
# ['38fc69c10c [HBASE-8206] Thread safety issues with Compression.Algorithm.GZ']
# ['8e664d8133 HBASE-8125 HBASE-7435 breaks BuiltInGzipDecompressor on Hadoop < 1.0.x, real fix (Ted Yu)', '2c684ee552 HBASE-8125 HBASE-7435 breaks BuiltInGzipDecompressor on Hadoop < 1.0.x (Ted Yu)']
# ['089e876398 HBASE-8119. Optimize StochasticLoadBalancer. Addendum patch for javadoc fixes', '77904ce78a HBASE-8119 Optimize StochasticLoadBalancer', 'e21a1ee4ae HBASE-8119 Optimize StochasticLoadBalancer']
# ['9e270796d1 [HBASE-8111] Avoids un necessary DNS lookup for master web ui page']
# ['0696c139f5 HBASE-811 fix whitespaace', 'a5a72605cf HBASE-811 fix whitespaace', 'dbba69fce5 HBASE-811 fix whitespace', 'ca41de9b1b HBASE-811   HTD is not fully copyable (Andrew Purtell via Jim Kellerman)', '0c3bd478b3 HBASE-811   HTD is not fully copyable (Andrew Purtell via Jim Kellerman)', 'b55027819e HBASE-811   HTD is not fully copyable (Andrew Purtell via Jim Kellerman)']
# ['d004827b82 HBASE-8085 Backport the fix for Bytes.toStringBinary() into 94 (HBASE-6991) (Tianying Chang)', '7465b3d076 HBASE-8085 Backport the fix for Bytes.toStringBinary() into 94 (HBASE-6991) (Tianying Chang)']
# ["4456a8f5cf    HBASE-808,809 MAX_VERSIONS not respected, and Deletall doesn't and inserts; fix misapplication of patch", "aabc02c44b    HBASE-808,809 MAX_VERSIONS not respected, and Deletall doesn't and inserts; fix misapplication of patch", "4c2a6f66f1    HBASE-808,809 MAX_VERSIONS not respected, and Deletall doesn't and inserts; fix misapplication of patch", "fba07d1808 HBASE-808,809 MAX_VERSIONS not respected, and Deletall doesn't and inserts after delete don't work as expected", "78b53558b8 HBASE-808,809 MAX_VERSIONS not respected, and Deletall doesn't and inserts after delete don't work as expected", "f85e23cb43 HBASE-808,809 MAX_VERSIONS not respected, and Deletall doesn't and inserts after delete don't work as expected"]
# ['50256d7035 HBASE-8067 TestHFileArchiving.testArchiveOnTableDelete sometimes fails', '39e7e66ae9 HBASE-8067 TestHFileArchiving.testArchiveOnTableDelete sometimes fails', '448f2f7902 HBASE-8067 TestHFileArchiving.testArchiveOnTableDelete sometimes fails', '986c9fbed6 HBASE-8067 TestHFileArchiving.testArchiveOnTableDelete sometimes fails -- more debug', '9230c45c7e HBASE-8067 TestHFileArchiving.testArchiveOnTableDelete sometimes fails', '770219fccc HBASE-8067 TestHFileArchiving.testArchiveOnTableDelete sometimes fails', '302ce0325b HBASE-8067 TestHFileArchiving.testArchiveOnTableDelete sometimes fails', '90eaac74d5 HBASE-8067 TestHFileArchiving.testArchiveOnTableDelete sometimes fails -- more debug', '95e4f53090 HBASE-8067 TestHFileArchiving.testArchiveOnTableDelete sometimes fails -- more debug']
# ['24736e83bb HBASE-8062 Replace HBaseFsck.debugLsr() in TestFlushSnapshotFromClient with FSUtils.logFileSystemState()', '7181fa35a3 HBASE-8062 Replace HBaseFsck.debugLsr() in TestFlushSnapshotFromClient with FSUtils.logFileSystemState()']
# ['ddb06ad449 HBASE-8058 Upgrade site plugin; fix assembly doc up on jenkins builds', '3564568830 HBASE-8058 Upgrade site plugin; fix assembly doc up on jenkins builds']
# ['579c4eb3b2 HBASE-8050 Small fix to book/hbase.tests.html']
# ['41e2c36c82 HBASE-8044 Revert, fixed by HBASE-6643', '486b290863 HBASE-8044 Revert, fixed by HBASE-6643', '831e3dc59a HBASE-8044 split/flush/compact/major_compact from hbase shell does not work for region key with \\\\x format (Tianying)', '16c7c1e769 HBASE-8044 split/flush/compact/major_compact from hbase shell does not work for region key with \\\\x format (Tianying)']
# ['3a1b53f2fc HBASE-7966 ACL tests fail on trunk (flaky)', 'fd45b6fe06 HBASE-7966 ACL tests fail on trunk (flaky)', '70b1899e88 HBASE-7966 ACL tests fail on trunk (flaky)', '6f3af86452 HBASE-7966 ACL tests fail on trunk (flaky)', 'ca1a0ea654 HBASE-7966 ACL tests fail on trunk (flaky) -- Some debug log', '27dd86e0a0 HBASE-7966 ACL tests fail on trunk (flaky) -- Some debug log']
# ['30f12477b2 HBASE-7953 Some HFilePerformanceEvaluation tests might fail because of scanner.getValue when there is no more row; ADDENDUM', 'cf328edb97 HBASE-7953 Some HFilePerformanceEvaluation tests might fail because of scanner.getValue when there is no more row', 'f7d02a07d8 HBASE-7953 Addendum fixes syntax error', '4742310a5f HBASE-7953 Some HFilePerformanceEvaluation tests might fail because of scanner.getValue when there is no more row (Jean-Marc)']
# ['ad99387bfe HBASE-7920 Addendum fixes checking for FilterList', '66512747bf HBASE-7920 Move isFamilyEssential(byte[] name) out of Filter interface in 0.94 (Ted Yu)', '3c44b28c94 HBASE-7920 Addendum fixes checking for FilterList', '99a9328680 HBASE-7920 Move isFamilyEssential(byte[] name) out of Filter interface in 0.94 (Ted Yu)']
# ['92bd62bf58 Fix overlogging; part of HBASE-792 patch', 'e2a146d694 Fix overlogging; part of HBASE-792 patch', 'b3bdd512f3 Patches to alleviate HBASE-790 and HBASE-792', '9f00684d05 Patches to alleviate HBASE-790 and HBASE-792']
# ['2cccddf35d HBASE-7914 Port the fix of HBASE-6748 into 0.94 branch (Jeffrey Zhong)', '195e23fe01 HBASE-7914 Port the fix of HBASE-6748 into 0.94 branch (Jeffrey Zhong)']
# ['942c54cf56 HBASE-790 During import, single region blocks requests for >10 minutes, thread dumps, throws out pending requests, and continues', '0d8ab3cad8 HBASE-790 During import, single region blocks requests for >10 minutes, thread dumps, throws out pending requests, and continues', '165e2ed915 Fix deadlock caused by HBASE-790 patch', 'a9aef2181d Fix deadlock caused by HBASE-790 patch', 'b3bdd512f3 Patches to alleviate HBASE-790 and HBASE-792', '9f00684d05 Patches to alleviate HBASE-790 and HBASE-792']
# ["c565b2f13a HBASE-8354 Backport HBASE-7878 \\'recoverFileLease does not check return value of recoverLease\\' to 0.94", '1aa9c548fc HBASE-7878  recoverFileLease does not check return value of recoverLease', 'c5d6b90eb8 Revert "HBASE-8354 Backport HBASE-7878 \\\'recoverFileLease does not check return value of recoverLease\\\' to 0.94 (Liang Xie)"', "57a4c03bbb HBASE-8354 Backport HBASE-7878 \\'recoverFileLease does not check return value of recoverLease\\' to 0.94 (Liang Xie)", "ed9a0a5091 HBASE-8354 Backport HBASE-7878 \\'recoverFileLease does not check return value of recoverLease\\' to 0.94 (Liang Xie)", '030628c553 HBASE-7878 revert due to TestHLogSplit test failure', 'b3647fec74 HBASE-7878 Addendum for trying fs.append in case recoverLease throws exception', '3b4b9b3c7a HBASE-7878 add debug log for recoverLease timeout', '7850fda086 HBASE-7878 recoverFileLease does not check return value of recoverLease (Ted Yu)', '17c662c46c HBASE-7878 recoverFileLease does not check return value of recoverLease, addendum', '28cfad9739 HBASE-7878 recoverFileLease does not check return value of recoverLease, addendum', '31c1c9e7e6 HBASE-7878 recoverFileLease does not check return value of recoverLease (Ted Yu)', '708669b53f HBASE-7878 recoverFileLease does not check return value of recoverLease, third attempt (Ted Yu)', 'e253150cf3 HBASE-7878 recoverFileLease does not check return value of recoverLease, revert', '6722e26df1 HBASE-7878 recoverFileLease does not check return value of recoverLease (Ted Yu)', 'dc470e0be7 HBASE-7878 revert due to TestHLogSplit test failure', 'bfbc70a68a HBASE-7878 revert due to TestHLogSplit test failure', '46db70556e HBASE-7878 revert due to TestHLogSplit test failure', '21eda243ad HBASE-7878 Addendum for trying fs.append in case recoverLease throws exception', '33f7a4d7ff HBASE-7878 Addendum for trying fs.append in case recoverLease throws exception', '50a47a9023 HBASE-7878 Addendum for trying fs.append in case recoverLease throws exception', '539ff195e8 HBASE-7878 add debug log for recoverLease timeout', '3b923a92c5 HBASE-7878 recoverFileLease does not check return value of recoverLease (Ted Yu)', '41208aa44f HBASE-7878 recoverFileLease does not check return value of recoverLease (Ted Yu)', '2e2d95af14 HBASE-7878 recoverFileLease does not check return value of recoverLease (Ted Yu)']
# ['2f1579e92e [0.89-fb] [HBASE-7852] fix TestLoadIncrementalHFiles', '1bafc48511 [0.89-fb] [HBASE-7852] Ensure that the command line options are respected.']
# ['77df789608 HBASE-7817: Suggested JDWP debug options in hbase-env.sh are wrong (Vasu Mariyala)', 'ff3ae92d1f HBASE-7817: Suggested JDWP debug options in hbase-env.sh are wrong (Vasu Mariyala)', '5ca140fe2f HBASE-7817: Suggested JDWP debug options in hbase-env.sh are wrong (Vasu Mariyala)']
# ['5068650101 HBASE-7725: Add ability to create custom compaction request', '43edd93495 HBASE-7725: Add ability to create custom compaction request', 'f66bbf1ca4 HBASE-7725: Add ability to create custom compaction request - ADDENDUM: fix javadocs', '1a766c42a1 HBASE-7725: Add ability to create custom compaction request']
# ['a3f0aea354 HBASE-7682 Replace HRegion custom File-System debug, with FSUtils.logFileSystemState()']
# ["479232c610 HBASE-7669 ROOT region wouldn't be handled by PRI-IPC-Handler(Chunhui)", 'e9f14f1073 HBASE-7669 Addendum fixes TestPriorityRpc', "4d7b2824be HBASE-7669 ROOT region wouldn't be handled by PRI-IPC-Handler(Chunhui)", "898f661663 HBASE-7669 ROOT region wouldn't be handled by PRI-IPC-Handler(Chunhui)"]
# ['b96d60d659 HBASE-7601 Fix 8 remaining EQ findbug warnings from hbase-server.']
# ['28b79e1214 HBASE-7595 Fix one findbug warning in ReplicationSourceManager']
# ['f60b8246e7 HBASE-7588 Fix two findbugs warning in MemStoreFlusher; REAPPLIED', 'c3e140cd14 HBASE-7588 Fix two findbugs warning in MemStoreFlusher; REVERTED', '3b345cd684 HBASE-7588 Fix two findbugs warning in MemStoreFlusher']
# ['152ec1cc7f HBASE-7587. Fix two findbugs warnings in RowResource (Jean-Marc Spaggiari)', '05934d7405 HBASE-7587. Fix two findbugs warnings in RowResource (Jean-Marc Spaggiari)', 'bda467aeca HBASE-7587. Fix two findbugs warnings in RowResource (Jean-Marc Spaggiari)']
# ['5c8c3d0a8c HBASE-7586 Fix two findbugs warnings to get our count down to the tolerated number again']
# ['837f89bd79 HBASE-8040 - Race condition in AM after HBASE-7521 (only 0.94) (Ram)', 'efead793d4 HBASE-7521 fix HBASE-6060 (regions stuck in opening state) in 0.94 (Sergey and Rajeshbabu)', '6ab7671f08 HBASE-8040 - Race condition in AM after HBASE-7521 (only 0.94) (Ram)', '883ec67336 HBASE-7521 fix HBASE-6060 (regions stuck in opening state) in 0.94 (Sergey and Rajeshbabu)']
# ['24e4df74ea [0.89-fb] [ HBASE-7517] Add server name to PFFE Exceptions', '69cbc81e5c [0.89-fb] [HBASE-7517] Improve the PFFE mechanism such that (i) Ensure that if a thread gets the AtomicBoolean for a single server, it will not be stopped to get the AtomicBoolean for a different server. (ii) PFFE is only thrown for threads that are not a', '8eee0f17ba [0.89-fb] [ HBASE-7517] fix PFFE issue when ROOT moves around', '233dc24e3d [0.89-fb] [ HBASE-7517] Do not throw PreemptiveFastFailExceptions when caused by another PFFE']
# ['4e0af48fe4 HBASE-7508 Fix simple findbugs']
# ['c739366d73 [HBASE-7491] testBatchedUpload test cases more deterministic']
# ['4409ba741c HBASE-7443 More findbugs fixes - addendum - fix compilation error', '92c98a76d1 HBASE-7443 More findbugs fixes']
# ['9ead77761f HBASE-7435 BuiltInGzipDecompressor is only released during full GC', '8e664d8133 HBASE-8125 HBASE-7435 breaks BuiltInGzipDecompressor on Hadoop < 1.0.x, real fix (Ted Yu)', '2c684ee552 HBASE-8125 HBASE-7435 breaks BuiltInGzipDecompressor on Hadoop < 1.0.x (Ted Yu)', '5640731663 HBASE-7435 BuiltInGzipDecompressor is only released during full GC', 'f356d580c5 HBASE-7435 BuiltInGzipDecompressor is only released during full GC']
# ['b8784b73e5 HBASE-7417 Test patch, hopefully fixes TestReplication', '65d764e979 HBASE-7417 Enable Cleaners required for Snapshots by default (Ted Yu)', '85d9f6b709 HBASE-7417 Test patch, hopefully fixes TestReplication']
# ['deeb84ae5a HBASE-7390 Add extra test cases for assignement on the region server and fix the related issues']
# ['289ab6b87c [HBASE-7275] Fix two bugs in HBase based on findBugs report']
# ['3b980dda5c [HBASE-7198] [0.89-fb] fix lastSeqWritten logic in HLog']
# ['75682c0c5b HBASE-7083 SSH#fixupDaughter should force re-assign missing daughter']
# ['f065232db0 HBASE-7002 Fix all 4 findbug performance warnings (Liang Xie)']
# ['d004827b82 HBASE-8085 Backport the fix for Bytes.toStringBinary() into 94 (HBASE-6991) (Tianying Chang)', '7465b3d076 HBASE-8085 Backport the fix for Bytes.toStringBinary() into 94 (HBASE-6991) (Tianying Chang)', '9b3e63dcb7 HBASE-6991 Escape "\\\\" in Bytes.toStringBinary() and its counterpart Bytes.toBytesBinary()']
# ['1371c33e8d HBASE-836 Update thrift examples to work with changed IDL (HBASE-697)', 'e522b64665 HBASE-836 Update thrift examples to work with changed IDL (HBASE-697)', '0023b81e82 HBASE-697 thrift idl needs update/edit to match new 0.2 API (and to fix bugs)', 'fddd62e6c5 HBASE-697 thrift idl needs update/edit to match new 0.2 API (and to fix bugs)', '83c1c30938 HBASE-697 thrift idl needs update/edit to match new 0.2 API (and to fix bugs)', 'e30ed932bb HBASE-697 thrift idl needs update/edit to match new 0.2 API (and to fix bugs)', 'c65c58905b HBASE-697 thrift idl needs update/edit to match new 0.2 API (and to fix bugs)', 'f346a3d85a HBASE-697 thrift idl needs update/edit to match new 0.2 API (and to fix bugs)']
# ['0750adf8a2 [jira] [HBASE-6943] [89-fb] Do not catch certain exceptions trying to get an RS connection']
# ["610ea30534 HBASE-6928 TestStoreFile sometimes fails with 'Column family prefix used twice' -- ATTEMPTED FIX", "e64430e970 HBASE-6928 TestStoreFile sometimes fails with 'Column family prefix used twice'"]
# ['12315b8597 HBASE-6987 Port HBASE-6920 to trunk (?)', 'ce9703aa4f HBASE-6920 Addendum2. Remove test code which does not work for the Secure build', '7bfd09e973 HBASE-6920 Addendum2. Remove test code which does not work for the Secure build', 'a0344c193f HBASE-6920 Addendum - fix SecureRpcEngine', 'bb54590ab5 HBASE-6920 Addendum - fix SecureRpcEngine', '11496b6f72 HBASE-6920 On timeout connecting to master, client can get stuck and never make progress', '205c9b83ac HBASE-6920 On timeout connecting to master, client can get stuck and never make progress']
# ['d6cca23ed3 HBASE-6918 Debugging to help figure what is different up on jenkins when TestHeapSize runs']
# ['2f850f964a HBASE-6871 HFileBlockIndex Write Error in HFile V2 due to incorrect split into intermediate index blocks; ADDENDUM2 REAPPLICATION', '6abd8dec5e HBASE-6871 HFileBlockIndex Write Error in HFile V2 due to incorrect split into intermediate index blocks; ADDENDUM2 REAPPLICATION', 'dd2015d6ad HBASE-6871 HFileBlockIndex Write Error in HFile V2 due to incorrect split into intermediate index blocks; ADDENDUM2 OVERCOMMIT', '061a2457b1 HBASE-6871 HFileBlockIndex Write Error in HFile V2 due to incorrect split into intermediate index blocks; ADDENDUM2 OVERCOMMIT', '9d470279dd HBASE-6871 HFileBlockIndex Write Error in HFile V2 due to incorrect split into intermediate index blocks; ADDENDUM2', '267b941c4c HBASE-6871 HFileBlockIndex Write Error in HFile V2 due to incorrect split into intermediate index blocks; ADDENDUM2', 'e496b61aa1 HBASE-6871 HFileBlockIndex Write Error in HFile V2 due to incorrect split into intermediate index blocks; ADDENDUM', '215d216275 HBASE-6871 HFileBlockIndex Write Error in HFile V2 due to incorrect split into intermediate index blocks; ADDENDUM', 'a4fbfcf640 HBASE-6871 Add TestHFileInlineToRootChunkConversion', '473dcddb55 HBASE-6871 HFileBlockIndex Write Error in HFile V2 due to incorrect split into intermediate index blocks (Mikhail)', '79e79ef090 HBASE-6871 HFileBlockIndex Write Error in HFile V2 due to incorrect split into intermediate index blocks', 'd02e466bc2 HBASE-6871 HFileBlockIndex Write Error in HFile V2 due to incorrect split into intermediate index blocks', 'c0b38e6c57 HBASE-6871 HFileBlockIndex Write Error in HFile V2 due to incorrect split into intermediate index blocks', '15e07e8548 [jira] [HBASE-6871] [89-fb] Block index corruption test case and fix']
# ['bb563c3603 HBASE-6858 Fix the incorrect BADVERSION checking in the recoverable zookeeper', '3a0b571d7b [HBASE-6858] Fix the incorrect BADVERSION checking in the recoverable zookeeper', 'e30829d8c1 HBASE-6858 Fix the incorrect BADVERSION checking in the recoverable zookeeper; REVERT.... BROKE', '9712f25f8f HBASE-6858 Fix the incorrect BADVERSION checking in the recoverable zookeeper; REVERT.... BROKE', '9526aeb2a8 HBASE-6858 Fix the incorrect BADVERSION checking in the recoverable zookeeper; REVERT.... BROKE', '9b789a9d67 HBASE-6858 Fix the incorrect BADVERSION checking in the recoverable zookeeper', '6bee1177a2 HBASE-6858 Fix the incorrect BADVERSION checking in the recoverable zookeeper', '529807b0e5 HBASE-6858 Fix the incorrect BADVERSION checking in the recoverable zookeeper']
# ['d487401613 HBASE-6846 BitComparator bug - ArrayIndexOutOfBoundsException (Lucian George Iordache)', '3ab7fe3e6e HBASE-6846 BitComparator bug - ArrayIndexOutOfBoundsException (Lucian George Iordache)', 'f4923b98a6 HBASE-6846 BitComparator bug - ArrayIndexOutOfBoundsException (Lucian George Iordache)']
# ['4ca039e4e3 [HBASE-6838] [89-fb] Regionserver generates identical scanner name', '17a2e1663a HBASE-6838 Regionserver may generate identical scanner name (Chunhui)']
# ['80fa33698f HBASE-613 Timestamp-anchored scanning fails to find all records HBASE-681 NPE in Memcache', 'f02a98da07 HBASE-613 Timestamp-anchored scanning fails to find all records HBASE-681 NPE in Memcache', '767d2765b5 HBASE-681   NPE in Memcache (Clint Morgan via Jim Kellerman)']
# ['2cccddf35d HBASE-7914 Port the fix of HBASE-6748 into 0.94 branch (Jeffrey Zhong)', '195e23fe01 HBASE-7914 Port the fix of HBASE-6748 into 0.94 branch (Jeffrey Zhong)', '10c1bceda4 HBASE-6748 Endless recursive of deleteNode happened in SplitLogManager#DeleteAsyncCallback (Jeffrey Zhong)']
# ['72aba5f19e [HBASE-6741] Move testRebalancingWithDuplicateNotification to a different test class', 'dbcad94d43 [HBASE-6741] [0.89-fb] Detect duplicate assignments more accurately.']
# ['db380918a4 [HBASE-6728] [89-fb] Improvements to SizeBasedThrottler', '5754b24e57 HBASE-6728 prevent OOM possibility due to per connection responseQueue being unbounded', '770605db8c HBASE-6728 prevent OOM possibility due to per connection responseQueue being unbounded', '1a32bfed45 HBASE-6728 revert', '1048d15c6a HBASE-6728 prevent OOM possibility due to per connection responseQueue being unbounded', '649126bdc5 [jira] [HBASE-6728] [89-fb] bound responseQueue to prevent OOM']
# ['4c7a465b00 HBASE-6775 Use ZK.multi when available for HBASE-6710 0.92/0.94 compatibility fix', '58f3f30cb3 HBASE-6775 Use ZK.multi when available for HBASE-6710 0.92/0.94 compatibility fix', '802f264f4e HBASE-6759 Forward port ZKReadOnly change from HBASE-6710', 'baa5d4675a HBASE-6710 0.92/0.94 compatibility issues due to HBASE-5206', '6c4e39dcae HBASE-6710 0.92/0.94 compatibility issues due to HBASE-5206']
# ['55fb6632b9 HBASE-6697  regionserver.TestPriorityRpc uses a fixed port (60020)']
# ['6f8104a966 [jira] [HBASE-6619] [89-fb] Do no unregister and re-register interest ops in RPC']
# ['564fc2e7c3 Port HBASE-6590 to trunk : Asssign sequence number to bulk loaded files (Amitanand)', '1673fee154 [HBASE-6590] [0.89-fb] Fix TestStoreFile.', 'dec419003a [HBASE-6590] Assign SequenceNumber to BulkLoaded files.']
# ['4606107e1d HBASE-6583. Enhance LoadTestTool to automatically create column families if not present (Sergey Shelukhin)', '510cb9f71d HBASE-6583. Enhance LoadTestTool to automatically create column families if not present (Sergey Shelukhin)', '7e02b67d30 HBASE-6583 Enhance Hbase load test tool to automatically create column families if not present (Sergey Shelukhin)', '3e2399a7b1 [HBASE-6583] Create a CF if its not present in the load test tool']
# ["f328681e00 HBASE-649 API polluted with default and protected access data members and methods HBASE-650 Add String versions of get, scanner, put in HTable HBASE-656 Do not retry exceptions such as unknown scanner or illegal argument A  src/java/org/apache/hadoop/hbase/ColumnNameParseException.java A  src/java/org/apache/hadoop/hbase/LeaseException.java     Added.  Thrown instead of IllegalArgumentExceptions M  src/java/org/apache/hadoop/hbase/Leases.java     Use new LeaseException in place of IllegalArgument M  src/java/org/apache/hadoop/hbase/HStoreKey.java     Use new ColumnNameParse in place of IllegalArgument M  src/java/org/apache/hadoop/hbase/master/ServerManager.java     Log at debug if LeaseException (Not important if it happens). A  src/java/org/apache/hadoop/hbase/DoNotRetryIOException.java     An IOE that shouldn't be retried. M  src/java/org/apache/hadoop/hbase/InvalidColumnNameException.java M  src/java/org/apache/hadoop/hbase/UnknownScannerException.java     Inherit from DoNotRetryIOException else we keep trying. M  src/java/org/apache/hadoop/hbase/util/Bytes.java     (toByteArrays): Added one to handle [] String. M  src/java/org/apache/hadoop/hbase/client/HTable.java     Make String overrides of all methods.  Made data members     private (turns out a bunch arent' even used).  Stopped it     inheriting from HConstants so we don't have big dump of     all HConstants as first thing in javadoc. M  src/java/org/apache/hadoop/hbase/client/HConnectionManager.java     If instance of DoNotRetryIOException, let the exception out. M  src/java/org/apache/hadoop/hbase/client/HBaseAdmin.java     Make String overrides of all methods.  Stopped it     inheriting from HConstants so we don't have big dump of     all HConstants as first thing in javadoc.", "c7165b1e30 HBASE-649 API polluted with default and protected access data members and methods HBASE-650 Add String versions of get, scanner, put in HTable HBASE-656 Do not retry exceptions such as unknown scanner or illegal argument A  src/java/org/apache/hadoop/hbase/ColumnNameParseException.java A  src/java/org/apache/hadoop/hbase/LeaseException.java     Added.  Thrown instead of IllegalArgumentExceptions M  src/java/org/apache/hadoop/hbase/Leases.java     Use new LeaseException in place of IllegalArgument M  src/java/org/apache/hadoop/hbase/HStoreKey.java     Use new ColumnNameParse in place of IllegalArgument M  src/java/org/apache/hadoop/hbase/master/ServerManager.java     Log at debug if LeaseException (Not important if it happens). A  src/java/org/apache/hadoop/hbase/DoNotRetryIOException.java     An IOE that shouldn't be retried. M  src/java/org/apache/hadoop/hbase/InvalidColumnNameException.java M  src/java/org/apache/hadoop/hbase/UnknownScannerException.java     Inherit from DoNotRetryIOException else we keep trying. M  src/java/org/apache/hadoop/hbase/util/Bytes.java     (toByteArrays): Added one to handle [] String. M  src/java/org/apache/hadoop/hbase/client/HTable.java     Make String overrides of all methods.  Made data members     private (turns out a bunch arent' even used).  Stopped it     inheriting from HConstants so we don't have big dump of     all HConstants as first thing in javadoc. M  src/java/org/apache/hadoop/hbase/client/HConnectionManager.java     If instance of DoNotRetryIOException, let the exception out. M  src/java/org/apache/hadoop/hbase/client/HBaseAdmin.java     Make String overrides of all methods.  Stopped it     inheriting from HConstants so we don't have big dump of     all HConstants as first thing in javadoc."]
# ...
# ['451e39bf9c [HBASE-11379] fixed exception-handling in the writing of .regioninfo files', '75ed75d3ed [HBASE-11379] Modified AlterTable to fix stale .regioninfo and wrote tests', 'd8ba4507b6 [HBASE-11379] added fixRegionInfo method to rewrite stale .regioninfo files']
# ['ce2995c49d HBASE-1136  HashFunction inadvertently destroys some randomness; REVERTING', 'b36d1fa6e4 HBASE-1136  HashFunction inadvertently destroys some randomness; REVERTING', '36cadbcef7 HBASE-1136  HashFunction inadvertently destroys some randomness; fixes broken build', '36def930a3 HBASE-1136  HashFunction inadvertently destroys some randomness; fixes broken build', '557f050021 HBASE-1136 HashFunction inadvertently destroys some randomness', 'fd719f0a37 HBASE-1136 HashFunction inadvertently destroys some randomness', '03adaea261 HBASE-1136 HashFunction inadvertently destroys some randomness', 'd94afa1249 HBASE-1136 HashFunction inadvertently destroys some randomness']
# ['3d3784dd22 HBASE-11329 Minor fixup of new blockcache tab number formatting']
# ['3d3e7eb228 HBASE-11310 Addendum fixes compilation error', 'aa916b81ce HBASE-11310 Addendum fixes compilation error', "af9fa42e1b HBASE-11310:Delete's copy constructor should copy the attributes also (Ram)", "9b94c14fa3 HBASE-11310:Delete's copy constructor should copy the attributes also (Ram)"]
# ['45883c6bd1 [HBASE-11258] Pull in Integration Tests from open source 0.96/trunk']
# ['191abb0b6b HBASE-11234 Addendum for PrefixTreeArrayScanner', 'a616bb42c6 HBASE-11234 FastDiffDeltaEncoder#getFirstKeyInBlock returns wrong result (Chunhui)', '90ece25b6e HBASE-11234 FastDiffDeltaEncoder#getFirstKeyInBlock returns wrong result', '56af657e5d HBASE-11234 Addendum for PrefixTreeArrayScanner', 'b985e4fd0e Revert "HBASE-11234 FastDiffDeltaEncoder#getFirstKeyInBlock returns wrong result"', '5f4537f06c Revert "HBASE-11234 FastDiffDeltaEncoder#getFirstKeyInBlock returns wrong result" due to test issues', '7d56e0523f HBASE-11234 FastDiffDeltaEncoder#getFirstKeyInBlock returns wrong result', 'b2a2e06098 HBASE-11234 FastDiffDeltaEncoder#getFirstKeyInBlock returns wrong result', '494e0b50e9 HBASE-11234 FastDiffDeltaEncoder#getFirstKeyInBlock returns wrong result', 'edae564856 HBASE-11234 FastDiffDeltaEncoder#getFirstKeyInBlock returns wrong result']
# ['c9c01e6eb1 HBASE-11225 Backport fix for HBASE-10417 index is not incremented in PutSortReducer#reduce() (Gustavo Anatoly)']
# ['812be0ca43 [0.94] port HBASE-11217 Race between SplitLogManager task creation + TimeoutMonitor. (LarsH - original patch by Enis)', '230a768a3c HBASE-11217 Race between SplitLogManager task creation + TimeoutMonitor - ADDENDUM to fix unit test', '9dcebc396b HBASE-11217 Race between SplitLogManager task creation + TimeoutMonitor - ADDENDUM to fix unit test', '49d7b9dc45 HBASE-11217 Race between SplitLogManager task creation + TimeoutMonitor', '92b2c86776 HBASE-11217 Race between SplitLogManager task creation + TimeoutMonitor']
# ['9d4cc565e0 HBASE-1121  Cluster confused about where -ROOT- is', '542abcf26d HBASE-1121  Cluster confused about where -ROOT- is', '8b53dd0396 HBASE-1121  Cluster confused about where -ROOT- is. This patch fixes "re-finding" the root region.', 'efe5944279 HBASE-1121  Cluster confused about where -ROOT- is. This patch fixes "re-finding" the root region.', '0b36056fde HBASE-1121 Cluster confused about where -ROOT- is; commit better logging', '21732392f3 HBASE-1121 Cluster confused about where -ROOT- is; commit better logging', 'a59ddf299e HBASE-1121 Cluster confused about where -ROOT- is; commit better logging', '8d03bf9b0e HBASE-1121 Cluster confused about where -ROOT- is; commit better logging']
# ['de727cc1d7 [HBASE-11187] Fix null pointer.', '3a61ebfb10 [HBASE-11187] Fix TableServers for jdk7', 'a7fe50b445 [HBASE-11187] Limit the number of client threads per regionserver']
# ['ced723b6d9 HBASE-11169 nit: fix incorrect javadoc in OrderedBytes about BlobVar and BlobCopy', 'daa7b14d52 HBASE-11169 nit: fix incorrect javadoc in OrderedBytes about BlobVar and BlobCopy', 'a5cbd502bb HBASE-11169 nit: fix incorrect javadoc in OrderedBytes about BlobVar and BlobCopy']
# ['52dd30727a HBASE-11149. Addendum for fixing unit test', 'e9017586ca HBASE-11149. Addendum for fixing unit test', '7caceb23c7 HBASE-11149 Wire encryption is broken (Devaraj Das)', 'b168b8b2d5 HBASE-11149 Wire encryption is broken (Devaraj Das)', '6ea0b7f8c2 HBASE-11149 Wire encryption is broken (Devaraj Das)']
# ['ec69c8833e HBASE-11145 UNEXPECTEDpatch -p1 < 11145v2.txt ! when HLog sync: Queue full', '288ffe6563 HBASE-11145 UNEXPECTEDpatch -p1 < 11145v2.txt ! when HLog sync: Queue full']
# ['f648f6060b [HBASE-11138][0.89-fb] Check for an empty split key before creating a table']
# ['85853f69c8 HBASE-11316 Expand info about compactions beyond HBASE-11120 ADDENDUM TO FIX BROKE TESTS', 'afae1e2583 HBASE-11316 Expand info about compactions beyond HBASE-11120 (Misty Stanley-Jones)', 'ee76225783 HBASE-11120 Addendum for fixing compilation error', '948b22f082 HBASE-11120 Update documentation about major compaction algorithm (Misty Stanley-Jones) + addendum fixing CompactionConfiguration']
# ['0296547aa2 [HBASE-11021] HBaseFsck Fix for Table Hole Reporting']
# ['c6a0ee0e83 HBASE-1092  FileNotFoundException trying to get index file size for metrics; fix the build', 'c36fafc65d HBASE-1092  FileNotFoundException trying to get index file size for metrics; fix the build', '22d184218d HBASE-1092 FileNotFoundException trying to get index file size for metrics; part 1', '522c34a707 HBASE-1092 FileNotFoundException trying to get index file size for metrics; part 1', '9f9198e21e HBASE-1092 shell tools -> close_region does not work for regions that did not deploy properly on startup', '95e76839d6 HBASE-1092 shell tools -> close_region does not work for regions that did not deploy properly on startup']
# ['b699fcfe6f [HBASE-10907] Stabilize TestRegionPlacement addendum', '495e30c18e [HBASE-10907] Stabilize TestRegionPlacement']
# ['79281ee0ba [HBASE-10901] Remove usage of createMultiRegions', 'c8ea643074 [HBASE-10901] Fix TestHRegionClose unstable bug']
# ['6a1b347964 [HBASE-10893] Fixing critical bug in FastDiffDeltaEncoder']
# ['4487333e5e HBASE-10840 Fix findbug warn induced by HBASE-10569.(Anoop)']
# ['54175f554a [HBASE-10808] Forward porting Leases and Histogram bug fixes to trunk.']
# ['cdb12941c4 HBASE-10715 Addendum; fixing double import', '4eb9e5225d HBASE-10715 TimeRange has poorly formatted error message (Alex Newman)']
# ['6f1951ddda HBASE-10675 Addendum fixes compilation - HTable import was missing', '829c3725c7 HBASE-10675 - IntegrationTestIngestWithACL should allow User to be passed as Parameter (Ram)', 'ba5de65ae0 HBASE-10675 - IntegrationTestIngestWithACL should allow User to be passed as Parameter (Ram)']
# ['2ef02e6e1c HBASE-10822 Thread local addendum to HBASE-10656 Counter', '6d6327b477 HBASE-10656 high-scale-lis Counter depends on Oracle (Sun) JRE, and also has some bug', 'a1a5f57bff HBASE-10656 high-scale-lis Counter depends on Oracle (Sun) JRE, and also has some bug']
# ['2e28ec44c8 [HBASE-10647] Fix the bug of not decrease from size in updateColumnValue when removing the old columns.']
# ['a11781eae8 HBASE-10624 Fix 2 new findbugs warnings introduced by HBASE-10598', '66f01155fe HBASE-10624 Fix 2 new findbugs warnings introduced by HBASE-10598', 'bc9834426a HBASE-10624 Fix 2 new findbugs warnings introduced by HBASE-10598', 'ce1e3b6c77 HBASE-10624 Fix 2 new findbugs warnings introduced by HBASE-10598']
# ['a11781eae8 HBASE-10624 Fix 2 new findbugs warnings introduced by HBASE-10598', '66f01155fe HBASE-10624 Fix 2 new findbugs warnings introduced by HBASE-10598', 'bc9834426a HBASE-10624 Fix 2 new findbugs warnings introduced by HBASE-10598', 'ce1e3b6c77 HBASE-10624 Fix 2 new findbugs warnings introduced by HBASE-10598', '5221dcfc00 HBASE-10598 Written data can not be read out because MemStore#timeRangeTracker might be updated concurrently (cuijianwei)', 'c6236a57a5 HBASE-10598 Written data can not be read out because MemStore#timeRangeTracker might be updated concurrently (cuijianwei)', 'e450b4a795 HBASE-10598 Written data can not be read out because MemStore#timeRangeTracker might be updated concurrently (cuijianwei)', '3233679759 HBASE-10598 Written data can not be read out because MemStore#timeRangeTracker might be updated concurrently (cuijianwei)']
# ['bf9ac84827 HBASE-1058 Prevent runaway compactions; patch 1058-2-v1', '1f900dca17 HBASE-1058 Prevent runaway compactions; patch 1058-2-v1', '816225f395 HBASE-1058 Prevent runaway compactions; patch 1058-2-v1', 'eb3cd124f8 HBASE-1058 Prevent runaway compactions', '63b81c5ad0 HBASE-1058 Prevent runaway compactions', '4dc924c609 HBASE-1058 Prevent runaway compactions']
# ['5f9420aba0 [HBASE-10578] [0.89-fb] Choose the correct KV from multiple scanners']
# ['20c4b8a685 HBASE-10555 Backport HBASE-8519 to 0.94, Backup master will never come up if primary master dies during initialization (Jingcheng Du, original patch by Jerry He)']
# ['1f0f62ced8 HBASE-10528 DefaultBalancer selects plans to move regions onto draining nodes. (churro morales)', '5e36e70cfd HBASE-10528 DefaultBalancer selects plans to move regions onto draining nodes', '72d17265c1 HBASE-10528 Revert due to test failure', '00a50d6b95 HBASE-10528 Revert due to test failure', '5cdc9890ec HBASE-10528 DefaultBalancer selects plans to move regions onto draining nodes (Churro Morales)', '8ed7dea397 HBASE-10528 DefaultBalancer selects plans to move regions onto draining nodes (Churro Morales)', '483e55e2fa HBASE-10528 DefaultBalancer selects plans to move regions onto draining nodes (Churro Morales)', 'c951238304 HBASE-10528 Addendum fixes TestRegionStates compilation', 'c5b0a1b8a0 HBASE-10528 DefaultBalancer selects plans to move regions onto draining nodes (Churro Morales)', '45fc2bdd86 HBASE-10528 DefaultBalancer selects plans to move regions onto draining nodes (Churro Morales)']
# ['3e054d4f8b HBASE-10751 TestHRegion testWritesWhileScanning occasional fail since HBASE-10514 went in', '2faa2015c1 HBASE-10514 Addendum; fixing missing import', 'a3b0f0fb86 HBASE-19751 TestHRegion testWritesWhileScanning occasional fail since HBASE-10514 went in', '76aa400b1b HBASE-10514 Forward port HBASE-10466, possible data loss when failed flushes', '8388be58e4 HBASE-10751 TestHRegion testWritesWhileScanning occasional fail since HBASE-10514 went in', 'fa6a85d2a0 HBASE-10751 TestHRegion testWritesWhileScanning occasional fail since HBASE-10514 went in', 'e97a4df4e0 HBASE-10751 TestHRegion testWritesWhileScanning occasional fail since HBASE-10514 went in', '45e5b76f37 HBASE-10514 Forward port HBASE-10466, possible data loss when failed flushes', '354f5da6a1 HBASE-10514 Forward port HBASE-10466, possible data loss when failed flushes', '731e2f6541 HBASE-10514 Forward port HBASE-10466, possible data loss when failed flushes']
# ['e115b5125a HBASE-10485 PrefixFilter#filterKeyValue() should perform filtering on row key (Ted Yu and LarsH)', '16151a654c HBASE-10485 PrefixFilter#filterKeyValue() should perform filtering on row key (Ted Yu and LarsH)', '598107a7d0 HBASE-10485 PrefixFilter#filterKeyValue() should perform filtering on row key', '083a1cfd9c HBASE-10485 PrefixFilter#filterKeyValue() should perform filtering on row key', '5550e328c4 HBASE-10485 Revert to address more review comments', '1615662683 HBASE-10485 Revert to address more review comments', '8755eb8bee HBASE-10485 Addendum', 'bda1351306 HBASE-10485 Addendum', '22c2d8c4e3 HBASE-10485 PrefixFilter#filterKeyValue() should perform filtering on row key', 'df5bd6e99f HBASE-10485 PrefixFilter#filterKeyValue() should perform filtering on row key']
# ['3ea0e50450 HBASE-10460 Return value of Scan#setSmall() should be void - Addendum patch to fix javadoc warning', 'a873e206c9 HBASE-10460 Return value of Scan#setSmall() should be void - Addendum patch to fix javadoc warning', '22d93bd3c6 HBASE-10460 Return value of Scan#setSmall() should be void', 'e4e61a2e63 HBASE-10460 Return value of Scan#setSmall() should be void']
# ['389e4f583e HBASE-10454 Tags presence file info can be wrong in HFiles when PrefixTree encoding is used.', '42a2456b44 HBASE-10454 Tags presence file info can be wrong in HFiles when PrefixTree encoding is used.']
# ['59c2b2bb09 HBASE-10452 Fix potential bugs in exception handlers (Ding Yuan)', 'f1ad5cb938 HBASE-10452 Fix potential bugs in exception handlers (Ding Yuan)']
# ['b3b3d0ddff HBASE-10446 Backup master gives Error 500 for debug dump']
# ['c9c01e6eb1 HBASE-11225 Backport fix for HBASE-10417 index is not incremented in PutSortReducer#reduce() (Gustavo Anatoly)', 'ffc7215a50 HBASE-10417 index is not incremented in PutSortReducer#reduce() (Gustavo)', '95444356ef HBASE-10417 index is not incremented in PutSortReducer#reduce() (Gustavo)']
# ['b5d161c513 HBASE-10397 Fix findbugs introduced from HBASE-9426.']
# ['5645d48eac HBASE-10377 Add test for HBASE-10370 Compaction in out-of-date Store causes region split failure', 'bebb59dc10 HBASE-10370 Compaction in out-of-date Store causes region split failure, fix only', '3b9b0e1bc8 HBASE-10370 Compaction in out-of-date Store causes region split failure, fix only', 'c27bfd6acc HBASE-10370 revert due to TestSplitTransactionOnCluster.testSplitFailedCompactionAndSplit failure', '1abfabaaa4 HBASE-10370 revert due to TestSplitTransactionOnCluster.testSplitFailedCompactionAndSplit failure', '9b10589954 HBASE-10370 Compaction in out-of-date Store causes region split failed', 'e7c36e7822 HBASE-10370 Compaction in out-of-date Store causes region split failed', '868f9e4b38 HBASE-10370 Compaction in out-of-date Store causes region split failed']
# ['05a11e7fcc HBASE-1013 Add debugging around commit log cleanup', 'dfd2d6af99 HBASE-1013 Add debugging around commit log cleanup']
# ['d6e86d0524 HBASE-10079 ADDENDUM javadoc fix', '8eca550e02 HBASE-10079 ADDENDUM javadoc fix', '584793fb6f HBASE-10079 ADDENDUM javadoc fix', '3fb88f10af HBASE-10079 Race in TableName cache', '6873efa5a2 HBASE-10079 Race in TableName cache', '923becd6c0 HBASE-10079 Race in TableName cache']
# ['22f54af029 HBASE-10011 Fix some findbugs in the client - addendum: set OK_FINDBUGS_WARNINGS=89', '100cfded38 HBASE-10011 Fix some findbugs in the client', '35cea57fe5 HBASE-10011 Fix some findbugs in the client']
# ['e0c324f9d5 HBASE-10004 Some fixes for scoping sequence Ids to region level (Himanshu Vashishtha)']
# ['ca8b80433e HBASE-9778 Addendum; fix documentation markup', 'a772c4110d HBASE-9778 Add hint to ExplicitColumnTracker to avoid seeking', '9ffe4843dd HBASE-9778 Add hint to ExplicitColumnTracker to avoid seeking', 'd2eac30d68 HBASE-9778 Add hint to ExplicitColumnTracker to avoid seeking', '330a8e1fc3 HBASE-9778 Add hint to ExplicitColumnTracker to avoid seeking']
# ['d16d6257e6 import HBASE-3015: fix cleanup of files in recovered.edits', '7daffb3a42 HBASE-3015 recovered.edits files not deleted if it only contain edits that have already been flushed; hurts perf for all future opens of the region', '0d53298953 HBASE-3015 recovered.edits files not deleted if it only contain edits that have already been flushed; hurts perf for all future opens of the region']
# ["9955118995 HBASE-15195 Don't run findbugs on hbase-it; it has nothing in src/main/java"]

# %% [markdown]
# Capturing bug id, and commit id related to the bug id

# %%
commits = []
for x in range(0,len(com_log)):
    com = []
    com.append(bug_links[x])
    for z in range(0,len(com_log[x])):
        temp = str(com_log[x][z].split()[0:1]).replace("['",'').replace("']",'')
        com.append(temp)
    commits.append(com)
print (commits)
# Out:
# [['HBASE-9971', '8a6291a896'], ['HBASE-9961', '1e7fdb06b2', '560f000424', 'e5946ba799', '18e018b3d9'], ['HBASE-9958', '8a6291a896', '4b84160b37', 'c5a3048fec'], ['HBASE-9908', 'f224e4721f', '16b799dae5', '61120fb62c', 'ff78f217fa'], ['HBASE-9893', 'c5fc5b993e', 'da89846cf7'], ['HBASE-9856', '13e9eda3e7'], ['HBASE-985', 'e3659aa246', '894c99bdb3'], ['HBASE-9843', '6dd52d7ed3', '53bb2f6be7'], ['HBASE-984', 'f78f944026', '963c1104dd'], ['HBASE-9786', '230cb08611', '6d0eade8b6'], ['HBASE-977', '5418547132', '1b49c9b6c4'], ['HBASE-9747', '201c67a7d8', '3f496372bf', 'b4df85d6b0', 'fc15e1ae39', 'a2a3071256', 'e7dfc21d4f'], ['HBASE-9745', '3d37252a32', '24f150ebbc', '0bd53be747', '86033abef2', 'd289eecd2f', '8aec79e00c', 'bcdd3eba60', 'ffeb4ab1e3'], ['HBASE-9704', '5ff5311da2', 'abbf77d9cb', 'bd01833201', '2d7c39e50c', 'a270d1c0a6', '045ee401b3', '8f76956cc6', '54b2f547c9', '84ee3d54d4', '94184eb5f8', '90c7d0d614', 'e475dca13d', 'db972590c6', 'e216445124', 'dcfd369293', 'ccc03f50f5', 'ff5a191a7b', '3b95287866', '29a28aa05c', 'e6b3951c4d', '7d38a444b3', '1d351abceb', '920e6f1ea5', '1aa35bf423'], ['HBASE-9698', '230cb08611', '6d0eade8b6', '36e4fe8a37', 'a07ef888e1'], ['HBASE-968', 'ae27a2bc3f', 'bf17c35a8f', 'c18a713726', 'f609ddabbc'], ['HBASE-9639', '91508fd564', '00927d1438'], ['HBASE-9534', '9f11a9d6b6', '5e36c8e6dd', '4793668c1d', '69e56e387d', '6bc48464ca'], ['HBASE-9519', '29909882ea'], ['HBASE-9415', 'de186bdb7b', 'd0cce3f48d', 'd50125a745'], ['HBASE-930', '029b37eade', 'c3c1c8ddbc', 'a0cffd6f12', '50ad3e6d12', '44b55114b4', 'f84bf5c8a1', 'ca07a6f30b', 'a1a6b437e0', '1f66d54b5d', '8dcc95d790', 'f69423a1d9', '3de18d1763', '06d1a00f83'], ['HBASE-927', 'cfb9cb2946', '838b238999', '55d0467c75', '78165487d9', '9950dd24de', '69cbc5d27c', '748842b131', '400e183da5', 'ad707c4f60'], ['HBASE-9238', '0c9f543e1c'], ['HBASE-9232', '7773da0cb4', '58ee2bbf24'], ['HBASE-9219', '8a9f332ac0'], ['HBASE-9205', '48c1e7aff3', 'f651b6a820'], ['HBASE-9164', '4dd82c9b1c', 'd7d0398713'], ['HBASE-9158', '2c80ed63b0', 'e7657c930b', 'bd3acd05d4', '3bc9e2c95c'], ['HBASE-9151', '87c2b88576', '57a307487f', '8d7ed731a9'], ['HBASE-9115', 'dc795cca20', 'd272cf1727', '2036dbb763', 'dfb7778d1a', 'b77483f695', '5b89721c1e'], ['HBASE-9114', '9f592ea0b4'], ['HBASE-9085', 'cea837fa8f', 'ee48ceb820', '08235fca23'], ['HBASE-9003', 'b2d1b154bb', 'a71dd16a70', 'bf2144fe60'], ['HBASE-9001', 'd06aa724b0', 'ff84a7ae16', '5dc4727113', '2fb6b8b7f3'], ['HBASE-8942', 'f14f42ec5b', '5f47f7b6a8', '8d3133aa0f', 'e97a20f8b1', 'a30d3f5c23', 'b0c406da07', '45e7540347'], ['HBASE-8930', 'e15deb5cf1', 'df4784be5a', 'da4167c42b', '6905ddc2e1', '30eb01f496', '633369205f', '41b9c58f96', '4f05fc60d5', '813f88a482', 'ee1562dace'], ['HBASE-8919', 'd390841912', '299b39532b'], ['HBASE-8917', 'da3e3046ad'], ['HBASE-8856', '6c43cd988b', 'afca885131'], ['HBASE-881', '428e685b75', '16a2c45780', '87102ae59b'], ['HBASE-8798', '9ccf16db51'], ['HBASE-8706', 'bcf89528dc', '8bb177d37f', '9763240f35', 'ba8801c2ff'], ['HBASE-8664', 'ed65f9bb6e', 'd6becac229'], ['HBASE-8627', 'f73a68178f', '2581ebb0b2'], ['HBASE-8615', 'dc716a9005', '4ec30df08f', '8bdcbb67ff', '1236068fd0'], ['HBASE-8532', '2eec2f340a', '93fab309db'], ['HBASE-8521', 'f2d10f4e9e', '49de0f9133'], ['HBASE-8519', '20c4b8a685', 'ad6292f86e', 'bc4992c0f8', 'f729fcd4ec'], ['HBASE-8500', 'b0a03df607', '0744c27fc8', 'e8b80ba94c', 'd2cfd53dc3', '0b6039a650', '98060a04ac', '1977527c57', 'c45f2f28f9', '04bbd5eaf7', '68b1e5c512'], ['HBASE-8467', '415e06f7a1', '2e44f61062'], ['HBASE-830', '986f364d03', '1fb69ec11a', '9b62798b11'], ['HBASE-826', '19c87a375d', 'ec8aeab847', '4dc9c3642c', '681367f310', '79d463d658', 'ed648b7327', 'd1adcf1629', '7627490bea'], ['HBASE-8259', 'b9c3497b8b', '8af84cb46d', 'ca669156cf', 'a34f3a364f', 'fff96309a6', '0c47666dee'], ['HBASE-8225', 'a79a77aa02', 'a96672bec6', '0bc9187d46'], ['HBASE-8223', '6605c597bd'], ['HBASE-8216', '635949147f'], ['HBASE-8207', '9e02c52762', '92d5967a86', '7e26d32349', 'ac97504dc5', '6930ff607f', 'aa ...

# %% [markdown]
# # Capturing bug-introducing change commit id

# %%
bugintro_cid = []
for jj, kk in enumerate(commits):
    if (len(kk) > 1):
        bi_cid = kk[len(kk)-1:]
        bi_cid.insert(0,kk[0])
        bugintro_cid.append(bi_cid)
print (len(bugintro_cid), "\n")
print (bugintro_cid)
# Out:
# 624
#
# [['HBASE-9971', '8a6291a896'], ['HBASE-9961', '18e018b3d9'], ['HBASE-9958', 'c5a3048fec'], ['HBASE-9908', 'ff78f217fa'], ['HBASE-9893', 'da89846cf7'], ['HBASE-9856', '13e9eda3e7'], ['HBASE-985', '894c99bdb3'], ['HBASE-9843', '53bb2f6be7'], ['HBASE-984', '963c1104dd'], ['HBASE-9786', '6d0eade8b6'], ['HBASE-977', '1b49c9b6c4'], ['HBASE-9747', 'e7dfc21d4f'], ['HBASE-9745', 'ffeb4ab1e3'], ['HBASE-9704', '1aa35bf423'], ['HBASE-9698', 'a07ef888e1'], ['HBASE-968', 'f609ddabbc'], ['HBASE-9639', '00927d1438'], ['HBASE-9534', '6bc48464ca'], ['HBASE-9519', '29909882ea'], ['HBASE-9415', 'd50125a745'], ['HBASE-930', '06d1a00f83'], ['HBASE-927', 'ad707c4f60'], ['HBASE-9238', '0c9f543e1c'], ['HBASE-9232', '58ee2bbf24'], ['HBASE-9219', '8a9f332ac0'], ['HBASE-9205', 'f651b6a820'], ['HBASE-9164', 'd7d0398713'], ['HBASE-9158', '3bc9e2c95c'], ['HBASE-9151', '8d7ed731a9'], ['HBASE-9115', '5b89721c1e'], ['HBASE-9114', '9f592ea0b4'], ['HBASE-9085', '08235fca23'], ['HBASE-9003', 'bf2144fe60'], ['HBASE-9001', '2fb6b8b7f3'], ['HBASE-8942', '45e7540347'], ['HBASE-8930', 'ee1562dace'], ['HBASE-8919', '299b39532b'], ['HBASE-8917', 'da3e3046ad'], ['HBASE-8856', 'afca885131'], ['HBASE-881', '87102ae59b'], ['HBASE-8798', '9ccf16db51'], ['HBASE-8706', 'ba8801c2ff'], ['HBASE-8664', 'd6becac229'], ['HBASE-8627', '2581ebb0b2'], ['HBASE-8615', '1236068fd0'], ['HBASE-8532', '93fab309db'], ['HBASE-8521', '49de0f9133'], ['HBASE-8519', 'f729fcd4ec'], ['HBASE-8500', '68b1e5c512'], ['HBASE-8467', '2e44f61062'], ['HBASE-830', '9b62798b11'], ['HBASE-826', '7627490bea'], ['HBASE-8259', '0c47666dee'], ['HBASE-8225', '0bc9187d46'], ['HBASE-8223', '6605c597bd'], ['HBASE-8216', '635949147f'], ['HBASE-8207', '1babc2abbc'], ['HBASE-8206', '38fc69c10c'], ['HBASE-8125', '2c684ee552'], ['HBASE-8119', 'e21a1ee4ae'], ['HBASE-8111', '9e270796d1'], ['HBASE-811', 'b55027819e'], ['HBASE-8085', '7465b3d076'], ['HBASE-808', 'f85e23cb43'], ['HBASE-8067', '95e4f53090'], ['HBASE-8062', '7181fa35a3'], ['HBASE-8058', '3564568830'], ['HBASE-8050', '579c4eb3b2'], ['HBASE-8044', '16c7c1e769'], ['HBASE-7966', '27dd86e0a0'], ['HBASE-7953', '4742310a5f'], ['HBASE-7920', '99a9328680'], ['HBASE-792', '9f00684d05'], ['HBASE-7914', '195e23fe01'], ['HBASE-790', '9f00684d05'], ['HBASE-7878', '2e2d95af14'], ['HBASE-7852', '1bafc48511'], ['HBASE-7817', '5ca140fe2f'], ['HBASE-7725', '1a766c42a1'], ['HBASE-7682', 'a3f0aea354'], ['HBASE-7669', '898f661663'], ['HBASE-7601', 'b96d60d659'], ['HBASE-7595', '28b79e1214'], ['HBASE-7588', '3b345cd684'], ['HBASE-7587', 'bda467aeca'], ['HBASE-7586', '5c8c3d0a8c'], ['HBASE-7521', '883ec67336'], ['HBASE-7517', '233dc24e3d'], ['HBASE-7508', '4e0af48fe4'], ['HBASE-7491', 'c739366d73'], ['HBASE-7443', '92c98a76d1'], ['HBASE-7435', 'f356d580c5'], ['HBASE-7417', '85d9f6b709'], ['HBASE-7390', 'deeb84ae5a'], ['HBASE-7275', '289ab6b87c'], ['HBASE-7198', '3b980dda5c'], ['HBASE-7083', '75682c0c5b'], ['HBASE-7002', 'f065232db0'], ['HBASE-6991', '9b3e63dcb7'], ['HBASE-697', 'f346a3d85a'], ['HBASE-6943', '0750adf8a2'], ['HBASE-6928', 'e64430e970'], ['HBASE-6920', '205c9b83ac'], ['HBASE-6918', 'd6cca23ed3'], ['HBASE-6871', '15e07e8548'], ['HBASE-6858', '529807b0e5'], ['HBASE-6846', 'f4923b98a6'], ['HBASE-6838', '17a2e1663a'], ['HBASE-681', '767d2765b5'], ['HBASE-6748', '10c1bceda4'], ['HBASE-6741', 'dbcad94d43'], ['HBASE-6728', '649126bdc5'], ['HBASE-6710', '6c4e39dcae'], ['HBASE-6697', '55fb6632b9'], ['HBASE-6619', '6f8104a966'], ['HBASE-6590', 'dec419003a'], ['HBASE-6583', '3e2399a7b1'], ['HBASE-656', 'c7165b1e30'], ['HBASE-649', 'c7165b1e30'], ['HBASE-6460', '4d726189eb'], ['HBASE-6421', 'd90f009688'], ['HBASE-6389', '3a68756704'], ['HBASE-6388', 'f5b5e66da1'], ['HBASE-6377', '349c82e0a0'], ['HBASE-6368', 'd6ed913ce5'], ['HBASE-6340', '6be9826a22'], ['HBASE-6284', '6505939970'], ['HBASE-6276', 'c80b254756'], ['HBASE-6200', '275bfdcc40'], ['HBASE-6164', '0c0e5af110'], ['HBASE-6138', '62154f1a1a'], ['HBASE-613', '4dbb084860'], ['HBASE-6123', '901c3a31ce'], ['HBASE-6121', 'f69428067b' ...

# %% [markdown]
# # Capturing candidate bug fix commit id

# %%
bugfix_cid = []
for jj, kk in enumerate(commits):
    if (len(kk) > 2):
        bugfix_cid.append(kk[0:len(kk)-1])
print (bugfix_cid)
# Out:
# [['HBASE-9971', '8a6291a896'], ['HBASE-9961', '1e7fdb06b2', '560f000424', 'e5946ba799', '18e018b3d9'], ['HBASE-9958', '8a6291a896', '4b84160b37', 'c5a3048fec'], ['HBASE-9908', 'f224e4721f', '16b799dae5', '61120fb62c', 'ff78f217fa'], ['HBASE-9893', 'c5fc5b993e', 'da89846cf7'], ['HBASE-9856', '13e9eda3e7'], ['HBASE-985', 'e3659aa246', '894c99bdb3'], ['HBASE-9843', '6dd52d7ed3', '53bb2f6be7'], ['HBASE-984', 'f78f944026', '963c1104dd'], ['HBASE-9786', '230cb08611', '6d0eade8b6'], ['HBASE-977', '5418547132', '1b49c9b6c4'], ['HBASE-9747', '201c67a7d8', '3f496372bf', 'b4df85d6b0', 'fc15e1ae39', 'a2a3071256', 'e7dfc21d4f'], ['HBASE-9745', '3d37252a32', '24f150ebbc', '0bd53be747', '86033abef2', 'd289eecd2f', '8aec79e00c', 'bcdd3eba60', 'ffeb4ab1e3'], ['HBASE-9704', '5ff5311da2', 'abbf77d9cb', 'bd01833201', '2d7c39e50c', 'a270d1c0a6', '045ee401b3', '8f76956cc6', '54b2f547c9', '84ee3d54d4', '94184eb5f8', '90c7d0d614', 'e475dca13d', 'db972590c6', 'e216445124', 'dcfd369293', 'ccc03f50f5', 'ff5a191a7b', '3b95287866', '29a28aa05c', 'e6b3951c4d', '7d38a444b3', '1d351abceb', '920e6f1ea5', '1aa35bf423'], ['HBASE-9698', '230cb08611', '6d0eade8b6', '36e4fe8a37', 'a07ef888e1'], ['HBASE-968', 'ae27a2bc3f', 'bf17c35a8f', 'c18a713726', 'f609ddabbc'], ['HBASE-9639', '91508fd564', '00927d1438'], ['HBASE-9534', '9f11a9d6b6', '5e36c8e6dd', '4793668c1d', '69e56e387d', '6bc48464ca'], ['HBASE-9519', '29909882ea'], ['HBASE-9415', 'de186bdb7b', 'd0cce3f48d', 'd50125a745'], ['HBASE-930', '029b37eade', 'c3c1c8ddbc', 'a0cffd6f12', '50ad3e6d12', '44b55114b4', 'f84bf5c8a1', 'ca07a6f30b', 'a1a6b437e0', '1f66d54b5d', '8dcc95d790', 'f69423a1d9', '3de18d1763', '06d1a00f83'], ['HBASE-927', 'cfb9cb2946', '838b238999', '55d0467c75', '78165487d9', '9950dd24de', '69cbc5d27c', '748842b131', '400e183da5', 'ad707c4f60'], ['HBASE-9238', '0c9f543e1c'], ['HBASE-9232', '7773da0cb4', '58ee2bbf24'], ['HBASE-9219', '8a9f332ac0'], ['HBASE-9205', '48c1e7aff3', 'f651b6a820'], ['HBASE-9164', '4dd82c9b1c', 'd7d0398713'], ['HBASE-9158', '2c80ed63b0', 'e7657c930b', 'bd3acd05d4', '3bc9e2c95c'], ['HBASE-9151', '87c2b88576', '57a307487f', '8d7ed731a9'], ['HBASE-9115', 'dc795cca20', 'd272cf1727', '2036dbb763', 'dfb7778d1a', 'b77483f695', '5b89721c1e'], ['HBASE-9114', '9f592ea0b4'], ['HBASE-9085', 'cea837fa8f', 'ee48ceb820', '08235fca23'], ['HBASE-9003', 'b2d1b154bb', 'a71dd16a70', 'bf2144fe60'], ['HBASE-9001', 'd06aa724b0', 'ff84a7ae16', '5dc4727113', '2fb6b8b7f3'], ['HBASE-8942', 'f14f42ec5b', '5f47f7b6a8', '8d3133aa0f', 'e97a20f8b1', 'a30d3f5c23', 'b0c406da07', '45e7540347'], ['HBASE-8930', 'e15deb5cf1', 'df4784be5a', 'da4167c42b', '6905ddc2e1', '30eb01f496', '633369205f', '41b9c58f96', '4f05fc60d5', '813f88a482', 'ee1562dace'], ['HBASE-8919', 'd390841912', '299b39532b'], ['HBASE-8917', 'da3e3046ad'], ['HBASE-8856', '6c43cd988b', 'afca885131'], ['HBASE-881', '428e685b75', '16a2c45780', '87102ae59b'], ['HBASE-8798', '9ccf16db51'], ['HBASE-8706', 'bcf89528dc', '8bb177d37f', '9763240f35', 'ba8801c2ff'], ['HBASE-8664', 'ed65f9bb6e', 'd6becac229'], ['HBASE-8627', 'f73a68178f', '2581ebb0b2'], ['HBASE-8615', 'dc716a9005', '4ec30df08f', '8bdcbb67ff', '1236068fd0'], ['HBASE-8532', '2eec2f340a', '93fab309db'], ['HBASE-8521', 'f2d10f4e9e', '49de0f9133'], ['HBASE-8519', '20c4b8a685', 'ad6292f86e', 'bc4992c0f8', 'f729fcd4ec'], ['HBASE-8500', 'b0a03df607', '0744c27fc8', 'e8b80ba94c', 'd2cfd53dc3', '0b6039a650', '98060a04ac', '1977527c57', 'c45f2f28f9', '04bbd5eaf7', '68b1e5c512'], ['HBASE-8467', '415e06f7a1', '2e44f61062'], ['HBASE-830', '986f364d03', '1fb69ec11a', '9b62798b11'], ['HBASE-826', '19c87a375d', 'ec8aeab847', '4dc9c3642c', '681367f310', '79d463d658', 'ed648b7327', 'd1adcf1629', '7627490bea'], ['HBASE-8259', 'b9c3497b8b', '8af84cb46d', 'ca669156cf', 'a34f3a364f', 'fff96309a6', '0c47666dee'], ['HBASE-8225', 'a79a77aa02', 'a96672bec6', '0bc9187d46'], ['HBASE-8223', '6605c597bd'], ['HBASE-8216', '635949147f'], ['HBASE-8207', '9e02c52762', '92d5967a86', '7e26d32349', 'ac97504dc5', '6930ff607f', 'aa ...

# %% [markdown]
# Counting the number of candidate bug fix commit id

# %%
summ = 0
for b, bfc in enumerate(bugfix_cid):
    summ = summ + (len(bfc)-1)
print ("The number of candidate bug fix commit id = %i" %summ)
# Out:
# The number of candidate bug fix commit id = 2533

# %%
bugintro = go.Bar(
    x = ['Bug-introducing change commits'],
    y = [len(bugintro_cid)],
    name = 'Bug-introducing change commits',
    text = [len(bugintro_cid)],
    textposition = 'auto'
)

bugfix = go.Bar(
    x = ['Candidate bug-fix commits'],
    y = [summ],
    name = 'Candidate bug-fix commits',
    text = [summ],
    textposition = 'auto'
)

data = [bugintro, bugfix]
layout = go.Layout(
    title = 'The number of Commits'
)

init_notebook_mode(connected=True)
fig = go.Figure(data=data, layout=layout)
iplot(fig, show_link=False)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="240cf794-adad-4eae-aabc-6e3b624a6ae1" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("240cf794-adad-4eae-aabc-6e3b624a6ae1", [{"type": "bar", "x": ["Bug-introducing change commits"], "y": [624], "name": "Bug-introducing change commits", "text": [624], "textposition": "auto"}, {"type": "bar", "x": ["Candidate bug-fix commits"], "y": [2533], "name": "Candidate bug-fix commits", "text": [2533], "textposition": "auto"}], {"title": "The number of Commits"}, {"showLink": false, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# # Extracting parent_id of bug-intro commits

# %%
parent_id = []
for v, w in enumerate(bugintro_cid):
    sys.stdout.write("\rExtracting parent id from bug-intro commit: {} / {}".format((v+1), len(bugintro_cid)))
    sys.stdout.flush()
    if w != []:
        git_cmd = "git log --pretty=%P -n1 " + w[1]
        temp = (str(execute_command(git_cmd, repository)).replace("b'",'').replace('(','',1).split("\\n"))[:-1]
        temps = [w,temp]
        newlist = list(chain.from_iterable(temps))

    parent_id.append(newlist)
# Out:
# Extracting parent id from bug-intro commit: 624 / 624

# %% [markdown]
# Saving parent id in CSV file

# %%
with open(analyze_dir + "02_extracting_commitid/parentid_of_bugintro.csv", 'w') as parent:
    header = ['bug_id','bugintro_commitID','parent_id']
    writers = csv.writer(parent, delimiter=',')
    writers.writerow(header)
    for item in parent_id:
        writers.writerow(item)

dfparent = pd.read_csv(analyze_dir + "02_extracting_commitid/parentid_of_bugintro.csv")
dfparent = dfparent[header]
dfparent
# Out:
#           bug_id bugintro_commitID                                 parent_id
# 0     HBASE-9971        8a6291a896  c9d4d2c9b5e30ae79d0ec7782709eaa917600f9a
# 1     HBASE-9961        18e018b3d9  16b799dae56b54f82a14dc0e0ad24977f06df6f6
# 2     HBASE-9958        c5a3048fec  feca3e26c468744c91a90ecd4a972a5bd114526c
# 3     HBASE-9908        ff78f217fa  bf5f9e5240847c8788c9dce700dd94750325863d
# 4     HBASE-9893        da89846cf7  560f000424a2d73c5054d8138831480d5dc6b4c0
# 5     HBASE-9856        13e9eda3e7  7b4b061bcfb7da9d1056f4f964f4cc438bdab36e
# 6      HBASE-985        894c99bdb3  963c1104ddca96cbf85ceda3257c4b3d046e58d3
# 7     HBASE-9843        53bb2f6be7  3bebeca24d8e678bda2700f742c85191c841d559
# 8      HBASE-984        963c1104dd  98174c32c91c2f3b14d8e391afc06119919c07d2
# 9     HBASE-9786        6d0eade8b6  180a6490d83353e71bf430bc0a873057fe1457d4
# 10     HBASE-977        1b49c9b6c4  fcf98a9671e04d67e05130af69ace405695c4e71
# 11    HBASE-9747        e7dfc21d4f  bcc5439d40dcd1b4e9a23940e80f8c7afbe29ea2
# 12    HBASE-9745        ffeb4ab1e3  30837458ee43b6c1ff4fc88597fd05aedd2e8362
# 13    HBASE-9704        1aa35bf423  c689a6244eccbb69b6e07b14c445b2e80cff7c68
# 14    HBASE-9698        a07ef888e1  3be068f6da0426750c173a46229e7d91b80fafb6
# 15     HBASE-968        f609ddabbc  fc6ea9bcae213a1372fea632a6057428607cb3e9
# 16    HBASE-9639        00927d1438  e0d2eeeec2f1d905cc3325d1e5a6d6212a37004b
# 17    HBASE-9534        6bc48464ca  db0a4b2d07969a742bce90dc7eba8b539215503c
# 18    HBASE-9519        29909882ea  3c986c4c674abd9912dda1e0342e887e0e968eb0
# 19    HBASE-9415        d50125a745  8e592fad7fcd73171b5798bc8b97b43133def18c
# 20     HBASE-930        06d1a00f83  8b7d4da0f94daf45d4e22491bb5d1038efeda590
# 21     HBASE-927        ad707c4f60  19b5b764bc7c7c085c2688a3a3820c63b8938b48
# 22    HBASE-9238        0c9f543e1c  78b227bdf6a0b45ac92169f044bd3241cb9e0806
# 23    HBASE-9232        58ee2bbf24  1fe8c622c957744d9ab3f772257bfb1c65c08830
# 24    HBASE-9219        8a9f332ac0  814ef40f8767b2a3ca4ec2bb91a186df62e2abc7
# 25    HBASE-9205        f651b6a820  2f6ec97988c53d4f3836b6fef9e9f37245b8f043
# 26    HBASE-9164        d7d0398713  7773da0cb47b97e6c9c679d27d8a223233c0291e
# 27    HBASE-9158        3bc9e2c95c  eb197cbf04806854ebf0bf59fee8280bf08a139c
# 28    HBASE-9151        8d7ed731a9  b6c898a138571ab4bd21f167edeb0b3a5860f260
# 29    HBASE-9115        5b89721c1e  1a76ba53369868cb21944e4609130de26202fdc4
# ..           ...               ...                                       ...
# 594  HBASE-10901        c8ea643074  1aa35bf4238b65f51a57a1ec78a2af26337907c7
# 595  HBASE-10893        6a1b347964  f963095b5bb7eb1ba17633583e1f6082ccafea31
# 596  HBASE-10840        4487333e5e  e44d0d8083e5d4087f1c3a32058daa779c1d3fbb
# 597  HBASE-10808        54175f554a  4820b519eebb4888ed72d7b1a64319ac6a219b92
# 598  HBASE-10715        4eb9e5225d  829c3725c72b28b3a8d14282a8d8f3680b81aed5
# 599  HBASE-10675        ba5de65ae0  b68c4c149346e591991bd7fc9edc592ac51d09a4
# 600  HBASE-10656        a1a5f57bff  6bf39f535970f3befc82a21c44843ec12dd49527
# 601  HBASE-10647        2e28ec44c8  032ea4b380a6e323faaa9d13e8c0f51c46d66bf6
# 602  HBASE-10624        ce1e3b6c77  4dcf1ea57faa74ec6efd52baf7a6062ac27041a5
# 603  HBASE-10598        3233679759  303da389c728553db3dfcfb554e337468bff6a21
# 604   HBASE-1058        4dc924c609  4a97e95864aaa1d32f365ce66cd3f9e2ec72b9b4
# 605  HBASE-10578        5f9420aba0  8ff98a50f70f9c488c02e8d1fe0105ec668bec69
# 606  HBASE-10555        20c4b8a685  941e9cbb445539ad619fa96a8f791cb90df83a6a
# 607  HBASE-10528        45fc2bdd86  f57a9f5bd509a7e532723d0b0e4c97032a3d5482
# 608  HBASE-10514        731e2f6541  98cf3e27ee5fa30b962984629cc4195e5bb38276
# 609  HBASE-10485        df5bd6e99f  653e682d99f8ea73a9bd615e8d4cbb88d0faa3b0
# 610  HBASE-10460        e4e61a2e63  b909daaa3711a22f458514d265b47ae7dfb3ba7d
# 611  HBASE-10454        42a2456b44  6b7fb21ec03bbed8b0da36d8028041960ade5e3c
# 612  HBASE-10452        f1ad5cb938  0bafd16057f7e396153df1feaeb898fb50397f7d
# 613  HBASE-10446        b3b3d0ddff  3f9f4e00b6349c2524b026ab92234bd8d900c10c
# 614  HBASE-10417        95444356ef  07caf4bf8e77b26469c8bc49eaa278c3a4047612
# 615  HBASE-10397        b5d161c513  eb998894abe63657698ce3c280e0b75c686445ce
# 616  HBASE-10370        868f9e4b38  b3bfb416d28f2c343a3222021e72b459bd1b2626
# 617   HBASE-1013        dfd2d6af99  ad707c4f6000c4c8393c7b44075bb92abb7ceb99
# 618  HBASE-10079        923becd6c0  29426d2caae9e3f22c00f6ef279e812d50297f34
# 619  HBASE-10011        35cea57fe5  81f21ca409c5a1eec1143cc1ca8b60c286cf8531
# 620  HBASE-10004        e0c324f9d5  56d089a3e4885500abdc0b43cdb19c52b0bacaee
# 621   HBASE-9778        330a8e1fc3  7f3161a61ad086a7996cc0c78f43e21ede8521ba
# 622   HBASE-3015        0d53298953  35a2d9b42359f62f8944ad8808d30949856b6996
# 623  HBASE-15195        9955118995  9ec408e25b70f4ce586340b9396da67a1e38f6ca
#
# [624 rows x 3 columns]

# %% [markdown]
# # Extracting commit_id of candidate bug fix commits

# %%
bugfix_cid
# Out:
# [['HBASE-9971', '8a6291a896'],
#  ['HBASE-9961', '1e7fdb06b2', '560f000424', 'e5946ba799', '18e018b3d9'],
#  ['HBASE-9958', '8a6291a896', '4b84160b37', 'c5a3048fec'],
#  ['HBASE-9908', 'f224e4721f', '16b799dae5', '61120fb62c', 'ff78f217fa'],
#  ['HBASE-9893', 'c5fc5b993e', 'da89846cf7'],
#  ['HBASE-9856', '13e9eda3e7'],
#  ['HBASE-985', 'e3659aa246', '894c99bdb3'],
#  ['HBASE-9843', '6dd52d7ed3', '53bb2f6be7'],
#  ['HBASE-984', 'f78f944026', '963c1104dd'],
#  ['HBASE-9786', '230cb08611', '6d0eade8b6'],
#  ['HBASE-977', '5418547132', '1b49c9b6c4'],
#  ['HBASE-9747',
#   '201c67a7d8',
#   '3f496372bf',
#   'b4df85d6b0',
#   'fc15e1ae39',
#   'a2a3071256',
#   'e7dfc21d4f'],
#  ['HBASE-9745',
#   '3d37252a32',
#   '24f150ebbc',
#   '0bd53be747',
#   '86033abef2',
#   'd289eecd2f',
#   '8aec79e00c',
#   'bcdd3eba60',
#   'ffeb4ab1e3'],
#  ['HBASE-9704',
#   '5ff5311da2',
#   'abbf77d9cb',
#   'bd01833201',
#   '2d7c39e50c',
#   'a270d1c0a6',
#   '045ee401b3',
#   '8f76956cc6',
#   '54b2f547c9',
#   '84ee3d54d4',
#   '94184eb5f8',
#   '90c7d0d614',
#   'e475dca13d',
#   'db972590c6',
#   'e216445124',
#   'dcfd369293',
#   'ccc03f50f5',
#   'ff5a191a7b',
#   '3b95287866',
#   '29a28aa05c',
#   'e6b3951c4d',
#   '7d38a444b3',
#   '1d351abceb',
#   '920e6f1ea5',
#   '1aa35bf423'],
#  ['HBASE-9698', '230cb08611', '6d0eade8b6', '36e4fe8a37', 'a07ef888e1'],
#  ['HBASE-968', 'ae27a2bc3f', 'bf17c35a8f', 'c18a713726', 'f609ddabbc'],
#  ['HBASE-9639', '91508fd564', '00927d1438'],
#  ['HBASE-9534',
#   '9f11a9d6b6',
#   '5e36c8e6dd',
#   '4793668c1d',
#   '69e56e387d',
#   '6bc48464ca'],
#  ['HBASE-9519', '29909882ea'],
#  ['HBASE-9415', 'de186bdb7b', 'd0cce3f48d', 'd50125a745'],
#  ['HBASE-930',
#   '029b37eade',
#   'c3c1c8ddbc',
#   'a0cffd6f12',
#   '50ad3e6d12',
#   '44b55114b4',
#   'f84bf5c8a1',
#   'ca07a6f30b',
#   'a1a6b437e0',
#   '1f66d54b5d',
#   '8dcc95d790',
#   'f69423a1d9',
#   '3de18d1763',
#   '06d1a00f83'],
#  ['HBASE-927',
#   'cfb9cb2946',
#   '838b238999',
#   '55d0467c75',
#   '78165487d9',
#   '9950dd24de',
#   '69cbc5d27c',
#   '748842b131',
#   '400e183da5',
#   'ad707c4f60'],
#  ['HBASE-9238', '0c9f543e1c'],
#  ['HBASE-9232', '7773da0cb4', '58ee2bbf24'],
#  ['HBASE-9219', '8a9f332ac0'],
#  ['HBASE-9205', '48c1e7aff3', 'f651b6a820'],
#  ['HBASE-9164', '4dd82c9b1c', 'd7d0398713'],
#  ['HBASE-9158', '2c80ed63b0', 'e7657c930b', 'bd3acd05d4', '3bc9e2c95c'],
#  ['HBASE-9151', '87c2b88576', '57a307487f', '8d7ed731a9'],
#  ['HBASE-9115',
#   'dc795cca20',
#   'd272cf1727',
#   '2036dbb763',
#   'dfb7778d1a',
#   'b77483f695',
#   '5b89721c1e'],
#  ['HBASE-9114', '9f592ea0b4'],
#  ['HBASE-9085', 'cea837fa8f', 'ee48ceb820', '08235fca23'],
#  ['HBASE-9003', 'b2d1b154bb', 'a71dd16a70', 'bf2144fe60'],
#  ['HBASE-9001', 'd06aa724b0', 'ff84a7ae16', '5dc4727113', '2fb6b8b7f3'],
#  ['HBASE-8942',
#   'f14f42ec5b',
#   '5f47f7b6a8',
#   '8d3133aa0f',
#   'e97a20f8b1',
#   'a30d3f5c23',
#   'b0c406da07',
#   '45e7540347'],
#  ['HBASE-8930',
#   'e15deb5cf1',
#   'df4784be5a',
#   'da4167c42b',
#   '6905ddc2e1',
#   '30eb01f496',
#   '633369205f',
#   '41b9c58f96',
#   '4f05fc60d5',
#   '813f88a482',
#   'ee1562dace'],
#  ['HBASE-8919', 'd390841912', '299b39532b'],
#  ['HBASE-8917', 'da3e3046ad'],
#  ['HBASE-8856', '6c43cd988b', 'afca885131'],
#  ['HBASE-881', '428e685b75', '16a2c45780', '87102ae59b'],
#  ['HBASE-8798', '9ccf16db51'],
#  ['HBASE-8706', 'bcf89528dc', '8bb177d37f', '9763240f35', 'ba8801c2ff'],
#  ['HBASE-8664', 'ed65f9bb6e', 'd6becac229'],
#  ['HBASE-8627', 'f73a68178f', '2581ebb0b2'],
#  ['HBASE-8615', 'dc716a9005', '4ec30df08f', '8bdcbb67ff', '1236068fd0'],
#  ['HBASE-8532', '2eec2f340a', '93fab309db'],
#  ['HBASE-8521', 'f2d10f4e9e', '49de0f9133'],
#  ['HBASE-8519', '20c4b8a685', 'ad6292f86e', 'bc4992c0f8', 'f729fcd4ec'],
#  ['HBASE-8500',
#   'b0a03df607',
#   '0744c27fc8',
#   'e8b80ba94c',
#   'd2cfd53dc3',
#   '0b6039a650',
#   '98060a04ac',
#   '1977527c57',
#   'c45f2f28f9',
#   '04bbd5eaf7',
#   '68b1e5c512'],
#  ['HBASE-8467', '415e06f7a1', '2e44f61062'],
#  ['HBASE-830', '986f364d03', '1fb69ec11a', '9b62798b11'],
#  ['HBASE-826',
#   '19c87a375d',
#   'ec8aeab847',
#   '4dc9c3642c',
#   '681367f310',
#   '79d463d658',
#   'ed648b7327',
#   'd1adcf1629',
#   '7627490bea'],
#  ['HBASE-8259',
#   'b9c3497b8b',
#   '8af84cb46d',
#   'ca669156cf',
#   'a34f3a364f',
#   'fff96309a6',
#   '0c47666dee'],
#  ['HBASE-8225', 'a79a77aa02', 'a96672bec6', '0bc9187d46'],
#  ['HBASE-8223', '6605c597bd'],
#  ['HBASE-8216', '635949147f'],
#  ['HBASE-8207',
#   '9e02c52762',
#   '92d5967a86',
#   '7e26d32349',
#   'ac97504dc5',
#   '6930ff607f',
#   'aa851e3b7a',
#   'c5a16ef24c',
#   '542b8dcc1f',
#   '9087f50a5f',
#   '1babc2abbc'],
#  ['HBASE-8206', '38fc69c10c'],
#  ['HBASE-8125', '8e664d8133', '2c684ee552'],
#  ['HBASE-8119', '089e876398', '77904ce78a', 'e21a1ee4ae'],
#  ['HBASE-8111', '9e270796d1'],
#  ['HBASE-811',
#   '0696c139f5',
#   'a5a72605cf',
#   'dbba69fce5',
#   'ca41de9b1b',
#   '0c3bd478b3',
#   'b55027819e'],
#  ['HBASE-8085', 'd004827b82', '7465b3d076'],
#  ['HBASE-808',
#   '4456a8f5cf',
#   'aabc02c44b',
#   '4c2a6f66f1',
#   'fba07d1808',
#   '78b53558b8',
#   'f85e23cb43'],
#  ['HBASE-8067',
#   '50256d7035',
#   '39e7e66ae9',
#   '448f2f7902',
#   '986c9fbed6',
#   '9230c45c7e',
#   '770219fccc',
#   '302ce0325b',
#   '90eaac74d5',
#   '95e4f53090'],
#  ['HBASE-8062', '24736e83bb', '7181fa35a3'],
#  ['HBASE-8058', 'ddb06ad449', '3564568830'],
#  ['HBASE-8050', '579c4eb3b2'],
#  ['HBASE-8044', '41e2c36c82', '486b290863', '831e3dc59a', '16c7c1e769'],
#  ['HBASE-7966',
#   '3a1b53f2fc',
#   'fd45b6fe06',
#   '70b1899e88',
#   '6f3af86452',
#   'ca1a0ea654',
#   '27dd86e0a0'],
#  ['HBASE-7953', '30f12477b2', 'cf328edb97', 'f7d02a07d8', '4742310a5f'],
#  ['HBASE-7920', 'ad99387bfe', '66512747bf', '3c44b28c94', '99a9328680'],
#  ['HBASE-792', '92bd62bf58', 'e2a146d694', 'b3bdd512f3', '9f00684d05'],
#  ['HBASE-7914', '2cccddf35d', '195e23fe01'],
#  ['HBASE-790',
#   '942c54cf56',
#   '0d8ab3cad8',
#   '165e2ed915',
#   'a9aef2181d',
#   'b3bdd512f3',
#   '9f00684d05'],
#  ['HBASE-7878',
#   'c565b2f13a',
#   '1aa9c548fc',
#   'c5d6b90eb8',
#   '57a4c03bbb',
#   'ed9a0a5091',
#   '030628c553',
#   'b3647fec74',
#   '3b4b9b3c7a',
#   '7850fda086',
#   '17c662c46c',
#   '28cfad9739',
#   '31c1c9e7e6',
#   '708669b53f',
#   'e253150cf3',
#   '6722e26df1',
#   'dc470e0be7',
#   'bfbc70a68a',
#   '46db70556e',
#   '21eda243ad',
#   '33f7a4d7ff',
#   '50a47a9023',
#   '539ff195e8',
#   '3b923a92c5',
#   '41208aa44f',
#   '2e2d95af14'],
#  ['HBASE-7852', '2f1579e92e', '1bafc48511'],
#  ['HBASE-7817', '77df789608', 'ff3ae92d1f', '5ca140fe2f'],
#  ['HBASE-7725', '5068650101', '43edd93495', 'f66bbf1ca4', '1a766c42a1'],
#  ['HBASE-7682', 'a3f0aea354'],
#  ['HBASE-7669', '479232c610', 'e9f14f1073', '4d7b2824be', '898f661663'],
#  ['HBASE-7601', 'b96d60d659'],
#  ['HBASE-7595', '28b79e1214'],
#  ['HBASE-7588', 'f60b8246e7', 'c3e140cd14', '3b345cd684'],
#  ['HBASE-7587', '152ec1cc7f', '05934d7405', 'bda467aeca'],
#  ['HBASE-7586', '5c8c3d0a8c'],
#  ['HBASE-7521', '837f89bd79', 'efead793d4', '6ab7671f08', '883ec67336'],
#  ['HBASE-7517', '24e4df74ea', '69cbc81e5c', '8eee0f17ba', '233dc24e3d'],
#  ['HBASE-7508', '4e0af48fe4'],
#  ['HBASE-7491', 'c739366d73'],
#  ['HBASE-7443', '4409ba741c', '92c98a76d1'],
#  ['HBASE-7435',
#   '9ead77761f',
#   '8e664d8133',
#   '2c684ee552',
#   '5640731663',
#   'f356d580c5'],
#  ['HBASE-7417', 'b8784b73e5', '65d764e979', '85d9f6b709'],
#  ['HBASE-7390', 'deeb84ae5a'],
#  ['HBASE-7275', '289ab6b87c'],
#  ['HBASE-7198', '3b980dda5c'],
#  ['HBASE-7083', '75682c0c5b'],
#  ['HBASE-7002', 'f065232db0'],
#  ['HBASE-6991', 'd004827b82', '7465b3d076', '9b3e63dcb7'],
#  ['HBASE-697',
#   '1371c33e8d',
#   'e522b64665',
#   '0023b81e82',
#   'fddd62e6c5',
#   '83c1c30938',
#   'e30ed932bb',
#   'c65c58905b',
#   'f346a3d85a'],
#  ['HBASE-6943', '0750adf8a2'],
#  ['HBASE-6928', '610ea30534', 'e64430e970'],
#  ['HBASE-6920',
#   '12315b8597',
#   'ce9703aa4f',
#   '7bfd09e973',
#   'a0344c193f',
#   'bb54590ab5',
#   '11496b6f72',
#   '205c9b83ac'],
#  ['HBASE-6918', 'd6cca23ed3'],
#  ['HBASE-6871',
#   '2f850f964a',
#   '6abd8dec5e',
#   'dd2015d6ad',
#   '061a2457b1',
#   '9d470279dd',
#   '267b941c4c',
#   'e496b61aa1',
#   '215d216275',
#   'a4fbfcf640',
#   '473dcddb55',
#   '79e79ef090',
#   'd02e466bc2',
#   'c0b38e6c57',
#   '15e07e8548'],
#  ['HBASE-6858',
#   'bb563c3603',
#   '3a0b571d7b',
#   'e30829d8c1',
#   '9712f25f8f',
#   '9526aeb2a8',
#   '9b789a9d67',
#   '6bee1177a2',
#   '529807b0e5'],
#  ['HBASE-6846', 'd487401613', '3ab7fe3e6e', 'f4923b98a6'],
#  ['HBASE-6838', '4ca039e4e3', '17a2e1663a'],
#  ['HBASE-681', '80fa33698f', 'f02a98da07', '767d2765b5'],
#  ['HBASE-6748', '2cccddf35d', '195e23fe01', '10c1bceda4'],
#  ['HBASE-6741', '72aba5f19e', 'dbcad94d43'],
#  ['HBASE-6728',
#   'db380918a4',
#   '5754b24e57',
#   '770605db8c',
#   '1a32bfed45',
#   '1048d15c6a',
#   '649126bdc5'],
#  ['HBASE-6710',
#   '4c7a465b00',
#   '58f3f30cb3',
#   '802f264f4e',
#   'baa5d4675a',
#   '6c4e39dcae'],
#  ['HBASE-6697', '55fb6632b9'],
#  ['HBASE-6619', '6f8104a966'],
#  ['HBASE-6590', '564fc2e7c3', '1673fee154', 'dec419003a'],
#  ['HBASE-6583', '4606107e1d', '510cb9f71d', '7e02b67d30', '3e2399a7b1'],
#  ['HBASE-656', 'f328681e00', 'c7165b1e30'],
#  ['HBASE-649', 'f328681e00', 'c7165b1e30'],
#  ['HBASE-6460',
#   '7c16621e1b',
#   '78b3ca68c1',
#   '936caf1b39',
#   '9734a67ab4',
#   '4d726189eb'],
#  ['HBASE-6421', 'd90f009688'],
#  ['HBASE-6389',
#   '505bfe4363',
#   '8738056386',
#   '6f6f425a31',
#   'c6038306f5',
#   '983d08709e',
#   '5586daa4de',
#   'd9a7c8cd60',
#   'e0d9503dd7',
#   '3a68756704'],
#  ['HBASE-6388', '27c67b8577', 'f5b5e66da1'],
#  ['HBASE-6377', '528d95d964', 'c3fcaa3560', '349c82e0a0'],
#  ['HBASE-6368', '07eb671bc9', 'd6ed913ce5'],
#  ['HBASE-6340',
#   '8767127966',
#   '7538a94704',
#   '3fadfe5958',
#   '124d48e61a',
#   '23f61b37bb',
#   'a7dde5bb90',
#   '4ae9102b28',
#   '6be9826a22'],
#  ['HBASE-6284', '003df0419f', 'c2afb45db9', '2bd71320b2', '6505939970'],
#  ['HBASE-6276',
#   'f4165e27ce',
#   'aae0227054',
#   'a39d417edd',
#   '5a676a601e',
#   'c80b254756'],
#  ['HBASE-6200',
#   '62f038308e',
#   'd97099951a',
#   '98b05fce1f',
#   'bf3697d750',
#   '275bfdcc40'],
#  ['HBASE-6164', 'f727c0d5ec', '0c0e5af110'],
#  ['HBASE-6138', '181d2ea889', '62154f1a1a'],
#  ['HBASE-613',
#   'ae97400be0',
#   '769b0e5c8c',
#   '193deb330d',
#   '80fa33698f',
#   'f02a98da07',
#   '4dbb084860'],
#  ['HBASE-6123', '901c3a31ce'],
#  ['HBASE-6121', 'f69428067b'],
#  ['HBASE-6112', '9aa80d2696', '4ae26c1246'],
#  ['HBASE-6110', '3fa097b01c', '99613b8746', 'a113f4c291'],
#  ['HBASE-6088',
#   '1761677cef',
#   '1869b424ba',
#   '77b446186c',
#   '4c5a7bbfb3',
#   'a9a4dbe59c',
#   'ccb9c74400'],
#  ['HBASE-6060', 'efead793d4', '883ec67336', 'ddb9e96654'],
#  ['HBASE-6059', '4eb48a2043', '5144d15ce3', '8ea00217ed', 'b3ec7ced77'],
#  ['HBASE-5974', '8f9faabf57', '624021fb4d', 'c9073c4631'],
#  ['HBASE-5919', '7692e2efb7'],
#  ['HBASE-588',
#   '03ce494494',
#   'fb2db8cdaa',
#   '75c73ccbbb',
#   'e1da900df8',
#   '1d199b4b7b'],
#  ['HBASE-586', 'ee27270ee9', 'cffa3a254e', '32ce612048'],
#  ['HBASE-5825', '10cada8d0b', '183b567f6f', 'a0a2674c42'],
#  ['HBASE-5824', 'e05c21c0cb', '85842f019e', '0b30494edb'],
#  ['HBASE-5805', '5ec931d5c7', '0f28bc4b6c'],
#  ['HBASE-5799', '44ec501a2b'],
#  ['HBASE-5781',
#   '8db34840c9',
#   '711a90655c',
#   'a91b3977f2',
#   '7f7bc2b6b6',
#   '44a05d4380'],
#  ['HBASE-5763', '421400c256', 'c21266e5b2'],
#  ['HBASE-5744', '00316a4a51', '46286a023e'],
#  ['HBASE-5743', '20e281d7e1'],
#  ['HBASE-5730', 'bff42e1d84'],
#  ['HBASE-5727', 'c831d7b512', '1044d5e353', '66772ce043', 'e1449b5538'],
#  ['HBASE-5700', '8764ccd917'],
#  ['HBASE-5611',
#   '1f5e7da87e',
#   '1ea241364f',
#   '224cfd640d',
#   '3f5800a3f1',
#   '9f3d9a4283',
#   '8c8922da96',
#   'c896b73549',
#   'b6f7573a3b',
#   'b8554c84d4',
#   'b695b64dfa'],
#  ['HBASE-5598', '9fac4877d3', '81b15f1907'],
#  ['HBASE-5597', '1629b1a219', '3c58fdacf1', '5856e90720'],
#  ['HBASE-5596', 'a703e49824', '998367baf1', 'd5b5fabf14', '3fd6997380'],
#  ['HBASE-5567', 'df97e219c4', 'ab2b1acced', '2314945b8b'],
#  ['HBASE-5566', '04c6066df8'],
#  ['HBASE-5562', '63bd5eae5b', '0ae06d72b6', 'd04201683a'],
#  ['HBASE-554', 'a00fd30d8a', '48899525e5', '53563c5586', '5a43af4b99'],
#  ['HBASE-552', 'de57a6f401', 'a1f8ee8ac1', 'c729049956', '425a522a45'],
#  ['HBASE-5499', '624b0a51b2', '6783a4cd96', 'ffa518256f'],
#  ['HBASE-5470', '85c90d9274', 'ded2006ec9'],
#  ['HBASE-5437', 'b0d4403059', 'e7cfa2da58'],
#  ['HBASE-5387', 'e4e8c9dc5b', 'b50714c043', 'a148490496'],
#  ['HBASE-532',
#   '03ce494494',
#   'fb2db8cdaa',
#   '75c73ccbbb',
#   'e1da900df8',
#   '1d199b4b7b',
#   '26c2702c12',
#   'ef5bb6f316',
#   '7475ce01fa',
#   '373761483f',
#   '64e3f031ea'],
#  ['HBASE-5286',
#   '3d906ed52b',
#   'eb42e72b89',
#   '84c103829e',
#   '0132176084',
#   '180b41f518',
#   '11446b1bd6',
#   'abaad0bec9'],
#  ['HBASE-5204', '0abb51186a', 'e20aa2b3a6', '35cd894356'],
#  ['HBASE-5137',
#   '051c8981c0',
#   'abe549d38e',
#   '17af5827a5',
#   'e06aaf4ecc',
#   '0820fbddd3'],
#  ['HBASE-5104', 'd2ca6bfe63', 'e83952f9af'],
#  ['HBASE-5085', '8edf120cf7', '31b10cd5f2'],
#  ['HBASE-5081',
#   'cb8e30ae17',
#   'ff3cf1aeda',
#   '00a846ff20',
#   '6b39d23401',
#   '04d9afead2',
#   '7569cea558',
#   '436e064a2c',
#   '6c97552ee1',
#   'eb9f9a9e78',
#   'fd27501c1c',
#   '3e92ac2ddb',
#   'fa979ebab2',
#   'b8c423408a',
#   '72c1f6c8c7',
#   '69a45fe909',
#   '9f986b0dca'],
#  ['HBASE-5077',
#   '482a460546',
#   'c5b874fff0',
#   '26de3b2c74',
#   '04dd71214a',
#   'e76a78e103',
#   'bcde7a436f'],
#  ['HBASE-505', 'f15048d4d0', 'b104b3235b', '90e3cb13ca'],
#  ['HBASE-5029',
#   '0766dd12f2',
#   '1222383f1d',
#   '48f3c24dc6',
#   '48ccb28e81',
#   '4c2c89a9d0',
#   '185c0c7dd7',
#   'cd8b64fb38',
#   'a157c07ead',
#   '86a3830175',
#   '203d2828be',
#   '3cad85bc77',
#   'badab7888f',
#   'e4c0fd9231'],
#  ['HBASE-501',
#   '4ea64897fe',
#   '1e27f603a1',
#   '277f675af6',
#   'c1f974bbee',
#   '55f01a9863',
#   'bba36ce79a'],
#  ['HBASE-500', 'da595915a9'],
#  ['HBASE-4997', 'bcaabd9105', '4b8eb16ea9', '76a2db4d50', '9a74916dae'],
#  ['HBASE-4927',
#   'bb7f82ac71',
#   '925c25fdda',
#   '61683142da',
#   'e8123d2b21',
#   '1f176022fe',
#   'e1855a9344'],
#  ['HBASE-4890', '0f7285a81a', '3c7cd28524', 'c5570926a2', 'c5354bf129'],
#  ['HBASE-4883', '8ed781ada7', 'ea764bd727', '01c389c879', '625889c281'],
#  ['HBASE-4823', '0d2aab190e'],
#  ['HBASE-4799',
#   'c991dba669',
#   'ea3484ecea',
#   'f7099fa5c7',
#   'c9d5a838d0',
#   '04b1c45b94'],
#  ['HBASE-4758', '2235988874'],
#  ['HBASE-4722',
#   '451303c3cb',
#   '2ce1d7c97c',
#   'ec1c5835ec',
#   '3fab67a8b5',
#   'b0a61e290e'],
#  ['HBASE-4686', '1c7d82cdad'],
#  ['HBASE-4645', '6e0c0ec263', '770cc7d5d2', 'aa2c97b3b7', '9ffe7cb666'],
#  ['HBASE-4589', 'af700ae33e', 'cbfd640aab', '4d776c28b9', 'efa951b6ab'],
#  ['HBASE-4540',
#   '0a98312a9e',
#   '5cd3b9979b',
#   '5331d83421',
#   '3d50077db1',
#   'bd06d43d93'],
#  ['HBASE-4539', '5331d83421', '3d50077db1', 'bd06d43d93'],
#  ['HBASE-4531',
#   '1f2f565409',
#   '6232eae926',
#   '82c9209931',
#   'ef24e43470',
#   'cb845c04d8',
#   '6ae7807237'],
#  ['HBASE-4505', '435fea6d79', '0db9b9b148'],
#  ['HBASE-4400',
#   'aa6d6c7a9e',
#   'e866d8091d',
#   '034215f247',
#   'ab404d8f36',
#   '89b5c7bf10',
#   '3cc7e62571',
#   'e282e25dac'],
#  ['HBASE-4367', '3dc7b7f69b', '9570f3c907', '7c56111aaa', '0aafb370ce'],
#  ['HBASE-4350', 'b043d60317', '2077f41f18', '76b123052e', '9f3c81e87d'],
#  ['HBASE-4153',
#   '0b9498a53c',
#   '083d104243',
#   'a7318c7969',
#   '1ad63afb70',
#   '9ab414f1dc',
#   '2786fd5863',
#   '83da96047e',
#   '08d56e35e4',
#   'bf8af69d8d',
#   '76ba002ef7',
#   'a36c666a87',
#   'd098ab3b2c',
#   '7e6a6538b4',
#   'bd372dcea7'],
#  ['HBASE-4150',
#   '738f80c221',
#   'd453688d1a',
#   '4b84ea5a0a',
#   '061f1bcd73',
#   '2c772a97ab',
#   '0aa723c2a3',
#   'a9031452f7',
#   '6acdab46a1'],
#  ['HBASE-4149', '026b437eff', 'b2d802611f'],
#  ['HBASE-4138',
#   '5cae3a6b66',
#   '2889431d93',
#   '1c5e23f215',
#   'b993a611e1',
#   '5e4f28c289',
#   'd1cb273b2f'],
#  ['HBASE-4078', 'df9b82c082', '98cad6e708', 'fa26da20db', '790feddf2d'],
#  ['HBASE-4075', '3314b87804', 'df9c2fdc30', 'd69b198ba9'],
#  ['HBASE-4020', 'a9e7b929e7', '1a5251661e', '829cdddeec'],
#  ['HBASE-4005', '2851a9dfe3', '7e87980347', '170bed8651'],
#  ['HBASE-3987', '73cb88aef3', '3f59c6a0e5', '6f09e358e0', '949f7a68db'],
#  ['HBASE-3979', 'c98dc2c4b4', '7ccbc3bbb1'],
#  ['HBASE-3939', 'ae0dccc833', '7ccda81373', '7d8d42d01b', '2e678eaab6'],
#  ['HBASE-3912',
#   'e341eb76cb',
#   '60d7a81833',
#   '7d86a5998b',
#   '1c6a02a046',
#   '981f414cd3',
#   'cd8f643954'],
#  ['HBASE-3904',
#   'edf2b7901a',
#   'd37e6eb390',
#   'de919df41a',
#   '04e89f8ae4',
#   '1add4cc5d2',
#   'abccc7fd9f',
#   '7fa7d15daf',
#   '1f3a4fefb8',
#   '46924a1dc2',
#   '521141cdc6',
#   '18987b9d4d',
#   'a4482ae1ac',
#   'e3f8560143',
#   '24c18ac1e9'],
#  ['HBASE-3872',
#   '6fd573c3b0',
#   'f54803aac2',
#   '185e57e58c',
#   '0a0ce9f1ae',
#   '5872ef811b',
#   '7f10f29425',
#   'ca7452b4b6'],
#  ['HBASE-3832', 'c80200bded', '097edf7bc4'],
#  ['HBASE-3821', 'ce20845951', '81e9be2518', '724ddc58bf', '8e0e63e0a8'],
#  ['HBASE-3819', '95a45d1341', '2e84b07763', 'e01e57ff92', '599b7e6f7d'],
#  ['HBASE-3813', '8ffaac2003', '1162a81b92', 'e56c8db56e'],
#  ['HBASE-3793', '7656d7568a', '243c222ccd', '76a743e8f0', 'f0b1b298c7'],
#  ['HBASE-3762', 'f616c0c709', '07353b5618', 'a7f8453d50', '02659a4882'],
#  ['HBASE-3750',
#   '7eddae4687',
#   '9fe4b7c5bc',
#   '1b438175a3',
#   'c81146580a',
#   '56b76bd434',
#   '13bc223d04'],
#  ['HBASE-3741', '4219e2accb', '0e29fbf876', 'afea4ede2a', 'a5863ce0e7'],
#  ['HBASE-3708', 'b634180d5c', '7f90ea5860', '6aa734ee92', 'b10bacf1e8'],
#  ['HBASE-3690', '04afdf9633', 'c40efc3887'],
#  ['HBASE-3674',
#   '992bf057e7',
#   '45e341b8b7',
#   '7437b11bec',
#   'dded2af3e0',
#   '5125ae04fb',
#   '53a031f00c',
#   '8070b53b13'],
#  ['HBASE-3671',
#   '05c9826cba',
#   '1889d7ed5c',
#   '56aeaec832',
#   '23916d541d',
#   'f56380f1ce',
#   '33f7f5525b',
#   '2e41ea820e',
#   '3579bdf84b',
#   '2ea5d45bb0'],
#  ['HBASE-3669', '86e9f5f8c9', '237bc82af2', 'bd688ffaae'],
#  ['HBASE-3636', '32d4618caf', '856065dee8', '129ced5a3d'],
#  ['HBASE-3627',
#   '23606d0645',
#   '79b522db0c',
#   '89794648e6',
#   '16bb3bb633',
#   'cf3284dfb9',
#   '833fd0095e'],
#  ['HBASE-3622', 'c38558e545', '42b7a92450'],
#  ['HBASE-3515',
#   '930eb49759',
#   '346aa36b77',
#   'cb9e52fe6b',
#   '08a9170236',
#   'fa8dcedb56',
#   'd051203938',
#   '1aaaac0c92',
#   'c9449f0598',
#   'ef29cac094',
#   '2b7560b147',
#   '01af2a830e'],
#  ['HBASE-3481', 'fa81c75aed'],
#  ['HBASE-3421',
#   'e3acd1dd77',
#   '15a396c926',
#   'd9158b505e',
#   'a8536b787c',
#   '61249dc5f3',
#   'ba305551e1',
#   '7efe1dbbce',
#   'bcaecda371',
#   '1244c9108f'],
#  ['HBASE-3416', '9937c30304', 'feda42e474', 'a3a2ce9215', '410d70fca7'],
#  ['HBASE-3374', 'a59bd1030b', 'e787973338', 'ec8f0ad428'],
#  ['HBASE-3337', 'c0c723f660', '092bdbbea6', '97adaad945'],
#  ['HBASE-3315', 'ef50ac96c4', 'd547429a14', 'b9c34cf91a'],
#  ['HBASE-3311', 'b1a82279a1', '5441eaa83d', 'ce3139a30e'],
#  ['HBASE-3298',
#   'b1a82279a1',
#   '5441eaa83d',
#   'ce3139a30e',
#   'be91a5326f',
#   'a3127bd6cd',
#   '0427950746',
#   '61fb4c2d77',
#   'd960ee49cb',
#   'b6a5c4189f',
#   'f6b7e8c6c3',
#   'fe2e720318',
#   '633c049091'],
#  ['HBASE-3275',
#   'cb85bf2e0a',
#   '182e82fa62',
#   '79a2cf9f3a',
#   '446c403dc4',
#   '429fc09852',
#   '9b45d9996f',
#   'de0ab29132'],
#  ['HBASE-3264',
#   '84134f360a',
#   '2778fced75',
#   'c0e4ac3571',
#   '307dafacfe',
#   '272806891a',
#   'e9b54394cb',
#   'a7b528a712',
#   '4ff0e7ac89',
#   '4122dc1fe5'],
#  ['HBASE-3241', 'd68e62c6b8', '4a6d4ff453', '3027f23030', '1c76849d3d'],
#  ['HBASE-3239', 'd68e62c6b8', '4a6d4ff453', '3027f23030', '1c76849d3d'],
#  ['HBASE-3232',
#   '3093d81540',
#   '571e8f8520',
#   '3fd0eedcdf',
#   'a3e56bb694',
#   'a14cd5950c',
#   '069fecaeb7',
#   '717fee6602'],
#  ['HBASE-3199', 'f102ec2722', '0cb9652dd1', 'ea9618df63'],
#  ['HBASE-3183', '053141a64f', '2fbceee800', '9009d8e489'],
#  ['HBASE-3179', '18a78fef4d', '10e1d0d6fc'],
#  ['HBASE-3159', '3523b66eec', '289ca8adae'],
#  ['HBASE-3114', '0f27ee880c', '13d8b4fdad'],
#  ['HBASE-3113',
#   'dcbcd4f2d4',
#   '02d9066f9e',
#   '509beae1e2',
#   '0d2dcd023c',
#   'e20615b917',
#   '98edfa4ba1',
#   'bcaa2dea49',
#   'c0be59b731'],
#  ['HBASE-3111', '954efa6e76', 'e334903b44', 'cd2bfd5b6a', '2379ca5a68'],
#  ['HBASE-3110', 'a01b4c5576', '095b37ecdf', '3d75d323e5', '14554236ef'],
#  ['HBASE-3100',
#   '0fcd520eb3',
#   '9a6b4f7bf7',
#   '25ae7a7b20',
#   '93fc8931f0',
#   '52bbd22187',
#   'af7f5c7d01'],
#  ['HBASE-3098',
#   'c8f2f45a99',
#   '7bee275901',
#   '9d3bb109db',
#   '4c85c84305',
#   '924f28e5c3',
#   '9ebe296b7f',
#   'b7f3cfbf05',
#   'dd74b67762'],
#  ['HBASE-3081', '2ca04bc197', 'aab46757ec', '586207bfbc'],
#  ['HBASE-3074',
#   '50b3582e33',
#   'a6b507c8f9',
#   'ff2d19229f',
#   'cfc48f2756',
#   'c4d59d99dd',
#   '2fa7c6b5c4',
#   '8ff999cf9a',
#   '5e2b839fc4'],
#  ['HBASE-3073', 'de39f4328d', '52fce12da6', '1ef046250f', '6a0a29bbf7'],
#  ['HBASE-3065',
#   '3444e23986',
#   'b41f705662',
#   '75673cbf9e',
#   'c75e396fb6',
#   '69bba8194c',
#   '5a8e6ff615',
#   'cf4b388e40',
#   '54e4164ce7',
#   '41d7084601',
#   'b11659d679',
#   '6dc7ccf377'],
#  ['HBASE-3063', 'b70e4b83c1', '937ede3133'],
#  ['HBASE-3060',
#   '5ccf27683b',
#   'c5450a99bc',
#   '78f75e6c7f',
#   '42a5ec76d3',
#   '2d8fb6f26c',
#   '91f6026883'],
#  ['HBASE-3039', '10a84f3b88', '6283630181'],
#  ['HBASE-3038',
#   'ad529f50de',
#   '4d25275040',
#   '07ad66ff14',
#   'd3a8c97ad8',
#   'b0dfb073a0'],
#  ['HBASE-3008',
#   '405eef0025',
#   '1e14da3d78',
#   '0787fa776c',
#   '1c2775af44',
#   '4e64653921'],
#  ['HBASE-3006',
#   '995fe0ddc7',
#   '1c2775af44',
#   '4e64653921',
#   'e532293310',
#   'c138f60112',
#   '96f8cbe9e2',
#   '6bd82e694f',
#   'cac06d4573',
#   '114a233eeb',
#   '763865630c',
#   '8d0f1cc155'],
#  ['HBASE-2997',
#   '1c2775af44',
#   '4e64653921',
#   '55633e79f1',
#   '8af3337f07',
#   '009f461738',
#   'cd10620e41'],
#  ['HBASE-2992', '1c2775af44', '4e64653921', 'b05d9ac937', '46f95e2df1'],
#  ['HBASE-2990', '1c2775af44', '4e64653921'],
#  ['HBASE-2989', '1c2775af44', '4e64653921', 'da611388b4', '1132c150e9'],
#  ['HBASE-2985', 'ae2f69790f', '1eede65ae1', '8ad7a706ac'],
#  ['HBASE-2944', '3f4115638c', '04afcd034c', 'f583f2912c'],
#  ['HBASE-2941', '1c2775af44', '4e64653921', '5581a249e8', '81d9c8a1a3'],
#  ['HBASE-2928', '5e9f6d1528', 'b79904c6e4'],
#  ['HBASE-2927', '1378305a4d', '0e481c64e8', '1bedadad6b', 'c1714d094b'],
#  ['HBASE-2889',
#   'f796ab4ea4',
#   'fc19a6d26e',
#   '1c2775af44',
#   '4e64653921',
#   'a85ee11f3b',
#   'aca8c1164a',
#   'bd7e091b2d',
#   'abb60c4ce8',
#   '9d91a28a10',
#   'ca8a9fc9f3',
#   '74066765bb',
#   '7e444dfcaf',
#   'eb7b42ea1a',
#   '395215d12d',
#   '3b16358da3',
#   '46c1a80358'],
#  ['HBASE-288',
#   '7e1d49358d',
#   '83955d0aff',
#   '56380dab8a',
#   '990e568564',
#   '9a88155bf0',
#   '5c866c070e'],
#  ['HBASE-2815', '112611bcbf', 'e60312c1bd', 'b7ffd6858e'],
#  ['HBASE-2806', 'c2c41f0439', '1be8ef2c26', '2993d97c97', '191c7126b8'],
#  ['HBASE-2781', 'e9eebe3a1f', '783f4c7e0c', '643ae0c985', 'dacde7bbac'],
#  ['HBASE-2763', '994e8574b6', '97657cccd2', '6352d1b50f', '8e969fe745'],
#  ['HBASE-2755', 'c1503d63a8', '01bbb65792', '2d214ccc52', '0d8798ad26'],
#  ['HBASE-2740',
#   '98a6a203c0',
#   '844c334e7b',
#   '0beea3751b',
#   'e99f325a34',
#   '64d710a15f'],
#  ['HBASE-2703', '84dc5513f3', 'bdcc7f126a', 'fef2801e20'],
#  ['HBASE-2669', '1b5666c84b', '113d533ad7', 'ed79dc2fd0'],
#  ['HBASE-2643',
#   '9c48e9b125',
#   '1c2775af44',
#   '4e64653921',
#   '39e213e62d',
#   'e4d54b2e01'],
#  ['HBASE-2616',
#   'fc52e8d359',
#   'debff13033',
#   '8b30b7b8f5',
#   '0091aaa719',
#   'c7368fafc0',
#   '1586720f65',
#   '81d73cfb03'],
#  ['HBASE-2606', 'c32fa61729'],
#  ['HBASE-2581', '70b7e2649e', 'f1b580649f'],
#  ['HBASE-2562',
#   'ca482b185b',
#   '4ac2588b3e',
#   '302ce75933',
#   '45915b027b',
#   '960a9c0d7a',
#   'b8c2c518ef'],
#  ['HBASE-2558',
#   '63e72a9228',
#   '441177caf8',
#   '5e6a5b0aaa',
#   '909de0d5bb',
#   'e6de46ef37',
#   'd72de27307'],
#  ['HBASE-2513',
#   '013fd99d0d',
#   'fba3028f4e',
#   '68fc3d38b5',
#   '14b68ca4c0',
#   '3bda18cf3b',
#   'a61b762f75',
#   '9acf2c8d47',
#   'b38a2c4d2b',
#   'eb8d88239b'],
#  ['HBASE-2460', 'f6fb68ab0c', 'dc4fe91de6', 'f4b4aca339', 'ee28986e8e'],
#  ['HBASE-2402',
#   'd01feb01f2',
#   '58251bd97d',
#   '358b82d728',
#   '6248806d81',
#   'e1b5bff0f0',
#   'bda097edea',
#   '3d581a6fce'],
#  ['HBASE-2378',
#   '5ee1efceb3',
#   '5dcc800ad1',
#   '3e02fe03d6',
#   '276b433b07',
#   'dc0e68b5cb',
#   '34a18635a3',
#   'd3e7116b6e'],
#  ['HBASE-2344', '6a132e92c0'],
#  ['HBASE-2338',
#   '4cbfa4b594',
#   'b03ec3eae9',
#   '394f47a7c8',
#   '961b0938cb',
#   'dbb4470533',
#   '4edec2ee88'],
#  ['HBASE-2313', 'e7907b94fd', 'dfc23200bd'],
#  ['HBASE-2311', '4286167c15', '266cd54710'],
#  ['HBASE-2307',
#   '7fbf74129f',
#   '8102fb3269',
#   'a72cb63ec8',
#   '1030b60316',
#   '5708d2710d'],
#  ['HBASE-23',
#   '7bbe456b0f',
#   '71ab6e2152',
#   '99fc06705d',
#   '1336a981e2',
#   '822ba8bc3b',
#   '28f907df4a'],
#  ['HBASE-2284',
#   '019e972b63',
#   'b3f302c30c',
#   'f06ac93e19',
#   'cda22507a9',
#   'b4037fe76d',
#   'b4e29fb201',
#   '0e39bba759'],
#  ['HBASE-2248',
#   '4cadb9a7a8',
#   '6e3e0fa328',
#   'f65e61c7ab',
#   '7d6ebda6e2',
#   'a026befba3',
#   'd5ad1f4d91',
#   'bb48806392',
#   '1a0e63d8bc',
#   'f46d84bbaf',
#   '57dca6f753',
#   '8683ab8b67',
#   '088bc1fd75',
#   '0ec53ead07',
#   '5ceafba751',
#   '1f58ab7c38',
#   '2d31b1b152',
#   'f93306a2b4',
#   '26bef53cb8',
#   '3da69ac069',
#   '4a42172f0b',
#   '774120e21a',
#   '36433ef067'],
#  ['HBASE-2202', '7ceb77a46f', '68edfbe421'],
#  ['HBASE-2180', '11fa3025c2', '443d61e41a', 'f945fd0797', '2a1bfea2e9'],
#  ['HBASE-2156',
#   '315d5da29b',
#   '9f9599f185',
#   'e5bcb748a5',
#   '60eee421aa',
#   'aea3907209'],
#  ['HBASE-2140', '51cba4d982', '8bc2888278'],
#  ['HBASE-2093', '4d5637d100', 'f3cc48d9fa', '9039e79ec2'],
#  ['HBASE-2090', '58e94388ee', 'e2f7f90e00'],
#  ['HBASE-2077',
#   '84a2131313',
#   '791659b27e',
#   '8e57cfc1ab',
#   'c03c059e8b',
#   'a54151b54a',
#   'ee6ae40426',
#   '201b7548bf',
#   '6c100b6de3',
#   '97da52fc69',
#   '96eb421891',
#   '58039a7bc2',
#   '1ffb3c4842'],
#  ['HBASE-2066', 'b4d2ad7cc5', '8c2b87877b', 'f94c5a3406', 'c6ee51819a'],
#  ['HBASE-2044', 'dc0c2feb19', '04155cac92'],
#  ['HBASE-20169', 'acbdb86bb4', '0b44b13609', 'fabb1d97cc'],
#  ['HBASE-20141',
#   '51a35aafcd',
#   '009295a3a6',
#   '10a7b5ea15',
#   '6bf967adfb',
#   'aaa90d8069'],
#  ['HBASE-20121', 'f89a1f7d7a'],
#  ['HBASE-20110', '5b64de45ed', '03f9cb89a6'],
#  ['HBASE-20106',
#   '0d58092c06',
#   'ecc4c87ef3',
#   '1181dab14d',
#   '0cd89ed653',
#   '2f3632a2a4',
#   '96ebab748f'],
#  ['HBASE-20078', '81bf068b2f', '7bd39250e7', 'e83ac38d68'],
#  ['HBASE-20074',
#   '06cf04e458',
#   'e0f8076693',
#   '0fa5d69fc7',
#   'e4ce38df32',
#   '73028d5bd9',
#   'a312705dbc'],
#  ['HBASE-19972',
#   '1ae64ccee0',
#   '00f8877323',
#   'd793db7c7d',
#   '7ced28f099',
#   '1af0078a43',
#   '629eaf8b74'],
#  ['HBASE-19930', 'af804a586b', '07e93458fe'],
#  ['HBASE-19919',
#   '00653a4d18',
#   '12f3c82a86',
#   '06dec20582',
#   '6519b98ac3',
#   '40250f8c5f',
#   'bac4687345'],
#  ['HBASE-19892',
#   '85b4615a1f',
#   '052a8c0c73',
#   '80f8a8d885',
#   '8a1fca09cb',
#   '67f91f1282'],
#  ['HBASE-19835', 'a66fa85a16', '216d2d4648', 'bc080e7500', 'f1a81618fd'],
#  ['HBASE-19815', '13547d53eb', '581fabe7b2', '53d0c2388d', '0f5b0fb759'],
#  ['HBASE-1977',
#   '1bbfcc8ac6',
#   'dc28f778ed',
#   '394c64ddcc',
#   '947b62178d',
#   'f2d0fcbb0d',
#   'bbb6ce9d34'],
#  ['HBASE-19753', 'a7f9668c33', 'a917a4e796'],
#  ['HBASE-19734', '8118d5de4e', 'efa911f56f'],
#  ['HBASE-19694',
#   'c799b0e69b',
#   'd8271b0361',
#   '3787c60cd1',
#   'd0aff98a67',
#   '1a11fc92b1'],
#  ['HBASE-1967',
#   'c35411e5cb',
#   '983262f86d',
#   'dd23e89d3a',
#   'da45a6ba2c',
#   'afb2a3ef06',
#   '6e89016929',
#   'fac9b60d2f',
#   '9ae54b277b',
#   '450cd7ae02'],
#  ['HBASE-1966', 'fac9b60d2f', '9ae54b277b', '450cd7ae02'],
#  ['HBASE-19654', '97dc7d87cd', 'd8ef30c5e1'],
#  ['HBASE-19598',
#   'd2e5e11f65',
#   '3576eb6bd8',
#   '756cccecff',
#   '04798d6747',
#   '033485dff3',
#   '0732ef5ebf',
#   '016cf0c64b'],
#  ['HBASE-19542', 'c811d7f965', '0a5ef1ed88'],
#  ['HBASE-19508', 'fb6625fdd9', 'b475f15f25', 'd28e126b29', '736dd93c31'],
#  ['HBASE-19457', 'e8ba7b2320', '7092b814bd'],
#  ['HBASE-19454', 'a70b9b5e94', '033e64a8b1'],
#  ['HBASE-1941', '88fb04c4bc'],
#  ['HBASE-19391',
#   '569f16ea2c',
#   '2d12ae2031',
#   'cadc2efd12',
#   '11af33af2a',
#   '38a97b87e6',
#   'c06c4f30d1',
#   '9e7e58d551',
#   'a0900857c7'],
#  ['HBASE-19387', '139c3305a5'],
#  ['HBASE-19386', 'd32ba0977f', 'ddbff4fd87'],
#  ['HBASE-19384', 'db49391683', '1856237e2d'],
#  ['HBASE-19319', '96e63ac7b8', 'f886716617'],
#  ['HBASE-19287', 'cb4bbea0f1', 'd1fb987265'],
#  ['HBASE-19246', '72ba5c294e', '41f6bf6b89'],
#  ['HBASE-19195', '110f2db756', '027ef60a75', '2413a10e67', '0d4f33ca27'],
#  ['HBASE-19160', '50f30668b8', 'cfddfcf23c', '9ee8e2714d'],
#  ['HBASE-19102',
#   'a2ae58f6ee',
#   'afa1b91509',
#   '123f765eb4',
#   '498bcba095',
#   '9ad6e0422f',
#   'f6be6e0d7b',
#   '371e6093f1',
#   'cdeb377148',
#   'b89a40c990',
#   '1937a93c1b',
#   '9f7df19dfa',
#   '6547128789',
#   '0fb3bd2e3c',
#   '4985e27307'],
#  ['HBASE-1906',
#   'd5eac0bb99',
#   'fec0197064',
#   '27667c858b',
#   '75e7bf3ebb',
#   '14d5dae80c',
#   'cb4c765635'],
#  ['HBASE-19038',
#   'c16eb7881f',
#   'df4505e7e3',
#   '2c6e26f877',
#   '0706fb3cf0',
#   '12e058b880',
#   '95e926100d',
#   '723eb7c6ba'],
#  ['HBASE-19032',
#   '6d03d25009',
#   '80c14c9b70',
#   'b7000706a4',
#   '9908edc887',
#   '16ccd55c43',
#   '5368fd5bf0'],
#  ['HBASE-19023', 'b2f9b7bc19', 'eabad8a91c'],
#  ['HBASE-18983', '33ae6dce42', '3a0f59d031'],
#  ['HBASE-18946', '672c440b9f', '010012cbcb'],
#  ['HBASE-18934',
#   'c01c55d5f1',
#   'ffed972fd0',
#   '5b7bcdfc4d',
#   '4358af214b',
#   '8d99b0cfe4',
#   'e4647da0db',
#   '087edf0172'],
#  ['HBASE-18846', '94748a3c93', '456057ef90'],
#  ['HBASE-18834', '5ed2f899e1', 'efb95a1794'],
#  ['HBASE-18830',
#   'ede916af5a',
#   '91e1f834bf',
#   'f391fc44df',
#   '3abc0458e9',
#   'decf9d6235',
#   '9d68535e8e',
#   '3e1ceadc80',
#   '4b208eb2b6'],
#  ['HBASE-1880', 'c32fa61729'],
#  ['HBASE-18723',
#   '62db6bf1a4',
#   '8bbfc836db',
#   '48bc132e12',
#   '52d4b25754',
#   '91ab25b469',
#   '0e95a8a0ae',
#   '43c4bc5761',
#   'fb537fe736'],
#  ['HBASE-18634', '61b2508f29', '078a6be7d0'],
#  ['HBASE-18607',
#   '1347635309',
#   '22e8f87ae1',
#   'ca6714d54b',
#   '50c67e9697',
#   '37c40afaff',
#   '158f3da167'],
#  ['HBASE-1859', '741d967228', '6d0dddcc00', '41558cf59d'],
#  ['HBASE-18543', 'baecf33ea6', '5847c901a7', '6f6f0a4849', 'd5f34adcdb'],
#  ['HBASE-18491', '3f540f3801', 'ba5e8706de'],
#  ['HBASE-18487',
#   'f67dae90f9',
#   '6cadd1def7',
#   '8436811026',
#   '2d9dbf27b3',
#   '80b85a857c',
#   '422a57223a'],
#  ['HBASE-18431',
#   '6a1a97422c',
#   'ee87edd890',
#   '3feb87b005',
#   'ea5789a7f2',
#   '5e21e30682'],
#  ['HBASE-18430', '6a3af2e52b', '70a357dc5c'],
#  ['HBASE-18406', 'dbc8ea6486', '0e9390bd6d'],
#  ['HBASE-18404', '5cf0e62a55', '2a0d18928e'],
#  ['HBASE-18376', 'ea0062fa54'],
#  ['HBASE-18369', '5531be160b', 'bbf23d9627'],
#  ['HBASE-18366', 'a9352fe956', '4663d7b9a7'],
#  ['HBASE-18357', 'e063b231da', '3a4655019d'],
#  ['HBASE-18350', '6765f5e203', '41cc9a125f'],
#  ['HBASE-18335', 'd53430b5f7', '48d28c7a24'],
#  ['HBASE-1833', 'ad398468a1', '651490942d', 'fea85fecd0'],
#  ['HBASE-18311', '3c1d4a5d47', '8318a092ac'],
#  ['HBASE-18254', '0357c2266a', '7cc458e129'],
#  ['HBASE-18247', '30d58a1421', '22233a28cd', 'b50eb4bed5', '9427d6c73c'],
#  ['HBASE-18233', '2f7a6f21eb', '6c490625aa', '9f102b293f', 'e1d6950381'],
#  ['HBASE-1821', '9b59163f56', '764cd0fa52', '41d4ed1858'],
#  ['HBASE-18167', '34ab9edde1', 'd5bba50794', '3d9c544428', '01027f805b'],
#  ['HBASE-18143', 'e1f3c89b3b'],
#  ['HBASE-18122',
#   'c945d2b2d9',
#   'b9b01f75f0',
#   'afbbfb4474',
#   'ae7b631399',
#   'e670be690f',
#   '9cf1a08c53'],
#  ['HBASE-18044', '841bb00655'],
#  ['HBASE-17839', '721b9576d8', '3536c58afb'],
#  ['HBASE-17813', 'ab335bf9d3'],
#  ['HBASE-17803',
#   'f62069897b',
#   'e4f65bf7b5',
#   '02d9bf0c57',
#   '261aa9445c',
#   '23abc90068'],
#  ['HBASE-17718', 'ca5b8a44a4', '6a57050c24', '7fa7156f2c'],
#  ['HBASE-1768',
#   'd0a5410c01',
#   '502c9e826d',
#   '08c60dc517',
#   '7136c7c07e',
#   '7d0cf3fe08',
#   '58e3ad8b6c'],
#  ['HBASE-17661', '964e17f7b0', 'd08bafad1a'],
#  ['HBASE-17653', 'b392de3e31'],
#  ['HBASE-17624', 'b392de3e31', 'e019961150'],
#  ['HBASE-17538', 'c725d4d334'],
#  ['HBASE-17501', '4f5f7fbd47', '226b6fa448', 'd1ea718e43', '6fb44f7eb8'],
#  ['HBASE-1743', 'df2e2315b9', '0344394edb', 'b3653a6295'],
#  ['HBASE-17326', 'a5ee36d937', 'c3ce02d592'],
#  ['HBASE-17171', '2f35956eb8', 'c50a79a9ee'],
#  ['HBASE-17154', '0c59d23689'],
#  ['HBASE-17082', '48439e5720', '0f7a7f4751', '08cb550ccd', '8847a70902'],
#  ['HBASE-17072', '6cbdc5eb79', '987205caf9', '3d5e686070'],
#  ['HBASE-16983',
#   'ab335bf9d3',
#   '0998af01df',
#   '9afcb4366d',
#   'f9c23f5e9d',
#   'a70f73c1e1',
#   '26cbe44337',
#   'b3ddea9fc4'],
#  ['HBASE-16949', 'c776b3144d'],
#  ['HBASE-16944', 'bbe88d942e'],
#  ['HBASE-16886',
#   'ac9bde6997',
#   'baf940969a',
#   'c9f388bece',
#   '3dac4f38cd',
#   'a9526f6fdb',
#   'd4826e1665',
#   'd35b65883c'],
#  ['HBASE-16880', '9875c699af', '96c5a02217', 'ce493642c0'],
#  ['HBASE-16870',
#   'b7f9ac0b63',
#   '99798411e5',
#   'd76cc4c1f0',
#   '5bbaae5220',
#   'b437a61db3',
#   '59857a41ea',
#   'b2a7f31a06',
#   'c02b672e83',
#   '674511875d'],
#  ['HBASE-16785', 'da5722cb48', 'fb2c89b1b3', '1ee8776273'],
#  ['HBASE-16712', 'e1a6c94033', '8e100628a4'],
#  ['HBASE-1670', 'fcffb78531', '926a17e351', '7436f772c4', '69f8d4e935'],
#  ['HBASE-16683', '9952b134fc'],
#  ['HBASE-16679', 'b4f7ad62ef', '9a510e9ba2', '4082424305'],
#  ['HBASE-16630',
#   'ea5ac3856c',
#   'e08f4bf684',
#   'f64a52a0c2',
#   '052343a17e',
#   'bef27396e5',
#   '5ac32c4b7a',
#   'fa61aad9ce',
#   '2fcfb847ef',
#   '779f9cb07f',
#   'a8fd1119ce'],
#  ['HBASE-16624', '8c4b09dfba'],
#  ['HBASE-16621', 'f59cf6f02e', '34ffca1357'],
#  ['HBASE-16620',
#   'fef9218607',
#   '759a2c17a9',
#   '7650f60590',
#   'c96a263d77',
#   'e5d77d095c'],
#  ['HBASE-16611', 'd12abb1ad8', 'd2e6f55cc5', 'cd9f422373'],
#  ['HBASE-1659', '26d7f3b368', '979091d4b3', '3e6fa5f0b8'],
#  ['HBASE-16535',
#   '5a1b3a548e',
#   '4de27ee312',
#   'c25c36274f',
#   '3c5d01c3e4',
#   '966aeb06a8',
#   '1da0a48f6b'],
#  ['HBASE-16527',
#   'd525b0efb0',
#   'c8da39429c',
#   'bd61885ba1',
#   '81655cab96',
#   'b41565d21e',
#   'a034a2bdcb',
#   'a1cd601ad7'],
#  ['HBASE-16515', '64135da824', 'c536c85116', '1d365f580c', '0f92e943ac'],
#  ['HBASE-16456', 'c11923d8aa'],
#  ['HBASE-16430', '741d0a4511', 'fbd87f91bc'],
#  ['HBASE-16409',
#   'dd488c06f6',
#   'e05e70c245',
#   'c78a5fd650',
#   '3fd59b0ba9',
#   'd260108e39',
#   'd077219d3a'],
#  ['HBASE-16384', '7999bb9bd3'],
#  ['HBASE-16360',
#   'ce58f58902',
#   '8eca263c43',
#   '71e583df30',
#   '6c5d0cf235',
#   'a1e57d942e',
#   'cb507b8cff'],
#  ['HBASE-16359', 'b1c60940da', '00f6af2e85', '4b3e45fceb', '5e23b3aad5'],
#  ['HBASE-16356', '27eab2c6ef', 'ac1024af21'],
#  ['HBASE-16355', 'af6ebcd1a2', '737e063240', '544dc1e558'],
#  ['HBASE-16303',
#   '76658440df',
#   'c5183b83b4',
#   '7a62076ae4',
#   'e8f08ba0c7',
#   '8570e7f8db',
#   '6278ece8b6',
#   '19c609fa5e'],
#  ['HBASE-16290', '6ceb4a4f41', '7cdfbde37d'],
#  ['HBASE-16272',
#   '9281661306',
#   'e8a146a784',
#   '6dfdc0d898',
#   '6e54ac352a',
#   '4f6647b9f0',
#   '0ed7d5f803',
#   'ad91bfd0a8',
#   '24a3d6952c',
#   'cc766df28b'],
#  ['HBASE-16209',
#   'cbdc9fcb8a',
#   '1b303ad75d',
#   '51c8c1891a',
#   'c46f56b382',
#   '3729320099',
#   '39153b8824',
#   '7c97acf6e3',
#   'fe44383619'],
#  ['HBASE-16201',
#   '33d64e021a',
#   '73189eb801',
#   'b99efe65e9',
#   '43626fc06e',
#   '09d9dc4b59',
#   '3c39cbd92c'],
#  ['HBASE-16160', '896148af07', '00c91b01ea', '3ff6f45851', '3b5fbf8d73'],
#  ['HBASE-16157', '368c32e322', 'd016338e45', 'fe75edb556', '5a7c9939cb'],
#  ['HBASE-1615', '5d85f284e5', '2739d38a58', '619a7243d0'],
#  ['HBASE-16129',
#   'dcd6f62520',
#   'd50944e986',
#   'be3b9f46f4',
#   '7335a1f987',
#   'aa361a20ce',
#   '294c2dae9e'],
#  ['HBASE-16074', '88af9466e0', '496fd9837a', '9563ab4ca1', '2e2a3fda40'],
#  ['HBASE-16066', '4421fdf981'],
#  ['HBASE-16060', '67b69fb2c7', 'c7473df2c3'],
#  ['HBASE-16000', '8e2d410195'],
#  ['HBASE-15982', 'ec7bca1769', '6e7baa07f0'],
#  ['HBASE-1597',
#   '2739d38a58',
#   '619a7243d0',
#   'ddfba836d8',
#   '15641df8c9',
#   '1f85226103'],
#  ['HBASE-15965', '48492ec7fd', 'c2b4c6f637', '15c03fd1c9'],
#  ['HBASE-15946',
#   '947e74efa7',
#   'd2d3dcdaec',
#   'd8d63d6715',
#   '37807b38a3',
#   '6da6babe4f'],
#  ['HBASE-15944', '4ffea7711a'],
#  ['HBASE-15938', '9593a9f396'],
#  ['HBASE-15920', 'b41bf10edf', '536a8e836a', '32258c2b3a'],
#  ['HBASE-15912', '4abc602e3b'],
#  ['HBASE-15909', 'b41bf10edf', '536a8e836a', '32258c2b3a', '74442fde0f'],
#  ['HBASE-15846', '95df62b207'],
#  ['HBASE-15828', 'c47511baa7'],
#  ['HBASE-15811',
#   '4e9ee73473',
#   'df634737cc',
#   '09934af5c7',
#   '77f511fceb',
#   '6904430a3d'],
#  ['HBASE-15742',
#   'a2a6b95a05',
#   '64530c01a1',
#   'b3aece8004',
#   'c3370fc507',
#   'dc8bb1f835',
#   '8f1deac1f8',
#   'f76ffb7f38'],
#  ['HBASE-15725', 'b6e2bc5ad1', 'c7e5672d4d', 'c12eaa5cc4', '0e281e1929'],
#  ['HBASE-15673', '446101f39b', '07cc9ac2f5', 'bd64db97c8', '501030d204'],
#  ['HBASE-15650',
#   '88af9466e0',
#   'a0bb623ccf',
#   '496fd9837a',
#   '9563ab4ca1',
#   '2e2a3fda40',
#   '47c19607c2',
#   '017ab8d7f1',
#   '4b69faa190',
#   'fd49923350',
#   'd815211f5a'],
#  ['HBASE-15638', 'c6289f1976', '95c1dc93fb'],
#  ['HBASE-1554', 'f7800ce374', 'ac9b0d924f', '627ef9e3a1', '9880f155e2'],
#  ['HBASE-15467', '4421fdf981', 'bdb0cc8808'],
#  ['HBASE-15441', 'd501920378', 'dd4ac94387', 'aaaae83423', 'ecec35ae4e'],
#  ['HBASE-15360',
#   '76a71084f9',
#   'a3d550fbca',
#   '2348478506',
#   '4b9495e807',
#   '3f9ce9785a',
#   '9eb25bd5c9'],
#  ['HBASE-15348', 'e0d7e0eb3b', 'e88d943183'],
#  ['HBASE-15291',
#   '519f87fc2b',
#   '9f2bd55d78',
#   '95221918c1',
#   '7811d28b2a',
#   '2e537bc4ad',
#   '8b81cf04e6',
#   '105fd08651',
#   '17b39763c9',
#   'b3c62680bc',
#   '4fba1c3627',
#   'fe7bcf58d9',
#   'dc4bdb9928',
#   'd74f99fbc1',
#   '77c3c61b34',
#   'edc5ab5af9',
#   '2538b92364',
#   '5031c4ace7',
#   '49cb0cfccb',
#   '58283fa1b1'],
#  ['HBASE-1526',
#   'efe6adae26',
#   'bbdf0ecaf2',
#   'ac9a9e01c9',
#   'e165611e04',
#   'a8167fcffa',
#   '19e31441e2',
#   'e8d66ea285'],
#  ['HBASE-15253', 'a975408b7c'],
#  ['HBASE-15236', 'e39e0e634a', 'a6f8214e9b', '11740570c1'],
#  ['HBASE-15152',
#   '970adb357e',
#   'fd7862889f',
#   '55229d4576',
#   '24002e2362',
#   '8c858c214a',
#   '6187bea711',
#   'b6f091e0fd'],
#  ['HBASE-15148', '52355ab1de', 'cd920940b7', '37d15e05d8', 'f9e69b51e1'],
#  ['HBASE-15122',
#   '29ce46a67f',
#   '3733223e40',
#   'a6f53600dd',
#   'f280c45956',
#   '68b300173f',
#   'd82ae42126',
#   'efc7a0d347'],
#  ['HBASE-15117', 'cb17c7a97a'],
#  ['HBASE-15065',
#   '2e08227b4b',
#   'd277c15330',
#   '4a26644245',
#   'a5438f4a55',
#   '5a0658377d',
#   '6e781a1f34'],
#  ['HBASE-1504', '870fa31ff2', '0c83a265a4', 'd6ec5ed8a2'],
#  ['HBASE-15028', 'ff069ef97b', '2439f7a688'],
#  ['HBASE-15027', '894ce84b83', '28c2b18d30'],
#  ['HBASE-15009',
#   'ad5503190f',
#   'd93b43723c',
#   '7ac9eb9d95',
#   '90947a37dd',
#   '0f2a937ed1',
#   '299ade435a'],
#  ['HBASE-14977',
#   '73b4d377b1',
#   '4f3c969dfc',
#   '1b66f474b5',
#   '95a13b51ee',
#   'a4bbc461e3',
#   '2c9361602c',
#   'ef19c2147d',
#   '31d73a4bde'],
#  ['HBASE-14917', '80afb839ec'],
#  ['HBASE-14904',
#   'b04a09da35',
#   '46536baa97',
#   'f3d3bd9d3b',
#   'a75a93f98c',
#   'edb8edfeb3',
#   'b3260423b1'],
#  ['HBASE-1488',
#   '05d71eb093',
#   '2a702a24cc',
#   '3b01f1a469',
#   '9af479db63',
#   '83b3772eb3'],
#  ['HBASE-14802',
#   'f5cebbbaf1',
#   'b7a4c5f5dc',
#   'dd5f454b03',
#   'bb6581345f',
#   'b22feba7fe',
#   'bb9fbdb2d2',
#   '7c3c9ac9c6'],
#  ['HBASE-14797', '96b2c0703b'],
#  ['HBASE-14777',
#   '89e34f36a4',
#   'dbbdb7b2e8',
#   '6531b465a7',
#   'ca7fbeadaf',
#   'f56c605e73',
#   '8dbbe96e04',
#   'c831a4522f',
#   'de4f235bf4',
#   'c8fbaf0c96'],
#  ['HBASE-14769', 'bebcc09fb3', '92e178df28', '6adce67572'],
#  ['HBASE-1464',
#   'a078253619',
#   '3fbad5236d',
#   '3c8bc3db89',
#   '8cb2279ce8',
#   'dca4256907'],
#  ['HBASE-14532', 'e8d6bf7d46'],
#  ['HBASE-14512',
#   '387eaff316',
#   'b6dc3c5ae6',
#   '8272c84f60',
#   'd5f8300c08',
#   '474c399137',
#   '8d94773044',
#   '54b64871ff',
#   'cca2ba4d93',
#   'a463984945'],
#  ['HBASE-14343', 'b3e40e4257', '6f21cfbf27', '6875e6d4d4'],
#  ['HBASE-14337', 'a5261b6f44'],
#  ['HBASE-14317',
#   'e0ff595744',
#   'd7adc58e52',
#   '0bf97bac2e',
#   '5b0f30d5f4',
#   '2966e2744a',
#   '990e3698a7',
#   'bbafb47f72',
#   'ec4d719f19',
#   '54717a6314',
#   '661faf6fe0'],
#  ['HBASE-14307',
#   '378f3c6a7d',
#   '677b28ab05',
#   '856d240019',
#   'f440ed936d',
#   '272ca1f61a',
#   'c438052cc2',
#   '6531e1ae17',
#   'c20cb7dd1d',
#   '954a6e0a75',
#   '346fc3483f',
#   '05f1389c56'],
#  ['HBASE-14258',
#   'bcfb91d4e4',
#   '5532af9727',
#   '1ca1409a36',
#   '861d546b87',
#   '4256128fa2',
#   'ae54390512',
#   '268a69f17b',
#   '9b55f1cd29',
#   '506726ed28'],
#  ['HBASE-1425', 'cc805ddfad', 'e5c9b2fd3a', '02a969d3e1'],
#  ['HBASE-14243',
#   '20dc291342',
#   'a21cfb26ce',
#   '6826a126c1',
#   '15bde49921',
#   'f622297aa5',
#   'ebd34844ce'],
#  ['HBASE-14201', '25bf721b51', '881d2c1d74', '0c63d415d9'],
#  ['HBASE-14198', 'a6f3057dbf'],
#  ['HBASE-14100', '17829bbb54', 'ca57ef2cf2', '12f6470bf3', '257df19cc3'],
#  ['HBASE-14048', 'e6f9dc0fec'],
#  ['HBASE-1396', 'da8cbfe4a3', 'b8854372bc'],
#  ['HBASE-13945',
#   '5467da9fb9',
#   '533f1ddb24',
#   '92f4e30f45',
#   '994c728bc4',
#   '1b5f72e1f5',
#   'd7356667be'],
#  ['HBASE-13930', '4936766d1a', '3af21f154b', '854d27350d', '7dbb2e6977'],
#  ['HBASE-13923',
#   'c34db5e837',
#   '5f8219fbcc',
#   '4c3ff1c224',
#   '90a1400c95',
#   '5b287a3e5a',
#   'db5dd1ebef',
#   'f248f86396',
#   'f94e8b9eb6',
#   '23b78587e9',
#   'bc7dfe9edd',
#   'b7f241d73b',
#   '41aa841241'],
#  ['HBASE-13897',
#   '16ada33709',
#   '94d5e7accc',
#   '372b71b7fe',
#   '0cd94f2f42',
#   '9be31d0526',
#   '7ab78d9ddf',
#   '1162cbdf15'],
#  ['HBASE-13888', '84a50393ee', 'e8821d1806', '49700460da'],
#  ['HBASE-13853',
#   '0ec677bb73',
#   '978c503d9b',
#   'cd71d37cb3',
#   '5f92b91e60',
#   '8079ec504b',
#   '0f88746827',
#   '26458b41ce',
#   'fe5712f9b4'],
#  ['HBASE-13811',
#   '5dd4c9832d',
#   'c19bc6d6e0',
#   '3dfccbd424',
#   '0ec677bb73',
#   '978c503d9b',
#   'cd71d37cb3',
#   '5f92b91e60',
#   '8079ec504b',
#   '0f88746827',
#   '26458b41ce',
#   'fe5712f9b4',
#   '5c16b34e32',
#   '2baf3bfc9f'],
#  ['HBASE-13802',
#   '02be1f9c47',
#   '695c4790cd',
#   'cca687d718',
#   '5646071c73',
#   '6ac0356687',
#   '46c9a5b339'],
#  ['HBASE-13760', '9ee184b673'],
#  ['HBASE-13686',
#   '84a50393ee',
#   'e8821d1806',
#   '49700460da',
#   'd34e9c5c5c',
#   '69ec2f4eed',
#   '9f43a3bea6'],
#  ['HBASE-13648', 'a7e77821d2'],
#  ['HBASE-13635',
#   '4e0d26ea23',
#   'b6cd923966',
#   '2537825179',
#   '95f1fe52ed',
#   'c3f83a9eff'],
#  ['HBASE-13599', '671ae8f150'],
#  ['HBASE-13528',
#   '5688ab4fa2',
#   '5b8f70d368',
#   '93fce057a3',
#   '42ad845032',
#   'e1cb405adc'],
#  ['HBASE-1352', '78ec818a41'],
#  ['HBASE-13471',
#   '79d11dc2c7',
#   '1214b69adb',
#   'f28cd4aa23',
#   '1862b58425',
#   'e80face0e9',
#   '90bdb0dc74',
#   'b4a77895a8',
#   'ea3c2e9064',
#   '214ea33d13',
#   'd6a2d7ab2d',
#   'd4d3b1954c',
#   '5ebd7660a9',
#   '40ae5bec21',
#   '8c8b434332',
#   '4c4a435389',
#   'b15a05d7b6',
#   'dcce2ed09c',
#   'ec021a7b25',
#   '4c04e8065f',
#   '0c1b112848',
#   'fd1108a2f7',
#   'e3c96b1007',
#   'ba8d985000',
#   '0b4e32a206'],
#  ['HBASE-13409',
#   '2982768153',
#   '935352c4d8',
#   '418e61ab00',
#   '6f463c5740',
#   '8c707499ba'],
#  ['HBASE-13331', 'c21abd512b', '885a170ec5', 'cc750c656a', 'e78aeb24e0'],
#  ['HBASE-13330',
#   '7aa5a89776',
#   '760edc68f2',
#   'e12e0e4248',
#   'cf23ae7500',
#   '7bfe2a3af7',
#   '779e404f4b',
#   '7732bb93c8',
#   '2c301d535b'],
#  ['HBASE-13262',
#   '0daae43342',
#   'ced0e324a1',
#   '20189c258c',
#   'b0116398ff',
#   '1abf3aa0fd'],
#  ['HBASE-1323', '622a1001fa', 'bf9a5aeb19'],
#  ['HBASE-1322', '75035d5191', '6ada5b2db8', '966643fe14', '55d09dcc84'],
#  ['HBASE-1321', 'efe6adae26', 'b78d0ee1bc', '040ce7cbe2', '8aeb808e00'],
#  ['HBASE-13208', '5bf98d0827'],
#  ['HBASE-1318',
#   'e8f06894b3',
#   '06bbb86c20',
#   '24d739c305',
#   'f1bc7a2592',
#   'fa65571384',
#   '4bd6e90b1b',
#   '0b50495837'],
#  ['HBASE-13167', '9c83fa7b52'],
#  ['HBASE-13155', 'c15e684bf9', 'efb6e7005f'],
#  ['HBASE-13123', '309e124a57', 'bd8544f662', '9c3cbdcd05', '4fb6f91cba'],
#  ['HBASE-13081', 'a8555f65f0'],
#  ['HBASE-13058',
#   '1dfcbdf5e3',
#   '2392a3e437',
#   'af848f8a71',
#   'f938999ef4',
#   '6f81a0982a',
#   '977d65a81c'],
#  ['HBASE-13039',
#   '71be2f0360',
#   'b8d45562ed',
#   '911432a7cb',
#   '285729cc94',
#   '76a3b50f1f'],
#  ['HBASE-13005', 'a6e4b3ba33', '4ee823b3f2'],
#  ['HBASE-13004', 'ede20aa288', '968c4574d7', '8fdc5bdb2a', 'a3f495f20d'],
#  ['HBASE-12985', '3216b8b6e3', 'b3d8a8843c', 'eea9873cef'],
#  ['HBASE-12922', 'a7816d88bd'],
#  ['HBASE-12902', '5fbf80ee5e'],
#  ['HBASE-12782',
#   'b0ea2fba42',
#   'a69e1b6733',
#   '86b8b8da00',
#   'fbbbf7e6d8',
#   'e06be2060c',
#   '825871431e',
#   'fd498f1854',
#   '1bb55d86ec'],
#  ['HBASE-12746', 'a32f485fec', 'd5f63f1221', '2df74fbd4a'],
#  ['HBASE-12716', '0256cdd1b4', '74f303ba24', '882f4c9761', 'fbdaf62bf8'],
#  ['HBASE-12711', '4083306c3d', '3021c060bd', 'd436559378'],
#  ['HBASE-12693', 'ae684cac87'],
#  ['HBASE-12665', '51bbbbaf2b', 'df22270756'],
#  ['HBASE-1264',
#   'ea2cfa96ec',
#   'fc1d07392d',
#   '42cae38a26',
#   'df77fa2ea9',
#   'b2f34edde3',
#   '31cd01f656'],
#  ['HBASE-12607',
#   'e88d74d6e9',
#   'c1fcb8fe33',
#   '1f613bccea',
#   '034b10733d',
#   '57b1efaabe'],
#  ['HBASE-12550',
#   'e83082a888',
#   '524dcd1323',
#   '9afe1e8efd',
#   'db73050a67',
#   '0df5ed2ca6',
#   '860ddd2c22',
#   '339fd6bdca'],
#  ['HBASE-12548', 'd0e4fb6ae3', 'ca0c1774c9'],
#  ['HBASE-12544', 'f43cb80327'],
#  ['HBASE-12541', '42cbdea76d', 'bfda57d4f2', 'c5690b1be3'],
#  ['HBASE-12539', '8dcb03c245', '2d4a3ff2db', 'f1048a148b', 'b6dd9b441f'],
#  ['HBASE-12490', 'e424d4254e', '7a3396f0e1', '2b976c6bd1'],
#  ['HBASE-12488', '9ea80f8f11'],
#  ['HBASE-12479',
#   '679e164e39',
#   '9e9d3f4cec',
#   '11bd497a9b',
#   '0a5ab37d77',
#   '9904252615'],
#  ['HBASE-12457',
#   '7f5f1570ce',
#   '1861f9ce25',
#   '880c7c35fc',
#   'c29318c038',
#   '9d634772fa',
#   '9d2ad55cfa',
#   'f6d8cde1e4',
#   '56af34831f',
#   '0e795c1cf8',
#   '231d3ee2ad'],
#  ['HBASE-1245', 'f44faab860', '094a2030f0'],
#  ['HBASE-12316', '9ddb25cf3a', '3dd7c03357', '85c66191d6', 'a470a1f3f3'],
#  ['HBASE-12281', 'a4169e7b04', '31ccaa519b'],
#  ['HBASE-12270',
#   '6314063e74',
#   '9b25e850df',
#   'bb7074b3d8',
#   '99acd66a95',
#   '809de6ae1c',
#   'dd566e0347',
#   '2ff16e532b',
#   '305267b8e2'],
#  ['HBASE-12261', '487b58313c', '990fb0b9d6', 'efa813ed2f'],
#  ['HBASE-12219',
#   'a4b800c824',
#   '0aca51e89c',
#   'a21352f4de',
#   '1f18d706a8',
#   '233fb8bf18',
#   'ba7344f5d1'],
#  ['HBASE-12198', 'a28a90eefb', 'c61f233dfd', '3c1fbd2ddf'],
#  ['HBASE-12172', '5f6a055bb6'],
#  ['HBASE-12167', '51ef418534', 'dbef2bdafe', 'c452942f57', '5375ff07bc'],
#  ['HBASE-12145', 'ecf09fd02b', '9f33edab0e', '43301167db'],
#  ['HBASE-12088', 'c9d0d11e18', 'ecc1c294f5', '13d6acbc7f', 'a90d433a2c'],
#  ['HBASE-12070', '78380e166d', 'a8632593b6', '4969368bf1'],
#  ['HBASE-12006', '24958f959b', '2da1bf10b8', 'c2eeddfb27'],
#  ['HBASE-11998', '1636afb0aa'],
#  ['HBASE-11957',
#   'baccf6c9d4',
#   'ae65975426',
#   'dc5295df8c',
#   '9f5c397e27',
#   '66cfcbe153',
#   '8f9faabf57'],
#  ['HBASE-11932', 'a1b956eb30', '364519fb7c', '2816487247'],
#  ['HBASE-11921', 'f2898985ad', 'f7bcf3df6b'],
#  ['HBASE-11868', '39771b8f73', 'ee32706c5d', 'fd10bde5af'],
#  ['HBASE-11689',
#   '679e164e39',
#   '9e9d3f4cec',
#   '11bd497a9b',
#   '0a5ab37d77',
#   '9904252615',
#   'b7f7514762'],
#  ['HBASE-11662', '74c7169252', '6a7f923c0d', '41ecb18c20'],
#  ['HBASE-11652', 'cce7a9770c'],
#  ['HBASE-1155', 'ec216bb98e', '4872cd1ab1', '0c24711331', '69bbf6b099'],
#  ['HBASE-11544',
#   '408b916175',
#   '62d47e175c',
#   '8cd3001f81',
#   '26ba621e47',
#   '0c64a57e52',
#   'de9791e91e'],
#  ['HBASE-11514', '2a20143f72', '96dcd67f56'],
#  ['HBASE-11463', '8d62d85864', '6da1a485fc'],
#  ['HBASE-11413', 'a181dff8e0', '1b2a05c944', '9ff90931dc'],
#  ['HBASE-11403',
#   '4e9ee73473',
#   'df634737cc',
#   '09934af5c7',
#   '77f511fceb',
#   '6904430a3d',
#   '01d5e7626c',
#   'ab72babd97'],
#  ['HBASE-11379', '451e39bf9c', '75ed75d3ed', 'd8ba4507b6'],
#  ['HBASE-1136',
#   'ce2995c49d',
#   'b36d1fa6e4',
#   '36cadbcef7',
#   '36def930a3',
#   '557f050021',
#   'fd719f0a37',
#   '03adaea261',
#   'd94afa1249'],
#  ['HBASE-11329', '3d3784dd22'],
#  ['HBASE-11310', '3d3e7eb228', 'aa916b81ce', 'af9fa42e1b', '9b94c14fa3'],
#  ['HBASE-11258', '45883c6bd1'],
#  ['HBASE-11234',
#   '191abb0b6b',
#   'a616bb42c6',
#   '90ece25b6e',
#   '56af657e5d',
#   'b985e4fd0e',
#   '5f4537f06c',
#   '7d56e0523f',
#   'b2a2e06098',
#   '494e0b50e9',
#   'edae564856'],
#  ['HBASE-11225', 'c9c01e6eb1'],
#  ['HBASE-11217',
#   '812be0ca43',
#   '230a768a3c',
#   '9dcebc396b',
#   '49d7b9dc45',
#   '92b2c86776'],
#  ['HBASE-1121',
#   '9d4cc565e0',
#   '542abcf26d',
#   '8b53dd0396',
#   'efe5944279',
#   '0b36056fde',
#   '21732392f3',
#   'a59ddf299e',
#   '8d03bf9b0e'],
#  ['HBASE-11187', 'de727cc1d7', '3a61ebfb10', 'a7fe50b445'],
#  ['HBASE-11169', 'ced723b6d9', 'daa7b14d52', 'a5cbd502bb'],
#  ['HBASE-11149',
#   '52dd30727a',
#   'e9017586ca',
#   '7caceb23c7',
#   'b168b8b2d5',
#   '6ea0b7f8c2'],
#  ['HBASE-11145', 'ec69c8833e', '288ffe6563'],
#  ['HBASE-11138', 'f648f6060b'],
#  ['HBASE-11120', '85853f69c8', 'afae1e2583', 'ee76225783', '948b22f082'],
#  ['HBASE-11021', '0296547aa2'],
#  ['HBASE-1092',
#   'c6a0ee0e83',
#   'c36fafc65d',
#   '22d184218d',
#   '522c34a707',
#   '9f9198e21e',
#   '95e76839d6'],
#  ['HBASE-10907', 'b699fcfe6f', '495e30c18e'],
#  ['HBASE-10901', '79281ee0ba', 'c8ea643074'],
#  ['HBASE-10893', '6a1b347964'],
#  ['HBASE-10840', '4487333e5e'],
#  ['HBASE-10808', '54175f554a'],
#  ['HBASE-10715', 'cdb12941c4', '4eb9e5225d'],
#  ['HBASE-10675', '6f1951ddda', '829c3725c7', 'ba5de65ae0'],
#  ['HBASE-10656', '2ef02e6e1c', '6d6327b477', 'a1a5f57bff'],
#  ['HBASE-10647', '2e28ec44c8'],
#  ['HBASE-10624', 'a11781eae8', '66f01155fe', 'bc9834426a', 'ce1e3b6c77'],
#  ['HBASE-10598',
#   'a11781eae8',
#   '66f01155fe',
#   'bc9834426a',
#   'ce1e3b6c77',
#   '5221dcfc00',
#   'c6236a57a5',
#   'e450b4a795',
#   '3233679759'],
#  ['HBASE-1058',
#   'bf9ac84827',
#   '1f900dca17',
#   '816225f395',
#   'eb3cd124f8',
#   '63b81c5ad0',
#   '4dc924c609'],
#  ['HBASE-10578', '5f9420aba0'],
#  ['HBASE-10555', '20c4b8a685'],
#  ['HBASE-10528',
#   '1f0f62ced8',
#   '5e36e70cfd',
#   '72d17265c1',
#   '00a50d6b95',
#   '5cdc9890ec',
#   '8ed7dea397',
#   '483e55e2fa',
#   'c951238304',
#   'c5b0a1b8a0',
#   '45fc2bdd86'],
#  ['HBASE-10514',
#   '3e054d4f8b',
#   '2faa2015c1',
#   'a3b0f0fb86',
#   '76aa400b1b',
#   '8388be58e4',
#   'fa6a85d2a0',
#   'e97a4df4e0',
#   '45e5b76f37',
#   '354f5da6a1',
#   '731e2f6541'],
#  ['HBASE-10485',
#   'e115b5125a',
#   '16151a654c',
#   '598107a7d0',
#   '083a1cfd9c',
#   '5550e328c4',
#   '1615662683',
#   '8755eb8bee',
#   'bda1351306',
#   '22c2d8c4e3',
#   'df5bd6e99f'],
#  ['HBASE-10460', '3ea0e50450', 'a873e206c9', '22d93bd3c6', 'e4e61a2e63'],
#  ['HBASE-10454', '389e4f583e', '42a2456b44'],
#  ['HBASE-10452', '59c2b2bb09', 'f1ad5cb938'],
#  ['HBASE-10446', 'b3b3d0ddff'],
#  ['HBASE-10417', 'c9c01e6eb1', 'ffc7215a50', '95444356ef'],
#  ['HBASE-10397', 'b5d161c513'],
#  ['HBASE-10370',
#   '5645d48eac',
#   'bebb59dc10',
#   '3b9b0e1bc8',
#   'c27bfd6acc',
#   '1abfabaaa4',
#   '9b10589954',
#   'e7c36e7822',
#   '868f9e4b38'],
#  ['HBASE-1013', '05a11e7fcc', 'dfd2d6af99'],
#  ['HBASE-10079',
#   'd6e86d0524',
#   '8eca550e02',
#   '584793fb6f',
#   '3fb88f10af',
#   '6873efa5a2',
#   '923becd6c0'],
#  ['HBASE-10011', '22f54af029', '100cfded38', '35cea57fe5'],
#  ['HBASE-10004', 'e0c324f9d5'],
#  ['HBASE-9778',
#   'ca8b80433e',
#   'a772c4110d',
#   '9ffe4843dd',
#   'd2eac30d68',
#   '330a8e1fc3'],
#  ['HBASE-3015', 'd16d6257e6', '7daffb3a42', '0d53298953'],
#  ['HBASE-15195', '9955118995']]

# %%
commit_idfix = []
for y in range(0,len(bugfix_cid)):
    sys.stdout.write("\rExtracting commit id from candidate bug-fix commit: {} / {}".format((y+1), len(bugfix_cid)))
    sys.stdout.flush()
    if w != []:
        for s in range(1,len(bugfix_cid[y])):
            temps = [bugfix_cid[y][0],bugfix_cid[y][s]]         
            commit_idfix.append(temps)
commit_idfix
# Out:
# Extracting commit id from candidate bug-fix commit: 624 / 624
# [['HBASE-9971', '8a6291a896'],
#  ['HBASE-9961', '1e7fdb06b2'],
#  ['HBASE-9961', '560f000424'],
#  ['HBASE-9961', 'e5946ba799'],
#  ['HBASE-9961', '18e018b3d9'],
#  ['HBASE-9958', '8a6291a896'],
#  ['HBASE-9958', '4b84160b37'],
#  ['HBASE-9958', 'c5a3048fec'],
#  ['HBASE-9908', 'f224e4721f'],
#  ['HBASE-9908', '16b799dae5'],
#  ['HBASE-9908', '61120fb62c'],
#  ['HBASE-9908', 'ff78f217fa'],
#  ['HBASE-9893', 'c5fc5b993e'],
#  ['HBASE-9893', 'da89846cf7'],
#  ['HBASE-9856', '13e9eda3e7'],
#  ['HBASE-985', 'e3659aa246'],
#  ['HBASE-985', '894c99bdb3'],
#  ['HBASE-9843', '6dd52d7ed3'],
#  ['HBASE-9843', '53bb2f6be7'],
#  ['HBASE-984', 'f78f944026'],
#  ['HBASE-984', '963c1104dd'],
#  ['HBASE-9786', '230cb08611'],
#  ['HBASE-9786', '6d0eade8b6'],
#  ['HBASE-977', '5418547132'],
#  ['HBASE-977', '1b49c9b6c4'],
#  ['HBASE-9747', '201c67a7d8'],
#  ['HBASE-9747', '3f496372bf'],
#  ['HBASE-9747', 'b4df85d6b0'],
#  ['HBASE-9747', 'fc15e1ae39'],
#  ['HBASE-9747', 'a2a3071256'],
#  ['HBASE-9747', 'e7dfc21d4f'],
#  ['HBASE-9745', '3d37252a32'],
#  ['HBASE-9745', '24f150ebbc'],
#  ['HBASE-9745', '0bd53be747'],
#  ['HBASE-9745', '86033abef2'],
#  ['HBASE-9745', 'd289eecd2f'],
#  ['HBASE-9745', '8aec79e00c'],
#  ['HBASE-9745', 'bcdd3eba60'],
#  ['HBASE-9745', 'ffeb4ab1e3'],
#  ['HBASE-9704', '5ff5311da2'],
#  ['HBASE-9704', 'abbf77d9cb'],
#  ['HBASE-9704', 'bd01833201'],
#  ['HBASE-9704', '2d7c39e50c'],
#  ['HBASE-9704', 'a270d1c0a6'],
#  ['HBASE-9704', '045ee401b3'],
#  ['HBASE-9704', '8f76956cc6'],
#  ['HBASE-9704', '54b2f547c9'],
#  ['HBASE-9704', '84ee3d54d4'],
#  ['HBASE-9704', '94184eb5f8'],
#  ['HBASE-9704', '90c7d0d614'],
#  ['HBASE-9704', 'e475dca13d'],
#  ['HBASE-9704', 'db972590c6'],
#  ['HBASE-9704', 'e216445124'],
#  ['HBASE-9704', 'dcfd369293'],
#  ['HBASE-9704', 'ccc03f50f5'],
#  ['HBASE-9704', 'ff5a191a7b'],
#  ['HBASE-9704', '3b95287866'],
#  ['HBASE-9704', '29a28aa05c'],
#  ['HBASE-9704', 'e6b3951c4d'],
#  ['HBASE-9704', '7d38a444b3'],
#  ['HBASE-9704', '1d351abceb'],
#  ['HBASE-9704', '920e6f1ea5'],
#  ['HBASE-9704', '1aa35bf423'],
#  ['HBASE-9698', '230cb08611'],
#  ['HBASE-9698', '6d0eade8b6'],
#  ['HBASE-9698', '36e4fe8a37'],
#  ['HBASE-9698', 'a07ef888e1'],
#  ['HBASE-968', 'ae27a2bc3f'],
#  ['HBASE-968', 'bf17c35a8f'],
#  ['HBASE-968', 'c18a713726'],
#  ['HBASE-968', 'f609ddabbc'],
#  ['HBASE-9639', '91508fd564'],
#  ['HBASE-9639', '00927d1438'],
#  ['HBASE-9534', '9f11a9d6b6'],
#  ['HBASE-9534', '5e36c8e6dd'],
#  ['HBASE-9534', '4793668c1d'],
#  ['HBASE-9534', '69e56e387d'],
#  ['HBASE-9534', '6bc48464ca'],
#  ['HBASE-9519', '29909882ea'],
#  ['HBASE-9415', 'de186bdb7b'],
#  ['HBASE-9415', 'd0cce3f48d'],
#  ['HBASE-9415', 'd50125a745'],
#  ['HBASE-930', '029b37eade'],
#  ['HBASE-930', 'c3c1c8ddbc'],
#  ['HBASE-930', 'a0cffd6f12'],
#  ['HBASE-930', '50ad3e6d12'],
#  ['HBASE-930', '44b55114b4'],
#  ['HBASE-930', 'f84bf5c8a1'],
#  ['HBASE-930', 'ca07a6f30b'],
#  ['HBASE-930', 'a1a6b437e0'],
#  ['HBASE-930', '1f66d54b5d'],
#  ['HBASE-930', '8dcc95d790'],
#  ['HBASE-930', 'f69423a1d9'],
#  ['HBASE-930', '3de18d1763'],
#  ['HBASE-930', '06d1a00f83'],
#  ['HBASE-927', 'cfb9cb2946'],
#  ['HBASE-927', '838b238999'],
#  ['HBASE-927', '55d0467c75'],
#  ['HBASE-927', '78165487d9'],
#  ['HBASE-927', '9950dd24de'],
#  ['HBASE-927', '69cbc5d27c'],
#  ['HBASE-927', '748842b131'],
#  ['HBASE-927', '400e183da5'],
#  ['HBASE-927', 'ad707c4f60'],
#  ['HBASE-9238', '0c9f543e1c'],
#  ['HBASE-9232', '7773da0cb4'],
#  ['HBASE-9232', '58ee2bbf24'],
#  ['HBASE-9219', '8a9f332ac0'],
#  ['HBASE-9205', '48c1e7aff3'],
#  ['HBASE-9205', 'f651b6a820'],
#  ['HBASE-9164', '4dd82c9b1c'],
#  ['HBASE-9164', 'd7d0398713'],
#  ['HBASE-9158', '2c80ed63b0'],
#  ['HBASE-9158', 'e7657c930b'],
#  ['HBASE-9158', 'bd3acd05d4'],
#  ['HBASE-9158', '3bc9e2c95c'],
#  ['HBASE-9151', '87c2b88576'],
#  ['HBASE-9151', '57a307487f'],
#  ['HBASE-9151', '8d7ed731a9'],
#  ['HBASE-9115', 'dc795cca20'],
#  ['HBASE-9115', 'd272cf1727'],
#  ['HBASE-9115', '2036dbb763'],
#  ['HBASE-9115', 'dfb7778d1a'],
#  ['HBASE-9115', 'b77483f695'],
#  ['HBASE-9115', '5b89721c1e'],
#  ['HBASE-9114', '9f592ea0b4'],
#  ['HBASE-9085', 'cea837fa8f'],
#  ['HBASE-9085', 'ee48ceb820'],
#  ['HBASE-9085', '08235fca23'],
#  ['HBASE-9003', 'b2d1b154bb'],
#  ['HBASE-9003', 'a71dd16a70'],
#  ['HBASE-9003', 'bf2144fe60'],
#  ['HBASE-9001', 'd06aa724b0'],
#  ['HBASE-9001', 'ff84a7ae16'],
#  ['HBASE-9001', '5dc4727113'],
#  ['HBASE-9001', '2fb6b8b7f3'],
#  ['HBASE-8942', 'f14f42ec5b'],
#  ['HBASE-8942', '5f47f7b6a8'],
#  ['HBASE-8942', '8d3133aa0f'],
#  ['HBASE-8942', 'e97a20f8b1'],
#  ['HBASE-8942', 'a30d3f5c23'],
#  ['HBASE-8942', 'b0c406da07'],
#  ['HBASE-8942', '45e7540347'],
#  ['HBASE-8930', 'e15deb5cf1'],
#  ['HBASE-8930', 'df4784be5a'],
#  ['HBASE-8930', 'da4167c42b'],
#  ['HBASE-8930', '6905ddc2e1'],
#  ['HBASE-8930', '30eb01f496'],
#  ['HBASE-8930', '633369205f'],
#  ['HBASE-8930', '41b9c58f96'],
#  ['HBASE-8930', '4f05fc60d5'],
#  ['HBASE-8930', '813f88a482'],
#  ['HBASE-8930', 'ee1562dace'],
#  ['HBASE-8919', 'd390841912'],
#  ['HBASE-8919', '299b39532b'],
#  ['HBASE-8917', 'da3e3046ad'],
#  ['HBASE-8856', '6c43cd988b'],
#  ['HBASE-8856', 'afca885131'],
#  ['HBASE-881', '428e685b75'],
#  ['HBASE-881', '16a2c45780'],
#  ['HBASE-881', '87102ae59b'],
#  ['HBASE-8798', '9ccf16db51'],
#  ['HBASE-8706', 'bcf89528dc'],
#  ['HBASE-8706', '8bb177d37f'],
#  ['HBASE-8706', '9763240f35'],
#  ['HBASE-8706', 'ba8801c2ff'],
#  ['HBASE-8664', 'ed65f9bb6e'],
#  ['HBASE-8664', 'd6becac229'],
#  ['HBASE-8627', 'f73a68178f'],
#  ['HBASE-8627', '2581ebb0b2'],
#  ['HBASE-8615', 'dc716a9005'],
#  ['HBASE-8615', '4ec30df08f'],
#  ['HBASE-8615', '8bdcbb67ff'],
#  ['HBASE-8615', '1236068fd0'],
#  ['HBASE-8532', '2eec2f340a'],
#  ['HBASE-8532', '93fab309db'],
#  ['HBASE-8521', 'f2d10f4e9e'],
#  ['HBASE-8521', '49de0f9133'],
#  ['HBASE-8519', '20c4b8a685'],
#  ['HBASE-8519', 'ad6292f86e'],
#  ['HBASE-8519', 'bc4992c0f8'],
#  ['HBASE-8519', 'f729fcd4ec'],
#  ['HBASE-8500', 'b0a03df607'],
#  ['HBASE-8500', '0744c27fc8'],
#  ['HBASE-8500', 'e8b80ba94c'],
#  ['HBASE-8500', 'd2cfd53dc3'],
#  ['HBASE-8500', '0b6039a650'],
#  ['HBASE-8500', '98060a04ac'],
#  ['HBASE-8500', '1977527c57'],
#  ['HBASE-8500', 'c45f2f28f9'],
#  ['HBASE-8500', '04bbd5eaf7'],
#  ['HBASE-8500', '68b1e5c512'],
#  ['HBASE-8467', '415e06f7a1'],
#  ['HBASE-8467', '2e44f61062'],
#  ['HBASE-830', '986f364d03'],
#  ['HBASE-830', '1fb69ec11a'],
#  ['HBASE-830', '9b62798b11'],
#  ['HBASE-826', '19c87a375d'],
#  ['HBASE-826', 'ec8aeab847'],
#  ['HBASE-826', '4dc9c3642c'],
#  ['HBASE-826', '681367f310'],
#  ['HBASE-826', '79d463d658'],
#  ['HBASE-826', 'ed648b7327'],
#  ['HBASE-826', 'd1adcf1629'],
#  ['HBASE-826', '7627490bea'],
#  ['HBASE-8259', 'b9c3497b8b'],
#  ['HBASE-8259', '8af84cb46d'],
#  ['HBASE-8259', 'ca669156cf'],
#  ['HBASE-8259', 'a34f3a364f'],
#  ['HBASE-8259', 'fff96309a6'],
#  ['HBASE-8259', '0c47666dee'],
#  ['HBASE-8225', 'a79a77aa02'],
#  ['HBASE-8225', 'a96672bec6'],
#  ['HBASE-8225', '0bc9187d46'],
#  ['HBASE-8223', '6605c597bd'],
#  ['HBASE-8216', '635949147f'],
#  ['HBASE-8207', '9e02c52762'],
#  ['HBASE-8207', '92d5967a86'],
#  ['HBASE-8207', '7e26d32349'],
#  ['HBASE-8207', 'ac97504dc5'],
#  ['HBASE-8207', '6930ff607f'],
#  ['HBASE-8207', 'aa851e3b7a'],
#  ['HBASE-8207', 'c5a16ef24c'],
#  ['HBASE-8207', '542b8dcc1f'],
#  ['HBASE-8207', '9087f50a5f'],
#  ['HBASE-8207', '1babc2abbc'],
#  ['HBASE-8206', '38fc69c10c'],
#  ['HBASE-8125', '8e664d8133'],
#  ['HBASE-8125', '2c684ee552'],
#  ['HBASE-8119', '089e876398'],
#  ['HBASE-8119', '77904ce78a'],
#  ['HBASE-8119', 'e21a1ee4ae'],
#  ['HBASE-8111', '9e270796d1'],
#  ['HBASE-811', '0696c139f5'],
#  ['HBASE-811', 'a5a72605cf'],
#  ['HBASE-811', 'dbba69fce5'],
#  ['HBASE-811', 'ca41de9b1b'],
#  ['HBASE-811', '0c3bd478b3'],
#  ['HBASE-811', 'b55027819e'],
#  ['HBASE-8085', 'd004827b82'],
#  ['HBASE-8085', '7465b3d076'],
#  ['HBASE-808', '4456a8f5cf'],
#  ['HBASE-808', 'aabc02c44b'],
#  ['HBASE-808', '4c2a6f66f1'],
#  ['HBASE-808', 'fba07d1808'],
#  ['HBASE-808', '78b53558b8'],
#  ['HBASE-808', 'f85e23cb43'],
#  ['HBASE-8067', '50256d7035'],
#  ['HBASE-8067', '39e7e66ae9'],
#  ['HBASE-8067', '448f2f7902'],
#  ['HBASE-8067', '986c9fbed6'],
#  ['HBASE-8067', '9230c45c7e'],
#  ['HBASE-8067', '770219fccc'],
#  ['HBASE-8067', '302ce0325b'],
#  ['HBASE-8067', '90eaac74d5'],
#  ['HBASE-8067', '95e4f53090'],
#  ['HBASE-8062', '24736e83bb'],
#  ['HBASE-8062', '7181fa35a3'],
#  ['HBASE-8058', 'ddb06ad449'],
#  ['HBASE-8058', '3564568830'],
#  ['HBASE-8050', '579c4eb3b2'],
#  ['HBASE-8044', '41e2c36c82'],
#  ['HBASE-8044', '486b290863'],
#  ['HBASE-8044', '831e3dc59a'],
#  ['HBASE-8044', '16c7c1e769'],
#  ['HBASE-7966', '3a1b53f2fc'],
#  ['HBASE-7966', 'fd45b6fe06'],
#  ['HBASE-7966', '70b1899e88'],
#  ['HBASE-7966', '6f3af86452'],
#  ['HBASE-7966', 'ca1a0ea654'],
#  ['HBASE-7966', '27dd86e0a0'],
#  ['HBASE-7953', '30f12477b2'],
#  ['HBASE-7953', 'cf328edb97'],
#  ['HBASE-7953', 'f7d02a07d8'],
#  ['HBASE-7953', '4742310a5f'],
#  ['HBASE-7920', 'ad99387bfe'],
#  ['HBASE-7920', '66512747bf'],
#  ['HBASE-7920', '3c44b28c94'],
#  ['HBASE-7920', '99a9328680'],
#  ['HBASE-792', '92bd62bf58'],
#  ['HBASE-792', 'e2a146d694'],
#  ['HBASE-792', 'b3bdd512f3'],
#  ['HBASE-792', '9f00684d05'],
#  ['HBASE-7914', '2cccddf35d'],
#  ['HBASE-7914', '195e23fe01'],
#  ['HBASE-790', '942c54cf56'],
#  ['HBASE-790', '0d8ab3cad8'],
#  ['HBASE-790', '165e2ed915'],
#  ['HBASE-790', 'a9aef2181d'],
#  ['HBASE-790', 'b3bdd512f3'],
#  ['HBASE-790', '9f00684d05'],
#  ['HBASE-7878', 'c565b2f13a'],
#  ['HBASE-7878', '1aa9c548fc'],
#  ['HBASE-7878', 'c5d6b90eb8'],
#  ['HBASE-7878', '57a4c03bbb'],
#  ['HBASE-7878', 'ed9a0a5091'],
#  ['HBASE-7878', '030628c553'],
#  ['HBASE-7878', 'b3647fec74'],
#  ['HBASE-7878', '3b4b9b3c7a'],
#  ['HBASE-7878', '7850fda086'],
#  ['HBASE-7878', '17c662c46c'],
#  ['HBASE-7878', '28cfad9739'],
#  ['HBASE-7878', '31c1c9e7e6'],
#  ['HBASE-7878', '708669b53f'],
#  ['HBASE-7878', 'e253150cf3'],
#  ['HBASE-7878', '6722e26df1'],
#  ['HBASE-7878', 'dc470e0be7'],
#  ['HBASE-7878', 'bfbc70a68a'],
#  ['HBASE-7878', '46db70556e'],
#  ['HBASE-7878', '21eda243ad'],
#  ['HBASE-7878', '33f7a4d7ff'],
#  ['HBASE-7878', '50a47a9023'],
#  ['HBASE-7878', '539ff195e8'],
#  ['HBASE-7878', '3b923a92c5'],
#  ['HBASE-7878', '41208aa44f'],
#  ['HBASE-7878', '2e2d95af14'],
#  ['HBASE-7852', '2f1579e92e'],
#  ['HBASE-7852', '1bafc48511'],
#  ['HBASE-7817', '77df789608'],
#  ['HBASE-7817', 'ff3ae92d1f'],
#  ['HBASE-7817', '5ca140fe2f'],
#  ['HBASE-7725', '5068650101'],
#  ['HBASE-7725', '43edd93495'],
#  ['HBASE-7725', 'f66bbf1ca4'],
#  ['HBASE-7725', '1a766c42a1'],
#  ['HBASE-7682', 'a3f0aea354'],
#  ['HBASE-7669', '479232c610'],
#  ['HBASE-7669', 'e9f14f1073'],
#  ['HBASE-7669', '4d7b2824be'],
#  ['HBASE-7669', '898f661663'],
#  ['HBASE-7601', 'b96d60d659'],
#  ['HBASE-7595', '28b79e1214'],
#  ['HBASE-7588', 'f60b8246e7'],
#  ['HBASE-7588', 'c3e140cd14'],
#  ['HBASE-7588', '3b345cd684'],
#  ['HBASE-7587', '152ec1cc7f'],
#  ['HBASE-7587', '05934d7405'],
#  ['HBASE-7587', 'bda467aeca'],
#  ['HBASE-7586', '5c8c3d0a8c'],
#  ['HBASE-7521', '837f89bd79'],
#  ['HBASE-7521', 'efead793d4'],
#  ['HBASE-7521', '6ab7671f08'],
#  ['HBASE-7521', '883ec67336'],
#  ['HBASE-7517', '24e4df74ea'],
#  ['HBASE-7517', '69cbc81e5c'],
#  ['HBASE-7517', '8eee0f17ba'],
#  ['HBASE-7517', '233dc24e3d'],
#  ['HBASE-7508', '4e0af48fe4'],
#  ['HBASE-7491', 'c739366d73'],
#  ['HBASE-7443', '4409ba741c'],
#  ['HBASE-7443', '92c98a76d1'],
#  ['HBASE-7435', '9ead77761f'],
#  ['HBASE-7435', '8e664d8133'],
#  ['HBASE-7435', '2c684ee552'],
#  ['HBASE-7435', '5640731663'],
#  ['HBASE-7435', 'f356d580c5'],
#  ['HBASE-7417', 'b8784b73e5'],
#  ['HBASE-7417', '65d764e979'],
#  ['HBASE-7417', '85d9f6b709'],
#  ['HBASE-7390', 'deeb84ae5a'],
#  ['HBASE-7275', '289ab6b87c'],
#  ['HBASE-7198', '3b980dda5c'],
#  ['HBASE-7083', '75682c0c5b'],
#  ['HBASE-7002', 'f065232db0'],
#  ['HBASE-6991', 'd004827b82'],
#  ['HBASE-6991', '7465b3d076'],
#  ['HBASE-6991', '9b3e63dcb7'],
#  ['HBASE-697', '1371c33e8d'],
#  ['HBASE-697', 'e522b64665'],
#  ['HBASE-697', '0023b81e82'],
#  ['HBASE-697', 'fddd62e6c5'],
#  ['HBASE-697', '83c1c30938'],
#  ['HBASE-697', 'e30ed932bb'],
#  ['HBASE-697', 'c65c58905b'],
#  ['HBASE-697', 'f346a3d85a'],
#  ['HBASE-6943', '0750adf8a2'],
#  ['HBASE-6928', '610ea30534'],
#  ['HBASE-6928', 'e64430e970'],
#  ['HBASE-6920', '12315b8597'],
#  ['HBASE-6920', 'ce9703aa4f'],
#  ['HBASE-6920', '7bfd09e973'],
#  ['HBASE-6920', 'a0344c193f'],
#  ['HBASE-6920', 'bb54590ab5'],
#  ['HBASE-6920', '11496b6f72'],
#  ['HBASE-6920', '205c9b83ac'],
#  ['HBASE-6918', 'd6cca23ed3'],
#  ['HBASE-6871', '2f850f964a'],
#  ['HBASE-6871', '6abd8dec5e'],
#  ['HBASE-6871', 'dd2015d6ad'],
#  ['HBASE-6871', '061a2457b1'],
#  ['HBASE-6871', '9d470279dd'],
#  ['HBASE-6871', '267b941c4c'],
#  ['HBASE-6871', 'e496b61aa1'],
#  ['HBASE-6871', '215d216275'],
#  ['HBASE-6871', 'a4fbfcf640'],
#  ['HBASE-6871', '473dcddb55'],
#  ['HBASE-6871', '79e79ef090'],
#  ['HBASE-6871', 'd02e466bc2'],
#  ['HBASE-6871', 'c0b38e6c57'],
#  ['HBASE-6871', '15e07e8548'],
#  ['HBASE-6858', 'bb563c3603'],
#  ['HBASE-6858', '3a0b571d7b'],
#  ['HBASE-6858', 'e30829d8c1'],
#  ['HBASE-6858', '9712f25f8f'],
#  ['HBASE-6858', '9526aeb2a8'],
#  ['HBASE-6858', '9b789a9d67'],
#  ['HBASE-6858', '6bee1177a2'],
#  ['HBASE-6858', '529807b0e5'],
#  ['HBASE-6846', 'd487401613'],
#  ['HBASE-6846', '3ab7fe3e6e'],
#  ['HBASE-6846', 'f4923b98a6'],
#  ['HBASE-6838', '4ca039e4e3'],
#  ['HBASE-6838', '17a2e1663a'],
#  ['HBASE-681', '80fa33698f'],
#  ['HBASE-681', 'f02a98da07'],
#  ['HBASE-681', '767d2765b5'],
#  ['HBASE-6748', '2cccddf35d'],
#  ['HBASE-6748', '195e23fe01'],
#  ['HBASE-6748', '10c1bceda4'],
#  ['HBASE-6741', '72aba5f19e'],
#  ['HBASE-6741', 'dbcad94d43'],
#  ['HBASE-6728', 'db380918a4'],
#  ['HBASE-6728', '5754b24e57'],
#  ['HBASE-6728', '770605db8c'],
#  ['HBASE-6728', '1a32bfed45'],
#  ['HBASE-6728', '1048d15c6a'],
#  ['HBASE-6728', '649126bdc5'],
#  ['HBASE-6710', '4c7a465b00'],
#  ['HBASE-6710', '58f3f30cb3'],
#  ['HBASE-6710', '802f264f4e'],
#  ['HBASE-6710', 'baa5d4675a'],
#  ['HBASE-6710', '6c4e39dcae'],
#  ['HBASE-6697', '55fb6632b9'],
#  ['HBASE-6619', '6f8104a966'],
#  ['HBASE-6590', '564fc2e7c3'],
#  ['HBASE-6590', '1673fee154'],
#  ['HBASE-6590', 'dec419003a'],
#  ['HBASE-6583', '4606107e1d'],
#  ['HBASE-6583', '510cb9f71d'],
#  ['HBASE-6583', '7e02b67d30'],
#  ['HBASE-6583', '3e2399a7b1'],
#  ['HBASE-656', 'f328681e00'],
#  ['HBASE-656', 'c7165b1e30'],
#  ['HBASE-649', 'f328681e00'],
#  ['HBASE-649', 'c7165b1e30'],
#  ['HBASE-6460', '7c16621e1b'],
#  ['HBASE-6460', '78b3ca68c1'],
#  ['HBASE-6460', '936caf1b39'],
#  ['HBASE-6460', '9734a67ab4'],
#  ['HBASE-6460', '4d726189eb'],
#  ['HBASE-6421', 'd90f009688'],
#  ['HBASE-6389', '505bfe4363'],
#  ['HBASE-6389', '8738056386'],
#  ['HBASE-6389', '6f6f425a31'],
#  ['HBASE-6389', 'c6038306f5'],
#  ['HBASE-6389', '983d08709e'],
#  ['HBASE-6389', '5586daa4de'],
#  ['HBASE-6389', 'd9a7c8cd60'],
#  ['HBASE-6389', 'e0d9503dd7'],
#  ['HBASE-6389', '3a68756704'],
#  ['HBASE-6388', '27c67b8577'],
#  ['HBASE-6388', 'f5b5e66da1'],
#  ['HBASE-6377', '528d95d964'],
#  ['HBASE-6377', 'c3fcaa3560'],
#  ['HBASE-6377', '349c82e0a0'],
#  ['HBASE-6368', '07eb671bc9'],
#  ['HBASE-6368', 'd6ed913ce5'],
#  ['HBASE-6340', '8767127966'],
#  ['HBASE-6340', '7538a94704'],
#  ['HBASE-6340', '3fadfe5958'],
#  ['HBASE-6340', '124d48e61a'],
#  ['HBASE-6340', '23f61b37bb'],
#  ['HBASE-6340', 'a7dde5bb90'],
#  ['HBASE-6340', '4ae9102b28'],
#  ['HBASE-6340', '6be9826a22'],
#  ['HBASE-6284', '003df0419f'],
#  ['HBASE-6284', 'c2afb45db9'],
#  ['HBASE-6284', '2bd71320b2'],
#  ['HBASE-6284', '6505939970'],
#  ['HBASE-6276', 'f4165e27ce'],
#  ['HBASE-6276', 'aae0227054'],
#  ['HBASE-6276', 'a39d417edd'],
#  ['HBASE-6276', '5a676a601e'],
#  ['HBASE-6276', 'c80b254756'],
#  ['HBASE-6200', '62f038308e'],
#  ['HBASE-6200', 'd97099951a'],
#  ['HBASE-6200', '98b05fce1f'],
#  ['HBASE-6200', 'bf3697d750'],
#  ['HBASE-6200', '275bfdcc40'],
#  ['HBASE-6164', 'f727c0d5ec'],
#  ['HBASE-6164', '0c0e5af110'],
#  ['HBASE-6138', '181d2ea889'],
#  ['HBASE-6138', '62154f1a1a'],
#  ['HBASE-613', 'ae97400be0'],
#  ['HBASE-613', '769b0e5c8c'],
#  ['HBASE-613', '193deb330d'],
#  ['HBASE-613', '80fa33698f'],
#  ['HBASE-613', 'f02a98da07'],
#  ['HBASE-613', '4dbb084860'],
#  ['HBASE-6123', '901c3a31ce'],
#  ['HBASE-6121', 'f69428067b'],
#  ['HBASE-6112', '9aa80d2696'],
#  ['HBASE-6112', '4ae26c1246'],
#  ['HBASE-6110', '3fa097b01c'],
#  ['HBASE-6110', '99613b8746'],
#  ['HBASE-6110', 'a113f4c291'],
#  ['HBASE-6088', '1761677cef'],
#  ['HBASE-6088', '1869b424ba'],
#  ['HBASE-6088', '77b446186c'],
#  ['HBASE-6088', '4c5a7bbfb3'],
#  ['HBASE-6088', 'a9a4dbe59c'],
#  ['HBASE-6088', 'ccb9c74400'],
#  ['HBASE-6060', 'efead793d4'],
#  ['HBASE-6060', '883ec67336'],
#  ['HBASE-6060', 'ddb9e96654'],
#  ['HBASE-6059', '4eb48a2043'],
#  ['HBASE-6059', '5144d15ce3'],
#  ['HBASE-6059', '8ea00217ed'],
#  ['HBASE-6059', 'b3ec7ced77'],
#  ['HBASE-5974', '8f9faabf57'],
#  ['HBASE-5974', '624021fb4d'],
#  ['HBASE-5974', 'c9073c4631'],
#  ['HBASE-5919', '7692e2efb7'],
#  ['HBASE-588', '03ce494494'],
#  ['HBASE-588', 'fb2db8cdaa'],
#  ['HBASE-588', '75c73ccbbb'],
#  ['HBASE-588', 'e1da900df8'],
#  ['HBASE-588', '1d199b4b7b'],
#  ['HBASE-586', 'ee27270ee9'],
#  ['HBASE-586', 'cffa3a254e'],
#  ['HBASE-586', '32ce612048'],
#  ['HBASE-5825', '10cada8d0b'],
#  ['HBASE-5825', '183b567f6f'],
#  ['HBASE-5825', 'a0a2674c42'],
#  ['HBASE-5824', 'e05c21c0cb'],
#  ['HBASE-5824', '85842f019e'],
#  ['HBASE-5824', '0b30494edb'],
#  ['HBASE-5805', '5ec931d5c7'],
#  ['HBASE-5805', '0f28bc4b6c'],
#  ['HBASE-5799', '44ec501a2b'],
#  ['HBASE-5781', '8db34840c9'],
#  ['HBASE-5781', '711a90655c'],
#  ['HBASE-5781', 'a91b3977f2'],
#  ['HBASE-5781', '7f7bc2b6b6'],
#  ['HBASE-5781', '44a05d4380'],
#  ['HBASE-5763', '421400c256'],
#  ['HBASE-5763', 'c21266e5b2'],
#  ['HBASE-5744', '00316a4a51'],
#  ['HBASE-5744', '46286a023e'],
#  ['HBASE-5743', '20e281d7e1'],
#  ['HBASE-5730', 'bff42e1d84'],
#  ['HBASE-5727', 'c831d7b512'],
#  ['HBASE-5727', '1044d5e353'],
#  ['HBASE-5727', '66772ce043'],
#  ['HBASE-5727', 'e1449b5538'],
#  ['HBASE-5700', '8764ccd917'],
#  ['HBASE-5611', '1f5e7da87e'],
#  ['HBASE-5611', '1ea241364f'],
#  ['HBASE-5611', '224cfd640d'],
#  ['HBASE-5611', '3f5800a3f1'],
#  ['HBASE-5611', '9f3d9a4283'],
#  ['HBASE-5611', '8c8922da96'],
#  ['HBASE-5611', 'c896b73549'],
#  ['HBASE-5611', 'b6f7573a3b'],
#  ['HBASE-5611', 'b8554c84d4'],
#  ['HBASE-5611', 'b695b64dfa'],
#  ['HBASE-5598', '9fac4877d3'],
#  ['HBASE-5598', '81b15f1907'],
#  ['HBASE-5597', '1629b1a219'],
#  ['HBASE-5597', '3c58fdacf1'],
#  ['HBASE-5597', '5856e90720'],
#  ['HBASE-5596', 'a703e49824'],
#  ['HBASE-5596', '998367baf1'],
#  ['HBASE-5596', 'd5b5fabf14'],
#  ['HBASE-5596', '3fd6997380'],
#  ['HBASE-5567', 'df97e219c4'],
#  ['HBASE-5567', 'ab2b1acced'],
#  ['HBASE-5567', '2314945b8b'],
#  ['HBASE-5566', '04c6066df8'],
#  ['HBASE-5562', '63bd5eae5b'],
#  ['HBASE-5562', '0ae06d72b6'],
#  ['HBASE-5562', 'd04201683a'],
#  ['HBASE-554', 'a00fd30d8a'],
#  ['HBASE-554', '48899525e5'],
#  ['HBASE-554', '53563c5586'],
#  ['HBASE-554', '5a43af4b99'],
#  ['HBASE-552', 'de57a6f401'],
#  ['HBASE-552', 'a1f8ee8ac1'],
#  ['HBASE-552', 'c729049956'],
#  ['HBASE-552', '425a522a45'],
#  ['HBASE-5499', '624b0a51b2'],
#  ['HBASE-5499', '6783a4cd96'],
#  ['HBASE-5499', 'ffa518256f'],
#  ['HBASE-5470', '85c90d9274'],
#  ['HBASE-5470', 'ded2006ec9'],
#  ['HBASE-5437', 'b0d4403059'],
#  ['HBASE-5437', 'e7cfa2da58'],
#  ['HBASE-5387', 'e4e8c9dc5b'],
#  ['HBASE-5387', 'b50714c043'],
#  ['HBASE-5387', 'a148490496'],
#  ['HBASE-532', '03ce494494'],
#  ['HBASE-532', 'fb2db8cdaa'],
#  ['HBASE-532', '75c73ccbbb'],
#  ['HBASE-532', 'e1da900df8'],
#  ['HBASE-532', '1d199b4b7b'],
#  ['HBASE-532', '26c2702c12'],
#  ['HBASE-532', 'ef5bb6f316'],
#  ['HBASE-532', '7475ce01fa'],
#  ['HBASE-532', '373761483f'],
#  ['HBASE-532', '64e3f031ea'],
#  ['HBASE-5286', '3d906ed52b'],
#  ['HBASE-5286', 'eb42e72b89'],
#  ['HBASE-5286', '84c103829e'],
#  ['HBASE-5286', '0132176084'],
#  ['HBASE-5286', '180b41f518'],
#  ['HBASE-5286', '11446b1bd6'],
#  ['HBASE-5286', 'abaad0bec9'],
#  ['HBASE-5204', '0abb51186a'],
#  ['HBASE-5204', 'e20aa2b3a6'],
#  ['HBASE-5204', '35cd894356'],
#  ['HBASE-5137', '051c8981c0'],
#  ['HBASE-5137', 'abe549d38e'],
#  ['HBASE-5137', '17af5827a5'],
#  ['HBASE-5137', 'e06aaf4ecc'],
#  ['HBASE-5137', '0820fbddd3'],
#  ['HBASE-5104', 'd2ca6bfe63'],
#  ['HBASE-5104', 'e83952f9af'],
#  ['HBASE-5085', '8edf120cf7'],
#  ['HBASE-5085', '31b10cd5f2'],
#  ['HBASE-5081', 'cb8e30ae17'],
#  ['HBASE-5081', 'ff3cf1aeda'],
#  ['HBASE-5081', '00a846ff20'],
#  ['HBASE-5081', '6b39d23401'],
#  ['HBASE-5081', '04d9afead2'],
#  ['HBASE-5081', '7569cea558'],
#  ['HBASE-5081', '436e064a2c'],
#  ['HBASE-5081', '6c97552ee1'],
#  ['HBASE-5081', 'eb9f9a9e78'],
#  ['HBASE-5081', 'fd27501c1c'],
#  ['HBASE-5081', '3e92ac2ddb'],
#  ['HBASE-5081', 'fa979ebab2'],
#  ['HBASE-5081', 'b8c423408a'],
#  ['HBASE-5081', '72c1f6c8c7'],
#  ['HBASE-5081', '69a45fe909'],
#  ['HBASE-5081', '9f986b0dca'],
#  ['HBASE-5077', '482a460546'],
#  ['HBASE-5077', 'c5b874fff0'],
#  ['HBASE-5077', '26de3b2c74'],
#  ['HBASE-5077', '04dd71214a'],
#  ['HBASE-5077', 'e76a78e103'],
#  ['HBASE-5077', 'bcde7a436f'],
#  ['HBASE-505', 'f15048d4d0'],
#  ['HBASE-505', 'b104b3235b'],
#  ['HBASE-505', '90e3cb13ca'],
#  ['HBASE-5029', '0766dd12f2'],
#  ['HBASE-5029', '1222383f1d'],
#  ['HBASE-5029', '48f3c24dc6'],
#  ['HBASE-5029', '48ccb28e81'],
#  ['HBASE-5029', '4c2c89a9d0'],
#  ['HBASE-5029', '185c0c7dd7'],
#  ['HBASE-5029', 'cd8b64fb38'],
#  ['HBASE-5029', 'a157c07ead'],
#  ['HBASE-5029', '86a3830175'],
#  ['HBASE-5029', '203d2828be'],
#  ['HBASE-5029', '3cad85bc77'],
#  ['HBASE-5029', 'badab7888f'],
#  ['HBASE-5029', 'e4c0fd9231'],
#  ['HBASE-501', '4ea64897fe'],
#  ['HBASE-501', '1e27f603a1'],
#  ['HBASE-501', '277f675af6'],
#  ['HBASE-501', 'c1f974bbee'],
#  ['HBASE-501', '55f01a9863'],
#  ['HBASE-501', 'bba36ce79a'],
#  ['HBASE-500', 'da595915a9'],
#  ['HBASE-4997', 'bcaabd9105'],
#  ['HBASE-4997', '4b8eb16ea9'],
#  ['HBASE-4997', '76a2db4d50'],
#  ['HBASE-4997', '9a74916dae'],
#  ['HBASE-4927', 'bb7f82ac71'],
#  ['HBASE-4927', '925c25fdda'],
#  ['HBASE-4927', '61683142da'],
#  ['HBASE-4927', 'e8123d2b21'],
#  ['HBASE-4927', '1f176022fe'],
#  ['HBASE-4927', 'e1855a9344'],
#  ['HBASE-4890', '0f7285a81a'],
#  ['HBASE-4890', '3c7cd28524'],
#  ['HBASE-4890', 'c5570926a2'],
#  ['HBASE-4890', 'c5354bf129'],
#  ['HBASE-4883', '8ed781ada7'],
#  ['HBASE-4883', 'ea764bd727'],
#  ['HBASE-4883', '01c389c879'],
#  ['HBASE-4883', '625889c281'],
#  ['HBASE-4823', '0d2aab190e'],
#  ['HBASE-4799', 'c991dba669'],
#  ['HBASE-4799', 'ea3484ecea'],
#  ['HBASE-4799', 'f7099fa5c7'],
#  ['HBASE-4799', 'c9d5a838d0'],
#  ['HBASE-4799', '04b1c45b94'],
#  ['HBASE-4758', '2235988874'],
#  ['HBASE-4722', '451303c3cb'],
#  ['HBASE-4722', '2ce1d7c97c'],
#  ['HBASE-4722', 'ec1c5835ec'],
#  ['HBASE-4722', '3fab67a8b5'],
#  ['HBASE-4722', 'b0a61e290e'],
#  ['HBASE-4686', '1c7d82cdad'],
#  ['HBASE-4645', '6e0c0ec263'],
#  ['HBASE-4645', '770cc7d5d2'],
#  ['HBASE-4645', 'aa2c97b3b7'],
#  ['HBASE-4645', '9ffe7cb666'],
#  ['HBASE-4589', 'af700ae33e'],
#  ['HBASE-4589', 'cbfd640aab'],
#  ['HBASE-4589', '4d776c28b9'],
#  ['HBASE-4589', 'efa951b6ab'],
#  ['HBASE-4540', '0a98312a9e'],
#  ['HBASE-4540', '5cd3b9979b'],
#  ['HBASE-4540', '5331d83421'],
#  ['HBASE-4540', '3d50077db1'],
#  ['HBASE-4540', 'bd06d43d93'],
#  ['HBASE-4539', '5331d83421'],
#  ['HBASE-4539', '3d50077db1'],
#  ['HBASE-4539', 'bd06d43d93'],
#  ['HBASE-4531', '1f2f565409'],
#  ['HBASE-4531', '6232eae926'],
#  ['HBASE-4531', '82c9209931'],
#  ['HBASE-4531', 'ef24e43470'],
#  ['HBASE-4531', 'cb845c04d8'],
#  ['HBASE-4531', '6ae7807237'],
#  ['HBASE-4505', '435fea6d79'],
#  ['HBASE-4505', '0db9b9b148'],
#  ['HBASE-4400', 'aa6d6c7a9e'],
#  ['HBASE-4400', 'e866d8091d'],
#  ['HBASE-4400', '034215f247'],
#  ['HBASE-4400', 'ab404d8f36'],
#  ['HBASE-4400', '89b5c7bf10'],
#  ['HBASE-4400', '3cc7e62571'],
#  ['HBASE-4400', 'e282e25dac'],
#  ['HBASE-4367', '3dc7b7f69b'],
#  ['HBASE-4367', '9570f3c907'],
#  ['HBASE-4367', '7c56111aaa'],
#  ['HBASE-4367', '0aafb370ce'],
#  ['HBASE-4350', 'b043d60317'],
#  ['HBASE-4350', '2077f41f18'],
#  ['HBASE-4350', '76b123052e'],
#  ['HBASE-4350', '9f3c81e87d'],
#  ['HBASE-4153', '0b9498a53c'],
#  ['HBASE-4153', '083d104243'],
#  ['HBASE-4153', 'a7318c7969'],
#  ['HBASE-4153', '1ad63afb70'],
#  ['HBASE-4153', '9ab414f1dc'],
#  ['HBASE-4153', '2786fd5863'],
#  ['HBASE-4153', '83da96047e'],
#  ['HBASE-4153', '08d56e35e4'],
#  ['HBASE-4153', 'bf8af69d8d'],
#  ['HBASE-4153', '76ba002ef7'],
#  ['HBASE-4153', 'a36c666a87'],
#  ['HBASE-4153', 'd098ab3b2c'],
#  ['HBASE-4153', '7e6a6538b4'],
#  ['HBASE-4153', 'bd372dcea7'],
#  ['HBASE-4150', '738f80c221'],
#  ['HBASE-4150', 'd453688d1a'],
#  ['HBASE-4150', '4b84ea5a0a'],
#  ['HBASE-4150', '061f1bcd73'],
#  ['HBASE-4150', '2c772a97ab'],
#  ['HBASE-4150', '0aa723c2a3'],
#  ['HBASE-4150', 'a9031452f7'],
#  ['HBASE-4150', '6acdab46a1'],
#  ['HBASE-4149', '026b437eff'],
#  ['HBASE-4149', 'b2d802611f'],
#  ['HBASE-4138', '5cae3a6b66'],
#  ['HBASE-4138', '2889431d93'],
#  ['HBASE-4138', '1c5e23f215'],
#  ['HBASE-4138', 'b993a611e1'],
#  ['HBASE-4138', '5e4f28c289'],
#  ['HBASE-4138', 'd1cb273b2f'],
#  ['HBASE-4078', 'df9b82c082'],
#  ['HBASE-4078', '98cad6e708'],
#  ['HBASE-4078', 'fa26da20db'],
#  ['HBASE-4078', '790feddf2d'],
#  ['HBASE-4075', '3314b87804'],
#  ['HBASE-4075', 'df9c2fdc30'],
#  ['HBASE-4075', 'd69b198ba9'],
#  ['HBASE-4020', 'a9e7b929e7'],
#  ['HBASE-4020', '1a5251661e'],
#  ['HBASE-4020', '829cdddeec'],
#  ['HBASE-4005', '2851a9dfe3'],
#  ['HBASE-4005', '7e87980347'],
#  ['HBASE-4005', '170bed8651'],
#  ['HBASE-3987', '73cb88aef3'],
#  ['HBASE-3987', '3f59c6a0e5'],
#  ['HBASE-3987', '6f09e358e0'],
#  ['HBASE-3987', '949f7a68db'],
#  ['HBASE-3979', 'c98dc2c4b4'],
#  ['HBASE-3979', '7ccbc3bbb1'],
#  ['HBASE-3939', 'ae0dccc833'],
#  ['HBASE-3939', '7ccda81373'],
#  ['HBASE-3939', '7d8d42d01b'],
#  ['HBASE-3939', '2e678eaab6'],
#  ['HBASE-3912', 'e341eb76cb'],
#  ['HBASE-3912', '60d7a81833'],
#  ['HBASE-3912', '7d86a5998b'],
#  ['HBASE-3912', '1c6a02a046'],
#  ['HBASE-3912', '981f414cd3'],
#  ['HBASE-3912', 'cd8f643954'],
#  ['HBASE-3904', 'edf2b7901a'],
#  ['HBASE-3904', 'd37e6eb390'],
#  ['HBASE-3904', 'de919df41a'],
#  ['HBASE-3904', '04e89f8ae4'],
#  ['HBASE-3904', '1add4cc5d2'],
#  ['HBASE-3904', 'abccc7fd9f'],
#  ['HBASE-3904', '7fa7d15daf'],
#  ['HBASE-3904', '1f3a4fefb8'],
#  ['HBASE-3904', '46924a1dc2'],
#  ['HBASE-3904', '521141cdc6'],
#  ['HBASE-3904', '18987b9d4d'],
#  ['HBASE-3904', 'a4482ae1ac'],
#  ['HBASE-3904', 'e3f8560143'],
#  ['HBASE-3904', '24c18ac1e9'],
#  ['HBASE-3872', '6fd573c3b0'],
#  ['HBASE-3872', 'f54803aac2'],
#  ['HBASE-3872', '185e57e58c'],
#  ['HBASE-3872', '0a0ce9f1ae'],
#  ['HBASE-3872', '5872ef811b'],
#  ['HBASE-3872', '7f10f29425'],
#  ['HBASE-3872', 'ca7452b4b6'],
#  ['HBASE-3832', 'c80200bded'],
#  ['HBASE-3832', '097edf7bc4'],
#  ['HBASE-3821', 'ce20845951'],
#  ['HBASE-3821', '81e9be2518'],
#  ['HBASE-3821', '724ddc58bf'],
#  ['HBASE-3821', '8e0e63e0a8'],
#  ['HBASE-3819', '95a45d1341'],
#  ['HBASE-3819', '2e84b07763'],
#  ['HBASE-3819', 'e01e57ff92'],
#  ['HBASE-3819', '599b7e6f7d'],
#  ['HBASE-3813', '8ffaac2003'],
#  ['HBASE-3813', '1162a81b92'],
#  ['HBASE-3813', 'e56c8db56e'],
#  ['HBASE-3793', '7656d7568a'],
#  ['HBASE-3793', '243c222ccd'],
#  ['HBASE-3793', '76a743e8f0'],
#  ['HBASE-3793', 'f0b1b298c7'],
#  ['HBASE-3762', 'f616c0c709'],
#  ['HBASE-3762', '07353b5618'],
#  ['HBASE-3762', 'a7f8453d50'],
#  ['HBASE-3762', '02659a4882'],
#  ['HBASE-3750', '7eddae4687'],
#  ['HBASE-3750', '9fe4b7c5bc'],
#  ['HBASE-3750', '1b438175a3'],
#  ['HBASE-3750', 'c81146580a'],
#  ['HBASE-3750', '56b76bd434'],
#  ['HBASE-3750', '13bc223d04'],
#  ['HBASE-3741', '4219e2accb'],
#  ['HBASE-3741', '0e29fbf876'],
#  ['HBASE-3741', 'afea4ede2a'],
#  ['HBASE-3741', 'a5863ce0e7'],
#  ['HBASE-3708', 'b634180d5c'],
#  ['HBASE-3708', '7f90ea5860'],
#  ['HBASE-3708', '6aa734ee92'],
#  ['HBASE-3708', 'b10bacf1e8'],
#  ['HBASE-3690', '04afdf9633'],
#  ['HBASE-3690', 'c40efc3887'],
#  ['HBASE-3674', '992bf057e7'],
#  ['HBASE-3674', '45e341b8b7'],
#  ['HBASE-3674', '7437b11bec'],
#  ['HBASE-3674', 'dded2af3e0'],
#  ['HBASE-3674', '5125ae04fb'],
#  ['HBASE-3674', '53a031f00c'],
#  ['HBASE-3674', '8070b53b13'],
#  ['HBASE-3671', '05c9826cba'],
#  ['HBASE-3671', '1889d7ed5c'],
#  ['HBASE-3671', '56aeaec832'],
#  ['HBASE-3671', '23916d541d'],
#  ['HBASE-3671', 'f56380f1ce'],
#  ['HBASE-3671', '33f7f5525b'],
#  ['HBASE-3671', '2e41ea820e'],
#  ['HBASE-3671', '3579bdf84b'],
#  ['HBASE-3671', '2ea5d45bb0'],
#  ['HBASE-3669', '86e9f5f8c9'],
#  ['HBASE-3669', '237bc82af2'],
#  ['HBASE-3669', 'bd688ffaae'],
#  ['HBASE-3636', '32d4618caf'],
#  ['HBASE-3636', '856065dee8'],
#  ['HBASE-3636', '129ced5a3d'],
#  ['HBASE-3627', '23606d0645'],
#  ['HBASE-3627', '79b522db0c'],
#  ['HBASE-3627', '89794648e6'],
#  ['HBASE-3627', '16bb3bb633'],
#  ['HBASE-3627', 'cf3284dfb9'],
#  ['HBASE-3627', '833fd0095e'],
#  ['HBASE-3622', 'c38558e545'],
#  ['HBASE-3622', '42b7a92450'],
#  ['HBASE-3515', '930eb49759'],
#  ['HBASE-3515', '346aa36b77'],
#  ['HBASE-3515', 'cb9e52fe6b'],
#  ['HBASE-3515', '08a9170236'],
#  ['HBASE-3515', 'fa8dcedb56'],
#  ['HBASE-3515', 'd051203938'],
#  ['HBASE-3515', '1aaaac0c92'],
#  ['HBASE-3515', 'c9449f0598'],
#  ['HBASE-3515', 'ef29cac094'],
#  ['HBASE-3515', '2b7560b147'],
#  ['HBASE-3515', '01af2a830e'],
#  ['HBASE-3481', 'fa81c75aed'],
#  ['HBASE-3421', 'e3acd1dd77'],
#  ['HBASE-3421', '15a396c926'],
#  ['HBASE-3421', 'd9158b505e'],
#  ['HBASE-3421', 'a8536b787c'],
#  ['HBASE-3421', '61249dc5f3'],
#  ['HBASE-3421', 'ba305551e1'],
#  ['HBASE-3421', '7efe1dbbce'],
#  ['HBASE-3421', 'bcaecda371'],
#  ['HBASE-3421', '1244c9108f'],
#  ['HBASE-3416', '9937c30304'],
#  ['HBASE-3416', 'feda42e474'],
#  ['HBASE-3416', 'a3a2ce9215'],
#  ['HBASE-3416', '410d70fca7'],
#  ['HBASE-3374', 'a59bd1030b'],
#  ['HBASE-3374', 'e787973338'],
#  ['HBASE-3374', 'ec8f0ad428'],
#  ['HBASE-3337', 'c0c723f660'],
#  ['HBASE-3337', '092bdbbea6'],
#  ['HBASE-3337', '97adaad945'],
#  ['HBASE-3315', 'ef50ac96c4'],
#  ['HBASE-3315', 'd547429a14'],
#  ['HBASE-3315', 'b9c34cf91a'],
#  ['HBASE-3311', 'b1a82279a1'],
#  ['HBASE-3311', '5441eaa83d'],
#  ['HBASE-3311', 'ce3139a30e'],
#  ['HBASE-3298', 'b1a82279a1'],
#  ['HBASE-3298', '5441eaa83d'],
#  ['HBASE-3298', 'ce3139a30e'],
#  ['HBASE-3298', 'be91a5326f'],
#  ['HBASE-3298', 'a3127bd6cd'],
#  ['HBASE-3298', '0427950746'],
#  ['HBASE-3298', '61fb4c2d77'],
#  ['HBASE-3298', 'd960ee49cb'],
#  ['HBASE-3298', 'b6a5c4189f'],
#  ['HBASE-3298', 'f6b7e8c6c3'],
#  ['HBASE-3298', 'fe2e720318'],
#  ['HBASE-3298', '633c049091'],
#  ['HBASE-3275', 'cb85bf2e0a'],
#  ['HBASE-3275', '182e82fa62'],
#  ['HBASE-3275', '79a2cf9f3a'],
#  ['HBASE-3275', '446c403dc4'],
#  ['HBASE-3275', '429fc09852'],
#  ['HBASE-3275', '9b45d9996f'],
#  ['HBASE-3275', 'de0ab29132'],
#  ['HBASE-3264', '84134f360a'],
#  ['HBASE-3264', '2778fced75'],
#  ['HBASE-3264', 'c0e4ac3571'],
#  ['HBASE-3264', '307dafacfe'],
#  ['HBASE-3264', '272806891a'],
#  ['HBASE-3264', 'e9b54394cb'],
#  ['HBASE-3264', 'a7b528a712'],
#  ['HBASE-3264', '4ff0e7ac89'],
#  ['HBASE-3264', '4122dc1fe5'],
#  ['HBASE-3241', 'd68e62c6b8'],
#  ['HBASE-3241', '4a6d4ff453'],
#  ['HBASE-3241', '3027f23030'],
#  ['HBASE-3241', '1c76849d3d'],
#  ['HBASE-3239', 'd68e62c6b8'],
#  ['HBASE-3239', '4a6d4ff453'],
#  ['HBASE-3239', '3027f23030'],
#  ['HBASE-3239', '1c76849d3d'],
#  ['HBASE-3232', '3093d81540'],
#  ['HBASE-3232', '571e8f8520'],
#  ['HBASE-3232', '3fd0eedcdf'],
#  ['HBASE-3232', 'a3e56bb694'],
#  ['HBASE-3232', 'a14cd5950c'],
#  ['HBASE-3232', '069fecaeb7'],
#  ['HBASE-3232', '717fee6602'],
#  ['HBASE-3199', 'f102ec2722'],
#  ['HBASE-3199', '0cb9652dd1'],
#  ['HBASE-3199', 'ea9618df63'],
#  ['HBASE-3183', '053141a64f'],
#  ['HBASE-3183', '2fbceee800'],
#  ['HBASE-3183', '9009d8e489'],
#  ['HBASE-3179', '18a78fef4d'],
#  ['HBASE-3179', '10e1d0d6fc'],
#  ['HBASE-3159', '3523b66eec'],
#  ['HBASE-3159', '289ca8adae'],
#  ['HBASE-3114', '0f27ee880c'],
#  ['HBASE-3114', '13d8b4fdad'],
#  ['HBASE-3113', 'dcbcd4f2d4'],
#  ['HBASE-3113', '02d9066f9e'],
#  ['HBASE-3113', '509beae1e2'],
#  ['HBASE-3113', '0d2dcd023c'],
#  ['HBASE-3113', 'e20615b917'],
#  ['HBASE-3113', '98edfa4ba1'],
#  ['HBASE-3113', 'bcaa2dea49'],
#  ['HBASE-3113', 'c0be59b731'],
#  ['HBASE-3111', '954efa6e76'],
#  ['HBASE-3111', 'e334903b44'],
#  ['HBASE-3111', 'cd2bfd5b6a'],
#  ['HBASE-3111', '2379ca5a68'],
#  ['HBASE-3110', 'a01b4c5576'],
#  ['HBASE-3110', '095b37ecdf'],
#  ['HBASE-3110', '3d75d323e5'],
#  ['HBASE-3110', '14554236ef'],
#  ['HBASE-3100', '0fcd520eb3'],
#  ...]

# %% [markdown]
# Saving into CSV file

# %%
with open(analyze_dir + "02_extracting_commitid/commitid_of_candidatebugfix.csv", 'w') as parentfix:
    cols = ['bug_id','candidate_bugfix_commitID']
    writers = csv.writer(parentfix, delimiter=',')
    writers.writerow(cols)
    for item in commit_idfix:
        writers.writerow(item)

dfcommitfix = pd.read_csv(analyze_dir + "02_extracting_commitid/commitid_of_candidatebugfix.csv")
dfcommitfix = dfcommitfix[cols]
dfcommitfix
# Out:
#            bug_id candidate_bugfix_commitID
# 0      HBASE-9971                8a6291a896
# 1      HBASE-9961                1e7fdb06b2
# 2      HBASE-9961                560f000424
# 3      HBASE-9961                e5946ba799
# 4      HBASE-9961                18e018b3d9
# 5      HBASE-9958                8a6291a896
# 6      HBASE-9958                4b84160b37
# 7      HBASE-9958                c5a3048fec
# 8      HBASE-9908                f224e4721f
# 9      HBASE-9908                16b799dae5
# 10     HBASE-9908                61120fb62c
# 11     HBASE-9908                ff78f217fa
# 12     HBASE-9893                c5fc5b993e
# 13     HBASE-9893                da89846cf7
# 14     HBASE-9856                13e9eda3e7
# 15      HBASE-985                e3659aa246
# 16      HBASE-985                894c99bdb3
# 17     HBASE-9843                6dd52d7ed3
# 18     HBASE-9843                53bb2f6be7
# 19      HBASE-984                f78f944026
# 20      HBASE-984                963c1104dd
# 21     HBASE-9786                230cb08611
# 22     HBASE-9786                6d0eade8b6
# 23      HBASE-977                5418547132
# 24      HBASE-977                1b49c9b6c4
# 25     HBASE-9747                201c67a7d8
# 26     HBASE-9747                3f496372bf
# 27     HBASE-9747                b4df85d6b0
# 28     HBASE-9747                fc15e1ae39
# 29     HBASE-9747                a2a3071256
# ...           ...                       ...
# 2503  HBASE-10397                b5d161c513
# 2504  HBASE-10370                5645d48eac
# 2505  HBASE-10370                bebb59dc10
# 2506  HBASE-10370                3b9b0e1bc8
# 2507  HBASE-10370                c27bfd6acc
# 2508  HBASE-10370                1abfabaaa4
# 2509  HBASE-10370                9b10589954
# 2510  HBASE-10370                e7c36e7822
# 2511  HBASE-10370                868f9e4b38
# 2512   HBASE-1013                05a11e7fcc
# 2513   HBASE-1013                dfd2d6af99
# 2514  HBASE-10079                d6e86d0524
# 2515  HBASE-10079                8eca550e02
# 2516  HBASE-10079                584793fb6f
# 2517  HBASE-10079                3fb88f10af
# 2518  HBASE-10079                6873efa5a2
# 2519  HBASE-10079                923becd6c0
# 2520  HBASE-10011                22f54af029
# 2521  HBASE-10011                100cfded38
# 2522  HBASE-10011                35cea57fe5
# 2523  HBASE-10004                e0c324f9d5
# 2524   HBASE-9778                ca8b80433e
# 2525   HBASE-9778                a772c4110d
# 2526   HBASE-9778                9ffe4843dd
# 2527   HBASE-9778                d2eac30d68
# 2528   HBASE-9778                330a8e1fc3
# 2529   HBASE-3015                d16d6257e6
# 2530   HBASE-3015                7daffb3a42
# 2531   HBASE-3015                0d53298953
# 2532  HBASE-15195                9955118995
#
# [2533 rows x 2 columns]
