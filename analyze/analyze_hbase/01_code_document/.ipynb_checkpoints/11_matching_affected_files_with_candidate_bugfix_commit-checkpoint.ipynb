# %% [markdown]
# # Importing libraries

# %%
import os, glob, json, csv, subprocess, sys, re, operator
from git import *
from subprocess import Popen, PIPE
from os import path
import pandas as pd
import plotly.graph_objs as go
from plotly.offline import plot, init_notebook_mode, iplot

# %matplotlib inline

# %% [markdown]
# # Defining repository and directories

# %%
userhome = os.path.expanduser('~')
repository = userhome + r'/different-diff/dataset/hbase/'
analyze_dir = userhome + r'/different-diff/analyze/analyze_hbase/'

# %% [markdown]
# # Load dataset number of files

# %%
algorithms = ['histogram','minimal','myers','patience']

# %% [markdown]
# Adding a field key to combine 2 CSV files

# %%
for j, alg in enumerate(algorithms):
    with open(analyze_dir + "03_file-diff/03_number_of_files/" + alg + "_total_bugline.csv",'r') as csvinput:
        with open(analyze_dir + "04_annotate/05_matching_affectedfiles/temp_" + alg + "_bugline.csv", 'w') as csvoutput:
            writer = csv.writer(csvoutput, lineterminator='\n')
            reader = csv.reader(csvinput)

            all = []
            row = next(reader)
            row.append('file_key')
            all.append(row)
            
            num = 1
            for row in reader:
                row.append(row[0] + "_" + row[1] + "-" + row[2][:10] + "_" + row[4] + "_" + str(num))
                all.append(row)
                num += 1

            writer.writerows(all)

# %%
for j, alg in enumerate(algorithms):
    with open(analyze_dir + "04_annotate/04_grouping_affected_non-affected_files/" + alg + "_affected_files.csv",'r') as csvinput:
        with open(analyze_dir + "04_annotate/05_matching_affectedfiles/temp_" + alg + "_aff_files.csv", 'w') as csvoutput:
            writer = csv.writer(csvoutput, lineterminator='\n')
            reader = csv.reader(csvinput)

            all = []
            row = next(reader)
            row.append('file_key')
            all.append(row)
            
            num = 1
            for row in reader:
                row.append(row[1] + "_" + row[3] + "-" + row[4] + "_" + row[2] + "_" + str(num))
                all.append(row)
                num += 1

            writer.writerows(all)

# %% [markdown]
# # Joining bugline files and affected files

# %%
for k, algo in enumerate(algorithms):
    filedatabug = pd.read_csv(analyze_dir + '04_annotate/05_matching_affectedfiles/temp_' + algo + '_bugline.csv')
    filedataaff = pd.read_csv(analyze_dir + "04_annotate/05_matching_affectedfiles/temp_" + algo + "_aff_files.csv")

    details = filedatabug.join(filedataaff.set_index('file_key')[['filenumber','affect_version?']], on='file_key')
    details = details[details['number_of_buggyline'] != 0]
    details.to_csv(analyze_dir + '05_finding_versions/02_files_affect/' + algo + '_joining_files.csv')

# %%
details
# Out:
#            bug_id bugintro_commitID                                 parent_id  \
# 0     HBASE-17624        e019961150  b2217d1d8f17a8de1a0cf91b74a7170f5ffc1eed
# 1     HBASE-11258        45883c6bd1  2ab2e5c40e6354012f38bd153a77b53335d9b6e8
# 2     HBASE-16620        e5d77d095c  44812cf1ed6255649bd0d67b1cfe46940f11fc1a
# 3     HBASE-15650        d815211f5a  6930da781b2142ed8a0e6fc67095453dea38a072
# 4      HBASE-3100        af7f5c7d01  516667bc74081244ba5c33304125938172e5776a
# 5     HBASE-19319        f886716617  5a0881a98b3575d900d483222e2fdfab15159656
# 6     HBASE-15638        95c1dc93fb  cc237c4b78517a6b370c55c8573b14c9edf683de
# 7     HBASE-15638        95c1dc93fb  cc237c4b78517a6b370c55c8573b14c9edf683de
# 8     HBASE-15638        95c1dc93fb  cc237c4b78517a6b370c55c8573b14c9edf683de
# 9     HBASE-18946        010012cbcb  11e82de8a1d782be85a776ec08e8cd6a071185bf
# 10    HBASE-15638        95c1dc93fb  cc237c4b78517a6b370c55c8573b14c9edf683de
# 11    HBASE-19160        9ee8e2714d  888f2335c952040646ce820f6191f6433ec9411d
# 12    HBASE-15638        95c1dc93fb  cc237c4b78517a6b370c55c8573b14c9edf683de
# 13    HBASE-17624        e019961150  b2217d1d8f17a8de1a0cf91b74a7170f5ffc1eed
# 14    HBASE-18431        5e21e30682  f67dae90f952e84681a07a612b8005a2d688cae5
# 15    HBASE-15638        95c1dc93fb  cc237c4b78517a6b370c55c8573b14c9edf683de
# 16    HBASE-15638        95c1dc93fb  cc237c4b78517a6b370c55c8573b14c9edf683de
# 17    HBASE-11544        de9791e91e  39425a8558fabaffa0e2b9421a8a7926d73b040c
# 18    HBASE-18431        5e21e30682  f67dae90f952e84681a07a612b8005a2d688cae5
# 19     HBASE-7443        92c98a76d1  3e600deba265c02283c9a354e25d9f6652240945
# 20    HBASE-15638        95c1dc93fb  cc237c4b78517a6b370c55c8573b14c9edf683de
# 21    HBASE-19919        bac4687345  897afb7d1870d0e14fedbdc6289a272607069605
# 22     HBASE-9164        d7d0398713  7773da0cb47b97e6c9c679d27d8a223233c0291e
# 23    HBASE-11544        de9791e91e  39425a8558fabaffa0e2b9421a8a7926d73b040c
# 24    HBASE-17624        e019961150  b2217d1d8f17a8de1a0cf91b74a7170f5ffc1eed
# 25     HBASE-7601        b96d60d659  da18540ea37ad4e80cf0616a2234ff60de0339c4
# 26    HBASE-10555        20c4b8a685  941e9cbb445539ad619fa96a8f791cb90df83a6a
# 27     HBASE-5596        3fd6997380  080206de01833e7bdc049f9183b87eb593e71573
# 28    HBASE-15638        95c1dc93fb  cc237c4b78517a6b370c55c8573b14c9edf683de
# 29    HBASE-19919        bac4687345  897afb7d1870d0e14fedbdc6289a272607069605
# ...           ...               ...                                       ...
# 2532   HBASE-5085        31b10cd5f2  436e064a2c06c8d55d11e8f55023b4676bb1f99c
# 2533  HBASE-13208        5bf98d0827  b5bfbc8a9f4e9e25ba622c8a6f35f258d72af8ed
# 2534   HBASE-6123        901c3a31ce  00e53c8fa2c0920caa160f3c4e59ac74c51a4ff7
# 2535  HBASE-12316        a470a1f3f3  e545953c32584dec6488a64c3027214b9c061bed
# 2536  HBASE-14337        a5261b6f44  3aa2b2d638e9517bfa019431f9e6ecf320c9c86d
# 2537  HBASE-13648        a7e77821d2  52f635df0061a89f94b010e7cded7796816d7742
# 2538  HBASE-13081        a8555f65f0  9a311303a88d355f8c982d2f3cc77bd6427dfb80
# 2539   HBASE-5562        d04201683a  be78e3c4ee08dda7d14f31577ead5bd6fc12d197
# 2540  HBASE-12261        efa813ed2f  776a0b09a2bde71210033a77ff56af5d73534f7e
# 2541  HBASE-15965        15c03fd1c9  3d7840a173aab97fb72409fa8c0f161fd7ad0e8f
# 2542   HBASE-8532        93fab309db  a77ffb23d088f5e52be3c267742d722a7edc9fa5
# 2543  HBASE-18369        bbf23d9627  f1b3528d791e01427c98d7209f266cfa2380778c
# 2544  HBASE-12902        5fbf80ee5e  38701ea8ec8c112f31548b7d9697810a8af953ec
# 2545  HBASE-12922        a7816d88bd  eaacc5a0ce73252566997e4c71aedc0bd2e88328
# 2546  HBASE-12902        5fbf80ee5e  38701ea8ec8c112f31548b7d9697810a8af953ec
# 2547  HBASE-12902        5fbf80ee5e  38701ea8ec8c112f31548b7d9697810a8af953ec
# 2548  HBASE-12922        a7816d88bd  eaacc5a0ce73252566997e4c71aedc0bd2e88328
# 2549  HBASE-19023        eabad8a91c  27ed4d8add20c5424943eee54acff266567e765a
# 2550  HBASE-11932        2816487247  eec15bd17218a2543c9f4cbb9a78841a9fdec043
# 2551  HBASE-15965        15c03fd1c9  3d7840a173aab97fb72409fa8c0f161fd7ad0e8f
# 2552  HBASE-15965        15c03fd1c9  3d7840a173aab97fb72409fa8c0f161fd7ad0e8f
# 2553  HBASE-12902        5fbf80ee5e  38701ea8ec8c112f31548b7d9697810a8af953ec
# 2554  HBASE-12902        5fbf80ee5e  38701ea8ec8c112f31548b7d9697810a8af953ec
# 2555  HBASE-12922        a7816d88bd  eaacc5a0ce73252566997e4c71aedc0bd2e88328
# 2556  HBASE-11932        2816487247  eec15bd17218a2543c9f4cbb9a78841a9fdec043
# 2557  HBASE-14769        6adce67572  47082579a85fae1b3f7156963609819369b353d8
# 2558  HBASE-15965        15c03fd1c9  3d7840a173aab97fb72409fa8c0f161fd7ad0e8f
# 2559   HBASE-8532        93fab309db  a77ffb23d088f5e52be3c267742d722a7edc9fa5
# 2560  HBASE-12902        5fbf80ee5e  38701ea8ec8c112f31548b7d9697810a8af953ec
# 2561  HBASE-11932        2816487247  eec15bd17218a2543c9f4cbb9a78841a9fdec043
#
#                                                filepath  \
# 0     hbase-server/src/main/java/org/apache/hadoop/h...
# 1     src/main/java/org/apache/hadoop/hbase/util/Abs...
# 2     hbase-server/src/main/java/org/apache/hadoop/h...
# 3     hbase-server/src/main/java/org/apache/hadoop/h...
# 4     src/test/java/org/apache/hadoop/hbase/Abstract...
# 5     hbase-procedure/src/main/java/org/apache/hadoo...
# 6     hbase-server/src/main/java/org/apache/hadoop/h...
# 7     hbase-client/src/main/java/org/apache/hadoop/h...
# 8     hbase-client/src/main/java/org/apache/hadoop/h...
# 9     hbase-server/src/test/java/org/apache/hadoop/h...
# 10    hbase-server/src/test/java/org/apache/hadoop/h...
# 11    hbase-server/src/test/java/org/apache/hadoop/h...
# 12    hbase-server/src/test/java/org/apache/hadoop/h...
# 13    hbase-server/src/test/java/org/apache/hadoop/h...
# 14    hbase-protocol/src/main/protobuf/AccessControl...
# 15    hbase-client/src/main/java/org/apache/hadoop/h...
# 16    hbase-server/src/main/java/org/apache/hadoop/h...
# 17    hbase-server/src/main/java/org/apache/hadoop/h...
# 18    hbase-protocol/src/main/java/org/apache/hadoop...
# 19    hbase-server/src/main/java/org/apache/hadoop/h...
# 20    hbase-server/src/main/java/org/apache/hadoop/h...
# 21    hbase-server/src/main/java/org/apache/hadoop/h...
# 22    hbase-server/src/main/java/org/apache/hadoop/h...
# 23    hbase-server/src/main/java/org/apache/hadoop/h...
# 24    hbase-server/src/main/java/org/apache/hadoop/h...
# 25    hbase-server/src/main/java/org/apache/hadoop/h...
# 26    src/main/java/org/apache/hadoop/hbase/master/A...
# 27    src/main/java/org/apache/hadoop/hbase/master/A...
# 28    hbase-server/src/main/java/org/apache/hadoop/h...
# 29    hbase-server/src/main/java/org/apache/hadoop/h...
# ...                                                 ...
# 2532                          dev-support/test-patch.sh
# 2533                          dev-support/test-patch.sh
# 2534                          dev-support/test-patch.sh
# 2535                          dev-support/test-patch.sh
# 2536                          dev-support/test-patch.sh
# 2537                          dev-support/test-patch.sh
# 2538                          dev-support/test-patch.sh
# 2539                          dev-support/test-patch.sh
# 2540                          dev-support/test-patch.sh
# 2541           hbase-shell/src/test/ruby/test_helper.rb
# 2542  hbase-server/src/main/resources/hbase-webapps/...
# 2543  hbase-server/src/main/resources/hbase-webapps/...
# 2544  src/main/asciidoc/_chapters/thrift_filter_lang...
# 2545  src/main/asciidoc/_chapters/thrift_filter_lang...
# 2546           src/main/asciidoc/_chapters/tracing.adoc
# 2547   src/main/asciidoc/_chapters/troubleshooting.adoc
# 2548   src/main/asciidoc/_chapters/troubleshooting.adoc
# 2549   src/main/asciidoc/_chapters/troubleshooting.adoc
# 2550                src/main/docbkx/troubleshooting.xml
# 2551  hbase-shell/src/main/ruby/shell/commands/trunc...
# 2552  hbase-shell/src/main/ruby/shell/commands/trunc...
# 2553      src/main/asciidoc/_chapters/unit_testing.adoc
# 2554         src/main/asciidoc/_chapters/upgrading.adoc
# 2555         src/main/asciidoc/_chapters/upgrading.adoc
# 2556                      src/main/docbkx/upgrading.xml
# 2557  hbase-shell/src/main/ruby/hbase/visibility_lab...
# 2558  hbase-shell/src/test/ruby/hbase/visibility_lab...
# 2559  hbase-server/src/main/resources/hbase-webapps/...
# 2560         src/main/asciidoc/_chapters/zookeeper.adoc
# 2561                      src/main/docbkx/zookeeper.xml
#
#                                filename  number_of_buggyline  \
# 0            AbstractFSWALProvider.java                    1
# 1                AbstractHBaseTool.java                   13
# 2                AbstractHBaseTool.java                    5
# 3                 AbstractMemStore.java                    2
# 4            AbstractMergeTestBase.java                  143
# 5       AbstractProcedureScheduler.java                   53
# 6        AbstractProtobufLogWriter.java                    4
# 7     AbstractRegionServerCallable.java                  138
# 8                AbstractRpcClient.java                   11
# 9                  AbstractTestDLS.java                    1
# 10                 AbstractTestIPC.java                   12
# 11    AbstractTestScanQueryMatcher.java                    3
# 12           AbstractTestWALReplay.java                    1
# 13           AbstractTestWALReplay.java                    1
# 14                  AccessControl.proto                    1
# 15             AccessControlClient.java                   13
# 16              AccessControlLists.java                    5
# 17              AccessControlLists.java                    1
# 18             AccessControlProtos.java                   46
# 19                AccessController.java                    9
# 20                AccessController.java                   18
# 21                AccessController.java                    1
# 22                AccessController.java                    5
# 23                AccessController.java                    1
# 24                AccessController.java                    2
# 25                          Action.java                    1
# 26             ActiveMasterManager.java                    3
# 27             ActiveMasterManager.java                    1
# 28             ActiveMasterManager.java                    1
# 29             ActiveMasterManager.java                    2
# ...                                 ...                  ...
# 2532                      test-patch.sh                    1
# 2533                      test-patch.sh                    1
# 2534                      test-patch.sh                    7
# 2535                      test-patch.sh                    1
# 2536                      test-patch.sh                    1
# 2537                      test-patch.sh                    1
# 2538                      test-patch.sh                    2
# 2539                      test-patch.sh                    1
# 2540                      test-patch.sh                   43
# 2541                     test_helper.rb                    3
# 2542                         thrift.jsp                    1
# 2543                         thrift.jsp                  135
# 2544        thrift_filter_language.adoc                   19
# 2545        thrift_filter_language.adoc                   25
# 2546                       tracing.adoc                   10
# 2547               troubleshooting.adoc                   59
# 2548               troubleshooting.adoc                   99
# 2549               troubleshooting.adoc                    1
# 2550                troubleshooting.xml                   13
# 2551                        truncate.rb                    2
# 2552               truncate_preserve.rb                    2
# 2553                  unit_testing.adoc                    8
# 2554                     upgrading.adoc                   15
# 2555                     upgrading.adoc                   38
# 2556                      upgrading.xml                    6
# 2557               visibility_labels.rb                    1
# 2558    visibility_labels_admin_test.rb                   10
# 2559                             zk.jsp                    1
# 2560                     zookeeper.adoc                   46
# 2561                      zookeeper.xml                    3
#
#                                                file_key  filenumber  \
# 0     HBASE-17624_e019961150-b2217d1d8f_AbstractFSWA...           1
# 1     HBASE-11258_45883c6bd1-2ab2e5c40e_AbstractHBas...           2
# 2     HBASE-16620_e5d77d095c-44812cf1ed_AbstractHBas...           3
# 3     HBASE-15650_d815211f5a-6930da781b_AbstractMemS...           4
# 4     HBASE-3100_af7f5c7d01-516667bc74_AbstractMerge...           5
# 5     HBASE-19319_f886716617-5a0881a98b_AbstractProc...           6
# 6     HBASE-15638_95c1dc93fb-cc237c4b78_AbstractProt...           7
# 7     HBASE-15638_95c1dc93fb-cc237c4b78_AbstractRegi...           8
# 8     HBASE-15638_95c1dc93fb-cc237c4b78_AbstractRpcC...           9
# 9     HBASE-18946_010012cbcb-11e82de8a1_AbstractTest...          10
# 10    HBASE-15638_95c1dc93fb-cc237c4b78_AbstractTest...          11
# 11    HBASE-19160_9ee8e2714d-888f2335c9_AbstractTest...          12
# 12    HBASE-15638_95c1dc93fb-cc237c4b78_AbstractTest...          13
# 13    HBASE-17624_e019961150-b2217d1d8f_AbstractTest...          14
# 14    HBASE-18431_5e21e30682-f67dae90f9_AccessContro...          15
# 15    HBASE-15638_95c1dc93fb-cc237c4b78_AccessContro...          16
# 16    HBASE-15638_95c1dc93fb-cc237c4b78_AccessContro...          17
# 17    HBASE-11544_de9791e91e-39425a8558_AccessContro...          18
# 18    HBASE-18431_5e21e30682-f67dae90f9_AccessContro...          19
# 19    HBASE-7443_92c98a76d1-3e600deba2_AccessControl...          20
# 20    HBASE-15638_95c1dc93fb-cc237c4b78_AccessContro...          21
# 21    HBASE-19919_bac4687345-897afb7d18_AccessContro...          22
# 22    HBASE-9164_d7d0398713-7773da0cb4_AccessControl...          23
# 23    HBASE-11544_de9791e91e-39425a8558_AccessContro...          24
# 24    HBASE-17624_e019961150-b2217d1d8f_AccessContro...          25
# 25      HBASE-7601_b96d60d659-da18540ea3_Action.java_26          26
# 26    HBASE-10555_20c4b8a685-941e9cbb44_ActiveMaster...          27
# 27    HBASE-5596_3fd6997380-080206de01_ActiveMasterM...          28
# 28    HBASE-15638_95c1dc93fb-cc237c4b78_ActiveMaster...          29
# 29    HBASE-19919_bac4687345-897afb7d18_ActiveMaster...          30
# ...                                                 ...         ...
# 2532  HBASE-5085_31b10cd5f2-436e064a2c_test-patch.sh...        2533
# 2533  HBASE-13208_5bf98d0827-b5bfbc8a9f_test-patch.s...        2534
# 2534  HBASE-6123_901c3a31ce-00e53c8fa2_test-patch.sh...        2535
# 2535  HBASE-12316_a470a1f3f3-e545953c32_test-patch.s...        2536
# 2536  HBASE-14337_a5261b6f44-3aa2b2d638_test-patch.s...        2537
# 2537  HBASE-13648_a7e77821d2-52f635df00_test-patch.s...        2538
# 2538  HBASE-13081_a8555f65f0-9a311303a8_test-patch.s...        2539
# 2539  HBASE-5562_d04201683a-be78e3c4ee_test-patch.sh...        2540
# 2540  HBASE-12261_efa813ed2f-776a0b09a2_test-patch.s...        2541
# 2541  HBASE-15965_15c03fd1c9-3d7840a173_test_helper....        2542
# 2542   HBASE-8532_93fab309db-a77ffb23d0_thrift.jsp_2543        2543
# 2543  HBASE-18369_bbf23d9627-f1b3528d79_thrift.jsp_2544        2544
# 2544  HBASE-12902_5fbf80ee5e-38701ea8ec_thrift_filte...        2545
# 2545  HBASE-12922_a7816d88bd-eaacc5a0ce_thrift_filte...        2546
# 2546  HBASE-12902_5fbf80ee5e-38701ea8ec_tracing.adoc...        2547
# 2547  HBASE-12902_5fbf80ee5e-38701ea8ec_troubleshoot...        2548
# 2548  HBASE-12922_a7816d88bd-eaacc5a0ce_troubleshoot...        2549
# 2549  HBASE-19023_eabad8a91c-27ed4d8add_troubleshoot...        2550
# 2550  HBASE-11932_2816487247-eec15bd172_troubleshoot...        2551
# 2551  HBASE-15965_15c03fd1c9-3d7840a173_truncate.rb_...        2552
# 2552  HBASE-15965_15c03fd1c9-3d7840a173_truncate_pre...        2553
# 2553  HBASE-12902_5fbf80ee5e-38701ea8ec_unit_testing...        2554
# 2554  HBASE-12902_5fbf80ee5e-38701ea8ec_upgrading.ad...        2555
# 2555  HBASE-12922_a7816d88bd-eaacc5a0ce_upgrading.ad...        2556
# 2556  HBASE-11932_2816487247-eec15bd172_upgrading.xm...        2557
# 2557  HBASE-14769_6adce67572-47082579a8_visibility_l...        2558
# 2558  HBASE-15965_15c03fd1c9-3d7840a173_visibility_l...        2559
# 2559       HBASE-8532_93fab309db-a77ffb23d0_zk.jsp_2560        2560
# 2560  HBASE-12902_5fbf80ee5e-38701ea8ec_zookeeper.ad...        2561
# 2561  HBASE-11932_2816487247-eec15bd172_zookeeper.xm...        2562
#
#                   affect_version?
# 0     Does not affect the version
# 1     Does not affect the version
# 2     Does not affect the version
# 3              Affect the version
# 4     Does not affect the version
# 5     Does not affect the version
# 6     Does not affect the version
# 7     Does not affect the version
# 8     Does not affect the version
# 9              Affect the version
# 10    Does not affect the version
# 11    Does not affect the version
# 12    Does not affect the version
# 13    Does not affect the version
# 14    Does not affect the version
# 15    Does not affect the version
# 16    Does not affect the version
# 17    Does not affect the version
# 18    Does not affect the version
# 19             Affect the version
# 20    Does not affect the version
# 21    Does not affect the version
# 22             Affect the version
# 23    Does not affect the version
# 24    Does not affect the version
# 25    Does not affect the version
# 26             Affect the version
# 27             Affect the version
# 28    Does not affect the version
# 29    Does not affect the version
# ...                           ...
# 2532  Does not affect the version
# 2533  Does not affect the version
# 2534  Does not affect the version
# 2535           Affect the version
# 2536  Does not affect the version
# 2537           Affect the version
# 2538  Does not affect the version
# 2539           Affect the version
# 2540           Affect the version
# 2541  Does not affect the version
# 2542           Affect the version
# 2543           Affect the version
# 2544  Does not affect the version
# 2545  Does not affect the version
# 2546  Does not affect the version
# 2547  Does not affect the version
# 2548  Does not affect the version
# 2549           Affect the version
# 2550  Does not affect the version
# 2551  Does not affect the version
# 2552  Does not affect the version
# 2553  Does not affect the version
# 2554  Does not affect the version
# 2555  Does not affect the version
# 2556  Does not affect the version
# 2557  Does not affect the version
# 2558  Does not affect the version
# 2559           Affect the version
# 2560  Does not affect the version
# 2561  Does not affect the version
#
# [2562 rows x 9 columns]

# %% [markdown]
# # Separating affected and non-affected files

# %%
headname = ['bug_id','bugintro_commitID','parent_id','filepath','filename','number_of_buggyline','file_key','filenumber','affect_version?']

# %%
for p, algor in enumerate(algorithms):
    ds = pd.read_csv(analyze_dir + "05_finding_versions/02_files_affect/" + algor + "_joining_files.csv")
    ds_affect = ds[headname][ds['affect_version?'] == 'Affect the version']
    ds_nonaffect = ds[headname][ds['affect_version?'] == 'Does not affect the version']
    
    ds_affect = ds_affect[headname]
    ds_nonaffect = ds_nonaffect[headname]
    
    ds_affect.to_csv(analyze_dir + "05_finding_versions/02_files_affect/01_affected_files/" + algor + "_affected_files.csv")
    ds_nonaffect.to_csv(analyze_dir + "05_finding_versions/02_files_affect/02_non-affected_files/" + algor + "_non-affected_files.csv")

# %% [markdown]
# # Defining validated file as a bug-introducing change file

# %%
for aa, algrt in enumerate(algorithms):
    valid_file = pd.read_csv(analyze_dir + "05_finding_versions/02_files_affect/01_affected_files/" + algrt + "_affected_files.csv")
    valid_file = (pd.to_numeric(valid_file['number_of_buggyline'], errors='coerce')
                       .groupby(valid_file['filepath'])
                       .sum()
                       .to_frame()
                       .add_prefix('total')
                       .reset_index())

    valid_file = valid_file.dropna(subset=['totalnumber_of_buggyline'])
    valid_file = valid_file.sort_values('totalnumber_of_buggyline', ascending=False)
    valid_file = valid_file[['filepath','totalnumber_of_buggyline']]
    valid_file.to_csv(analyze_dir + "05_finding_versions/02_files_affect/01_affected_files/distinct_files/unique_affected_files_" + algrt + ".csv", index=False)

# %%
uniq_hist_file = pd.read_csv(analyze_dir + "05_finding_versions/02_files_affect/01_affected_files/distinct_files/unique_affected_files_histogram.csv")
uniq_hist_file
# Out:
#                                               filepath  \
# 0    hbase-protocol/src/main/java/org/apache/hadoop...
# 1    src/java/org/apache/hadoop/hbase/thrift/genera...
# 2    hbase-server/src/main/java/org/apache/hadoop/h...
# 3    src/main/java/org/apache/hadoop/hbase/executor...
# 4    src/test/java/org/apache/hadoop/hbase/master/T...
# 5    hbase-server/src/main/java/org/apache/hadoop/h...
# 6    src/test/java/org/apache/hadoop/hbase/master/T...
# 7    hbase-server/src/main/java/org/apache/hadoop/h...
# 8    src/main/java/org/apache/hadoop/hbase/zookeepe...
# 9    src/main/java/org/apache/hadoop/hbase/master/Z...
# 10   src/java/org/apache/hadoop/hbase/regionserver/...
# 11   hbase-server/src/main/java/org/apache/hadoop/h...
# 12   hbase-server/src/main/java/org/apache/hadoop/h...
# 13   src/main/java/org/apache/hadoop/hbase/executor...
# 14   hbase-server/src/main/java/org/apache/hadoop/h...
# 15   src/main/java/org/apache/hadoop/hbase/regionse...
# 16   src/java/org/apache/hadoop/hbase/thrift/genera...
# 17   hbase-server/src/main/resources/hbase-webapps/...
# 18   hbase-server/src/main/java/org/apache/hadoop/h...
# 19   src/main/java/org/apache/hadoop/hbase/master/h...
# 20   src/java/org/apache/hadoop/hbase/thrift/genera...
# 21   src/java/org/apache/hadoop/hbase/regionserver/...
# 22   src/java/org/apache/hadoop/hbase/regionserver/...
# 23   hbase-client/src/main/java/org/apache/hadoop/h...
# 24   hbase-server/src/test/java/org/apache/hadoop/h...
# 25   src/java/org/apache/hadoop/hbase/thrift/Thrift...
# 26   src/java/org/apache/hadoop/hbase/regionserver/...
# 27   src/main/java/org/apache/hadoop/hbase/master/h...
# 28   src/main/java/org/apache/hadoop/hbase/executor...
# 29   src/test/java/org/apache/hadoop/hbase/master/T...
# ..                                                 ...
# 521   src/main/java/org/apache/hadoop/hbase/Chore.java
# 522  hbase-hadoop2-compat/src/main/java/org/apache/...
# 523  src/main/java/org/apache/hadoop/hbase/catalog/...
# 524  src/main/java/org/apache/hadoop/hbase/client/H...
# 525  src/main/java/org/apache/hadoop/hbase/client/c...
# 526                      hbase-protocol-shaded/pom.xml
# 527  src/java/org/apache/hadoop/hbase/ipc/HBaseRPCP...
# 528  hbase-server/src/main/java/org/apache/hadoop/h...
# 529  hbase-server/src/test/java/org/apache/hadoop/h...
# 530  hbase-server/src/test/java/org/apache/hadoop/h...
# 531  hbase-server/src/test/java/org/apache/hadoop/h...
# 532  hbase-server/src/test/java/org/apache/hadoop/h...
# 533  hbase-server/src/test/java/org/apache/hadoop/h...
# 534  hbase-server/src/test/java/org/apache/hadoop/h...
# 535  hbase-server/src/test/java/org/apache/hadoop/h...
# 536  hbase-server/src/main/java/org/apache/hadoop/h...
# 537  hbase-server/src/main/java/org/apache/hadoop/h...
# 538  hbase-server/src/main/java/org/apache/hadoop/h...
# 539  hbase-shell/src/main/ruby/shell/commands/move_...
# 540  hbase-resource-bundle/src/main/resources/META-...
# 541                                src/docbkx/book.xml
# 542  hbase-server/src/main/java/org/apache/hadoop/h...
# 543  hbase-rsgroup/src/main/java/org/apache/hadoop/...
# 544  src/java/org/apache/hadoop/hbase/client/Scan.java
# 545  src/java/org/apache/hadoop/hbase/client/Unmodi...
# 546  src/java/org/apache/hadoop/hbase/filter/RegexS...
# 547  src/java/org/apache/hadoop/hbase/filter/Substr...
# 548  src/java/org/apache/hadoop/hbase/io/SequenceFi...
# 549  hbase-resource-bundle/src/main/resources/META-...
# 550  hbase-server/src/main/resources/hbase-webapps/...
#
#      totalnumber_of_buggyline
# 0                         656
# 1                         602
# 2                         318
# 3                         278
# 4                         268
# 5                         245
# 6                         241
# 7                         237
# 8                         206
# 9                         185
# 10                        182
# 11                        177
# 12                        173
# 13                        171
# 14                        165
# 15                        164
# 16                        153
# 17                        136
# 18                        130
# 19                        112
# 20                        111
# 21                        110
# 22                        105
# 23                        104
# 24                        103
# 25                        102
# 26                         99
# 27                         94
# 28                         92
# 29                         91
# ..                        ...
# 521                         1
# 522                         1
# 523                         1
# 524                         1
# 525                         1
# 526                         1
# 527                         1
# 528                         1
# 529                         1
# 530                         1
# 531                         1
# 532                         1
# 533                         1
# 534                         1
# 535                         1
# 536                         1
# 537                         1
# 538                         1
# 539                         1
# 540                         1
# 541                         1
# 542                         1
# 543                         1
# 544                         1
# 545                         1
# 546                         1
# 547                         1
# 548                         1
# 549                         1
# 550                         1
#
# [551 rows x 2 columns]

# %%
total_bugline = []
for ff, algorit in enumerate(algorithms):
    file = pd.read_csv(analyze_dir + "05_finding_versions/02_files_affect/01_affected_files/distinct_files/unique_affected_files_" + algorit + ".csv")
    file = file[['filepath','totalnumber_of_buggyline']]
    filenum = file['filepath'].count()
    bugnumber = 0
    for z in range(0,len(file)):
        bugnumber = bugnumber + file.iloc[z][1]
    temp = [algorit, filenum, bugnumber]
    total_bugline.append(temp)

# %%
total_bugline
# Out:
# [['histogram', 551, 10972],
#  ['minimal', 551, 10872],
#  ['myers', 551, 11103],
#  ['patience', 551, 10912]]

# %% [markdown]
# # Defining validated bug id

# %%
for bb, algrt in enumerate(algorithms):
    valid_bugid = pd.read_csv(analyze_dir + "05_finding_versions/02_files_affect/01_affected_files/" + algrt + "_affected_files.csv")
    valid_bugid = (pd.to_numeric(valid_bugid['number_of_buggyline'], errors='coerce')
                       .groupby(valid_bugid['bug_id'])
                       .sum()
                       .to_frame()
                       .add_prefix('total')
                       .reset_index())

    valid_bugid = valid_bugid.dropna(subset=['totalnumber_of_buggyline'])
    valid_bugid = valid_bugid.sort_values('totalnumber_of_buggyline', ascending=False)
    valid_bugid = valid_bugid[['bug_id','totalnumber_of_buggyline']]
    valid_bugid.to_csv(analyze_dir + "05_finding_versions/02_files_affect/01_affected_files/distinct_files/unique_affected_bugID_" + algrt + ".csv", index=False)

# %%
uniq_hist_bugid = pd.read_csv(analyze_dir + "05_finding_versions/02_files_affect/01_affected_files/distinct_files/unique_affected_bugID_histogram.csv")
uniq_hist_bugid
# Out:
#           bug_id  totalnumber_of_buggyline
# 0     HBASE-2990                      2104
# 1    HBASE-15467                      1218
# 2      HBASE-697                      1064
# 3    HBASE-13811                       466
# 4    HBASE-11689                       361
# 5      HBASE-532                       301
# 6     HBASE-8119                       259
# 7    HBASE-18946                       256
# 8     HBASE-7390                       175
# 9     HBASE-7725                       161
# 10   HBASE-18350                       159
# 11   HBASE-18369                       155
# 12    HBASE-9164                       138
# 13   HBASE-15650                       122
# 14     HBASE-790                       120
# 15   HBASE-14317                       117
# 16   HBASE-16074                       109
# 17    HBASE-9843                       101
# 18   HBASE-12219                        98
# 19   HBASE-17718                        94
# 20   HBASE-16160                        93
# 21   HBASE-13686                        90
# 22    HBASE-1597                        88
# 23   HBASE-19598                        84
# 24   HBASE-13004                        83
# 25   HBASE-20078                        75
# 26   HBASE-17538                        72
# 27    HBASE-8930                        71
# 28    HBASE-3872                        67
# 29   HBASE-13262                        64
# ..           ...                       ...
# 210   HBASE-4890                         1
# 211  HBASE-19930                         1
# 212   HBASE-2156                         1
# 213   HBASE-4020                         1
# 214   HBASE-3821                         1
# 215   HBASE-2581                         1
# 216   HBASE-3750                         1
# 217   HBASE-3708                         1
# 218   HBASE-3669                         1
# 219   HBASE-3421                         1
# 220   HBASE-3183                         1
# 221   HBASE-5567                         1
# 222   HBASE-5597                         1
# 223  HBASE-17839                         1
# 224   HBASE-3241                         1
# 225  HBASE-15152                         1
# 226  HBASE-15360                         1
# 227  HBASE-15725                         1
# 228   HBASE-6846                         1
# 229    HBASE-681                         1
# 230  HBASE-15828                         1
# 231  HBASE-16290                         1
# 232  HBASE-17803                         1
# 233   HBASE-6368                         1
# 234  HBASE-16360                         1
# 235  HBASE-16624                         1
# 236   HBASE-6138                         1
# 237  HBASE-17082                         1
# 238  HBASE-17326                         1
# 239  HBASE-16066                         1
#
# [240 rows x 2 columns]

# %%
numof_bugid = []
for ff, algorit in enumerate(algorithms):
    file = pd.read_csv(analyze_dir + "05_finding_versions/02_files_affect/01_affected_files/distinct_files/unique_affected_bugID_" + algorit + ".csv")
    file = file[['bug_id','totalnumber_of_buggyline']]
    num = file['bug_id'].count()
    temp = [algorit, num]
    numof_bugid.append(temp)

# %%
print (numof_bugid)
# Out:
# [['histogram', 240], ['minimal', 240], ['myers', 240], ['patience', 240]]

# %%
#Merging the list of total_bugline and numof_bugid
d = dict(numof_bugid)
join_list = [i + [d[i[0]]] for i in total_bugline]

# %%
with open(analyze_dir + "06_statistics/final_stats.csv","w") as finalfile:
    writers = csv.writer(finalfile, delimiter=",")
    colnames = ['algorithm','#validated_files', '#validated_bugline','#validated_bugid']
    writers.writerow(colnames)
    for row in join_list:
        writers.writerow(row)

# %%
data_stat = pd.read_csv(analyze_dir + "06_statistics/final_stats.csv")
data_stat
# Out:
#    algorithm  #validated_files  #validated_bugline  #validated_bugid
# 0  histogram               551               10972               240
# 1    minimal               551               10872               240
# 2      myers               551               11103               240
# 3   patience               551               10912               240

# %% [markdown]
# # Finding validated candidate bugfix commit id

# %%
candidate_bugfix = pd.read_csv(analyze_dir + "02_extracting_commitid/commitid_of_candidatebugfix.csv")
candidate_bugfix
# Out:
#            bug_id candidate_bugfix_commitID
# 0      HBASE-9961                1e7fdb06b2
# 1      HBASE-9961                560f000424
# 2      HBASE-9961                e5946ba799
# 3      HBASE-9958                8a6291a896
# 4      HBASE-9958                4b84160b37
# 5      HBASE-9908                f224e4721f
# 6      HBASE-9908                16b799dae5
# 7      HBASE-9908                61120fb62c
# 8      HBASE-9893                c5fc5b993e
# 9       HBASE-985                e3659aa246
# 10     HBASE-9843                6dd52d7ed3
# 11      HBASE-984                f78f944026
# 12     HBASE-9786                230cb08611
# 13      HBASE-977                5418547132
# 14     HBASE-9747                201c67a7d8
# 15     HBASE-9747                3f496372bf
# 16     HBASE-9747                b4df85d6b0
# 17     HBASE-9747                fc15e1ae39
# 18     HBASE-9747                a2a3071256
# 19     HBASE-9745                3d37252a32
# 20     HBASE-9745                24f150ebbc
# 21     HBASE-9745                0bd53be747
# 22     HBASE-9745                86033abef2
# 23     HBASE-9745                d289eecd2f
# 24     HBASE-9745                8aec79e00c
# 25     HBASE-9745                bcdd3eba60
# 26     HBASE-9704                5ff5311da2
# 27     HBASE-9704                abbf77d9cb
# 28     HBASE-9704                bd01833201
# 29     HBASE-9704                2d7c39e50c
# ...           ...                       ...
# 1879  HBASE-10485                bda1351306
# 1880  HBASE-10485                22c2d8c4e3
# 1881  HBASE-10460                3ea0e50450
# 1882  HBASE-10460                a873e206c9
# 1883  HBASE-10460                22d93bd3c6
# 1884  HBASE-10454                389e4f583e
# 1885  HBASE-10452                59c2b2bb09
# 1886  HBASE-10417                c9c01e6eb1
# 1887  HBASE-10417                ffc7215a50
# 1888  HBASE-10370                5645d48eac
# 1889  HBASE-10370                bebb59dc10
# 1890  HBASE-10370                3b9b0e1bc8
# 1891  HBASE-10370                c27bfd6acc
# 1892  HBASE-10370                1abfabaaa4
# 1893  HBASE-10370                9b10589954
# 1894  HBASE-10370                e7c36e7822
# 1895   HBASE-1013                05a11e7fcc
# 1896  HBASE-10079                d6e86d0524
# 1897  HBASE-10079                8eca550e02
# 1898  HBASE-10079                584793fb6f
# 1899  HBASE-10079                3fb88f10af
# 1900  HBASE-10079                6873efa5a2
# 1901  HBASE-10011                22f54af029
# 1902  HBASE-10011                100cfded38
# 1903   HBASE-9778                ca8b80433e
# 1904   HBASE-9778                a772c4110d
# 1905   HBASE-9778                9ffe4843dd
# 1906   HBASE-9778                d2eac30d68
# 1907   HBASE-3015                d16d6257e6
# 1908   HBASE-3015                7daffb3a42
#
# [1909 rows x 2 columns]

# %%
#Filter candidate bugfix commit id based on validated bug id
