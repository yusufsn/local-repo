# %% [markdown]
# # Importing libraries

# %%
import os, glob, json, csv, subprocess, sys, re, operator
from git import *
from subprocess import Popen, PIPE
from os import path
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import plotly.graph_objs as go
import plotly.plotly as ply
import plotly
from plotly.offline import plot, init_notebook_mode, iplot

# %matplotlib inline

# %% [markdown]
# # Defining repository and directories

# %%
userhome = os.path.expanduser('~')
repository = userhome + r'/different-diff/dataset/hbase/'
analyze_dir = userhome + r'/different-diff/analyze/analyze_hbase/'

# %% [markdown]
# # Defining function to execute git command

# %%
def execute_command(cmd, work_dir):
   #Executes a shell command in a subprocess, waiting until it has completed.
    pipe = subprocess.Popen(cmd, shell=True, cwd=work_dir, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    (out, error) = pipe.communicate()
    return out, error
    pipe.wait()

# %% [markdown]
# # Defining algorithms

# %%
algorithms = ['histogram','minimal','myers','patience']

# %% [markdown]
# # Loading the files data for each algorithm

# %%
fields = ['bug_id','bugintro_commitID','parent_id','filename','#deletions']

# %%
dthist = pd.read_csv(analyze_dir + '03_file-diff/01_filename/histogram_files.csv')
dtmin = pd.read_csv(analyze_dir + '03_file-diff/01_filename/minimal_files.csv')
dtmyers = pd.read_csv(analyze_dir + '03_file-diff/01_filename/myers_files.csv')
dtpat = pd.read_csv(analyze_dir + '03_file-diff/01_filename/patience_files.csv')

dthist = dthist[fields]
dtmin = dtmin[fields]
dtmyers = dtmyers[fields]
dtpat = dtpat[fields]

# %%
dthist
# Out:
#            bug_id bugintro_commitID                                 parent_id  \
# 0      HBASE-9971        8a6291a896  c9d4d2c9b5e30ae79d0ec7782709eaa917600f9a
# 1      HBASE-9961        18e018b3d9  16b799dae56b54f82a14dc0e0ad24977f06df6f6
# 2      HBASE-9958        c5a3048fec  feca3e26c468744c91a90ecd4a972a5bd114526c
# 3      HBASE-9958        c5a3048fec  feca3e26c468744c91a90ecd4a972a5bd114526c
# 4      HBASE-9958        c5a3048fec  feca3e26c468744c91a90ecd4a972a5bd114526c
# 5      HBASE-9958        c5a3048fec  feca3e26c468744c91a90ecd4a972a5bd114526c
# 6      HBASE-9908        ff78f217fa  bf5f9e5240847c8788c9dce700dd94750325863d
# 7      HBASE-9908        ff78f217fa  bf5f9e5240847c8788c9dce700dd94750325863d
# 8      HBASE-9908        ff78f217fa  bf5f9e5240847c8788c9dce700dd94750325863d
# 9      HBASE-9908        ff78f217fa  bf5f9e5240847c8788c9dce700dd94750325863d
# 10     HBASE-9908        ff78f217fa  bf5f9e5240847c8788c9dce700dd94750325863d
# 11     HBASE-9908        ff78f217fa  bf5f9e5240847c8788c9dce700dd94750325863d
# 12     HBASE-9908        ff78f217fa  bf5f9e5240847c8788c9dce700dd94750325863d
# 13     HBASE-9908        ff78f217fa  bf5f9e5240847c8788c9dce700dd94750325863d
# 14     HBASE-9908        ff78f217fa  bf5f9e5240847c8788c9dce700dd94750325863d
# 15     HBASE-9908        ff78f217fa  bf5f9e5240847c8788c9dce700dd94750325863d
# 16     HBASE-9856        13e9eda3e7  7b4b061bcfb7da9d1056f4f964f4cc438bdab36e
# 17     HBASE-9856        13e9eda3e7  7b4b061bcfb7da9d1056f4f964f4cc438bdab36e
# 18      HBASE-985        894c99bdb3  963c1104ddca96cbf85ceda3257c4b3d046e58d3
# 19     HBASE-9843        53bb2f6be7  3bebeca24d8e678bda2700f742c85191c841d559
# 20     HBASE-9843        53bb2f6be7  3bebeca24d8e678bda2700f742c85191c841d559
# 21     HBASE-9843        53bb2f6be7  3bebeca24d8e678bda2700f742c85191c841d559
# 22     HBASE-9843        53bb2f6be7  3bebeca24d8e678bda2700f742c85191c841d559
# 23     HBASE-9843        53bb2f6be7  3bebeca24d8e678bda2700f742c85191c841d559
# 24     HBASE-9843        53bb2f6be7  3bebeca24d8e678bda2700f742c85191c841d559
# 25     HBASE-9843        53bb2f6be7  3bebeca24d8e678bda2700f742c85191c841d559
# 26      HBASE-984        963c1104dd  98174c32c91c2f3b14d8e391afc06119919c07d2
# 27      HBASE-984        963c1104dd  98174c32c91c2f3b14d8e391afc06119919c07d2
# 28      HBASE-977        1b49c9b6c4  fcf98a9671e04d67e05130af69ace405695c4e71
# 29      HBASE-977        1b49c9b6c4  fcf98a9671e04d67e05130af69ace405695c4e71
# ...           ...               ...                                       ...
# 2569  HBASE-10454        42a2456b44  6b7fb21ec03bbed8b0da36d8028041960ade5e3c
# 2570  HBASE-10452        f1ad5cb938  0bafd16057f7e396153df1feaeb898fb50397f7d
# 2571  HBASE-10452        f1ad5cb938  0bafd16057f7e396153df1feaeb898fb50397f7d
# 2572  HBASE-10452        f1ad5cb938  0bafd16057f7e396153df1feaeb898fb50397f7d
# 2573  HBASE-10452        f1ad5cb938  0bafd16057f7e396153df1feaeb898fb50397f7d
# 2574  HBASE-10452        f1ad5cb938  0bafd16057f7e396153df1feaeb898fb50397f7d
# 2575  HBASE-10452        f1ad5cb938  0bafd16057f7e396153df1feaeb898fb50397f7d
# 2576  HBASE-10452        f1ad5cb938  0bafd16057f7e396153df1feaeb898fb50397f7d
# 2577  HBASE-10452        f1ad5cb938  0bafd16057f7e396153df1feaeb898fb50397f7d
# 2578  HBASE-10452        f1ad5cb938  0bafd16057f7e396153df1feaeb898fb50397f7d
# 2579  HBASE-10446        b3b3d0ddff  3f9f4e00b6349c2524b026ab92234bd8d900c10c
# 2580  HBASE-10417        95444356ef  07caf4bf8e77b26469c8bc49eaa278c3a4047612
# 2581  HBASE-10397        b5d161c513  eb998894abe63657698ce3c280e0b75c686445ce
# 2582   HBASE-1013        dfd2d6af99  ad707c4f6000c4c8393c7b44075bb92abb7ceb99
# 2583   HBASE-1013        dfd2d6af99  ad707c4f6000c4c8393c7b44075bb92abb7ceb99
# 2584   HBASE-1013        dfd2d6af99  ad707c4f6000c4c8393c7b44075bb92abb7ceb99
# 2585  HBASE-10079        923becd6c0  29426d2caae9e3f22c00f6ef279e812d50297f34
# 2586  HBASE-10079        923becd6c0  29426d2caae9e3f22c00f6ef279e812d50297f34
# 2587  HBASE-10011        35cea57fe5  81f21ca409c5a1eec1143cc1ca8b60c286cf8531
# 2588  HBASE-10011        35cea57fe5  81f21ca409c5a1eec1143cc1ca8b60c286cf8531
# 2589  HBASE-10011        35cea57fe5  81f21ca409c5a1eec1143cc1ca8b60c286cf8531
# 2590  HBASE-10004        e0c324f9d5  56d089a3e4885500abdc0b43cdb19c52b0bacaee
# 2591  HBASE-10004        e0c324f9d5  56d089a3e4885500abdc0b43cdb19c52b0bacaee
# 2592  HBASE-10004        e0c324f9d5  56d089a3e4885500abdc0b43cdb19c52b0bacaee
# 2593   HBASE-9778        330a8e1fc3  7f3161a61ad086a7996cc0c78f43e21ede8521ba
# 2594   HBASE-9778        330a8e1fc3  7f3161a61ad086a7996cc0c78f43e21ede8521ba
# 2595   HBASE-9778        330a8e1fc3  7f3161a61ad086a7996cc0c78f43e21ede8521ba
# 2596   HBASE-9778        330a8e1fc3  7f3161a61ad086a7996cc0c78f43e21ede8521ba
# 2597   HBASE-3015        0d53298953  35a2d9b42359f62f8944ad8808d30949856b6996
# 2598  HBASE-15195        9955118995  9ec408e25b70f4ce586340b9396da67a1e38f6ca
#
#                                                filename  #deletions
# 0     src/main/java/org/apache/hadoop/hbase/client/H...           5
# 1     hbase-client/src/main/java/org/apache/hadoop/h...          13
# 2     hbase-client/src/main/java/org/apache/hadoop/h...          31
# 3     hbase-client/src/main/java/org/apache/hadoop/h...           5
# 4     hbase-client/src/main/java/org/apache/hadoop/h...           8
# 5     hbase-client/src/main/java/org/apache/hadoop/h...           2
# 6     hbase-common/src/main/java/org/apache/hadoop/h...           1
# 7     hbase-common/src/test/java/org/apache/hadoop/h...           2
# 8     hbase-common/src/test/java/org/apache/hadoop/h...           3
# 9     hbase-server/src/main/java/org/apache/hadoop/h...           1
# 10    hbase-server/src/test/java/org/apache/hadoop/h...          13
# 11    hbase-server/src/test/java/org/apache/hadoop/h...           2
# 12    hbase-server/src/test/java/org/apache/hadoop/h...           3
# 13    hbase-server/src/test/java/org/apache/hadoop/h...           4
# 14    hbase-server/src/test/java/org/apache/hadoop/h...           1
# 15    hbase-server/src/test/java/org/apache/hadoop/h...           2
# 16    hbase-server/src/main/java/org/apache/hadoop/h...           1
# 17    hbase-server/src/main/java/org/apache/hadoop/h...           2
# 18                                            build.xml           1
# 19    hbase-client/src/main/java/org/apache/hadoop/h...          53
# 20    hbase-client/src/main/java/org/apache/hadoop/h...          31
# 21    hbase-client/src/test/java/org/apache/hadoop/h...           7
# 22    hbase-common/src/main/java/org/apache/hadoop/h...           3
# 23    hbase-server/src/main/java/org/apache/hadoop/h...           2
# 24    hbase-server/src/main/java/org/apache/hadoop/h...           2
# 25    hbase-server/src/test/java/org/apache/hadoop/h...           3
# 26    src/java/org/apache/hadoop/hbase/io/HalfMapFil...           7
# 27    src/java/org/apache/hadoop/hbase/util/InfoServ...           1
# 28      src/java/org/apache/hadoop/hbase/HStoreKey.java           4
# 29    src/java/org/apache/hadoop/hbase/regionserver/...         145
# ...                                                 ...         ...
# 2569  hbase-server/src/main/java/org/apache/hadoop/h...           1
# 2570  hbase-client/src/main/java/org/apache/hadoop/h...           3
# 2571  hbase-client/src/main/java/org/apache/hadoop/h...           2
# 2572  hbase-client/src/main/java/org/apache/hadoop/h...           2
# 2573  hbase-common/src/main/java/org/apache/hadoop/h...           1
# 2574  hbase-common/src/main/java/org/apache/hadoop/h...           1
# 2575  hbase-server/src/main/java/org/apache/hadoop/h...           1
# 2576  hbase-server/src/main/java/org/apache/hadoop/h...           2
# 2577  hbase-server/src/main/java/org/apache/hadoop/h...           2
# 2578  hbase-server/src/main/java/org/apache/hadoop/h...           3
# 2579  hbase-server/src/main/java/org/apache/hadoop/h...           3
# 2580  hbase-server/src/main/java/org/apache/hadoop/h...           1
# 2581  hbase-client/src/main/java/org/apache/hadoop/h...           8
# 2582  src/java/org/apache/hadoop/hbase/regionserver/...          54
# 2583  src/java/org/apache/hadoop/hbase/regionserver/...           1
# 2584  src/java/org/apache/hadoop/hbase/regionserver/...           2
# 2585  hbase-common/src/main/java/org/apache/hadoop/h...           5
# 2586  hbase-common/src/main/java/org/apache/hadoop/h...           7
# 2587  hbase-client/src/main/java/org/apache/hadoop/h...          15
# 2588  hbase-client/src/main/java/org/apache/hadoop/h...           1
# 2589  hbase-client/src/main/java/org/apache/hadoop/h...           2
# 2590  hbase-server/src/main/java/org/apache/hadoop/h...           1
# 2591  hbase-server/src/test/java/org/apache/hadoop/h...           2
# 2592  hbase-server/src/test/java/org/apache/hadoop/h...           4
# 2593  src/main/java/org/apache/hadoop/hbase/regionse...           3
# 2594  src/main/java/org/apache/hadoop/hbase/regionse...           2
# 2595  src/test/java/org/apache/hadoop/hbase/regionse...           6
# 2596  src/test/java/org/apache/hadoop/hbase/regionse...          12
# 2597  src/main/java/org/apache/hadoop/hbase/regionse...           1
# 2598                   dev-support/hbase-personality.sh           1
#
# [2599 rows x 5 columns]

# %% [markdown]
# Make a list of dataframe

# %%
data_algorithm = [dthist, dtmin, dtmyers, dtpat]

# %% [markdown]
# # Creating txt files of filenames list for each algorithm

# %%
for da, dt_alg in enumerate(data_algorithm):
    filename = []
    for jj in range(0,len(dt_alg)):
        if dt_alg.iloc[jj]['#deletions'] != 0:
            filename.append(((dt_alg.iloc[jj][3].split('/'))[-1:])[0] + "_"+ dt_alg.iloc[jj][1] + "-" + dt_alg.iloc[jj][2][:10] + "_" + dt_alg.iloc[jj][0] + "_" + str(jj+1))

    with open(analyze_dir + '03_file-diff/01_filename/filename-listof_'+ algorithms[da] + '.txt', mode='wt', encoding="utf-8") as myfile:
        myfile.write('\n'.join(filename))

print ("Filename_<algorithm-name>.txt has been created")
# Out:
# Filename_<algorithm-name>.txt has been created

# %% [markdown]
# # Extracting the buggylines of files

# %% [markdown]
# Loading txt filename

# %%
fn_hist = (open(analyze_dir + '03_file-diff/01_filename/filename-listof_histogram.txt')).read().split('\n')
fn_min = (open(analyze_dir + '03_file-diff/01_filename/filename-listof_minimal.txt')).read().split('\n')
fn_myers = (open(analyze_dir + '03_file-diff/01_filename/filename-listof_myers.txt')).read().split('\n')
fn_pat = (open(analyze_dir + '03_file-diff/01_filename/filename-listof_patience.txt')).read().split('\n')

# %%
f_names = [fn_hist, fn_min, fn_myers, fn_pat]

# %% [markdown]
# Buggylines extraction

# %%
buggylinefiles = []
for n, d_algo in enumerate(data_algorithm):
    bf = []
    for aa in range(0,len(d_algo)):
        sys.stdout.write('\r%i: ' %(n+1) + ' Extracting data %i' %(aa+1))
        sys.stdout.flush()
        name = analyze_dir + "03_file-diff/02_buggylines/" + algorithms[n] + "/" + f_names[n][aa] + "_" + algorithms[n] + "buglines_" + str(aa+1) + ".diff"
        diff_cmd = "git diff -w --ignore-blank-lines --diff-algorithm=" + algorithms[n] + " " + d_algo.iloc[aa][2] + " " + d_algo.iloc[aa][1] + " -- " + d_algo.iloc[aa][3] + " | grep '^[-]' | grep -Ev '^(--- a/|\+\+\+ b/)' > " + name
        execute_command(diff_cmd, repository)
        zzz = [d_algo.iloc[aa][0], d_algo.iloc[aa][1], d_algo.iloc[aa][2], d_algo.iloc[aa][3], (f_names[n][aa] + "_" + algorithms[n] + "buglines_" + str(aa+1) + ".diff")]
        bf.append(zzz)
    bf = sorted(bf, key=operator.itemgetter(4,1,2,0))
    buggylinefiles.append(bf)
print('\nExtraction is complete')
# Out:
# 4:  Extracting data 2599
# Extraction is complete

# %%
buggylinefiles[0]
# Out:
# [['HBASE-17624',
#   'e019961150',
#   'b2217d1d8f17a8de1a0cf91b74a7170f5ffc1eed',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/wal/AbstractFSWALProvider.java',
#   'AbstractFSWALProvider.java_e019961150-b2217d1d8f_HBASE-17624_1275_histogrambuglines_1275.diff'],
#  ['HBASE-11258',
#   '45883c6bd1',
#   '2ab2e5c40e6354012f38bd153a77b53335d9b6e8',
#   'src/main/java/org/apache/hadoop/hbase/util/AbstractHBaseTool.java',
#   'AbstractHBaseTool.java_45883c6bd1-2ab2e5c40e_HBASE-11258_2494_histogrambuglines_2494.diff'],
#  ['HBASE-16620',
#   'e5d77d095c',
#   '44812cf1ed6255649bd0d67b1cfe46940f11fc1a',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/util/AbstractHBaseTool.java',
#   'AbstractHBaseTool.java_e5d77d095c-44812cf1ed_HBASE-16620_1359_histogrambuglines_1359.diff'],
#  ['HBASE-15650',
#   'd815211f5a',
#   '6930da781b2142ed8a0e6fc67095453dea38a072',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/AbstractMemStore.java',
#   'AbstractMemStore.java_d815211f5a-6930da781b_HBASE-15650_1478_histogrambuglines_1478.diff'],
#  ['HBASE-3100',
#   'af7f5c7d01',
#   '516667bc74081244ba5c33304125938172e5776a',
#   'src/test/java/org/apache/hadoop/hbase/AbstractMergeTestBase.java',
#   'AbstractMergeTestBase.java_af7f5c7d01-516667bc74_HBASE-3100_682_histogrambuglines_682.diff'],
#  ['HBASE-19319',
#   'f886716617',
#   '5a0881a98b3575d900d483222e2fdfab15159656',
#   'hbase-procedure/src/main/java/org/apache/hadoop/hbase/procedure2/AbstractProcedureScheduler.java',
#   'AbstractProcedureScheduler.java_f886716617-5a0881a98b_HBASE-19319_1031_histogrambuglines_1031.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/wal/AbstractProtobufLogWriter.java',
#   'AbstractProtobufLogWriter.java_95c1dc93fb-cc237c4b78_HBASE-15638_1803_histogrambuglines_1803.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/AbstractRegionServerCallable.java',
#   'AbstractRegionServerCallable.java_95c1dc93fb-cc237c4b78_HBASE-15638_1497_histogrambuglines_1497.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/ipc/AbstractRpcClient.java',
#   'AbstractRpcClient.java_95c1dc93fb-cc237c4b78_HBASE-15638_1574_histogrambuglines_1574.diff'],
#  ['HBASE-18946',
#   '010012cbcb',
#   '11e82de8a1d782be85a776ec08e8cd6a071185bf',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/master/AbstractTestDLS.java',
#   'AbstractTestDLS.java_010012cbcb-11e82de8a1_HBASE-18946_1139_histogrambuglines_1139.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/ipc/AbstractTestIPC.java',
#   'AbstractTestIPC.java_95c1dc93fb-cc237c4b78_HBASE-15638_1892_histogrambuglines_1892.diff'],
#  ['HBASE-19160',
#   '9ee8e2714d',
#   '888f2335c952040646ce820f6191f6433ec9411d',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/regionserver/querymatcher/AbstractTestScanQueryMatcher.java',
#   'AbstractTestScanQueryMatcher.java_9ee8e2714d-888f2335c9_HBASE-19160_1095_histogrambuglines_1095.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/regionserver/wal/AbstractTestWALReplay.java',
#   'AbstractTestWALReplay.java_95c1dc93fb-cc237c4b78_HBASE-15638_1954_histogrambuglines_1954.diff'],
#  ['HBASE-17624',
#   'e019961150',
#   'b2217d1d8f17a8de1a0cf91b74a7170f5ffc1eed',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/regionserver/wal/AbstractTestWALReplay.java',
#   'AbstractTestWALReplay.java_e019961150-b2217d1d8f_HBASE-17624_1282_histogrambuglines_1282.diff'],
#  ['HBASE-18431',
#   '5e21e30682',
#   'f67dae90f952e84681a07a612b8005a2d688cae5',
#   'hbase-protocol/src/main/protobuf/AccessControl.proto',
#   'AccessControl.proto_5e21e30682-f67dae90f9_HBASE-18431_1186_histogrambuglines_1186.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/security/access/AccessControlClient.java',
#   'AccessControlClient.java_95c1dc93fb-cc237c4b78_HBASE-15638_1603_histogrambuglines_1603.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/security/access/AccessControlLists.java',
#   'AccessControlLists.java_95c1dc93fb-cc237c4b78_HBASE-15638_1824_histogrambuglines_1824.diff'],
#  ['HBASE-11544',
#   'de9791e91e',
#   '39425a8558fabaffa0e2b9421a8a7926d73b040c',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/security/access/AccessControlLists.java',
#   'AccessControlLists.java_de9791e91e-39425a8558_HBASE-11544_2432_histogrambuglines_2432.diff'],
#  ['HBASE-18431',
#   '5e21e30682',
#   'f67dae90f952e84681a07a612b8005a2d688cae5',
#   'hbase-protocol/src/main/java/org/apache/hadoop/hbase/protobuf/generated/AccessControlProtos.java',
#   'AccessControlProtos.java_5e21e30682-f67dae90f9_HBASE-18431_1181_histogrambuglines_1181.diff'],
#  ['HBASE-7443',
#   '92c98a76d1',
#   '3e600deba265c02283c9a354e25d9f6652240945',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/security/access/AccessController.java',
#   'AccessController.java_92c98a76d1-3e600deba2_HBASE-7443_277_histogrambuglines_277.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/security/access/AccessController.java',
#   'AccessController.java_95c1dc93fb-cc237c4b78_HBASE-15638_1825_histogrambuglines_1825.diff'],
#  ['HBASE-19919',
#   'bac4687345',
#   '897afb7d1870d0e14fedbdc6289a272607069605',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/security/access/AccessController.java',
#   'AccessController.java_bac4687345-897afb7d18_HBASE-19919_970_histogrambuglines_970.diff'],
#  ['HBASE-9164',
#   'd7d0398713',
#   '7773da0cb47b97e6c9c679d27d8a223233c0291e',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/security/access/AccessController.java',
#   'AccessController.java_d7d0398713-7773da0cb4_HBASE-9164_72_histogrambuglines_72.diff'],
#  ['HBASE-11544',
#   'de9791e91e',
#   '39425a8558fabaffa0e2b9421a8a7926d73b040c',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/security/access/AccessController.java',
#   'AccessController.java_de9791e91e-39425a8558_HBASE-11544_2433_histogrambuglines_2433.diff'],
#  ['HBASE-17624',
#   'e019961150',
#   'b2217d1d8f17a8de1a0cf91b74a7170f5ffc1eed',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/security/access/AccessController.java',
#   'AccessController.java_e019961150-b2217d1d8f_HBASE-17624_1274_histogrambuglines_1274.diff'],
#  ['HBASE-7601',
#   'b96d60d659',
#   'da18540ea37ad4e80cf0616a2234ff60de0339c4',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/client/Action.java',
#   'Action.java_b96d60d659-da18540ea3_HBASE-7601_227_histogrambuglines_227.diff'],
#  ['HBASE-10555',
#   '20c4b8a685',
#   '941e9cbb445539ad619fa96a8f791cb90df83a6a',
#   'src/main/java/org/apache/hadoop/hbase/master/ActiveMasterManager.java',
#   'ActiveMasterManager.java_20c4b8a685-941e9cbb44_HBASE-10555_2559_histogrambuglines_2559.diff'],
#  ['HBASE-5596',
#   '3fd6997380',
#   '080206de01833e7bdc049f9183b87eb593e71573',
#   'src/main/java/org/apache/hadoop/hbase/master/ActiveMasterManager.java',
#   'ActiveMasterManager.java_3fd6997380-080206de01_HBASE-5596_458_histogrambuglines_458.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/ActiveMasterManager.java',
#   'ActiveMasterManager.java_95c1dc93fb-cc237c4b78_HBASE-15638_1726_histogrambuglines_1726.diff'],
#  ['HBASE-19919',
#   'bac4687345',
#   '897afb7d1870d0e14fedbdc6289a272607069605',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/ActiveMasterManager.java',
#   'ActiveMasterManager.java_bac4687345-897afb7d18_HBASE-19919_952_histogrambuglines_952.diff'],
#  ['HBASE-3311',
#   'ce3139a30e',
#   'a3127bd6cd681aeb9b5fbea04f2c44efe4ae2cc7',
#   'src/main/java/org/apache/hadoop/hbase/master/ActiveMasterManager.java',
#   'ActiveMasterManager.java_ce3139a30e-a3127bd6cd_HBASE-3311_641_histogrambuglines_641.diff'],
#  ['HBASE-8519',
#   'f729fcd4ec',
#   '2068d57f99d0cf8e0546fee862966e3ce781f758',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/ActiveMasterManager.java',
#   'ActiveMasterManager.java_f729fcd4ec-2068d57f99_HBASE-8519_137_histogrambuglines_137.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/procedure/AddColumnFamilyProcedure.java',
#   'AddColumnFamilyProcedure.java_95c1dc93fb-cc237c4b78_HBASE-15638_1743_histogrambuglines_1743.diff'],
#  ['HBASE-17624',
#   'e019961150',
#   'b2217d1d8f17a8de1a0cf91b74a7170f5ffc1eed',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/util/Addressing.java',
#   'Addressing.java_e019961150-b2217d1d8f_HBASE-17624_1249_histogrambuglines_1249.diff'],
#  ['HBASE-14769',
#   '6adce67572',
#   '47082579a85fae1b3f7156963609819369b353d8',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/Admin.java',
#   'Admin.java_6adce67572-47082579a8_HBASE-14769_2088_histogrambuglines_2088.diff'],
#  ['HBASE-16683',
#   '9952b134fc',
#   '7e6f19581bef830516608acd2e28c6c8fe3ccaff',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/Admin.java',
#   'Admin.java_9952b134fc-7e6f19581b_HBASE-16683_1340_histogrambuglines_1340.diff'],
#  ['HBASE-7508',
#   '4e0af48fe4',
#   '176ddb066c2011158b5dfb5c036a4af5687a70cd',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/coprocessor/AggregateImplementation.java',
#   'AggregateImplementation.java_4e0af48fe4-176ddb066c_HBASE-7508_253_histogrambuglines_253.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-endpoint/src/main/java/org/apache/hadoop/hbase/coprocessor/AggregateImplementation.java',
#   'AggregateImplementation.java_95c1dc93fb-cc237c4b78_HBASE-15638_1625_histogrambuglines_1625.diff'],
#  ['HBASE-11544',
#   'de9791e91e',
#   '39425a8558fabaffa0e2b9421a8a7926d73b040c',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/coprocessor/AggregateImplementation.java',
#   'AggregateImplementation.java_de9791e91e-39425a8558_HBASE-11544_2423_histogrambuglines_2423.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-endpoint/src/main/java/org/apache/hadoop/hbase/client/coprocessor/AggregationClient.java',
#   'AggregationClient.java_95c1dc93fb-cc237c4b78_HBASE-15638_1624_histogrambuglines_1624.diff'],
#  ['HBASE-697',
#   'f346a3d85a',
#   '7e6e530387e79e8f7e40cf26640f92495b7ee479',
#   'src/java/org/apache/hadoop/hbase/thrift/generated/AlreadyExists.java',
#   'AlreadyExists.java_f346a3d85a-7e6e530387_HBASE-697_308_histogrambuglines_308.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/AnnotationReadingPriorityFunction.java',
#   'AnnotationReadingPriorityFunction.java_95c1dc93fb-cc237c4b78_HBASE-15638_1781_histogrambuglines_1781.diff'],
#  ['HBASE-9115',
#   '5b89721c1e',
#   '1a76ba53369868cb21944e4609130de26202fdc4',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/Append.java',
#   'Append.java_5b89721c1e-1a76ba5336_HBASE-9115_84_histogrambuglines_84.diff'],
#  ['HBASE-9164',
#   'd7d0398713',
#   '7773da0cb47b97e6c9c679d27d8a223233c0291e',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/Append.java',
#   'Append.java_d7d0398713-7773da0cb4_HBASE-9164_55_histogrambuglines_55.diff'],
#  ['HBASE-19835',
#   'f1a81618fd',
#   '277ce3d8a3d68f87e82c98fdeb3a3cb3dee33036',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/Append.java',
#   'Append.java_f1a81618fd-277ce3d8a3_HBASE-19835_975_histogrambuglines_975.diff'],
#  ['HBASE-18946',
#   '010012cbcb',
#   '11e82de8a1d782be85a776ec08e8cd6a071185bf',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/assignment/AssignProcedure.java',
#   'AssignProcedure.java_010012cbcb-11e82de8a1_HBASE-18946_1127_histogrambuglines_1127.diff'],
#  ['HBASE-18946',
#   '010012cbcb',
#   '11e82de8a1d782be85a776ec08e8cd6a071185bf',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/assignment/AssignmentManager.java',
#   'AssignmentManager.java_010012cbcb-11e82de8a1_HBASE-18946_1128_histogrambuglines_1128.diff'],
#  ['HBASE-18167',
#   '01027f805b',
#   '532e0dda16f3c5034aa337201bf6d733cc0a1c7b',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java',
#   'AssignmentManager.java_01027f805b-532e0dda16_HBASE-18167_1222_histogrambuglines_1222.diff'],
#  ['HBASE-19598',
#   '016cf0c64b',
#   '372c88abd6d679a12d020c880e4cc6adec9f353a',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/assignment/AssignmentManager.java',
#   'AssignmentManager.java_016cf0c64b-372c88abd6_HBASE-19598_1011_histogrambuglines_1011.diff'],
#  ['HBASE-3832',
#   '097edf7bc4',
#   'c3fdac2f8da5809fdf8e7858dd29f3473777aa09',
#   'src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java',
#   'AssignmentManager.java_097edf7bc4-c3fdac2f8d_HBASE-3832_601_histogrambuglines_601.diff'],
#  ['HBASE-4367',
#   '0aafb370ce',
#   '5e411b680fe50538282b59aa6239ef2e296011c9',
#   'src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java',
#   'AssignmentManager.java_0aafb370ce-5e411b680f_HBASE-4367_544_histogrambuglines_544.diff'],
#  ['HBASE-3159',
#   '289ca8adae',
#   'a93316acb5da78cf536c8f23160d9363151e5e3d',
#   'src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java',
#   'AssignmentManager.java_289ca8adae-a93316acb5_HBASE-3159_666_histogrambuglines_666.diff'],
#  ['HBASE-8467',
#   '2e44f61062',
#   'ab728f5a0a9625b17556951248d7c847e087f887',
#   'src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java',
#   'AssignmentManager.java_2e44f61062-ab728f5a0a_HBASE-8467_146_histogrambuglines_146.diff'],
#  ['HBASE-18350',
#   '41cc9a125f',
#   'e1941aa6d14afd116a555fc93a3149f3e7c20af2',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/assignment/AssignmentManager.java',
#   'AssignmentManager.java_41cc9a125f-e1941aa6d1_HBASE-18350_1203_histogrambuglines_1203.diff'],
#  ['HBASE-12167',
#   '5375ff07bc',
#   'd8a7b67d798ab5fec399d4a0b97a025d5bff531c',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java',
#   'AssignmentManager.java_5375ff07bc-d8a7b67d79_HBASE-12167_2330_histogrambuglines_2330.diff'],
#  ['HBASE-3039',
#   '6283630181',
#   '5e844de967430e8ea2ff22c9c29add96f9f55cf1',
#   'src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java',
#   'AssignmentManager.java_6283630181-5e844de967_HBASE-3039_714_histogrambuglines_714.diff'],
#  ['HBASE-3298',
#   '633c049091',
#   'a621a21383b78aa3949a108ab44a2636fa8be76c',
#   'src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java',
#   'AssignmentManager.java_633c049091-a621a21383_HBASE-3298_647_histogrambuglines_647.diff'],
#  ['HBASE-3065',
#   '6dc7ccf377',
#   'f3eab16488fd7002bc20dd5d19269243679b1709',
#   'src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java',
#   'AssignmentManager.java_6dc7ccf377-f3eab16488_HBASE-3065_698_histogrambuglines_698.diff'],
#  ['HBASE-19457',
#   '7092b814bd',
#   'a5a77ae3d5bfef9396b6024ec723d83a911692ec',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/assignment/AssignmentManager.java',
#   'AssignmentManager.java_7092b814bd-a5a77ae3d5_HBASE-19457_1022_histogrambuglines_1022.diff'],
#  ['HBASE-7521',
#   '883ec67336',
#   'd738315143ec02d4c27104248daf26ff5628f439',
#   'src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java',
#   'AssignmentManager.java_883ec67336-d738315143_HBASE-7521_232_histogrambuglines_232.diff'],
#  ['HBASE-9151',
#   '8d7ed731a9',
#   'b6c898a138571ab4bd21f167edeb0b3a5860f260',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java',
#   'AssignmentManager.java_8d7ed731a9-b6c898a138_HBASE-9151_81_histogrambuglines_81.diff'],
#  ['HBASE-7443',
#   '92c98a76d1',
#   '3e600deba265c02283c9a354e25d9f6652240945',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java',
#   'AssignmentManager.java_92c98a76d1-3e600deba2_HBASE-7443_272_histogrambuglines_272.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java',
#   'AssignmentManager.java_95c1dc93fb-cc237c4b78_HBASE-15638_1727_histogrambuglines_1727.diff'],
#  ['HBASE-3337',
#   '97adaad945',
#   '13cd333cfba9c4e149f00c84b51b0858f2db4ec3',
#   'src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java',
#   'AssignmentManager.java_97adaad945-13cd333cfb_HBASE-3337_636_histogrambuglines_636.diff'],
#  ['HBASE-12479',
#   '9904252615',
#   '9701845ea7a2fd0e95a2f3c1e88a64041b8942d9',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java',
#   'AssignmentManager.java_9904252615-9701845ea7_HBASE-12479_2307_histogrambuglines_2307.diff'],
#  ['HBASE-11689',
#   'b7f7514762',
#   '2cd45eb9a006c67f0aee76745cab85ea21f66e50',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java',
#   'AssignmentManager.java_b7f7514762-2cd45eb9a0_HBASE-11689_2399_histogrambuglines_2399.diff'],
#  ['HBASE-19919',
#   'bac4687345',
#   '897afb7d1870d0e14fedbdc6289a272607069605',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/assignment/AssignmentManager.java',
#   'AssignmentManager.java_bac4687345-897afb7d18_HBASE-19919_958_histogrambuglines_958.diff'],
#  ['HBASE-4539',
#   'bd06d43d93',
#   'b90c4d3d263f55b56d70256aef12babedb3a283e',
#   'src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java',
#   'AssignmentManager.java_bd06d43d93-b90c4d3d26_HBASE-4539_535_histogrambuglines_535.diff'],
#  ['HBASE-4540',
#   'bd06d43d93',
#   'b90c4d3d263f55b56d70256aef12babedb3a283e',
#   'src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java',
#   'AssignmentManager.java_bd06d43d93-b90c4d3d26_HBASE-4540_531_histogrambuglines_531.diff'],
#  ['HBASE-4153',
#   'bd372dcea7',
#   '4ddfbe55b34785539a2a0ed65f6c65247993baaa',
#   'src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java',
#   'AssignmentManager.java_bd372dcea7-4ddfbe55b3_HBASE-4153_555_histogrambuglines_555.diff'],
#  ['HBASE-16060',
#   'c7473df2c3',
#   '43f507dfa83a526f1d2840a3e151f38a8875b9bb',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/assignment/AssignmentManager.java',
#   'AssignmentManager.java_c7473df2c3-43f507dfa8_HBASE-16060_1418_histogrambuglines_1418.diff'],
#  ['HBASE-3311',
#   'ce3139a30e',
#   'a3127bd6cd681aeb9b5fbea04f2c44efe4ae2cc7',
#   'src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java',
#   'AssignmentManager.java_ce3139a30e-a3127bd6cd_HBASE-3311_642_histogrambuglines_642.diff'],
#  ['HBASE-19287',
#   'd1fb987265',
#   '9ef115163be65860599dcabcc5ba885a758c2c03',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/assignment/AssignmentManager.java',
#   'AssignmentManager.java_d1fb987265-9ef115163b_HBASE-19287_1043_histogrambuglines_1043.diff'],
#  ['HBASE-6060',
#   'ddb9e96654',
#   '5dfdc621f14f263eba17517436bec5c84da18a2a',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java',
#   'AssignmentManager.java_ddb9e96654-5dfdc621f1_HBASE-6060_401_histogrambuglines_401.diff'],
#  ['HBASE-7390',
#   'deeb84ae5a',
#   '8d70de20e0d2e81abebd1f65f4b6d518cf0cf09e',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java',
#   'AssignmentManager.java_deeb84ae5a-8d70de20e0_HBASE-7390_283_histogrambuglines_283.diff'],
#  ['HBASE-4400',
#   'e282e25dac',
#   '1bc2f5e9895296dd7fdd535adb962580b1e3e9e4',
#   'src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java',
#   'AssignmentManager.java_e282e25dac-1bc2f5e989_HBASE-4400_540_histogrambuglines_540.diff'],
#  ['HBASE-2669',
#   'ed79dc2fd0',
#   '517f1ea25134a3622f3251f655208e15a1835f25',
#   'src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java',
#   'AssignmentManager.java_ed79dc2fd0-517f1ea251_HBASE-2669_827_histogrambuglines_827.diff'],
#  ['HBASE-19319',
#   'f886716617',
#   '5a0881a98b3575d900d483222e2fdfab15159656',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/assignment/AssignmentManager.java',
#   'AssignmentManager.java_f886716617-5a0881a98b_HBASE-19319_1036_histogrambuglines_1036.diff'],
#  ['HBASE-16209',
#   'fe44383619',
#   '2b1cbeb28d413c81bf8296f4b3fdcda9ab3b2dec',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java',
#   'AssignmentManager.java_fe44383619-2b1cbeb28d_HBASE-16209_1388_histogrambuglines_1388.diff'],
#  ['HBASE-16209',
#   'fe44383619',
#   '2b1cbeb28d413c81bf8296f4b3fdcda9ab3b2dec',
#   'hbase-server/src/main/jamon/org/apache/hadoop/hbase/tmpl/master/AssignmentManagerStatusTmpl.jamon',
#   'AssignmentManagerStatusTmpl.jamon_fe44383619-2b1cbeb28d_HBASE-16209_1387_histogrambuglines_1387.diff'],
#  ['HBASE-19542',
#   '0a5ef1ed88',
#   '90ac3c93c9113cfe9451ffc48ec0f6cc397e9457',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/wal/AsyncFSWAL.java',
#   'AsyncFSWAL.java_0a5ef1ed88-90ac3c93c9_HBASE-19542_1019_histogrambuglines_1019.diff'],
#  ['HBASE-16515',
#   '0f92e943ac',
#   '9cb0094bdbecf95455388278430833188bf021ef',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/AsyncProcess.java',
#   'AsyncProcess.java_0f92e943ac-9cb0094bdb_HBASE-16515_1366_histogrambuglines_1366.diff'],
#  ['HBASE-9843',
#   '53bb2f6be7',
#   '3bebeca24d8e678bda2700f742c85191c841d559',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/AsyncProcess.java',
#   'AsyncProcess.java_53bb2f6be7-3bebeca24d_HBASE-9843_20_histogrambuglines_20.diff'],
#  ['HBASE-15811',
#   '6904430a3d',
#   '60e19f60a9767db6b145cf9884d2295412baffe0',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/AsyncProcess.java',
#   'AsyncProcess.java_6904430a3d-60e19f60a9_HBASE-15811_1462_histogrambuglines_1462.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/AsyncProcess.java',
#   'AsyncProcess.java_95c1dc93fb-cc237c4b78_HBASE-15638_1498_histogrambuglines_1498.diff'],
#  ['HBASE-16611',
#   'cd9f422373',
#   '422734e73d8846e4a357178cf665220d689e2e6e',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/AsyncProcess.java',
#   'AsyncProcess.java_cd9f422373-422734e73d_HBASE-16611_1361_histogrambuglines_1361.diff'],
#  ['HBASE-11921',
#   'f7bcf3df6b',
#   '0259d2734164343038a99caf3051b42e29fbfcc5',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/AsyncProcess.java',
#   'AsyncProcess.java_f7bcf3df6b-0259d27341_HBASE-11921_2383_histogrambuglines_2383.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/wal/AsyncProtobufLogWriter.java',
#   'AsyncProtobufLogWriter.java_95c1dc93fb-cc237c4b78_HBASE-15638_1804_histogrambuglines_1804.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/AsyncRequestFutureImpl.java',
#   'AsyncRequestFutureImpl.java_95c1dc93fb-cc237c4b78_HBASE-15638_1499_histogrambuglines_1499.diff'],
#  ['HBASE-15148',
#   'f9e69b51e1',
#   'b1df2f8c881d418bb47e15a88c09d964ca89d2e2',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/security/token/AuthenticationTokenSecretManager.java',
#   'AuthenticationTokenSecretManager.java_f9e69b51e1-b1df2f8c88_HBASE-15148_2043_histogrambuglines_2043.diff'],
#  ['HBASE-13888',
#   '49700460da',
#   '778b3581120bcf5b93196d262e235634a38428c4',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/quotas/AverageIntervalRateLimiter.java',
#   'AverageIntervalRateLimiter.java_49700460da-778b358112_HBASE-13888_2146_histogrambuglines_2146.diff'],
#  ['HBASE-17154',
#   '0c59d23689',
#   '89e5b550875a306c443d16840d93ea8abcb7c49d',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/backup/impl/BackupCommands.java',
#   'BackupCommands.java_0c59d23689-89e5b55087_HBASE-17154_1309_histogrambuglines_1309.diff'],
#  ['HBASE-16620',
#   'e5d77d095c',
#   '44812cf1ed6255649bd0d67b1cfe46940f11fc1a',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/backup/impl/BackupCommands.java',
#   'BackupCommands.java_e5d77d095c-44812cf1ed_HBASE-16620_1356_histogrambuglines_1356.diff'],
#  ['HBASE-16620',
#   'e5d77d095c',
#   '44812cf1ed6255649bd0d67b1cfe46940f11fc1a',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/backup/BackupDriver.java',
#   'BackupDriver.java_e5d77d095c-44812cf1ed_HBASE-16620_1357_histogrambuglines_1357.diff'],
#  ['HBASE-8119',
#   'e21a1ee4ae',
#   '48ee32824f5b09d26fe3d71183c70b69b54a718e',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/master/balancer/BalancerTestBase.java',
#   'BalancerTestBase.java_e21a1ee4ae-48ee32824f_HBASE-8119_174_histogrambuglines_174.diff'],
#  ['HBASE-14904',
#   'b3260423b1',
#   '51503efcf05be734c14200233d5f1495e4c2c3f1',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/codec/BaseDecoder.java',
#   'BaseDecoder.java_b3260423b1-51503efcf0_HBASE-14904_2075_histogrambuglines_2075.diff'],
#  ['HBASE-14904',
#   'b3260423b1',
#   '51503efcf05be734c14200233d5f1495e4c2c3f1',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/codec/BaseEncoder.java',
#   'BaseEncoder.java_b3260423b1-51503efcf0_HBASE-14904_2076_histogrambuglines_2076.diff'],
#  ['HBASE-19598',
#   '016cf0c64b',
#   '372c88abd6d679a12d020c880e4cc6adec9f353a',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/balancer/BaseLoadBalancer.java',
#   'BaseLoadBalancer.java_016cf0c64b-372c88abd6_HBASE-19598_1012_histogrambuglines_1012.diff'],
#  ['HBASE-12167',
#   '5375ff07bc',
#   'd8a7b67d798ab5fec399d4a0b97a025d5bff531c',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/balancer/BaseLoadBalancer.java',
#   'BaseLoadBalancer.java_5375ff07bc-d8a7b67d79_HBASE-12167_2332_histogrambuglines_2332.diff'],
#  ['HBASE-17624',
#   'e019961150',
#   'b2217d1d8f17a8de1a0cf91b74a7170f5ffc1eed',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/balancer/BaseLoadBalancer.java',
#   'BaseLoadBalancer.java_e019961150-b2217d1d8f_HBASE-17624_1273_histogrambuglines_1273.diff'],
#  ['HBASE-12985',
#   'eea9873cef',
#   'ac175b1bd9ec3878f50458382563810142df032d',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/balancer/BaseLoadBalancer.java',
#   'BaseLoadBalancer.java_eea9873cef-ac175b1bd9_HBASE-12985_2202_histogrambuglines_2202.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/coprocessor/BaseMasterAndRegionObserver.java',
#   'BaseMasterAndRegionObserver.java_95c1dc93fb-cc237c4b78_HBASE-15638_1701_histogrambuglines_1701.diff'],
#  ['HBASE-17624',
#   'e019961150',
#   'b2217d1d8f17a8de1a0cf91b74a7170f5ffc1eed',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/coprocessor/BaseMasterAndRegionObserver.java',
#   'BaseMasterAndRegionObserver.java_e019961150-b2217d1d8f_HBASE-17624_1268_histogrambuglines_1268.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/coprocessor/BaseMasterObserver.java',
#   'BaseMasterObserver.java_95c1dc93fb-cc237c4b78_HBASE-15638_1702_histogrambuglines_1702.diff'],
#  ['HBASE-17624',
#   'e019961150',
#   'b2217d1d8f17a8de1a0cf91b74a7170f5ffc1eed',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/coprocessor/BaseMasterObserver.java',
#   'BaseMasterObserver.java_e019961150-b2217d1d8f_HBASE-17624_1269_histogrambuglines_1269.diff'],
#  ['HBASE-7725',
#   '1a766c42a1',
#   'a6f8131f9d4042915b672efc9b35a819634e09a4',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/coprocessor/BaseRegionObserver.java',
#   'BaseRegionObserver.java_1a766c42a1-a6f8131f9d_HBASE-7725_213_histogrambuglines_213.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/coprocessor/BaseRegionServerObserver.java',
#   'BaseRegionServerObserver.java_95c1dc93fb-cc237c4b78_HBASE-15638_1703_histogrambuglines_1703.diff'],
#  ['HBASE-15982',
#   '6e7baa07f0',
#   'd12eb7a4aae5c2dc7b230bf2a12d2313b93b8ba9',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/replication/BaseReplicationEndpoint.java',
#   'BaseReplicationEndpoint.java_6e7baa07f0-d12eb7a4aa_HBASE-15982_1426_histogrambuglines_1426.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/coprocessor/BaseRowProcessorEndpoint.java',
#   'BaseRowProcessorEndpoint.java_95c1dc93fb-cc237c4b78_HBASE-15638_1704_histogrambuglines_1704.diff'],
#  ['HBASE-2755',
#   '0d8798ad26',
#   'd4d8ab6b6d3e4257a6519757c3b1161b86516626',
#   'src/main/java/org/apache/hadoop/hbase/master/BaseScanner.java',
#   'BaseScanner.java_0d8798ad26-d4d8ab6b6d_HBASE-2755_816_histogrambuglines_816.diff'],
#  ['HBASE-2927',
#   'c1714d094b',
#   'c7f246c15650547f2a1fada9a6a3e197fc346434',
#   'src/java/org/apache/hadoop/hbase/master/BaseScanner.java',
#   'BaseScanner.java_c1714d094b-c7f246c156_HBASE-2927_802_histogrambuglines_802.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/util/BaseTestHBaseFsck.java',
#   'BaseTestHBaseFsck.java_95c1dc93fb-cc237c4b78_HBASE-15638_1977_histogrambuglines_1977.diff'],
#  ['HBASE-697',
#   'f346a3d85a',
#   '7e6e530387e79e8f7e40cf26640f92495b7ee479',
#   'src/java/org/apache/hadoop/hbase/thrift/generated/BatchMutation.java',
#   'BatchMutation.java_f346a3d85a-7e6e530387_HBASE-697_309_histogrambuglines_309.diff'],
#  ['HBASE-977',
#   '1b49c9b6c4',
#   'fcf98a9671e04d67e05130af69ace405695c4e71',
#   'src/java/org/apache/hadoop/hbase/regionserver/BeforeThisStoreKey.java',
#   'BeforeThisStoreKey.java_1b49c9b6c4-fcf98a9671_HBASE-977_30_histogrambuglines_30.diff'],
#  ['HBASE-11258',
#   '45883c6bd1',
#   '2ab2e5c40e6354012f38bd153a77b53335d9b6e8',
#   'src/test/java/org/apache/hadoop/hbase/benchmarks/Benchmark.java',
#   'Benchmark.java_45883c6bd1-2ab2e5c40e_HBASE-11258_2495_histogrambuglines_2495.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/coprocessor/BigDecimalColumnInterpreter.java',
#   'BigDecimalColumnInterpreter.java_95c1dc93fb-cc237c4b78_HBASE-15638_1538_histogrambuglines_1538.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/filter/BinaryComparator.java',
#   'BinaryComparator.java_95c1dc93fb-cc237c4b78_HBASE-15638_1540_histogrambuglines_1540.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/filter/BinaryPrefixComparator.java',
#   'BinaryPrefixComparator.java_95c1dc93fb-cc237c4b78_HBASE-15638_1541_histogrambuglines_1541.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/filter/BitComparator.java',
#   'BitComparator.java_95c1dc93fb-cc237c4b78_HBASE-15638_1542_histogrambuglines_1542.diff'],
#  ['HBASE-6846',
#   'f4923b98a6',
#   'cd572001f06e75f483ed474a015edb68ac21ae30',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/filter/BitComparator.java',
#   'BitComparator.java_f4923b98a6-cd572001f0_HBASE-6846_326_histogrambuglines_326.diff'],
#  ['HBASE-11329',
#   '3d3784dd22',
#   'aa916b81ceb0554ad88a7b076ef0b9a1c10d5dd0',
#   'hbase-server/src/main/jamon/org/apache/hadoop/hbase/tmpl/regionserver/BlockCacheTmpl.jamon',
#   'BlockCacheTmpl.jamon_3d3784dd22-aa916b81ce_HBASE-11329_2491_histogrambuglines_2491.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/ipc/BlockingRpcCallback.java',
#   'BlockingRpcCallback.java_95c1dc93fb-cc237c4b78_HBASE-15638_1575_histogrambuglines_1575.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/ipc/BlockingRpcConnection.java',
#   'BlockingRpcConnection.java_95c1dc93fb-cc237c4b78_HBASE-15638_1576_histogrambuglines_1576.diff'],
#  ['HBASE-552',
#   '425a522a45',
#   '5bcb81c9e3a9f49fc7cd821a0a141c7e10e9795b',
#   'src/java/org/onelab/filter/BloomFilter.java',
#   'BloomFilter.java_425a522a45-5bcb81c9e3_HBASE-552_468_histogrambuglines_468.diff'],
#  ['HBASE-14100',
#   '257df19cc3',
#   '9ebafe6b08eb2ec8fbb1974976ef5afd9e6f9c09',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/util/BloomFilterUtil.java',
#   'BloomFilterUtil.java_257df19cc3-9ebafe6b08_HBASE-14100_2137_histogrambuglines_2137.diff'],
#  ['HBASE-2180',
#   '2a1bfea2e9',
#   '5a8b8899885bf786e8947f715608228aa4aab7c2',
#   'src/java/org/apache/hadoop/hbase/io/hfile/BoundedRangeFileInputStream.java',
#   'BoundedRangeFileInputStream.java_2a1bfea2e9-5a8b889988_HBASE-2180_897_histogrambuglines_897.diff'],
#  ['HBASE-16630',
#   'a8fd1119ce',
#   '62de29e6f29efef5a87c57c6ff0c4995ee790f1f',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/io/hfile/bucket/BucketAllocator.java',
#   'BucketAllocator.java_a8fd1119ce-62de29e6f2_HBASE-16630_1350_histogrambuglines_1350.diff'],
#  ['HBASE-11514',
#   '96dcd67f56',
#   'bf2933e08ab65af3643bdadbc3d59c943d40602f',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/io/hfile/bucket/BucketCache.java',
#   'BucketCache.java_96dcd67f56-bf2933e08a_HBASE-11514_2473_histogrambuglines_2473.diff'],
#  ['HBASE-16630',
#   'a8fd1119ce',
#   '62de29e6f29efef5a87c57c6ff0c4995ee790f1f',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/io/hfile/bucket/BucketCache.java',
#   'BucketCache.java_a8fd1119ce-62de29e6f2_HBASE-16630_1351_histogrambuglines_1351.diff'],
#  ['HBASE-11403',
#   'ab72babd97',
#   'e991fd8055112e2ddc0bbeade2ef74504e2407dd',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/io/hfile/bucket/BucketCache.java',
#   'BucketCache.java_ab72babd97-e991fd8055_HBASE-11403_2483_histogrambuglines_2483.diff'],
#  ['HBASE-16272',
#   'cc766df28b',
#   '519f87fc2bde21031f95cbb6cab031eccc4ac2e1',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/io/hfile/bucket/BucketCache.java',
#   'BucketCache.java_cc766df28b-519f87fc2b_HBASE-16272_1384_histogrambuglines_1384.diff'],
#  ['HBASE-16160',
#   '3b5fbf8d73',
#   '356c1307021e931e871307077f71aab79dc43def',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/ipc/BufferChain.java',
#   'BufferChain.java_3b5fbf8d73-356c130702_HBASE-16160_1392_histogrambuglines_1392.diff'],
#  ['HBASE-16880',
#   'ce493642c0',
#   '2ff2c0ba6eb99f2c700b4d1f185d63fa71da05fe',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/ipc/BufferChain.java',
#   'BufferChain.java_ce493642c0-2ff2c0ba6e_HBASE-16880_1319_histogrambuglines_1319.diff'],
#  ['HBASE-12281',
#   '31ccaa519b',
#   'c01d9981d89ba3633377952d132c88536c86ebc5',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/io/encoding/BufferedDataBlockEncoder.java',
#   'BufferedDataBlockEncoder.java_31ccaa519b-c01d9981d8_HBASE-12281_2319_histogrambuglines_2319.diff'],
#  ['HBASE-19160',
#   '9ee8e2714d',
#   '888f2335c952040646ce820f6191f6433ec9411d',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/io/encoding/BufferedDataBlockEncoder.java',
#   'BufferedDataBlockEncoder.java_9ee8e2714d-888f2335c9_HBASE-19160_1061_histogrambuglines_1061.diff'],
#  ['HBASE-17326',
#   'c3ce02d592',
#   'e16e2a61c143ce95c632b92d38f8d95815b08fdf',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/BufferedMutatorParams.java',
#   'BufferedMutatorParams.java_c3ce02d592-e16e2a61c1_HBASE-17326_1307_histogrambuglines_1307.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-examples/src/main/java/org/apache/hadoop/hbase/coprocessor/example/BulkDeleteEndpoint.java',
#   'BulkDeleteEndpoint.java_95c1dc93fb-cc237c4b78_HBASE-15638_1638_histogrambuglines_1638.diff'],
#  ['HBASE-11544',
#   'de9791e91e',
#   '39425a8558fabaffa0e2b9421a8a7926d73b040c',
#   'hbase-examples/src/main/java/org/apache/hadoop/hbase/coprocessor/example/BulkDeleteEndpoint.java',
#   'BulkDeleteEndpoint.java_de9791e91e-39425a8558_HBASE-11544_2418_histogrambuglines_2418.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/replication/BulkLoadCellFilter.java',
#   'BulkLoadCellFilter.java_95c1dc93fb-cc237c4b78_HBASE-15638_1814_histogrambuglines_1814.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/coprocessor/BulkLoadObserver.java',
#   'BulkLoadObserver.java_95c1dc93fb-cc237c4b78_HBASE-15638_1705_histogrambuglines_1705.diff'],
#  ['HBASE-7443',
#   '92c98a76d1',
#   '3e600deba265c02283c9a354e25d9f6652240945',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/filter/ByteArrayComparable.java',
#   'ByteArrayComparable.java_92c98a76d1-3e600deba2_HBASE-7443_268_histogrambuglines_268.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/filter/ByteArrayComparable.java',
#   'ByteArrayComparable.java_95c1dc93fb-cc237c4b78_HBASE-15638_1622_histogrambuglines_1622.diff'],
#  ['HBASE-8085',
#   '7465b3d076',
#   'cbf1e90f81e37dcca9891e9dde9fef97e144445c',
#   'src/main/java/org/apache/hadoop/hbase/util/Bytes.java',
#   'Bytes.java_7465b3d076-cbf1e90f81_HBASE-8085_178_histogrambuglines_178.diff'],
#  ['HBASE-10079',
#   '923becd6c0',
#   '29426d2caae9e3f22c00f6ef279e812d50297f34',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/util/Bytes.java',
#   'Bytes.java_923becd6c0-29426d2caa_HBASE-10079_2587_histogrambuglines_2587.diff'],
#  ['HBASE-6991',
#   '9b3e63dcb7',
#   '571a8a3e6239d74b26d923536c8981033d1045d3',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/util/Bytes.java',
#   'Bytes.java_9b3e63dcb7-571a8a3e62_HBASE-6991_302_histogrambuglines_302.diff'],
#  ['HBASE-12716',
#   'fbdaf62bf8',
#   'a8766fd623e5679b13600646ac2808e733f98d07',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/util/Bytes.java',
#   'Bytes.java_fbdaf62bf8-a8766fd623_HBASE-12716_2256_histogrambuglines_2256.diff'],
#  ['HBASE-2180',
#   '2a1bfea2e9',
#   '5a8b8899885bf786e8947f715608228aa4aab7c2',
#   'CHANGES.txt',
#   'CHANGES.txt_2a1bfea2e9-5a8b889988_HBASE-2180_895_histogrambuglines_895.diff'],
#  ['HBASE-1264',
#   '31cd01f656',
#   '8abe303d1f4dd725d7bfc43d7af767f86470f6f6',
#   'CHANGES.txt',
#   'CHANGES.txt_31cd01f656-8abe303d1f_HBASE-1264_2265_histogrambuglines_2265.diff'],
#  ['HBASE-2402',
#   '3d581a6fce',
#   'f5b181931846a11a1dba2db32c82ca2ec3cb6973',
#   'CHANGES.txt',
#   'CHANGES.txt_3d581a6fce-f5b1819318_HBASE-2402_861_histogrambuglines_861.diff'],
#  ['HBASE-613',
#   '4dbb084860',
#   '2575bee321f5330df140d5fae1c8299a02924fc6',
#   'CHANGES.txt',
#   'CHANGES.txt_4dbb084860-2575bee321_HBASE-613_391_histogrambuglines_391.diff'],
#  ['HBASE-2990',
#   '4e64653921',
#   '0332648656a3a6a57a42828dc88e1b1745013765',
#   'CHANGES.txt',
#   'CHANGES.txt_4e64653921-0332648656_HBASE-2990_760_histogrambuglines_760.diff'],
#  ['HBASE-3008',
#   '4e64653921',
#   '0332648656a3a6a57a42828dc88e1b1745013765',
#   'CHANGES.txt',
#   'CHANGES.txt_4e64653921-0332648656_HBASE-3008_719_histogrambuglines_719.diff'],
#  ['HBASE-554',
#   '5a43af4b99',
#   '9e9cc68a7e767aa3b312bc52956decaa287143fa',
#   'CHANGES.txt',
#   'CHANGES.txt_5a43af4b99-9e9cc68a7e_HBASE-554_467_histogrambuglines_467.diff'],
#  ['HBASE-505',
#   '90e3cb13ca',
#   '9718fda9320e11738ab80bf67ff6f9f61eeec155',
#   'CHANGES.txt',
#   'CHANGES.txt_90e3cb13ca-9718fda932_HBASE-505_494_histogrambuglines_494.diff'],
#  ['HBASE-1396',
#   'b8854372bc',
#   '90dffef122f00aeed90a89fdd6b193eb9edfca49',
#   'CHANGES.txt',
#   'CHANGES.txt_b8854372bc-90dffef122_HBASE-1396_2139_histogrambuglines_2139.diff'],
#  ['HBASE-649',
#   'c7165b1e30',
#   '95e2eb11b4abee9d899cc001db78f8e89529ebb2',
#   'CHANGES.txt',
#   'CHANGES.txt_c7165b1e30-95e2eb11b4_HBASE-649_360_histogrambuglines_360.diff'],
#  ['HBASE-656',
#   'c7165b1e30',
#   '95e2eb11b4abee9d899cc001db78f8e89529ebb2',
#   'CHANGES.txt',
#   'CHANGES.txt_c7165b1e30-95e2eb11b4_HBASE-656_353_histogrambuglines_353.diff'],
#  ['HBASE-1526',
#   'e8d66ea285',
#   '76d4ac4d07123e3880c28f55ebb3d9cdf62bb8b8',
#   'CHANGES.txt',
#   'CHANGES.txt_e8d66ea285-76d4ac4d07_HBASE-1526_2025_histogrambuglines_2025.diff'],
#  ['HBASE-11514',
#   '96dcd67f56',
#   'bf2933e08ab65af3643bdadbc3d59c943d40602f',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/io/hfile/CacheConfig.java',
#   'CacheConfig.java_96dcd67f56-bf2933e08a_HBASE-11514_2471_histogrambuglines_2471.diff'],
#  ['HBASE-1554',
#   '9880f155e2',
#   '69f71c7d802708f3971250793850dd837d435dc5',
#   'src/java/org/apache/hadoop/hbase/io/hfile/CachedBlock.java',
#   'CachedBlock.java_9880f155e2-69f71c7d80_HBASE-1554_1988_histogrambuglines_1988.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/ipc/Call.java',
#   'Call.java_95c1dc93fb-cc237c4b78_HBASE-15638_1577_histogrambuglines_1577.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/ipc/CallRunner.java',
#   'CallRunner.java_95c1dc93fb-cc237c4b78_HBASE-15638_1713_histogrambuglines_1713.diff'],
#  ['HBASE-14512',
#   'a463984945',
#   '24370547c500df0026a71944d8be88cd5b51b23e',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/ipc/CallRunner.java',
#   'CallRunner.java_a463984945-24370547c5_HBASE-14512_2108_histogrambuglines_2108.diff'],
#  ['HBASE-7443',
#   '92c98a76d1',
#   '3e600deba265c02283c9a354e25d9f6652240945',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/tool/Canary.java',
#   'Canary.java_92c98a76d1-3e600deba2_HBASE-7443_278_histogrambuglines_278.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/CancellableRegionServerCallable.java',
#   'CancellableRegionServerCallable.java_95c1dc93fb-cc237c4b78_HBASE-15638_1500_histogrambuglines_1500.diff'],
#  ['HBASE-4799',
#   '04b1c45b94',
#   '6a476e4428b1776f4f6ed0d212bf4ea835ec1535',
#   'src/main/java/org/apache/hadoop/hbase/master/CatalogJanitor.java',
#   'CatalogJanitor.java_04b1c45b94-6a476e4428_HBASE-4799_513_histogrambuglines_513.diff'],
#  ['HBASE-11413',
#   '9ff90931dc',
#   '7a2527da4b1a654cd8dabedb9475c7173237b1f6',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/CatalogJanitor.java',
#   'CatalogJanitor.java_9ff90931dc-7a2527da4b_HBASE-11413_2480_histogrambuglines_2480.diff'],
#  ['HBASE-16527',
#   'a1cd601ad7',
#   'e30a66b9443618f04ad8cb0aee96ac77b174338b',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/CatalogJanitor.java',
#   'CatalogJanitor.java_a1cd601ad7-e30a66b944_HBASE-16527_1364_histogrambuglines_1364.diff'],
#  ['HBASE-3872',
#   'ca7452b4b6',
#   '88fb96318d64b87f02bed5d08d5ee3bfc07464da',
#   'src/main/java/org/apache/hadoop/hbase/master/CatalogJanitor.java',
#   'CatalogJanitor.java_ca7452b4b6-88fb96318d_HBASE-3872_592_histogrambuglines_592.diff'],
#  ['HBASE-4927',
#   'e1855a9344',
#   '0e66ea3c5d8a1ae79b7a476ff61eae933d9b1db0',
#   'src/main/java/org/apache/hadoop/hbase/master/CatalogJanitor.java',
#   'CatalogJanitor.java_e1855a9344-0e66ea3c5d_HBASE-4927_507_histogrambuglines_507.diff'],
#  ['HBASE-13331',
#   'e78aeb24e0',
#   '227ace9100043613a014d897dc78e97cc214ffac',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/CatalogJanitor.java',
#   'CatalogJanitor.java_e78aeb24e0-227ace9100_HBASE-13331_2176_histogrambuglines_2176.diff'],
#  ['HBASE-2558',
#   'd72de27307',
#   '33bf38702b8993b45d857369008659a4773b116b',
#   'src/docs/src/documentation/classes/CatalogManager.properties',
#   'CatalogManager.properties_d72de27307-33bf38702b_HBASE-2558_848_histogrambuglines_848.diff'],
#  ['HBASE-3074',
#   '5e2b839fc4',
#   '44842d7fbcccae4ea0c860263f8d02c8058a3a75',
#   'src/main/java/org/apache/hadoop/hbase/catalog/CatalogTracker.java',
#   'CatalogTracker.java_5e2b839fc4-44842d7fbc_HBASE-3074_691_histogrambuglines_691.diff'],
#  ['HBASE-3627',
#   '833fd0095e',
#   'bd688ffaaeba940c5e3320bbb6efadf2266496b6',
#   'src/main/java/org/apache/hadoop/hbase/catalog/CatalogTracker.java',
#   'CatalogTracker.java_833fd0095e-bd688ffaae_HBASE-3627_619_histogrambuglines_619.diff'],
#  ['HBASE-3100',
#   'af7f5c7d01',
#   '516667bc74081244ba5c33304125938172e5776a',
#   'src/main/java/org/apache/hadoop/hbase/catalog/CatalogTracker.java',
#   'CatalogTracker.java_af7f5c7d01-516667bc74_HBASE-3100_678_histogrambuglines_678.diff'],
#  ['HBASE-3098',
#   'dd74b67762',
#   'd02c00dcf0d4cd0394eef561b6ba924c388529be',
#   'src/main/java/org/apache/hadoop/hbase/catalog/CatalogTracker.java',
#   'CatalogTracker.java_dd74b67762-d02c00dcf0_HBASE-3098_686_histogrambuglines_686.diff'],
#  ['HBASE-968',
#   'f609ddabbc',
#   'fc6ea9bcae213a1372fea632a6057428607cb3e9',
#   'src/java/org/apache/hadoop/hbase/io/Cell.java',
#   'Cell.java_f609ddabbc-fc6ea9bcae_HBASE-968_40_histogrambuglines_40.diff'],
#  ['HBASE-19160',
#   '9ee8e2714d',
#   '888f2335c952040646ce820f6191f6433ec9411d',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/CellComparator.java',
#   'CellComparator.java_9ee8e2714d-888f2335c9_HBASE-19160_1058_histogrambuglines_1058.diff'],
#  ['HBASE-19160',
#   '9ee8e2714d',
#   '888f2335c952040646ce820f6191f6433ec9411d',
#   'hbase-mapreduce/src/main/java/org/apache/hadoop/hbase/mapreduce/CellSortReducer.java',
#   'CellSortReducer.java_9ee8e2714d-888f2335c9_HBASE-19160_1065_histogrambuglines_1065.diff'],
#  ['HBASE-19160',
#   '9ee8e2714d',
#   '888f2335c952040646ce820f6191f6433ec9411d',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/CellUtil.java',
#   'CellUtil.java_9ee8e2714d-888f2335c9_HBASE-19160_1059_histogrambuglines_1059.diff'],
#  ['HBASE-15253',
#   'a975408b7c',
#   '29a192ef3cbe3b9cc12a6ee38f39e1199ac9790f',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/CellUtil.java',
#   'CellUtil.java_a975408b7c-29a192ef3c_HBASE-15253_2028_histogrambuglines_2028.diff'],
#  ['HBASE-9164',
#   'd7d0398713',
#   '7773da0cb47b97e6c9c679d27d8a223233c0291e',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/CellUtil.java',
#   'CellUtil.java_d7d0398713-7773da0cb4_HBASE-9164_62_histogrambuglines_62.diff'],
#  ['HBASE-11921',
#   'f7bcf3df6b',
#   '0259d2734164343038a99caf3051b42e29fbfcc5',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/util/ChecksumType.java',
#   'ChecksumType.java_f7bcf3df6b-0259d27341_HBASE-11921_2386_histogrambuglines_2386.diff'],
#  ['HBASE-4367',
#   '0aafb370ce',
#   '5e411b680fe50538282b59aa6239ef2e296011c9',
#   'src/main/java/org/apache/hadoop/hbase/Chore.java',
#   'Chore.java_0aafb370ce-5e411b680f_HBASE-4367_541_histogrambuglines_541.diff'],
#  ['HBASE-14977',
#   '31d73a4bde',
#   'fbad4d2466441d09f45d6fd42486b5e6dc00a893',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/ChoreService.java',
#   'ChoreService.java_31d73a4bde-fbad4d2466_HBASE-14977_2074_histogrambuglines_2074.diff'],
#  ['HBASE-19919',
#   'bac4687345',
#   '897afb7d1870d0e14fedbdc6289a272607069605',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/ChoreService.java',
#   'ChoreService.java_bac4687345-897afb7d18_HBASE-19919_943_histogrambuglines_943.diff'],
#  ['HBASE-19919',
#   'bac4687345',
#   '897afb7d1870d0e14fedbdc6289a272607069605',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/ChunkCreator.java',
#   'ChunkCreator.java_bac4687345-897afb7d18_HBASE-19919_965_histogrambuglines_965.diff'],
#  ['HBASE-20169',
#   'fabb1d97cc',
#   '75ff2504ec057cb3f9df5fefaf68dac7d9221445',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/ChunkCreator.java',
#   'ChunkCreator.java_fabb1d97cc-75ff2504ec_HBASE-20169_934_histogrambuglines_934.diff'],
#  ['HBASE-1554',
#   '9880f155e2',
#   '69f71c7d802708f3971250793850dd837d435dc5',
#   'src/java/org/apache/hadoop/hbase/util/ClassSize.java',
#   'ClassSize.java_9880f155e2-69f71c7d80_HBASE-1554_1990_histogrambuglines_1990.diff'],
#  ['HBASE-19919',
#   'bac4687345',
#   '897afb7d1870d0e14fedbdc6289a272607069605',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/cleaner/CleanerChore.java',
#   'CleanerChore.java_bac4687345-897afb7d18_HBASE-19919_959_histogrambuglines_959.diff'],
#  ['HBASE-13262',
#   '1abf3aa0fd',
#   'eb294a357f51d2fa92c3a28a5ca27de8052f0e58',
#   'hbase-protocol/src/main/java/org/apache/hadoop/hbase/protobuf/generated/ClientProtos.java',
# ...
#   'LogRoller.java_06d1a00f83-8b7d4da0f9_HBASE-930_49_histogrambuglines_49.diff'],
#  ['HBASE-4367',
#   '0aafb370ce',
#   '5e411b680fe50538282b59aa6239ef2e296011c9',
#   'src/main/java/org/apache/hadoop/hbase/regionserver/LogRoller.java',
#   'LogRoller.java_0aafb370ce-5e411b680f_HBASE-4367_549_histogrambuglines_549.diff'],
#  ['HBASE-14317',
#   '661faf6fe0',
#   '2481b7f76fa7e4f2b120f8dc96004790b357e569',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/LogRoller.java',
#   'LogRoller.java_661faf6fe0-2481b7f76f_HBASE-14317_2115_histogrambuglines_2115.diff'],
#  ['HBASE-11403',
#   'ab72babd97',
#   'e991fd8055112e2ddc0bbeade2ef74504e2407dd',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/LogRoller.java',
#   'LogRoller.java_ab72babd97-e991fd8055_HBASE-11403_2486_histogrambuglines_2486.diff'],
#  ['HBASE-1013',
#   'dfd2d6af99',
#   'ad707c4f6000c4c8393c7b44075bb92abb7ceb99',
#   'src/java/org/apache/hadoop/hbase/regionserver/LogRoller.java',
#   'LogRoller.java_dfd2d6af99-ad707c4f60_HBASE-1013_2585_histogrambuglines_2585.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/filter/LongComparator.java',
#   'LongComparator.java_95c1dc93fb-cc237c4b78_HBASE-15638_1557_histogrambuglines_1557.diff'],
#  ['HBASE-4367',
#   '0aafb370ce',
#   '5e411b680fe50538282b59aa6239ef2e296011c9',
#   'src/main/java/org/apache/hadoop/hbase/io/hfile/LruBlockCache.java',
#   'LruBlockCache.java_0aafb370ce-5e411b680f_HBASE-4367_542_histogrambuglines_542.diff'],
#  ['HBASE-1597',
#   '1f85226103',
#   '80b5452a0d5898810e3fadcffb6b225c7cd5da25',
#   'src/java/org/apache/hadoop/hbase/io/hfile/LruBlockCache.java',
#   'LruBlockCache.java_1f85226103-80b5452a0d_HBASE-1597_1433_histogrambuglines_1433.diff'],
#  ['HBASE-7508',
#   '4e0af48fe4',
#   '176ddb066c2011158b5dfb5c036a4af5687a70cd',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/io/hfile/LruBlockCache.java',
#   'LruBlockCache.java_4e0af48fe4-176ddb066c_HBASE-7508_255_histogrambuglines_255.diff'],
#  ['HBASE-16157',
#   '5a7c9939cb',
#   'bc70dc00bb05580bdc597cedf152f8add1f48d90',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/io/hfile/LruBlockCache.java',
#   'LruBlockCache.java_5a7c9939cb-bc70dc00bb_HBASE-16157_1394_histogrambuglines_1394.diff'],
#  ['HBASE-11514',
#   '96dcd67f56',
#   'bf2933e08ab65af3643bdadbc3d59c943d40602f',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/io/hfile/LruBlockCache.java',
#   'LruBlockCache.java_96dcd67f56-bf2933e08a_HBASE-11514_2472_histogrambuglines_2472.diff'],
#  ['HBASE-1554',
#   '9880f155e2',
#   '69f71c7d802708f3971250793850dd837d435dc5',
#   'src/java/org/apache/hadoop/hbase/io/hfile/LruBlockCache.java',
#   'LruBlockCache.java_9880f155e2-69f71c7d80_HBASE-1554_1989_histogrambuglines_1989.diff'],
#  ['HBASE-16272',
#   'cc766df28b',
#   '519f87fc2bde21031f95cbb6cab031eccc4ac2e1',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/io/hfile/LruBlockCache.java',
#   'LruBlockCache.java_cc766df28b-519f87fc2b_HBASE-16272_1383_histogrambuglines_1383.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-protocol-shaded/src/main/protobuf/Master.proto',
#   'Master.proto_95c1dc93fb-cc237c4b78_HBASE-15638_1667_histogrambuglines_1667.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/zookeeper/MasterAddressTracker.java',
#   'MasterAddressTracker.java_95c1dc93fb-cc237c4b78_HBASE-15638_1608_histogrambuglines_1608.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/MasterAnnotationReadingPriorityFunction.java',
#   'MasterAnnotationReadingPriorityFunction.java_95c1dc93fb-cc237c4b78_HBASE-15638_1730_histogrambuglines_1730.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/MasterCallable.java',
#   'MasterCallable.java_95c1dc93fb-cc237c4b78_HBASE-15638_1511_histogrambuglines_1511.diff'],
#  ['HBASE-2990',
#   '4e64653921',
#   '0332648656a3a6a57a42828dc88e1b1745013765',
#   'src/main/java/org/apache/hadoop/hbase/master/handler/MasterCloseRegionHandler.java',
#   'MasterCloseRegionHandler.java_4e64653921-0332648656_HBASE-2990_776_histogrambuglines_776.diff'],
#  ['HBASE-3008',
#   '4e64653921',
#   '0332648656a3a6a57a42828dc88e1b1745013765',
#   'src/main/java/org/apache/hadoop/hbase/master/handler/MasterCloseRegionHandler.java',
#   'MasterCloseRegionHandler.java_4e64653921-0332648656_HBASE-3008_735_histogrambuglines_735.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/MasterCoprocessorHost.java',
#   'MasterCoprocessorHost.java_95c1dc93fb-cc237c4b78_HBASE-15638_1731_histogrambuglines_1731.diff'],
#  ['HBASE-19919',
#   'bac4687345',
#   '897afb7d1870d0e14fedbdc6289a272607069605',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/MasterCoprocessorHost.java',
#   'MasterCoprocessorHost.java_bac4687345-897afb7d18_HBASE-19919_954_histogrambuglines_954.diff'],
#  ['HBASE-17624',
#   'e019961150',
#   'b2217d1d8f17a8de1a0cf91b74a7170f5ffc1eed',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/MasterCoprocessorHost.java',
#   'MasterCoprocessorHost.java_e019961150-b2217d1d8f_HBASE-17624_1272_histogrambuglines_1272.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/ipc/MasterCoprocessorRpcChannel.java',
#   'MasterCoprocessorRpcChannel.java_95c1dc93fb-cc237c4b78_HBASE-15638_1584_histogrambuglines_1584.diff'],
#  ['HBASE-10446',
#   'b3b3d0ddff',
#   '3f9f4e00b6349c2524b026ab92234bd8d900c10c',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/MasterDumpServlet.java',
#   'MasterDumpServlet.java_b3b3d0ddff-3f9f4e00b6_HBASE-10446_2580_histogrambuglines_2580.diff'],
#  ['HBASE-5137',
#   '0820fbddd3',
#   '5b769502b85b93559b823a5025241b6c92a65605',
#   'src/main/java/org/apache/hadoop/hbase/master/MasterFileSystem.java',
#   'MasterFileSystem.java_0820fbddd3-5b769502b8_HBASE-5137_486_histogrambuglines_486.diff'],
#  ['HBASE-15467',
#   'bdb0cc8808',
#   '65a8d77433cf72ce67e8b5e2efb35f2c2603c349',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/MasterFileSystem.java',
#   'MasterFileSystem.java_bdb0cc8808-65a8d77433_HBASE-15467_1998_histogrambuglines_1998.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/procedure/flush/MasterFlushTableProcedureManager.java',
#   'MasterFlushTableProcedureManager.java_95c1dc93fb-cc237c4b78_HBASE-15638_1772_histogrambuglines_1772.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/MasterKeepAliveConnection.java',
#   'MasterKeepAliveConnection.java_95c1dc93fb-cc237c4b78_HBASE-15638_1512_histogrambuglines_1512.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/MasterMetaBootstrap.java',
#   'MasterMetaBootstrap.java_95c1dc93fb-cc237c4b78_HBASE-15638_1732_histogrambuglines_1732.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/coprocessor/MasterObserver.java',
#   'MasterObserver.java_95c1dc93fb-cc237c4b78_HBASE-15638_1706_histogrambuglines_1706.diff'],
#  ['HBASE-17624',
#   'e019961150',
#   'b2217d1d8f17a8de1a0cf91b74a7170f5ffc1eed',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/coprocessor/MasterObserver.java',
#   'MasterObserver.java_e019961150-b2217d1d8f_HBASE-17624_1270_histogrambuglines_1270.diff'],
#  ['HBASE-2990',
#   '4e64653921',
#   '0332648656a3a6a57a42828dc88e1b1745013765',
#   'src/main/java/org/apache/hadoop/hbase/master/handler/MasterOpenRegionHandler.java',
#   'MasterOpenRegionHandler.java_4e64653921-0332648656_HBASE-2990_777_histogrambuglines_777.diff'],
#  ['HBASE-3008',
#   '4e64653921',
#   '0332648656a3a6a57a42828dc88e1b1745013765',
#   'src/main/java/org/apache/hadoop/hbase/master/handler/MasterOpenRegionHandler.java',
#   'MasterOpenRegionHandler.java_4e64653921-0332648656_HBASE-3008_736_histogrambuglines_736.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-protocol-shaded/src/main/protobuf/MasterProcedure.proto',
#   'MasterProcedure.proto_95c1dc93fb-cc237c4b78_HBASE-15638_1668_histogrambuglines_1668.diff'],
#  ['HBASE-19319',
#   'f886716617',
#   '5a0881a98b3575d900d483222e2fdfab15159656',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/procedure/MasterProcedureEnv.java',
#   'MasterProcedureEnv.java_f886716617-5a0881a98b_HBASE-19319_1039_histogrambuglines_1039.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/procedure/MasterProcedureManager.java',
#   'MasterProcedureManager.java_95c1dc93fb-cc237c4b78_HBASE-15638_1769_histogrambuglines_1769.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-protocol-shaded/src/main/java/org/apache/hadoop/hbase/shaded/protobuf/generated/MasterProcedureProtos.java',
#   'MasterProcedureProtos.java_95c1dc93fb-cc237c4b78_HBASE-15638_1664_histogrambuglines_1664.diff'],
#  ['HBASE-19457',
#   '7092b814bd',
#   'a5a77ae3d5bfef9396b6024ec723d83a911692ec',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/master/procedure/MasterProcedureTestingUtility.java',
#   'MasterProcedureTestingUtility.java_7092b814bd-a5a77ae3d5_HBASE-19457_1023_histogrambuglines_1023.diff'],
#  ['HBASE-15467',
#   'bdb0cc8808',
#   '65a8d77433cf72ce67e8b5e2efb35f2c2603c349',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/master/procedure/MasterProcedureTestingUtility.java',
#   'MasterProcedureTestingUtility.java_bdb0cc8808-65a8d77433_HBASE-15467_2012_histogrambuglines_2012.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/procedure/MasterProcedureUtil.java',
#   'MasterProcedureUtil.java_95c1dc93fb-cc237c4b78_HBASE-15638_1753_histogrambuglines_1753.diff'],
#  ['HBASE-16683',
#   '9952b134fc',
#   '7e6f19581bef830516608acd2e28c6c8fe3ccaff',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/procedure/MasterProcedureUtil.java',
#   'MasterProcedureUtil.java_9952b134fc-7e6f19581b_HBASE-16683_1346_histogrambuglines_1346.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-protocol/src/main/java/org/apache/hadoop/hbase/protobuf/generated/MasterProtos.java',
#   'MasterProtos.java_95c1dc93fb-cc237c4b78_HBASE-15638_1675_histogrambuglines_1675.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/quotas/MasterQuotaManager.java',
#   'MasterQuotaManager.java_95c1dc93fb-cc237c4b78_HBASE-15638_1774_histogrambuglines_1774.diff'],
#  ['HBASE-18946',
#   '010012cbcb',
#   '11e82de8a1d782be85a776ec08e8cd6a071185bf',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/MasterRpcServices.java',
#   'MasterRpcServices.java_010012cbcb-11e82de8a1_HBASE-18946_1125_histogrambuglines_1125.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/MasterRpcServices.java',
#   'MasterRpcServices.java_95c1dc93fb-cc237c4b78_HBASE-15638_1733_histogrambuglines_1733.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/snapshot/MasterSnapshotVerifier.java',
#   'MasterSnapshotVerifier.java_95c1dc93fb-cc237c4b78_HBASE-15638_1763_histogrambuglines_1763.diff'],
#  ['HBASE-15638',
#   '95c1dc93fb',
#   'cc237c4b78517a6b370c55c8573b14c9edf683de',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/MasterWalManager.java',
#   'MasterWalManager.java_95c1dc93fb-cc237c4b78_HBASE-15638_1734_histogrambuglines_1734.diff'],
#  ['HBASE-10647',
#   '2e28ec44c8',
#   '032ea4b380a6e323faaa9d13e8c0f51c46d66bf6',
#   'src/main/java/org/apache/hadoop/hbase/regionserver/MemStore.java',
#   'MemStore.java_2e28ec44c8-032ea4b380_HBASE-10647_2551_histogrambuglines_2551.diff'],
#  ['HBASE-2990',
#   '4e64653921',
#   '0332648656a3a6a57a42828dc88e1b1745013765',
#   'src/main/java/org/apache/hadoop/hbase/regionserver/MemStore.java',
#   'MemStore.java_4e64653921-0332648656_HBASE-2990_779_histogrambuglines_779.diff'],
#  ['HBASE-3008',
#   '4e64653921',
#   '0332648656a3a6a57a42828dc88e1b1745013765',
#   'src/main/java/org/apache/hadoop/hbase/regionserver/MemStore.java',
#   'MemStore.java_4e64653921-0332648656_HBASE-3008_738_histogrambuglines_738.diff'],
#  ['HBASE-10514',
#   '731e2f6541',
#   '98cf3e27ee5fa30b962984629cc4195e5bb38276',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/MemStore.java',
#   'MemStore.java_731e2f6541-98cf3e27ee_HBASE-10514_2565_histogrambuglines_2565.diff'],
#  ['HBASE-2997',
#   'cd10620e41',
#   '81d9c8a1a3f70df483240f312e9b6f6f242fc048',
#   'src/main/java/org/apache/hadoop/hbase/regionserver/MemStore.java',
#   'MemStore.java_cd10620e41-81d9c8a1a3_HBASE-2997_759_histogrambuglines_759.diff'],
#  ['HBASE-9164',
#   'd7d0398713',
#   '7773da0cb47b97e6c9c679d27d8a223233c0291e',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/MemStore.java',
#   'MemStore.java_d7d0398713-7773da0cb4_HBASE-9164_68_histogrambuglines_68.diff'],
#  ['HBASE-19835',
#   'f1a81618fd',
#   '277ce3d8a3d68f87e82c98fdeb3a3cb3dee33036',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/MemStoreCompactor.java',
#   'MemStoreCompactor.java_f1a81618fd-277ce3d8a3_HBASE-19835_982_histogrambuglines_982.diff'],
#  ['HBASE-4367',
#   '0aafb370ce',
#   '5e411b680fe50538282b59aa6239ef2e296011c9',
#   'src/main/java/org/apache/hadoop/hbase/regionserver/MemStoreFlusher.java',
#   'MemStoreFlusher.java_0aafb370ce-5e411b680f_HBASE-4367_550_histogrambuglines_550.diff'],
#  ['HBASE-10656',
#   'a1a5f57bff',
#   '6bf39f535970f3befc82a21c44843ec12dd49527',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/MemStoreFlusher.java',
#   'MemStoreFlusher.java_a1a5f57bff-6bf39f5359_HBASE-10656_2547_histogrambuglines_2547.diff'],
#  ['HBASE-15236',
#   '11740570c1',
#   'a6e29676db1d2aa8ff40624573bfd93bf356d2b4',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/MemStoreScanner.java',
#   'MemStoreScanner.java_11740570c1-a6e29676db_HBASE-15236_2031_histogrambuglines_2031.diff'],
#  ['HBASE-586',
#   '32ce612048',
#   'd500acc392fafc540365ed90e6adbd0ce3be8152',
#   'src/java/org/apache/hadoop/hbase/regionserver/Memcache.java',
#   'Memcache.java_32ce612048-d500acc392_HBASE-586_430_histogrambuglines_430.diff'],
#  ['HBASE-532',
#   '64e3f031ea',
#   'f2b06cfe1b39abd4aa9f0294e6c692f0db23d0f5',
#   'src/java/org/apache/hadoop/hbase/regionserver/Memcache.java',
#   'Memcache.java_64e3f031ea-f2b06cfe1b_HBASE-532_480_histogrambuglines_480.diff'],
#  ['HBASE-826',
#   '7627490bea',
#   '0af55439a6eea26db0f975089a1adf72e3881469',
#   'src/java/org/apache/hadoop/hbase/regionserver/Memcache.java',
#   'Memcache.java_7627490bea-0af55439a6_HBASE-826_160_histogrambuglines_160.diff'],
#  ['HBASE-1352',
#   '78ec818a41',
#   'd1801625e6c359231c5ae09a3575f87f7cac1101',
#   'src/java/org/apache/hadoop/hbase/regionserver/Memcache.java',
#   'Memcache.java_78ec818a41-d1801625e6_HBASE-1352_2174_histogrambuglines_2174.diff'],
#  ['HBASE-790',
#   '9f00684d05',
#   'fb1d03ff3cabde59a5e87dd9a86027d1c6629b3f',
#   'src/java/org/apache/hadoop/hbase/regionserver/Memcache.java',
#   'Memcache.java_9f00684d05-fb1d03ff3c_HBASE-790_205_histogrambuglines_205.diff'],
#  ['HBASE-792',
#   '9f00684d05',
#   'fb1d03ff3cabde59a5e87dd9a86027d1c6629b3f',
#   'src/java/org/apache/hadoop/hbase/regionserver/Memcache.java',
#   'Memcache.java_9f00684d05-fb1d03ff3c_HBASE-792_198_histogrambuglines_198.diff'],
#  ...]

# %% [markdown]
# Reading files of buggylines for each algorithm

# %%
bug_file = []
for m, algrt in enumerate(algorithms):
    temp_file = []
    s = 0
    for f_name in glob.iglob(analyze_dir + '03_file-diff/02_buggylines/' + algrt + '/*', recursive=True):
        sys.stdout.write("\r%i " %(m+1) + "Counting bugline for file %i" %(s+1))
        sys.stdout.flush()
        s += 1
        
        temp_file.append(f_name)
    temp_file.sort()
    bug_file.append(temp_file)
print ("\nReading files are complete")
# Out:
# 4 Counting bugline for file 2599
# Reading files are complete

# %% [markdown]
# # Counting number of files and number of buggylines

# %%
for n, algr in enumerate(algorithms):
    total = []
    for rr, f_name in enumerate(bug_file[n]):
        sys.stdout.write("\r%i " %(n+1) + "Counting bugline for file %i" %(rr+1))
        sys.stdout.flush()
        
        fn = open(f_name, 'r')
        fn = fn.read().split('\n')
        if "--- /dev" in fn[0]:
            num = str(len(fn)-2)
        else:
            num = str(len(fn)-1)
        
        pattern = re.search("(?:\w+[-]\w+[-]\w+|\w+[-]\w+|\w+)[.]\w+[_]|(?<=" + algr + "\/)(\w+[_])(?<=[_])", f_name)
        pattern = pattern.group()[:-1]
        
        if num != '0':
            current = [buggylinefiles[n][rr][0], buggylinefiles[n][rr][1], buggylinefiles[n][rr][2], buggylinefiles[n][rr][3], pattern, num]
            total.append(current)
    
    total = sorted(total, key=operator.itemgetter(4,1,2,0))
    
    with open(analyze_dir + "03_file-diff/03_number_of_files/" + algr + "_total_bugline.csv", 'w') as myfile:
        writers = csv.writer(myfile)
        fields = ['bug_id','bugintro_commitID','parent_id','filepath','filename','number_of_buggyline']
        writers.writerow(fields)
        for row in total:
            writers.writerow(row)
            
print ("\nCounting buggylines are complete")
# Out:
# 4 Counting bugline for file 2599
# Counting buggylines are complete

# %% [markdown]
# Loading files total_bugline

# %%
df_totalhist = pd.read_csv(analyze_dir + '03_file-diff/03_number_of_files/histogram_total_bugline.csv')
df_totalmin = pd.read_csv(analyze_dir + '03_file-diff/03_number_of_files/minimal_total_bugline.csv')
df_totalmyers = pd.read_csv(analyze_dir + '03_file-diff/03_number_of_files/myers_total_bugline.csv')
df_totalpat = pd.read_csv(analyze_dir + '03_file-diff/03_number_of_files/patience_total_bugline.csv')

# %% [markdown]
# Grouping same files and sum of the number of buglines

# %%
d_frame = [df_totalhist, df_totalmin, df_totalmyers, df_totalpat]
for d, dfr in enumerate(d_frame):
    dframe = (pd.to_numeric(dfr['number_of_buggyline'], errors='coerce')
           .groupby(dfr['filepath'])
           .sum()
           .to_frame()
           .add_prefix('total')
           .reset_index())

    col = ['filepath','totalnumber_of_buggyline']
    dframe = dframe.dropna(subset=['totalnumber_of_buggyline'])
    dframe = dframe.sort_values('totalnumber_of_buggyline', ascending=False)

    dframe[col].to_csv(analyze_dir + '03_file-diff/03_number_of_files/totalbug_of_' + algorithms[d] + '_filechanged.csv')

# %% [markdown]
# # Eliminating files with zero total number of buggyline

# %% [markdown]
# Loading dataset

# %%
dfrhist = pd.read_csv(analyze_dir + '03_file-diff/03_number_of_files/totalbug_of_histogram_filechanged.csv')
dfrmin = pd.read_csv(analyze_dir + '03_file-diff/03_number_of_files/totalbug_of_minimal_filechanged.csv')
dfrmyers = pd.read_csv(analyze_dir + '03_file-diff/03_number_of_files/totalbug_of_myers_filechanged.csv')
dfrpat = pd.read_csv(analyze_dir + '03_file-diff/03_number_of_files/totalbug_of_patience_filechanged.csv')

# %% [markdown]
# Eliminating zero buggyline files

# %%
cols = ['filepath','totalnumber_of_buggyline']
filehist = dfrhist[cols][dfrhist['totalnumber_of_buggyline'] != 0]
filemin = dfrmin[cols][dfrmin['totalnumber_of_buggyline'] != 0]
filemyers = dfrmyers[cols][dfrmyers['totalnumber_of_buggyline'] != 0]
filepat = dfrpat[cols][dfrpat['totalnumber_of_buggyline'] != 0]

# %%
filehist
# Out:
#                                                filepath  \
# 0     hbase-protocol/src/main/java/org/apache/hadoop...
# 1     hbase-protocol/src/main/java/org/apache/hadoop...
# 2     hbase-client/src/main/java/org/apache/hadoop/h...
# 3     hbase-client/src/main/java/org/apache/hadoop/h...
# 4     hbase-protocol/src/main/java/org/apache/hadoop...
# 5     hbase-server/src/test/java/org/apache/hadoop/h...
# 6     hbase-server/src/test/java/org/apache/hadoop/h...
# 7     hbase-server/src/test/java/org/apache/hadoop/h...
# 8         src/main/asciidoc/_chapters/architecture.adoc
# 9     src/java/org/apache/hadoop/hbase/thrift/genera...
# 10    src/main/java/org/apache/hadoop/hbase/executor...
# 11    src/java/org/apache/hadoop/hbase/regionserver/...
# 12    src/test/java/org/apache/hadoop/hbase/master/T...
# 13    hbase-protocol/src/main/java/org/apache/hadoop...
# 14    hbase-server/src/main/java/org/apache/hadoop/h...
# 15    hbase-protocol/src/main/java/org/apache/hadoop...
# 16    src/test/java/org/apache/hadoop/hbase/master/T...
# 17    hbase-examples/src/test/java/org/apache/hadoop...
# 18    hbase-server/src/main/java/org/apache/hadoop/h...
# 19    src/main/java/org/apache/hadoop/hbase/zookeepe...
# 20    src/main/java/org/apache/hadoop/hbase/master/Z...
# 21              src/docs/src/documentation/skinconf.xml
# 22    src/main/java/org/apache/hadoop/hbase/executor...
# 23    hbase-protocol/src/main/java/org/apache/hadoop...
# 24    src/main/java/org/apache/hadoop/hbase/regionse...
# 25    hbase-server/src/main/java/org/apache/hadoop/h...
# 26    src/java/org/apache/hadoop/hbase/regionserver/...
# 27    src/java/org/apache/hadoop/hbase/regionserver/...
# 28    hbase-server/src/main/java/org/apache/hadoop/h...
# 29    src/main/java/org/apache/hadoop/hbase/regionse...
# ...                                                 ...
# 1505  hbase-server/src/test/java/org/apache/hadoop/h...
# 1506  src/java/org/apache/hadoop/hbase/HServerLoad.java
# 1507  hbase-server/src/main/java/org/apache/hadoop/h...
# 1508  hbase-replication/src/main/java/org/apache/had...
# 1509   src/main/java/org/apache/hadoop/hbase/Chore.java
# 1510  hbase-server/src/main/java/org/apache/hadoop/h...
# 1511  hbase-server/src/test/java/org/apache/hadoop/h...
# 1512  hbase-server/src/test/java/org/apache/hadoop/h...
# 1513  hbase-server/src/main/java/org/apache/hadoop/h...
# 1514  hbase-protocol/src/main/protobuf/AccessControl...
# 1515                            src/main/docbkx/rpc.xml
# 1516                        src/main/docbkx/preface.xml
# 1517  hbase-server/src/test/java/org/apache/hadoop/h...
# 1518  hbase-server/src/test/java/org/apache/hadoop/h...
# 1519  hbase-server/src/main/java/org/apache/hadoop/h...
# 1520  hbase-server/src/test/java/org/apache/hadoop/h...
# 1521  hbase-server/src/main/java/org/apache/hadoop/h...
# 1522  hbase-server/src/main/java/org/apache/hadoop/h...
# 1523                        src/main/asciidoc/book.adoc
# 1524  hbase-server/src/main/java/org/apache/hadoop/h...
# 1525  hbase-server/src/test/java/org/apache/hadoop/h...
# 1526  hbase-server/src/test/java/org/apache/hadoop/h...
# 1527  hbase-server/src/main/java/org/apache/hadoop/h...
# 1528  hbase-client/src/main/java/org/apache/hadoop/h...
# 1529  hbase-resource-bundle/src/main/resources/META-...
# 1530  src/main/java/org/apache/hadoop/hbase/HServerI...
# 1531  hbase-server/src/main/java/org/apache/hadoop/h...
# 1532  hbase-server/src/test/java/org/apache/hadoop/h...
# 1533  hbase-server/src/main/java/org/apache/hadoop/h...
# 1534  src/main/java/org/apache/hadoop/hbase/HRegionL...
#
#       totalnumber_of_buggyline
# 0                        66862
# 1                         9239
# 2                         2045
# 3                         1477
# 4                         1353
# 5                          831
# 6                          717
# 7                          716
# 8                          695
# 9                          603
# 10                         556
# 11                         549
# 12                         536
# 13                         530
# 14                         501
# 15                         485
# 16                         482
# 17                         443
# 18                         427
# 19                         412
# 20                         372
# 21                         345
# 22                         342
# 23                         341
# 24                         328
# 25                         322
# 26                         300
# 27                         299
# 28                         268
# 29                         264
# ...                        ...
# 1505                         1
# 1506                         1
# 1507                         1
# 1508                         1
# 1509                         1
# 1510                         1
# 1511                         1
# 1512                         1
# 1513                         1
# 1514                         1
# 1515                         1
# 1516                         1
# 1517                         1
# 1518                         1
# 1519                         1
# 1520                         1
# 1521                         1
# 1522                         1
# 1523                         1
# 1524                         1
# 1525                         1
# 1526                         1
# 1527                         1
# 1528                         1
# 1529                         1
# 1530                         1
# 1531                         1
# 1532                         1
# 1533                         1
# 1534                         1
#
# [1535 rows x 2 columns]

# %%
filehist.to_csv(analyze_dir + '03_file-diff/03_number_of_files/01_files_with_buglines/histogramfiles_with_buglines.csv')
filemin.to_csv(analyze_dir + '03_file-diff/03_number_of_files/01_files_with_buglines/minimalfiles_with_buglines.csv')
filemyers.to_csv(analyze_dir + '03_file-diff/03_number_of_files/01_files_with_buglines/myersfiles_with_buglines.csv')
filepat.to_csv(analyze_dir + '03_file-diff/03_number_of_files/01_files_with_buglines/patiencefiles_with_buglines.csv')

# %% [markdown]
# Counting number of files

# %%
stat = []
for n, algr in enumerate(algorithms):
    file = pd.read_csv(analyze_dir + '03_file-diff/03_number_of_files/01_files_with_buglines/' + algr + 'files_with_buglines.csv')
    file = file[cols]
    numfile = len(file)
    totbug = file['totalnumber_of_buggyline'].sum()
    temp = [algr, numfile, totbug]
    stat.append(temp)
print ("Counting files and number of buglines are complete")
# Out:
# Counting files and number of buglines are complete

# %%
with open(analyze_dir + '03_file-diff/03_number_of_files/01_files_with_buglines/file_and_bug-stats.csv','w') as statfile:
    column = ['algorithm', 'number_of_files', 'totalnumber_of_buglines']
    writers = csv.writer(statfile, delimiter=',')
    writers.writerow(column)
    for item in stat:
        writers.writerow(item)
    
stats = pd.read_csv(analyze_dir + '03_file-diff/03_number_of_files/01_files_with_buglines/file_and_bug-stats.csv')
stats = stats[column]
stats
# Out:
#    algorithm  number_of_files  totalnumber_of_buglines
# 0  histogram             1535                   116634
# 1    minimal             1535                   116454
# 2      myers             1535                   116798
# 3   patience             1535                   116558

# %% [markdown]
# Summarizing total number of buglines

# %% [markdown]
# # Visualizing number of files and total number of buglines

# %%
numfiles = go.Bar(
    x = stats['algorithm'],
    y = stats['number_of_files'],
    text = stats['number_of_files'],
    textposition = 'auto',
    opacity = 0.6,
    marker = dict(
        color = 'rgb(150,255,200)',
        line = dict(
            color='rgb(8,48,107)',
            width=1.5),
    )
)

dtbar = [numfiles]

layout = go.Layout(
    title = 'Number of files changed'
)

init_notebook_mode(connected=True)
fig = go.Figure(data=dtbar, layout=layout)
iplot(fig, show_link=False)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="928ec006-ae25-4ca4-bb9c-f003c7338f2e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("928ec006-ae25-4ca4-bb9c-f003c7338f2e", [{"type": "bar", "x": ["histogram", "minimal", "myers", "patience"], "y": [1535, 1535, 1535, 1535], "text": [1535, 1535, 1535, 1535], "textposition": "auto", "opacity": 0.6, "marker": {"color": "rgb(150,255,200)", "line": {"color": "rgb(8,48,107)", "width": 1.5}}}], {"title": "Number of files changed"}, {"showLink": false, "linkText": "Export to plot.ly"})});</script>

# %%
totbug = go.Bar(
    x = stats['algorithm'],
    y = stats['totalnumber_of_buglines'],
    text = stats['totalnumber_of_buglines'],
    textposition = 'auto',
    name = 'Number of buglines',
    opacity = 0.6,
    marker = dict(
        color = 'rgb(150,255,200)',
        line = dict(
            color='rgb(8,48,107)',
            width=1.5),
    )
)

dtbar = [totbug]

layout = go.Layout(
    title = 'Total number of buglines'
)

init_notebook_mode(connected=True)
fig = go.Figure(data=dtbar, layout=layout)
iplot(fig, show_link=False)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="6a34a586-e2a8-40be-adef-b0da91dd38e2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6a34a586-e2a8-40be-adef-b0da91dd38e2", [{"type": "bar", "x": ["histogram", "minimal", "myers", "patience"], "y": [116634, 116454, 116798, 116558], "text": [116634, 116454, 116798, 116558], "textposition": "auto", "name": "Number of buglines", "opacity": 0.6, "marker": {"color": "rgb(150,255,200)", "line": {"color": "rgb(8,48,107)", "width": 1.5}}}], {"title": "Total number of buglines"}, {"showLink": false, "linkText": "Export to plot.ly"})});</script>
