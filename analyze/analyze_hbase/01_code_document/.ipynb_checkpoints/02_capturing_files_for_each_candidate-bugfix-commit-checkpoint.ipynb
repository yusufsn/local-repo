# %%
import os, glob, json, csv, subprocess, sys, re
from urllib.request import urlopen
from itertools import chain
import urllib.request
from pprint import pprint
from bs4 import BeautifulSoup
from git import *
from subprocess import Popen, PIPE
from os import path
from collections import Counter
import pandas as pd
import plotly.graph_objs as go
import plotly
from plotly.offline import plot, init_notebook_mode, iplot
import itertools

# %matplotlib inline

# %% [markdown]
# # Defining directories

# %%
userhome = os.path.expanduser('~')
repository = userhome + r'/different-diff/dataset/hbase/'
analyze_dir = userhome + r'/different-diff/analyze/analyze_hbase/'

# %% [markdown]
# # Defining git command function

# %%
def execute_command(cmd, work_dir):
    #Executes a shell command in a subprocess, waiting until it has completed.
    pipe = subprocess.Popen(cmd, shell=True, cwd=work_dir, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    (out, error) = pipe.communicate()
    return out, error
    pipe.wait()

# %% [markdown]
# # Loading candidate bug-fix commit id

# %%
col = ['bug_id','candidate_bugfix_commitID']
bf_cid = pd.read_csv(analyze_dir + '02_extracting_commitid/commitid_of_candidatebugfix.csv')
bf_cid = bf_cid[col]
bf_cid
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-21c1ae6ab02d> in <module>()
#       1 col = ['bug_id','bugfix_commitID']
#       2 bf_cid = pd.read_csv(analyze_dir + '02_extracting_commitid/commitid_of_candidatebugfix.csv')
# ----> 3 bf_cid = bf_cid[col]
#       4 bf_cid
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2003             return self.take(indexer, axis=1, convert=True)
#    2004
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1229                 mask = check == -1
#    1230                 if mask.any():
# -> 1231                     raise KeyError('%s not in index' % objarr[mask])
#    1232
#    1233                 return _values_from_object(indexer)
#
# KeyError: "['bugfix_commitID'] not in index"

# %% [markdown]
# # Extracting files in each candidate bugfix_commitID

# %%
len(bf_cid)
# Out:
# 2533

# %% [markdown]
# Extracting the filename in each candidate bug-fix commit id

# %%
file_list = []
for el in range(0,len(bf_cid)):
    sys.stdout.write("\rExtracting bugfix_commitID: {} / {}".format((el+1),len(bf_cid)))
    sys.stdout.flush()
    cmd = "git show --pretty='' --name-only " + bf_cid.iloc[el][1]
    temp = str(execute_command(cmd, repository)).replace("(b'","").split("\\n")[:-1]
    for l, li in enumerate(temp):
        tmp = [bf_cid.iloc[el][0], bf_cid.iloc[el][1], li]
        file_list.append(tmp)
file_list
# Out:
# Extracting bugfix_commitID: 2533 / 2533
# [['HBASE-9971',
#   '8a6291a896',
#   'src/main/java/org/apache/hadoop/hbase/client/HConnectionManager.java'],
#  ['HBASE-9961',
#   '1e7fdb06b2',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/HConstants.java'],
#  ['HBASE-9961',
#   '560f000424',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/HConstants.java'],
#  ['HBASE-9961',
#   'e5946ba799',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/ClusterStatusListener.java'],
#  ['HBASE-9961',
#   'e5946ba799',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/HConstants.java'],
#  ['HBASE-9961',
#   '18e018b3d9',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/ClusterStatusListener.java'],
#  ['HBASE-9961',
#   '18e018b3d9',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/HConstants.java'],
#  ['HBASE-9958',
#   '8a6291a896',
#   'src/main/java/org/apache/hadoop/hbase/client/HConnectionManager.java'],
#  ['HBASE-9958',
#   '4b84160b37',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/HRegionInfo.java'],
#  ['HBASE-9958',
#   '4b84160b37',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/HConnectionManager.java'],
#  ['HBASE-9958',
#   '4b84160b37',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/MetaScanner.java'],
#  ['HBASE-9958',
#   '4b84160b37',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/protobuf/ProtobufUtil.java'],
#  ['HBASE-9958',
#   '4b84160b37',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/TableName.java'],
#  ['HBASE-9958',
#   'c5a3048fec',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/HRegionInfo.java'],
#  ['HBASE-9958',
#   'c5a3048fec',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/HConnectionManager.java'],
#  ['HBASE-9958',
#   'c5a3048fec',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/MetaScanner.java'],
#  ['HBASE-9958',
#   'c5a3048fec',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/protobuf/ProtobufUtil.java'],
#  ['HBASE-9958',
#   'c5a3048fec',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/TableName.java'],
#  ['HBASE-9908',
#   'f224e4721f',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/mapreduce/TestImportTsv.java'],
#  ['HBASE-9908',
#   '16b799dae5',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/mapreduce/TestImportTsv.java'],
#  ['HBASE-9908',
#   '61120fb62c',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/util/CoprocessorClassLoader.java'],
#  ['HBASE-9908',
#   '61120fb62c',
#   'hbase-common/src/test/java/org/apache/hadoop/hbase/HBaseCommonTestingUtility.java'],
#  ['HBASE-9908',
#   '61120fb62c',
#   'hbase-common/src/test/java/org/apache/hadoop/hbase/util/TestCoprocessorClassLoader.java'],
#  ['HBASE-9908',
#   '61120fb62c',
#   'hbase-common/src/test/java/org/apache/hadoop/hbase/util/TestDynamicClassLoader.java'],
#  ['HBASE-9908',
#   '61120fb62c',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/HStore.java'],
#  ['HBASE-9908',
#   '61120fb62c',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/HBaseTestingUtility.java'],
#  ['HBASE-9908',
#   '61120fb62c',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/backup/TestHFileArchiving.java'],
#  ['HBASE-9908',
#   '61120fb62c',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/regionserver/wal/HLogPerformanceEvaluation.java'],
#  ['HBASE-9908',
#   '61120fb62c',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/regionserver/wal/TestDurability.java'],
#  ['HBASE-9908',
#   '61120fb62c',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/security/access/TestAccessController.java'],
#  ['HBASE-9908',
#   '61120fb62c',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/util/TestFSUtils.java'],
#  ['HBASE-9908',
#   'ff78f217fa',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/util/CoprocessorClassLoader.java'],
#  ['HBASE-9908',
#   'ff78f217fa',
#   'hbase-common/src/test/java/org/apache/hadoop/hbase/HBaseCommonTestingUtility.java'],
#  ['HBASE-9908',
#   'ff78f217fa',
#   'hbase-common/src/test/java/org/apache/hadoop/hbase/util/TestCoprocessorClassLoader.java'],
#  ['HBASE-9908',
#   'ff78f217fa',
#   'hbase-common/src/test/java/org/apache/hadoop/hbase/util/TestDynamicClassLoader.java'],
#  ['HBASE-9908',
#   'ff78f217fa',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/HStore.java'],
#  ['HBASE-9908',
#   'ff78f217fa',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/HBaseTestingUtility.java'],
#  ['HBASE-9908',
#   'ff78f217fa',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/backup/TestHFileArchiving.java'],
#  ['HBASE-9908',
#   'ff78f217fa',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/regionserver/wal/HLogPerformanceEvaluation.java'],
#  ['HBASE-9908',
#   'ff78f217fa',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/regionserver/wal/TestDurability.java'],
#  ['HBASE-9908',
#   'ff78f217fa',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/security/access/TestAccessController.java'],
#  ['HBASE-9908',
#   'ff78f217fa',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/util/TestFSUtils.java'],
#  ['HBASE-9893',
#   'c5fc5b993e',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/util/OrderedBytes.java'],
#  ['HBASE-9893',
#   'c5fc5b993e',
#   'hbase-common/src/test/java/org/apache/hadoop/hbase/util/TestOrderedBytes.java'],
#  ['HBASE-9893',
#   'da89846cf7',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/util/OrderedBytes.java'],
#  ['HBASE-9893',
#   'da89846cf7',
#   'hbase-common/src/test/java/org/apache/hadoop/hbase/util/TestOrderedBytes.java'],
#  ['HBASE-9856',
#   '13e9eda3e7',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/HRegion.java'],
#  ['HBASE-9856',
#   '13e9eda3e7',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/wal/WALEditsReplaySink.java'],
#  ['HBASE-985', 'e3659aa246', 'CHANGES.txt'],
#  ['HBASE-985', 'e3659aa246', 'build.xml'],
#  ['HBASE-985', '894c99bdb3', 'CHANGES.txt'],
#  ['HBASE-985', '894c99bdb3', 'build.xml'],
#  ['HBASE-9843',
#   '6dd52d7ed3',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/AsyncProcess.java'],
#  ['HBASE-9843',
#   '6dd52d7ed3',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/HConnectionManager.java'],
#  ['HBASE-9843',
#   '6dd52d7ed3',
#   'hbase-client/src/test/java/org/apache/hadoop/hbase/client/TestAsyncProcess.java'],
#  ['HBASE-9843',
#   '6dd52d7ed3',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/HConstants.java'],
#  ['HBASE-9843',
#   '6dd52d7ed3',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/ClusterStatusPublisher.java'],
#  ['HBASE-9843',
#   '6dd52d7ed3',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/HRegion.java'],
#  ['HBASE-9843',
#   '6dd52d7ed3',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/client/TestHCM.java'],
#  ['HBASE-9843',
#   '53bb2f6be7',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/AsyncProcess.java'],
#  ['HBASE-9843',
#   '53bb2f6be7',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/HConnectionManager.java'],
#  ['HBASE-9843',
#   '53bb2f6be7',
#   'hbase-client/src/test/java/org/apache/hadoop/hbase/client/TestAsyncProcess.java'],
#  ['HBASE-9843',
#   '53bb2f6be7',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/HConstants.java'],
#  ['HBASE-9843',
#   '53bb2f6be7',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/ClusterStatusPublisher.java'],
#  ['HBASE-9843',
#   '53bb2f6be7',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/HRegion.java'],
#  ['HBASE-9843',
#   '53bb2f6be7',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/client/TestHCM.java'],
#  ['HBASE-984', 'f78f944026', 'CHANGES.txt'],
#  ['HBASE-984',
#   'f78f944026',
#   'src/java/org/apache/hadoop/hbase/io/HalfMapFileReader.java'],
#  ['HBASE-984',
#   'f78f944026',
#   'src/java/org/apache/hadoop/hbase/util/InfoServer.java'],
#  ['HBASE-984', '963c1104dd', 'CHANGES.txt'],
#  ['HBASE-984',
#   '963c1104dd',
#   'src/java/org/apache/hadoop/hbase/io/HalfMapFileReader.java'],
#  ['HBASE-984',
#   '963c1104dd',
#   'src/java/org/apache/hadoop/hbase/util/InfoServer.java'],
#  ['HBASE-9786',
#   '230cb08611',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/util/HBaseFsck.java'],
#  ['HBASE-9786',
#   '6d0eade8b6',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/util/HBaseFsck.java'],
#  ['HBASE-977', '5418547132', 'CHANGES.txt'],
#  ['HBASE-977',
#   '5418547132',
#   'src/java/org/apache/hadoop/hbase/HStoreKey.java'],
#  ['HBASE-977',
#   '5418547132',
#   'src/java/org/apache/hadoop/hbase/regionserver/BeforeThisStoreKey.java'],
#  ['HBASE-977',
#   '5418547132',
#   'src/java/org/apache/hadoop/hbase/regionserver/HStore.java'],
#  ['HBASE-977', '1b49c9b6c4', 'CHANGES.txt'],
#  ['HBASE-977',
#   '1b49c9b6c4',
#   'src/java/org/apache/hadoop/hbase/HStoreKey.java'],
#  ['HBASE-977',
#   '1b49c9b6c4',
#   'src/java/org/apache/hadoop/hbase/regionserver/BeforeThisStoreKey.java'],
#  ['HBASE-977',
#   '1b49c9b6c4',
#   'src/java/org/apache/hadoop/hbase/regionserver/HStore.java'],
#  ['HBASE-9747',
#   '201c67a7d8',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/filter/TestFilter.java'],
#  ['HBASE-9747',
#   '3f496372bf',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/filter/TestFilter.java'],
#  ['HBASE-9747',
#   'b4df85d6b0',
#   'src/test/java/org/apache/hadoop/hbase/filter/TestFilter.java'],
#  ['HBASE-9747',
#   'fc15e1ae39',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/filter/PrefixFilter.java'],
#  ['HBASE-9747',
#   'a2a3071256',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/filter/PrefixFilter.java'],
#  ['HBASE-9747',
#   'e7dfc21d4f',
#   'src/main/java/org/apache/hadoop/hbase/filter/PrefixFilter.java'],
#  ['HBASE-9745', '3d37252a32', 'bin/hbase'],
#  ['HBASE-9745', '24f150ebbc', 'bin/hbase'],
#  ['HBASE-9745', '0bd53be747', 'bin/hbase'],
#  ['HBASE-9745', '86033abef2', 'bin/hbase'],
#  ['HBASE-9745', 'd289eecd2f', 'bin/hbase'],
#  ['HBASE-9745', '8aec79e00c', 'bin/hbase'],
#  ['HBASE-9745', 'bcdd3eba60', 'bin/hbase'],
#  ['HBASE-9745', 'ffeb4ab1e3', 'bin/hbase'],
#  ['HBASE-9704',
#   '5ff5311da2',
#   'src/test/java/org/apache/hadoop/hbase/thrift/TestHeaderSendReceive.java'],
#  ['HBASE-9704',
#   'abbf77d9cb',
#   'src/main/java/org/apache/hadoop/hbase/regionserver/wal/HLog.java'],
#  ['HBASE-9704',
#   'bd01833201',
#   'src/main/java/org/apache/hadoop/hbase/HConstants.java'],
#  ['HBASE-9704',
#   'bd01833201',
#   'src/main/java/org/apache/hadoop/hbase/client/TableServers.java'],
#  ['HBASE-9704',
#   'bd01833201',
#   'src/main/java/org/apache/hadoop/hbase/master/HMaster.java'],
#  ['HBASE-9704',
#   'bd01833201',
#   'src/main/java/org/apache/hadoop/hbase/master/RegionManager.java'],
#  ['HBASE-9704',
#   'bd01833201',
#   'src/main/java/org/apache/hadoop/hbase/regionserver/HRegionServer.java'],
#  ['HBASE-9704',
#   'bd01833201',
#   'src/main/java/org/apache/hadoop/hbase/zookeeper/ZooKeeperWrapper.java'],
#  ['HBASE-9704',
#   '2d7c39e50c',
#   'src/main/java/org/apache/hadoop/hbase/client/MetaScanner.java'],
#  ['HBASE-9704',
#   '2d7c39e50c',
#   'src/test/java/org/apache/hadoop/hbase/HBaseTestingUtility.java'],
#  ['HBASE-9704',
#   '2d7c39e50c',
#   'src/test/java/org/apache/hadoop/hbase/util/TestDrainRegionServer.java'],
#  ['HBASE-9704',
#   'a270d1c0a6',
#   'src/main/java/org/apache/hadoop/hbase/client/TableServers.java'],
#  ['HBASE-9704',
#   '045ee401b3',
#   'src/main/java/org/apache/hadoop/hbase/ipc/thrift/ThriftClientCacheWithConnectionPooling.java'],
#  ['HBASE-9704',
#   '045ee401b3',
#   'src/test/java/org/apache/hadoop/hbase/HBaseTestingUtility.java'],
#  ['HBASE-9704',
#   '8f76956cc6',
#   'src/main/java/org/apache/hadoop/hbase/client/TableServers.java'],
#  ['HBASE-9704',
#   '54b2f547c9',
#   'src/main/java/org/apache/hadoop/hbase/client/TableServers.java'],
#  ['HBASE-9704',
#   '84ee3d54d4',
#   'src/main/java/org/apache/hadoop/hbase/client/HBaseAdmin.java'],
#  ['HBASE-9704',
#   '84ee3d54d4',
#   'src/main/java/org/apache/hadoop/hbase/client/TableServers.java'],
#  ['HBASE-9704',
#   '94184eb5f8',
#   'src/main/java/org/apache/hadoop/hbase/client/ClientLocalScanner.java'],
#  ['HBASE-9704',
#   '90c7d0d614',
#   'src/main/java/org/apache/hadoop/hbase/client/ScannerCallable.java'],
#  ['HBASE-9704',
#   'e475dca13d',
#   'src/main/java/org/apache/hadoop/hbase/ipc/thrift/ThriftClientObjectFactory.java'],
#  ['HBASE-9704',
#   'db972590c6',
#   'src/main/java/org/apache/hadoop/hbase/client/TableServers.java'],
#  ['HBASE-9704',
#   'e216445124',
#   'src/test/java/org/apache/hadoop/hbase/thrift/swift/TestSimpleOperations.java'],
#  ['HBASE-9704',
#   'dcfd369293',
#   'src/test/java/org/apache/hadoop/hbase/thrift/swift/TestSimpleOperations.java'],
#  ['HBASE-9704',
#   'ccc03f50f5',
#   'src/main/java/org/apache/hadoop/hbase/client/TableServers.java'],
#  ['HBASE-9704',
#   'ff5a191a7b',
#   'src/test/java/org/apache/hadoop/hbase/io/encoding/TestChangingEncoding.java'],
#  ['HBASE-9704',
#   '3b95287866',
#   'src/test/java/org/apache/hadoop/hbase/regionserver/TestRegionFavoredNodes.java'],
#  ['HBASE-9704',
#   '29a28aa05c',
#   'src/test/java/org/apache/hadoop/hbase/HBaseTestingUtility.java'],
#  ['HBASE-9704',
#   'e6b3951c4d',
#   'src/main/java/org/apache/hadoop/hbase/client/HConnection.java'],
#  ['HBASE-9704',
#   'e6b3951c4d',
#   'src/main/java/org/apache/hadoop/hbase/client/HTable.java'],
#  ['HBASE-9704',
#   'e6b3951c4d',
#   'src/main/java/org/apache/hadoop/hbase/regionserver/HRegionServer.java'],
#  ['HBASE-9704',
#   'e6b3951c4d',
#   'src/test/java/org/apache/hadoop/hbase/client/TestServerConfigFromClient.java'],
#  ['HBASE-9704',
#   '7d38a444b3',
#   'src/main/java/org/apache/hadoop/hbase/client/HTableClientScanner.java'],
#  ['HBASE-9704',
#   '7d38a444b3',
#   'src/main/java/org/apache/hadoop/hbase/regionserver/RegionScanner.java'],
#  ['HBASE-9704',
#   '7d38a444b3',
#   'src/main/java/org/apache/hadoop/hbase/util/Bytes.java'],
#  ['HBASE-9704',
#   '7d38a444b3',
#   'src/test/java/org/apache/hadoop/hbase/client/TestFromClientSide.java'],
#  ['HBASE-9704',
#   '1d351abceb',
#   'src/test/java/org/apache/hadoop/hbase/UnstableTestSuite.java'],
#  ['HBASE-9704',
#   '1d351abceb',
#   'src/test/java/org/apache/hadoop/hbase/client/TestClientLocalScanner.java'],
#  ['HBASE-9704',
#   '920e6f1ea5',
#   'src/main/java/org/apache/hadoop/hbase/ipc/HBaseServer.java'],
#  ['HBASE-9704',
#   '920e6f1ea5',
#   'src/main/java/org/apache/hadoop/hbase/ipc/thrift/ThriftCallStatsReporter.java'],
#  ['HBASE-9704',
#   '920e6f1ea5',
#   'src/test/java/org/apache/hadoop/hbase/client/TestFromClientSide.java'],
#  ['HBASE-9704',
#   '1aa35bf423',
#   'src/test/java/org/apache/hadoop/hbase/UnstableTestSuite.java'],
#  ['HBASE-9704',
#   '1aa35bf423',
#   'src/test/java/org/apache/hadoop/hbase/client/TestFromClientSide.java'],
#  ['HBASE-9698',
#   '230cb08611',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/util/HBaseFsck.java'],
#  ['HBASE-9698',
#   '6d0eade8b6',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/util/HBaseFsck.java'],
#  ['HBASE-9698',
#   '36e4fe8a37',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/util/HBaseFsck.java'],
#  ['HBASE-9698',
#   '36e4fe8a37',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/util/TestHBaseFsck.java'],
#  ['HBASE-9698',
#   '36e4fe8a37',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/util/hbck/TestOfflineMetaRebuildHole.java'],
#  ['HBASE-9698',
#   '36e4fe8a37',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/util/hbck/TestOfflineMetaRebuildOverlap.java'],
#  ['HBASE-9698',
#   'a07ef888e1',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/util/HBaseFsck.java'],
#  ['HBASE-9698',
#   'a07ef888e1',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/util/TestHBaseFsck.java'],
#  ['HBASE-9698',
#   'a07ef888e1',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/util/hbck/TestOfflineMetaRebuildHole.java'],
#  ['HBASE-9698',
#   'a07ef888e1',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/util/hbck/TestOfflineMetaRebuildOverlap.java'],
#  ['HBASE-968', 'ae27a2bc3f', 'CHANGES.txt'],
#  ['HBASE-968', 'ae27a2bc3f', 'src/java/org/apache/hadoop/hbase/io/Cell.java'],
#  ['HBASE-968', 'bf17c35a8f', 'CHANGES.txt'],
#  ['HBASE-968', 'bf17c35a8f', 'src/java/org/apache/hadoop/hbase/io/Cell.java'],
#  ['HBASE-968', 'c18a713726', 'CHANGES.txt'],
#  ['HBASE-968', 'c18a713726', 'src/java/org/apache/hadoop/hbase/io/Cell.java'],
#  ['HBASE-968', 'f609ddabbc', 'CHANGES.txt'],
#  ['HBASE-968', 'f609ddabbc', 'src/java/org/apache/hadoop/hbase/io/Cell.java'],
#  ['HBASE-9639',
#   '91508fd564',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/coprocessor/SecureBulkLoadClient.java'],
#  ['HBASE-9639',
#   '91508fd564',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/mapreduce/LoadIncrementalHFiles.java'],
#  ['HBASE-9639',
#   '00927d1438',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/coprocessor/SecureBulkLoadClient.java'],
#  ['HBASE-9639',
#   '00927d1438',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/mapreduce/LoadIncrementalHFiles.java'],
#  ['HBASE-9534',
#   '9f11a9d6b6',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/HTable.java'],
#  ['HBASE-9534',
#   '5e36c8e6dd',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/HTable.java'],
#  ['HBASE-9534',
#   '5e36c8e6dd',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/client/CoprocessorHConnection.java'],
#  ['HBASE-9534',
#   '5e36c8e6dd',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/coprocessor/CoprocessorHost.java'],
#  ['HBASE-9534',
#   '4793668c1d',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/HTable.java'],
#  ['HBASE-9534',
#   '4793668c1d',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/client/CoprocessorHConnection.java'],
#  ['HBASE-9534',
#   '4793668c1d',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/coprocessor/CoprocessorHost.java'],
#  ['HBASE-9534',
#   '69e56e387d',
#   'src/main/java/org/apache/hadoop/hbase/client/CoprocessorHConnection.java'],
#  ['HBASE-9534',
#   '69e56e387d',
#   'src/main/java/org/apache/hadoop/hbase/client/HTable.java'],
#  ['HBASE-9534',
#   '69e56e387d',
#   'src/main/java/org/apache/hadoop/hbase/coprocessor/CoprocessorHost.java'],
#  ['HBASE-9534',
#   '6bc48464ca',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/HTable.java'],
#  ['HBASE-9534',
#   '6bc48464ca',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/client/CoprocessorHConnection.java'],
#  ['HBASE-9534',
#   '6bc48464ca',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/coprocessor/CoprocessorHost.java'],
#  ['HBASE-9519',
#   '29909882ea',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/io/hfile/HFileReaderV2.java'],
#  ['HBASE-9415', 'de186bdb7b', 'conf/hbase-site.xml'],
#  ['HBASE-9415', 'd0cce3f48d', 'conf/hbase-site.xml'],
#  ['HBASE-9415',
#   'd0cce3f48d',
#   'src/main/java/org/apache/hadoop/hbase/ipc/HBaseServer.java'],
#  ['HBASE-9415',
#   'd50125a745',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/ipc/RpcServer.java'],
#  ['HBASE-930', '029b37eade', 'CHANGES.txt'],
#  ['HBASE-930',
#   '029b37eade',
#   'src/java/org/apache/hadoop/hbase/regionserver/LogRoller.java'],
#  ['HBASE-930', 'c3c1c8ddbc', 'CHANGES.txt'],
#  ['HBASE-930',
#   'c3c1c8ddbc',
#   'src/java/org/apache/hadoop/hbase/regionserver/LogRoller.java'],
#  ['HBASE-930',
#   'a0cffd6f12',
#   'src/java/org/apache/hadoop/hbase/regionserver/HLog.java'],
#  ['HBASE-930',
#   '50ad3e6d12',
#   'src/java/org/apache/hadoop/hbase/regionserver/HLog.java'],
#  ['HBASE-930',
#   '44b55114b4',
#   'src/java/org/apache/hadoop/hbase/regionserver/HLog.java'],
#  ['HBASE-930',
#   'f84bf5c8a1',
#   'src/java/org/apache/hadoop/hbase/regionserver/HLog.java'],
#  ['HBASE-930',
#   'ca07a6f30b',
#   'src/java/org/apache/hadoop/hbase/regionserver/FailedLogCloseException.java'],
#  ['HBASE-930',
#   'ca07a6f30b',
#   'src/java/org/apache/hadoop/hbase/regionserver/HLog.java'],
#  ['HBASE-930',
#   'a1a6b437e0',
#   'src/java/org/apache/hadoop/hbase/regionserver/FailedLogCloseException.java'],
#  ['HBASE-930',
#   'a1a6b437e0',
#   'src/java/org/apache/hadoop/hbase/regionserver/HLog.java'],
#  ['HBASE-930',
#   '1f66d54b5d',
#   'src/java/org/apache/hadoop/hbase/regionserver/FailedLogCloseException.java'],
#  ['HBASE-930',
#   '1f66d54b5d',
#   'src/java/org/apache/hadoop/hbase/regionserver/HLog.java'],
#  ['HBASE-930',
#   '8dcc95d790',
#   'src/java/org/apache/hadoop/hbase/regionserver/FailedLogCloseException.java'],
#  ['HBASE-930', 'f69423a1d9', 'CHANGES.txt'],
#  ['HBASE-930',
#   'f69423a1d9',
#   'src/java/org/apache/hadoop/hbase/regionserver/FailedLogCloseException.java'],
#  ['HBASE-930',
#   'f69423a1d9',
#   'src/java/org/apache/hadoop/hbase/regionserver/Flusher.java'],
#  ['HBASE-930',
#   'f69423a1d9',
#   'src/java/org/apache/hadoop/hbase/regionserver/HLog.java'],
#  ['HBASE-930',
#   'f69423a1d9',
#   'src/java/org/apache/hadoop/hbase/regionserver/LogRoller.java'],
#  ['HBASE-930',
#   'f69423a1d9',
#   'src/java/org/apache/hadoop/hbase/util/FSUtils.java'],
#  ['HBASE-930', '3de18d1763', 'CHANGES.txt'],
#  ['HBASE-930',
#   '3de18d1763',
#   'src/java/org/apache/hadoop/hbase/regionserver/FailedLogCloseException.java'],
#  ['HBASE-930',
#   '3de18d1763',
#   'src/java/org/apache/hadoop/hbase/regionserver/Flusher.java'],
#  ['HBASE-930',
#   '3de18d1763',
#   'src/java/org/apache/hadoop/hbase/regionserver/HLog.java'],
#  ['HBASE-930',
#   '3de18d1763',
#   'src/java/org/apache/hadoop/hbase/regionserver/LogRoller.java'],
#  ['HBASE-930',
#   '3de18d1763',
#   'src/java/org/apache/hadoop/hbase/util/FSUtils.java'],
#  ['HBASE-930', '06d1a00f83', 'CHANGES.txt'],
#  ['HBASE-930',
#   '06d1a00f83',
#   'src/java/org/apache/hadoop/hbase/regionserver/Flusher.java'],
#  ['HBASE-930',
#   '06d1a00f83',
#   'src/java/org/apache/hadoop/hbase/regionserver/HLog.java'],
#  ['HBASE-930',
#   '06d1a00f83',
#   'src/java/org/apache/hadoop/hbase/regionserver/LogRoller.java'],
#  ['HBASE-930',
#   '06d1a00f83',
#   'src/java/org/apache/hadoop/hbase/util/FSUtils.java'],
#  ['HBASE-927', 'cfb9cb2946', 'CHANGES.txt'],
#  ['HBASE-927',
#   'cfb9cb2946',
#   'src/java/org/apache/hadoop/hbase/HServerLoad.java'],
#  ['HBASE-927',
#   'cfb9cb2946',
#   'src/java/org/apache/hadoop/hbase/master/DeleteColumn.java'],
#  ['HBASE-927',
#   'cfb9cb2946',
#   'src/java/org/apache/hadoop/hbase/master/HMaster.java'],
#  ['HBASE-927',
#   'cfb9cb2946',
#   'src/java/org/apache/hadoop/hbase/master/MetaScanner.java'],
#  ['HBASE-927',
#   'cfb9cb2946',
#   'src/java/org/apache/hadoop/hbase/master/ModifyColumn.java'],
#  ['HBASE-927',
#   'cfb9cb2946',
#   'src/java/org/apache/hadoop/hbase/master/NotAllMetaRegionsOnlineException.java'],
#  ['HBASE-927',
#   'cfb9cb2946',
#   'src/java/org/apache/hadoop/hbase/master/ProcessRegionOpen.java'],
#  ['HBASE-927',
#   'cfb9cb2946',
#   'src/java/org/apache/hadoop/hbase/master/ProcessServerShutdown.java'],
#  ['HBASE-927',
#   'cfb9cb2946',
#   'src/java/org/apache/hadoop/hbase/master/RegionManager.java'],
#  ['HBASE-927',
#   'cfb9cb2946',
#   'src/java/org/apache/hadoop/hbase/master/RegionServerOperation.java'],
#  ['HBASE-927',
#   'cfb9cb2946',
#   'src/java/org/apache/hadoop/hbase/master/RetryableMetaOperation.java'],
#  ['HBASE-927',
#   'cfb9cb2946',
#   'src/java/org/apache/hadoop/hbase/master/ServerManager.java'],
#  ['HBASE-927',
#   'cfb9cb2946',
#   'src/java/org/apache/hadoop/hbase/regionserver/HLog.java'],
#  ['HBASE-927', '838b238999', 'CHANGES.txt'],
#  ['HBASE-927',
#   '838b238999',
#   'src/java/org/apache/hadoop/hbase/master/HMaster.java'],
#  ['HBASE-927', '55d0467c75', 'CHANGES.txt'],
#  ['HBASE-927',
#   '55d0467c75',
#   'src/java/org/apache/hadoop/hbase/master/HMaster.java'],
#  ['HBASE-927', '78165487d9', 'CHANGES.txt'],
#  ['HBASE-927',
#   '78165487d9',
#   'src/java/org/apache/hadoop/hbase/HServerLoad.java'],
#  ['HBASE-927',
#   '78165487d9',
#   'src/java/org/apache/hadoop/hbase/master/DeleteColumn.java'],
#  ['HBASE-927',
#   '78165487d9',
#   'src/java/org/apache/hadoop/hbase/master/HMaster.java'],
#  ['HBASE-927',
#   '78165487d9',
#   'src/java/org/apache/hadoop/hbase/master/MetaScanner.java'],
#  ['HBASE-927',
#   '78165487d9',
#   'src/java/org/apache/hadoop/hbase/master/ModifyColumn.java'],
#  ['HBASE-927',
#   '78165487d9',
#   'src/java/org/apache/hadoop/hbase/master/NotAllMetaRegionsOnlineException.java'],
#  ['HBASE-927',
#   '78165487d9',
#   'src/java/org/apache/hadoop/hbase/master/ProcessServerShutdown.java'],
#  ['HBASE-927',
#   '78165487d9',
#   'src/java/org/apache/hadoop/hbase/master/RegionManager.java'],
#  ['HBASE-927',
#   '78165487d9',
#   'src/java/org/apache/hadoop/hbase/master/RegionServerOperation.java'],
#  ['HBASE-927',
#   '78165487d9',
#   'src/java/org/apache/hadoop/hbase/master/RetryableMetaOperation.java'],
#  ['HBASE-927',
#   '78165487d9',
#   'src/java/org/apache/hadoop/hbase/master/ServerManager.java'],
#  ['HBASE-927',
#   '78165487d9',
#   'src/java/org/apache/hadoop/hbase/regionserver/HLog.java'],
#  ['HBASE-927', '9950dd24de', 'CHANGES.txt'],
#  ['HBASE-927',
#   '9950dd24de',
#   'src/java/org/apache/hadoop/hbase/HServerLoad.java'],
#  ['HBASE-927',
#   '9950dd24de',
#   'src/java/org/apache/hadoop/hbase/master/DeleteColumn.java'],
#  ['HBASE-927',
#   '9950dd24de',
#   'src/java/org/apache/hadoop/hbase/master/HMaster.java'],
#  ['HBASE-927',
#   '9950dd24de',
#   'src/java/org/apache/hadoop/hbase/master/MetaScanner.java'],
#  ['HBASE-927',
#   '9950dd24de',
#   'src/java/org/apache/hadoop/hbase/master/ModifyColumn.java'],
#  ['HBASE-927',
#   '9950dd24de',
#   'src/java/org/apache/hadoop/hbase/master/NotAllMetaRegionsOnlineException.java'],
#  ['HBASE-927',
#   '9950dd24de',
#   'src/java/org/apache/hadoop/hbase/master/ProcessServerShutdown.java'],
#  ['HBASE-927',
#   '9950dd24de',
#   'src/java/org/apache/hadoop/hbase/master/RegionManager.java'],
#  ['HBASE-927',
#   '9950dd24de',
#   'src/java/org/apache/hadoop/hbase/master/RegionServerOperation.java'],
#  ['HBASE-927',
#   '9950dd24de',
#   'src/java/org/apache/hadoop/hbase/master/RetryableMetaOperation.java'],
#  ['HBASE-927',
#   '9950dd24de',
#   'src/java/org/apache/hadoop/hbase/master/ServerManager.java'],
#  ['HBASE-927',
#   '9950dd24de',
#   'src/java/org/apache/hadoop/hbase/regionserver/HLog.java'],
#  ['HBASE-927',
#   '69cbc5d27c',
#   'src/java/org/apache/hadoop/hbase/regionserver/HRegionServer.java'],
#  ['HBASE-927',
#   '748842b131',
#   'src/java/org/apache/hadoop/hbase/regionserver/HRegionServer.java'],
#  ['HBASE-927', '400e183da5', 'CHANGES.txt'],
#  ['HBASE-927',
#   '400e183da5',
#   'src/java/org/apache/hadoop/hbase/regionserver/HRegionServer.java'],
#  ['HBASE-927', 'ad707c4f60', 'CHANGES.txt'],
#  ['HBASE-927',
#   'ad707c4f60',
#   'src/java/org/apache/hadoop/hbase/regionserver/HRegionServer.java'],
#  ['HBASE-9238',
#   '0c9f543e1c',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/Mutation.java'],
#  ['HBASE-9232',
#   '7773da0cb4',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/RpcRetryingCaller.java'],
#  ['HBASE-9232',
#   '7773da0cb4',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/ipc/RpcClient.java'],
#  ['HBASE-9232',
#   '7773da0cb4',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/security/access/TablePermission.java'],
#  ['HBASE-9232',
#   '58ee2bbf24',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/RpcRetryingCaller.java'],
#  ['HBASE-9232',
#   '58ee2bbf24',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/ipc/RpcClient.java'],
#  ['HBASE-9232',
#   '58ee2bbf24',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/security/access/TablePermission.java'],
#  ['HBASE-9219',
#   '8a9f332ac0',
#   'src/test/java/org/apache/hadoop/hbase/AbstractMergeTestBase.java'],
#  ['HBASE-9219',
#   '8a9f332ac0',
#   'src/test/java/org/apache/hadoop/hbase/HBaseClusterTestCase.java'],
#  ['HBASE-9205',
#   '48c1e7aff3',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/Increment.java'],
#  ['HBASE-9205',
#   '48c1e7aff3',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/coprocessor/AggregateImplementation.java'],
#  ['HBASE-9205',
#   'f651b6a820',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/Increment.java'],
#  ['HBASE-9164',
#   '4dd82c9b1c',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/Append.java'],
#  ['HBASE-9164',
#   '4dd82c9b1c',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/Delete.java'],
#  ['HBASE-9164',
#   '4dd82c9b1c',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/HTable.java'],
#  ['HBASE-9164',
#   '4dd82c9b1c',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/Increment.java'],
#  ['HBASE-9164',
#   '4dd82c9b1c',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/Mutation.java'],
#  ['HBASE-9164',
#   '4dd82c9b1c',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/Put.java'],
#  ['HBASE-9164',
#   '4dd82c9b1c',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/protobuf/ProtobufUtil.java'],
#  ['HBASE-9164',
#   '4dd82c9b1c',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/CellUtil.java'],
#  ['HBASE-9164',
#   '4dd82c9b1c',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/KeyValue.java'],
#  ['HBASE-9164',
#   '4dd82c9b1c',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/mapreduce/PutCombiner.java'],
#  ['HBASE-9164',
#   '4dd82c9b1c',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/mapreduce/PutSortReducer.java'],
#  ['HBASE-9164',
#   '4dd82c9b1c',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/protobuf/ReplicationProtbufUtil.java'],
#  ['HBASE-9164',
#   '4dd82c9b1c',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/HRegion.java'],
#  ['HBASE-9164',
#   '4dd82c9b1c',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/HStore.java'],
#  ['HBASE-9164',
#   '4dd82c9b1c',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/MemStore.java'],
#  ['HBASE-9164',
#   '4dd82c9b1c',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/MultiRowMutationProcessor.java'],
#  ['HBASE-9164',
#   '4dd82c9b1c',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/Store.java'],
#  ['HBASE-9164',
#   '4dd82c9b1c',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/rest/client/RemoteHTable.java'],
#  ['HBASE-9164',
#   '4dd82c9b1c',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/security/access/AccessController.java'],
#  ['HBASE-9164',
#   '4dd82c9b1c',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/thrift2/ThriftUtilities.java'],
#  ['HBASE-9164',
#   '4dd82c9b1c',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/coprocessor/SimpleRegionObserver.java'],
#  ['HBASE-9164',
#   '4dd82c9b1c',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/coprocessor/TestRegionObserverBypass.java'],
#  ['HBASE-9164',
#   '4dd82c9b1c',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/coprocessor/TestWALObserver.java'],
#  ['HBASE-9164',
#   '4dd82c9b1c',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/protobuf/TestReplicationProtobuf.java'],
#  ['HBASE-9164',
#   '4dd82c9b1c',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/regionserver/TestHRegion.java'],
#  ['HBASE-9164',
#   '4dd82c9b1c',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/regionserver/wal/HLogPerformanceEvaluation.java'],
#  ['HBASE-9164',
#   'd7d0398713',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/Append.java'],
#  ['HBASE-9164',
#   'd7d0398713',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/Delete.java'],
#  ['HBASE-9164',
#   'd7d0398713',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/HTable.java'],
#  ['HBASE-9164',
#   'd7d0398713',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/Increment.java'],
#  ['HBASE-9164',
#   'd7d0398713',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/Mutation.java'],
#  ['HBASE-9164',
#   'd7d0398713',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/Put.java'],
#  ['HBASE-9164',
#   'd7d0398713',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/protobuf/ProtobufUtil.java'],
#  ['HBASE-9164',
#   'd7d0398713',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/CellUtil.java'],
#  ['HBASE-9164',
#   'd7d0398713',
#   'hbase-common/src/main/java/org/apache/hadoop/hbase/KeyValue.java'],
#  ['HBASE-9164',
#   'd7d0398713',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/mapreduce/PutCombiner.java'],
#  ['HBASE-9164',
#   'd7d0398713',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/mapreduce/PutSortReducer.java'],
#  ['HBASE-9164',
#   'd7d0398713',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/protobuf/ReplicationProtbufUtil.java'],
#  ['HBASE-9164',
#   'd7d0398713',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/HRegion.java'],
#  ['HBASE-9164',
#   'd7d0398713',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/HStore.java'],
#  ['HBASE-9164',
#   'd7d0398713',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/MemStore.java'],
#  ['HBASE-9164',
#   'd7d0398713',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/MultiRowMutationProcessor.java'],
#  ['HBASE-9164',
#   'd7d0398713',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/Store.java'],
#  ['HBASE-9164',
#   'd7d0398713',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/rest/client/RemoteHTable.java'],
#  ['HBASE-9164',
#   'd7d0398713',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/security/access/AccessController.java'],
#  ['HBASE-9164',
#   'd7d0398713',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/thrift2/ThriftUtilities.java'],
#  ['HBASE-9164',
#   'd7d0398713',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/coprocessor/SimpleRegionObserver.java'],
#  ['HBASE-9164',
#   'd7d0398713',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/coprocessor/TestRegionObserverBypass.java'],
#  ['HBASE-9164',
#   'd7d0398713',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/coprocessor/TestWALObserver.java'],
#  ['HBASE-9164',
#   'd7d0398713',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/protobuf/TestReplicationProtobuf.java'],
#  ['HBASE-9164',
#   'd7d0398713',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/regionserver/TestHRegion.java'],
#  ['HBASE-9164',
#   'd7d0398713',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/regionserver/wal/HLogPerformanceEvaluation.java'],
#  ['HBASE-9158',
#   '2c80ed63b0',
#   'src/main/java/org/apache/hadoop/hbase/replication/regionserver/ReplicationSink.java'],
#  ['HBASE-9158',
#   '2c80ed63b0',
#   'src/test/java/org/apache/hadoop/hbase/replication/TestMasterReplication.java'],
#  ['HBASE-9158',
#   'e7657c930b',
#   'src/main/java/org/apache/hadoop/hbase/replication/regionserver/ReplicationSink.java'],
#  ['HBASE-9158',
#   'e7657c930b',
#   'src/test/java/org/apache/hadoop/hbase/replication/TestMasterReplication.java'],
#  ['HBASE-9158',
#   'bd3acd05d4',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/replication/regionserver/ReplicationSink.java'],
#  ['HBASE-9158',
#   'bd3acd05d4',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/replication/TestMasterReplication.java'],
#  ['HBASE-9158',
#   '3bc9e2c95c',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/replication/regionserver/ReplicationSink.java'],
#  ['HBASE-9158',
#   '3bc9e2c95c',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/replication/TestMasterReplication.java'],
#  ['HBASE-9151',
#   '87c2b88576',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java'],
#  ['HBASE-9151',
#   '87c2b88576',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/util/HBaseFsck.java'],
#  ['HBASE-9151',
#   '87c2b88576',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/regionserver/TestRSKilledWhenInitializing.java'],
#  ['HBASE-9151',
#   '87c2b88576',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/util/TestHBaseFsck.java'],
#  ['HBASE-9151',
#   '57a307487f',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java'],
#  ['HBASE-9151',
#   '57a307487f',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/util/HBaseFsck.java'],
#  ['HBASE-9151',
#   '57a307487f',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/regionserver/TestRSKilledWhenInitializing.java'],
#  ['HBASE-9151',
#   '57a307487f',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/util/TestHBaseFsck.java'],
#  ['HBASE-9151',
#   '8d7ed731a9',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java'],
#  ['HBASE-9151',
#   '8d7ed731a9',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/util/HBaseFsck.java'],
#  ['HBASE-9151',
#   '8d7ed731a9',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/regionserver/TestRSKilledWhenInitializing.java'],
#  ['HBASE-9151',
#   '8d7ed731a9',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/util/TestHBaseFsck.java'],
#  ['HBASE-9115',
#   'dc795cca20',
#   'src/main/java/org/apache/hadoop/hbase/client/Append.java'],
#  ['HBASE-9115',
#   'dc795cca20',
#   'src/main/java/org/apache/hadoop/hbase/regionserver/HRegion.java'],
#  ['HBASE-9115',
#   'd272cf1727',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/Append.java'],
#  ['HBASE-9115',
#   'd272cf1727',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/HRegion.java'],
#  ['HBASE-9115',
#   '2036dbb763',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/Append.java'],
#  ['HBASE-9115',
#   '2036dbb763',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/HRegion.java'],
#  ['HBASE-9115',
#   'dfb7778d1a',
#   'src/main/java/org/apache/hadoop/hbase/client/Append.java'],
#  ['HBASE-9115',
#   'dfb7778d1a',
#   'src/test/java/org/apache/hadoop/hbase/client/TestFromClientSide.java'],
#  ['HBASE-9115',
#   'b77483f695',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/Append.java'],
#  ['HBASE-9115',
#   'b77483f695',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/client/TestFromClientSide.java'],
#  ['HBASE-9115',
#   '5b89721c1e',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/Append.java'],
#  ['HBASE-9115',
#   '5b89721c1e',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/client/TestFromClientSide.java'],
#  ['HBASE-9114',
#   '9f592ea0b4',
#   'src/main/java/org/apache/hadoop/hbase/master/ThrottledRegionReopener.java'],
#  ['HBASE-9085',
#   'cea837fa8f',
#   'src/test/java/org/apache/hadoop/hbase/DistributedHBaseCluster.java'],
#  ['HBASE-9085',
#   'ee48ceb820',
#   'hbase-it/src/test/java/org/apache/hadoop/hbase/DistributedHBaseCluster.java'],
#  ['HBASE-9085',
#   '08235fca23',
#   'hbase-it/src/test/java/org/apache/hadoop/hbase/DistributedHBaseCluster.java'],
#  ['HBASE-9003',
#   'b2d1b154bb',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/mapreduce/JarFinder.java'],
#  ['HBASE-9003',
#   'b2d1b154bb',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/mapreduce/TableMapReduceUtil.java'],
#  ['HBASE-9003',
#   'b2d1b154bb',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/mapreduce/TestJarFinder.java'],
#  ['HBASE-9003',
#   'a71dd16a70',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/mapreduce/JarFinder.java'],
#  ['HBASE-9003',
#   'a71dd16a70',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/mapreduce/TableMapReduceUtil.java'],
#  ['HBASE-9003',
#   'a71dd16a70',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/mapreduce/TestJarFinder.java'],
#  ['HBASE-9003', 'bf2144fe60', 'dev-support/findbugs-exclude.xml'],
#  ['HBASE-9003', 'bf2144fe60', 'dev-support/test-patch.properties'],
#  ['HBASE-9001',
#   'd06aa724b0',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/HTable.java'],
#  ['HBASE-9001',
#   'd06aa724b0',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java'],
#  ['HBASE-9001',
#   'ff84a7ae16',
#   'hbase-client/src/main/java/org/apache/hadoop/hbase/client/HTable.java'],
#  ['HBASE-9001',
#   'ff84a7ae16',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java'],
#  ['HBASE-9001',
#   '5dc4727113',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/thrift/TestThriftServerCmdLine.java'],
#  ['HBASE-9001',
#   '2fb6b8b7f3',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/thrift/TestThriftServerCmdLine.java'],
#  ['HBASE-8942',
#   'f14f42ec5b',
#   'src/main/java/org/apache/hadoop/hbase/regionserver/Store.java'],
#  ['HBASE-8942',
#   '5f47f7b6a8',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/HStore.java'],
#  ['HBASE-8942',
#   '8d3133aa0f',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/HStore.java'],
#  ['HBASE-8942',
#   'e97a20f8b1',
#   'src/main/java/org/apache/hadoop/hbase/regionserver/Store.java'],
#  ['HBASE-8942',
#   'a30d3f5c23',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/HStore.java'],
#  ['HBASE-8942',
#   'b0c406da07',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/HStore.java'],
#  ['HBASE-8942',
#   '45e7540347',
#   'src/main/java/org/apache/hadoop/hbase/regionserver/Store.java'],
#  ['HBASE-8930',
#   'e15deb5cf1',
#   'src/main/java/org/apache/hadoop/hbase/regionserver/ColumnTracker.java'],
#  ['HBASE-8930',
#   'e15deb5cf1',
#   'src/main/java/org/apache/hadoop/hbase/regionserver/ExplicitColumnTracker.java'],
#  ['HBASE-8930',
#   'e15deb5cf1',
#   'src/main/java/org/apache/hadoop/hbase/regionserver/ScanQueryMatcher.java'],
#  ['HBASE-8930',
#   'e15deb5cf1',
#   'src/main/java/org/apache/hadoop/hbase/regionserver/ScanWildcardColumnTracker.java'],
#  ['HBASE-8930',
#   'e15deb5cf1',
#   'src/test/java/org/apache/hadoop/hbase/filter/TestInvocationRecordFilter.java'],
#  ['HBASE-8930',
#   'e15deb5cf1',
#   'src/test/java/org/apache/hadoop/hbase/regionserver/TestExplicitColumnTracker.java'],
#  ['HBASE-8930',
#   'e15deb5cf1',
#   'src/test/java/org/apache/hadoop/hbase/regionserver/TestScanWildcardColumnTracker.java'],
#  ['HBASE-8930',
#   'df4784be5a',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/ColumnTracker.java'],
#  ['HBASE-8930',
#   'df4784be5a',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/ExplicitColumnTracker.java'],
#  ['HBASE-8930',
#   'df4784be5a',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/ScanQueryMatcher.java'],
#  ['HBASE-8930',
#   'df4784be5a',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/ScanWildcardColumnTracker.java'],
#  ['HBASE-8930',
#   'df4784be5a',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/filter/TestInvocationRecordFilter.java'],
#  ['HBASE-8930',
#   'df4784be5a',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/regionserver/TestExplicitColumnTracker.java'],
#  ['HBASE-8930',
#   'df4784be5a',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/regionserver/TestScanWildcardColumnTracker.java'],
#  ['HBASE-8930',
#   'da4167c42b',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/ColumnTracker.java'],
#  ['HBASE-8930',
#   'da4167c42b',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/ExplicitColumnTracker.java'],
#  ['HBASE-8930',
#   'da4167c42b',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/ScanQueryMatcher.java'],
#  ['HBASE-8930',
#   'da4167c42b',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/ScanWildcardColumnTracker.java'],
#  ['HBASE-8930',
#   'da4167c42b',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/filter/TestInvocationRecordFilter.java'],
#  ['HBASE-8930',
#   'da4167c42b',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/regionserver/TestExplicitColumnTracker.java'],
#  ['HBASE-8930',
#   'da4167c42b',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/regionserver/TestScanWildcardColumnTracker.java'],
#  ['HBASE-8930',
#   '6905ddc2e1',
#   'src/main/java/org/apache/hadoop/hbase/regionserver/ColumnTracker.java'],
#  ['HBASE-8930',
#   '6905ddc2e1',
#   'src/main/java/org/apache/hadoop/hbase/regionserver/ExplicitColumnTracker.java'],
#  ['HBASE-8930',
#   '6905ddc2e1',
#   'src/main/java/org/apache/hadoop/hbase/regionserver/ScanQueryMatcher.java'],
#  ['HBASE-8930',
#   '6905ddc2e1',
#   'src/main/java/org/apache/hadoop/hbase/regionserver/ScanWildcardColumnTracker.java'],
#  ['HBASE-8930',
#   '6905ddc2e1',
#   'src/test/java/org/apache/hadoop/hbase/filter/TestInvocationRecordFilter.java'],
#  ['HBASE-8930',
#   '6905ddc2e1',
#   'src/test/java/org/apache/hadoop/hbase/regionserver/TestExplicitColumnTracker.java'],
#  ['HBASE-8930',
#   '6905ddc2e1',
#   'src/test/java/org/apache/hadoop/hbase/regionserver/TestScanWildcardColumnTracker.java'],
#  ['HBASE-8930',
#   '30eb01f496',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/ColumnTracker.java'],
#  ['HBASE-8930',
#   '30eb01f496',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/ExplicitColumnTracker.java'],
#  ['HBASE-8930',
#   '30eb01f496',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/ScanQueryMatcher.java'],
#  ['HBASE-8930',
#   '30eb01f496',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/ScanWildcardColumnTracker.java'],
#  ['HBASE-8930',
#   '30eb01f496',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/filter/TestInvocationRecordFilter.java'],
#  ['HBASE-8930',
#   '30eb01f496',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/regionserver/TestExplicitColumnTracker.java'],
#  ['HBASE-8930',
#   '30eb01f496',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/regionserver/TestScanWildcardColumnTracker.java'],
#  ['HBASE-8930',
#   '633369205f',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/ColumnTracker.java'],
#  ['HBASE-8930',
#   '633369205f',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/ExplicitColumnTracker.java'],
#  ['HBASE-8930',
#   '633369205f',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/ScanQueryMatcher.java'],
#  ['HBASE-8930',
#   '633369205f',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/ScanWildcardColumnTracker.java'],
#  ['HBASE-8930',
#   '633369205f',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/filter/TestInvocationRecordFilter.java'],
#  ['HBASE-8930',
#   '633369205f',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/regionserver/TestExplicitColumnTracker.java'],
#  ['HBASE-8930',
#   '633369205f',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/regionserver/TestScanWildcardColumnTracker.java'],
#  ['HBASE-8930',
#   '41b9c58f96',
#   'src/main/java/org/apache/hadoop/hbase/regionserver/ColumnTracker.java'],
#  ['HBASE-8930',
#   '41b9c58f96',
#   'src/main/java/org/apache/hadoop/hbase/regionserver/ExplicitColumnTracker.java'],
#  ['HBASE-8930',
#   '41b9c58f96',
#   'src/main/java/org/apache/hadoop/hbase/regionserver/ScanQueryMatcher.java'],
#  ['HBASE-8930',
#   '41b9c58f96',
#   'src/main/java/org/apache/hadoop/hbase/regionserver/ScanWildcardColumnTracker.java'],
#  ['HBASE-8930',
#   '41b9c58f96',
#   'src/test/java/org/apache/hadoop/hbase/filter/TestInvocationRecordFilter.java'],
#  ['HBASE-8930',
#   '41b9c58f96',
#   'src/test/java/org/apache/hadoop/hbase/regionserver/TestExplicitColumnTracker.java'],
#  ['HBASE-8930',
#   '41b9c58f96',
#   'src/test/java/org/apache/hadoop/hbase/regionserver/TestScanWildcardColumnTracker.java'],
#  ['HBASE-8930',
#   '4f05fc60d5',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/ColumnTracker.java'],
#  ['HBASE-8930',
#   '4f05fc60d5',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/ExplicitColumnTracker.java'],
#  ['HBASE-8930',
#   '4f05fc60d5',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/ScanQueryMatcher.java'],
#  ['HBASE-8930',
#   '4f05fc60d5',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/ScanWildcardColumnTracker.java'],
#  ['HBASE-8930',
#   '4f05fc60d5',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/filter/TestInvocationRecordFilter.java'],
#  ['HBASE-8930',
#   '4f05fc60d5',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/regionserver/TestExplicitColumnTracker.java'],
#  ['HBASE-8930',
#   '4f05fc60d5',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/regionserver/TestScanWildcardColumnTracker.java'],
#  ['HBASE-8930',
#   '813f88a482',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/filter/TestInvocationRecordFilter.java'],
#  ['HBASE-8930',
#   'ee1562dace',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/ColumnTracker.java'],
#  ['HBASE-8930',
#   'ee1562dace',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/ExplicitColumnTracker.java'],
#  ['HBASE-8930',
#   'ee1562dace',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/ScanQueryMatcher.java'],
#  ['HBASE-8930',
#   'ee1562dace',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/regionserver/ScanWildcardColumnTracker.java'],
#  ['HBASE-8930',
#   'ee1562dace',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/regionserver/TestExplicitColumnTracker.java'],
#  ['HBASE-8930',
#   'ee1562dace',
#   'hbase-server/src/test/java/org/apache/hadoop/hbase/regionserver/TestScanWildcardColumnTracker.java'],
#  ['HBASE-8919',
#   'd390841912',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/replication/regionserver/Replication.java'],
#  ['HBASE-8919',
#   'd390841912',
#   'hbase-server/src/main/java/org/apache/hadoop/hbase/replication/regionserver/ReplicationSource.java'],
#  ['HBASE-8919',
#   '299b39532b',
# ...
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/io/hfile/TestForceCacheImportantBlocks.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/io/hfile/TestLruBlockCache.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/io/hfile/TestScannerSelectionUsingTTL.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/ipc/TestPerRequestProfiling.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/ipc/TestRPCCompression.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/loadtest/ColumnFamilyProperties.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/loadtest/DataGenerator.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/loadtest/LoadTester.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/loadtest/MultiThreadedAction.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/loadtest/MultiThreadedWriter.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/loadtest/RegionSplitter.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/manual/utils/DataGenerator.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/manual/utils/HBaseUtils.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/manual/utils/HdfsAppender.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/mapreduce/NMapInputFormat.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/mapreduce/TestHFileOutputFormat.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/mapreduce/TestImportTsv.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/mapreduce/TestTableInputFormatNMappersPerRegion.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/master/TestDistributedLogSplitting.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/master/TestMaster.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/master/TestROOTAssignment.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/master/TestRegionPlacement.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/master/TestRegionServerOperationQueue.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/master/TestSplitLogManager.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/master/TestZKBasedCloseRegion.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/master/TestZKBasedReopenRegion.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/monitoring/TestTaskMonitor.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/regionserver/TestBlocksRead.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/regionserver/TestFSErrorsExposed.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/regionserver/TestHRegionCloseRetry.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/regionserver/TestMultiColumnScanner.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/regionserver/TestQOS.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/regionserver/TestQueryMatcher.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/regionserver/TestScannerResets.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/regionserver/TestSplitLogWorker.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/regionserver/TestStoreFileBlockCacheSummary.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/regionserver/TestWideScanner.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/regionserver/metrics/TestRpcMetricWrapper.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/rest/HBaseRESTClusterTestBase.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/rest/TestRowResource.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/rest/TestScannersWithFilters.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/rest/TestTableResource.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/thrift/TestCallQueue.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/thrift/TestHBCpp.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/thrift/TestHeaderSendReceive.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/thrift/TestNativeThriftClient.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/thrift/TestThriftServerLegacy.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/thrift/swift/TestHRegionInterfaceSimpleFunctions.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/thrift/swift/TestMasterToRSUseThrift.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/thrift/swift/TestServeRPCAndThriftConcurrently.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/thrift/swift/TestServerSideException.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/thrift/swift/TestSimpleOperations.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/thrift/swift/TestSimpleRowMutations.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/thrift/swift/TestSimpleScan.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/thrift/swift/TestSwiftSerDe.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/thrift/swift/TestThriftExceptions.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/thrift/swift/TestThriftMultiRSScenario.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/util/HBaseHomePath.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/util/ProcessBasedLocalHBaseCluster.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/util/RestartMetaTest.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/util/TagRunner.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/util/TestByteBloomFilter.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/util/TestBytes.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/util/TestMiniClusterLoadSequential.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/util/TestTag.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/util/TestThreads.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/util/TitanUserInfo.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/util/rpcbench/BenchmarkClient.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/util/rpcbench/BenchmarkFactory.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/util/rpcbench/HBaseRPCBenchmarkTool.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/util/rpcbench/HBaseRPCProtocolComparison.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/util/rpcbench/HadoopRPCBenchmarkClient.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/util/rpcbench/HadoopRPCBenchmarkFactory.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/util/rpcbench/ThriftBenchmarkClient.java'],
#  ['HBASE-8500',
#   'e8b80ba94c',
#   'src/test/java/org/apache/hadoop/hbase/util/rpcbench/ThriftBenchmarkFactory.java'],
#  ['HBASE-8500', 'e8b80ba94c', 'src/test/resources/hbase-site.xml'],
#  ['HBASE-8500', 'd2cfd53dc3', 'bin/rolling_restart_v2'],
#  ['HBASE-8500',
#   'd2cfd53dc3',
#   'src/main/java/org/apache/hadoop/hbase/util/RollingRestart.java'],
#  ['HBASE-8500',
#   '0b6039a650',
#   'src/test/java/org/apache/hadoop/hbase/client/TestBlacklistRegionServer.java'],
#  ['HBASE-8500',
#   '0b6039a650',
#   'src/test/java/org/apache/hadoop/hbase/client/TestHCM.java'],
#  ['HBASE-8500',
#   '98060a04ac',
#   'src/main/java/org/apache/hadoop/hbase/util/RollingRestart.java'],
#  ['HBASE-8500', '1977527c57', 'bin/rolling_restart_v2'],
#  ['HBASE-8500',
#   '1977527c57',
#   'src/main/java/org/apache/hadoop/hbase/util/RollingRestart.java'],
#  ['HBASE-8500', 'c45f2f28f9', 'bin/rolling_restart_v2'],
#  ['HBASE-8500',
#   'c45f2f28f9',
#   'src/main/java/org/apache/hadoop/hbase/util/RollingRestart.java'],
#  ['HBASE-8500', '04bbd5eaf7', 'bin/rolling_restart_v2'],
#  ['HBASE-8500',
#   '04bbd5eaf7',
#   'src/main/java/org/apache/hadoop/hbase/util/RollingRestart.java'],
#  ['HBASE-8500',
#   '68b1e5c512',
#   'src/main/java/org/apache/hadoop/hbase/client/HConnectionManager.java'],
#  ['HBASE-8500',
#   '68b1e5c512',
#   'src/main/java/org/apache/hadoop/hbase/ipc/HMasterInterface.java'],
#  ['HBASE-8500',
#   '68b1e5c512',
#   'src/main/java/org/apache/hadoop/hbase/master/HMaster.java'],
#  ['HBASE-8500',
#   '68b1e5c512',
#   'src/main/java/org/apache/hadoop/hbase/master/RegionManager.java'],
#  ['HBASE-8500',
#   '68b1e5c512',
#   'src/main/java/org/apache/hadoop/hbase/master/ServerManager.java'],
#  ['HBASE-8500',
#   '68b1e5c512',
#   'src/main/java/org/apache/hadoop/hbase/util/RollingRestart.java'],
#  ['HBASE-8500',
#   '68b1e5c512',
#   'src/test/java/org/apache/hadoop/hbase/client/TestHCM.java'],
#  ['HBASE-8467', '415e06f7a1', 'bin/rolling_restart_v2'],
#  ['HBASE-8467',
#   '2e44f61062',
#   'src/main/java/org/apache/hadoop/hbase/ipc/HMasterInterface.java'],
#  ['HBASE-8467',
#   '2e44f61062',
#   'src/main/java/org/apache/hadoop/hbase/master/AssignmentManager.java'],
#  ['HBASE-8467',
#   '2e44f61062',
#   'src/main/java/org/apache/hadoop/hbase/master/HMaster.java'],
#  ['HBASE-8467',
#   '2e44f61062',
#   'src/main/java/org/apache/hadoop/hbase/master/RegionManager.java'],
#  ['HBASE-8467',
#   '2e44f61062',
#   'src/main/java/org/apache/hadoop/hbase/master/ServerLoadMap.java'],
#  ['HBASE-8467',
#   '2e44f61062',
#   'src/main/java/org/apache/hadoop/hbase/master/ServerManager.java'],
#  ['HBASE-8467',
#   '2e44f61062',
#   'src/main/java/org/apache/hadoop/hbase/master/ThrottledRegionReopener.java'],
#  ['HBASE-8467',
#   '2e44f61062',
#   'src/main/java/org/apache/hadoop/hbase/regionserver/HRegionServer.java'],
#  ['HBASE-8467',
#   '2e44f61062',
#   'src/test/java/org/apache/hadoop/hbase/client/TestHCM.java'],
#  ['HBASE-8467',
#   '2e44f61062',
#   'src/test/java/org/apache/hadoop/hbase/master/TestRegionStateOnMasterFailure.java'],
#  ['HBASE-830', '986f364d03', 'CHANGES.txt'],
#  ['HBASE-830', '986f364d03', 'conf/hbase-default.xml'],
#  ['HBASE-830',
#   '986f364d03',
#   'src/java/org/apache/hadoop/hbase/HConstants.java'],
#  ['HBASE-830',
#   '986f364d03',
#   'src/java/org/apache/hadoop/hbase/client/HConnectionManager.java'],
#  ['HBASE-830', '1fb69ec11a', 'CHANGES.txt'],
#  ['HBASE-830', '1fb69ec11a', 'conf/hbase-default.xml'],
#  ['HBASE-830',
#   '1fb69ec11a',
#   'src/java/org/apache/hadoop/hbase/HConstants.java'],
#  ['HBASE-830',
#   '1fb69ec11a',
#   'src/java/org/apache/hadoop/hbase/client/HConnectionManager.java'],
#  ['HBASE-830', '9b62798b11', 'CHANGES.txt'],
#  ['HBASE-830', '9b62798b11', 'conf/hbase-default.xml'],
#  ['HBASE-830',
#   '9b62798b11',
#   'src/java/org/apache/hadoop/hbase/HConstants.java'],
#  ['HBASE-830',
#   '9b62798b11',
#   'src/java/org/apache/hadoop/hbase/client/HConnectionManager.java'],
#  ['HBASE-826', '19c87a375d', 'conf/hbase-default.xml'],
#  ['HBASE-826', 'ec8aeab847', 'conf/hbase-default.xml'],
#  ['HBASE-826', '4dc9c3642c', 'conf/hbase-default.xml'],
#  ['HBASE-826',
#   '681367f310',
#   'src/java/org/apache/hadoop/hbase/regionserver/HStore.java'],
#  ['HBASE-826',
#   '79d463d658',
#   'src/java/org/apache/hadoop/hbase/regionserver/HStore.java'],
#  ['HBASE-826', 'ed648b7327', 'CHANGES.txt'],
#  ['HBASE-826',
#   'ed648b7327',
#   'src/java/org/apache/hadoop/hbase/master/TableDelete.java'],
#  ['HBASE-826',
#   'ed648b7327',
#   'src/java/org/apache/hadoop/hbase/regionserver/HRegion.java'],
#  ['HBASE-826',
#   'ed648b7327',
#   'src/java/org/apache/hadoop/hbase/regionserver/HStore.java'],
#  ['HBASE-826',
#   'ed648b7327',
#   'src/java/org/apache/hadoop/hbase/regionserver/Memcache.java'],
#  ['HBASE-826',
#   'ed648b7327',
#   'src/java/org/apache/hadoop/hbase/rest/Dispatcher.java'],
#  ['HBASE-826',
#   'ed648b7327',
#   'src/java/org/apache/hadoop/hbase/rest/MetaHandler.java'],
#  ['HBASE-826',
#   'ed648b7327',
#   'src/java/org/apache/hadoop/hbase/rest/ScannerHandler.java'],
#  ['HBASE-826',
#   'ed648b7327',
#   'src/java/org/apache/hadoop/hbase/rest/TableHandler.java'],
#  ['HBASE-826',
#   'ed648b7327',
#   'src/java/org/apache/hadoop/hbase/util/MetaUtils.java'],
#  ['HBASE-826', 'd1adcf1629', 'CHANGES.txt'],
#  ['HBASE-826',
#   'd1adcf1629',
#   'src/java/org/apache/hadoop/hbase/master/TableDelete.java'],
#  ['HBASE-826',
#   'd1adcf1629',
#   'src/java/org/apache/hadoop/hbase/regionserver/HRegion.java'],
#  ['HBASE-826',
#   'd1adcf1629',
#   'src/java/org/apache/hadoop/hbase/regionserver/HStore.java'],
#  ['HBASE-826',
#   'd1adcf1629',
#   'src/java/org/apache/hadoop/hbase/regionserver/Memcache.java'],
#  ['HBASE-826',
#   'd1adcf1629',
#   'src/java/org/apache/hadoop/hbase/util/MetaUtils.java'],
#  ['HBASE-826', '7627490bea', 'CHANGES.txt'],
#  ['HBASE-826',
#   '7627490bea',
#   'src/java/org/apache/hadoop/hbase/master/TableDelete.java'],
#  ['HBASE-826',
#   '7627490bea',
#   'src/java/org/apache/hadoop/hbase/regionserver/HRegion.java'],
#  ['HBASE-826',
#   '7627490bea',
#   'src/java/org/apache/hadoop/hbase/regionserver/HStore.java'],
#  ['HBASE-826',
#   '7627490bea',
#   'src/java/org/apache/hadoop/hbase/regionserver/Memcache.java'],
#  ['HBASE-826',
#   '7627490bea',
#   'src/java/org/apache/hadoop/hbase/util/MetaUtils.java'],
#  ['HBASE-8259',
#   'b9c3497b8b',
#   'src/main/java/org/apache/hadoop/hbase/executor/EventHandler.java'],
#  ['HBASE-8259', '8af84cb46d', 'CHANGES.txt'],
#  ['HBASE-8259', '8af84cb46d', 'pom.xml'],
#  ['HBASE-8259',
#   '8af84cb46d',
#   'src/main/java/org/apache/hadoop/hbase/executor/EventHandler.java'],
#  ['HBASE-8259', 'ca669156cf', '0.94.6.1/CHANGES.txt'],
#  ['HBASE-8259', 'ca669156cf', '0.94.6.1/pom.xml'],
#  ['HBASE-8259',
#   'ca669156cf',
#   '0.94.6.1/src/main/java/org/apache/hadoop/hbase/executor/EventHandler.java'],
#  ['HBASE-8259', 'fff96309a6', '0.94.6.1/.arcconfig'],
#  ['HBASE-8259', 'fff96309a6', '0.94.6.1/.gitignore'],
#  ['HBASE-8259', 'fff96309a6', '0.94.6.1/CHANGES.txt'],
#  ['HBASE-8259', 'fff96309a6', '0.94.6.1/LICENSE.txt'],
#  ['HBASE-8259', 'fff96309a6', '0.94.6.1/NOTICE.txt'],
#  ['HBASE-8259', 'fff96309a6', '0.94.6.1/README.txt'],
#  ['HBASE-8259', 'fff96309a6', '0.94.6.1/bin/get-active-master.rb'],
#  ['HBASE-8259', 'fff96309a6', '0.94.6.1/bin/graceful_stop.sh'],
#  ['HBASE-8259', 'fff96309a6', '0.94.6.1/bin/hbase'],
#  ['HBASE-8259', 'fff96309a6', '0.94.6.1/bin/hbase-config.sh'],
#  ['HBASE-8259', 'fff96309a6', '0.94.6.1/bin/hbase-daemon.sh'],
#  ['HBASE-8259', 'fff96309a6', '0.94.6.1/bin/hbase-daemons.sh'],
#  ['HBASE-8259', 'fff96309a6', '0.94.6.1/bin/hbase-jruby'],
#  ['HBASE-8259', 'fff96309a6', '0.94.6.1/bin/hirb.rb'],
#  ['HBASE-8259', 'fff96309a6', '0.94.6.1/bin/local-master-backup.sh'],
#  ['HBASE-8259', 'fff96309a6', '0.94.6.1/bin/local-regionservers.sh'],
#  ['HBASE-8259', 'fff96309a6', '0.94.6.1/bin/master-backup.sh'],
#  ['HBASE-8259', 'fff96309a6', '0.94.6.1/bin/region_mover.rb'],
#  ['HBASE-8259', 'fff96309a6', '0.94.6.1/bin/region_status.rb'],
#  ...]

# %% [markdown]
# Saving into CSV file

# %%
with open(analyze_dir + "02_extracting_commitid/file_in_candidatebugfix_commitid.csv", "w") as csvfile:
    fields = ['bug_id', 'candidate_commitID', 'filename']
    writers = csv.writer(csvfile, delimiter = ",")
    writers.writerow(fields)
    for item in file_list:
        writers.writerow(item)
print("File file_in_candidatebugfix_commitid.csv has been created")
# Out:
# File file_in_candidatebugfix_commitid.csv has been created

# %% [markdown]
# Extracting the number of files in each candidate bug-fix commit id

# %%
file_num = []
for el in range(0,len(bf_cid)):
    sys.stdout.write("\rExtracting bugfix_commitID: {} / {}".format((el+1),len(bf_cid)))
    sys.stdout.flush()
    cmd = "git show --pretty='' --name-only " + bf_cid.iloc[el][1] + " | wc -l"
    temp = str(execute_command(cmd, repository)).replace("(b'","").replace(" ","").split("\\n")[:-1]
    for l, li in enumerate(temp):
        num = [bf_cid.iloc[el][0], bf_cid.iloc[el][1], li]
        file_num.append(num)
file_num
# Out:
# Extracting bugfix_commitID: 2533 / 2533
# [['HBASE-9971', '8a6291a896', '1'],
#  ['HBASE-9961', '1e7fdb06b2', '1'],
#  ['HBASE-9961', '560f000424', '1'],
#  ['HBASE-9961', 'e5946ba799', '2'],
#  ['HBASE-9961', '18e018b3d9', '2'],
#  ['HBASE-9958', '8a6291a896', '1'],
#  ['HBASE-9958', '4b84160b37', '5'],
#  ['HBASE-9958', 'c5a3048fec', '5'],
#  ['HBASE-9908', 'f224e4721f', '1'],
#  ['HBASE-9908', '16b799dae5', '1'],
#  ['HBASE-9908', '61120fb62c', '11'],
#  ['HBASE-9908', 'ff78f217fa', '11'],
#  ['HBASE-9893', 'c5fc5b993e', '2'],
#  ['HBASE-9893', 'da89846cf7', '2'],
#  ['HBASE-9856', '13e9eda3e7', '2'],
#  ['HBASE-985', 'e3659aa246', '2'],
#  ['HBASE-985', '894c99bdb3', '2'],
#  ['HBASE-9843', '6dd52d7ed3', '7'],
#  ['HBASE-9843', '53bb2f6be7', '7'],
#  ['HBASE-984', 'f78f944026', '3'],
#  ['HBASE-984', '963c1104dd', '3'],
#  ['HBASE-9786', '230cb08611', '1'],
#  ['HBASE-9786', '6d0eade8b6', '1'],
#  ['HBASE-977', '5418547132', '4'],
#  ['HBASE-977', '1b49c9b6c4', '4'],
#  ['HBASE-9747', '201c67a7d8', '1'],
#  ['HBASE-9747', '3f496372bf', '1'],
#  ['HBASE-9747', 'b4df85d6b0', '1'],
#  ['HBASE-9747', 'fc15e1ae39', '1'],
#  ['HBASE-9747', 'a2a3071256', '1'],
#  ['HBASE-9747', 'e7dfc21d4f', '1'],
#  ['HBASE-9745', '3d37252a32', '1'],
#  ['HBASE-9745', '24f150ebbc', '1'],
#  ['HBASE-9745', '0bd53be747', '1'],
#  ['HBASE-9745', '86033abef2', '1'],
#  ['HBASE-9745', 'd289eecd2f', '1'],
#  ['HBASE-9745', '8aec79e00c', '1'],
#  ['HBASE-9745', 'bcdd3eba60', '1'],
#  ['HBASE-9745', 'ffeb4ab1e3', '1'],
#  ['HBASE-9704', '5ff5311da2', '1'],
#  ['HBASE-9704', 'abbf77d9cb', '1'],
#  ['HBASE-9704', 'bd01833201', '6'],
#  ['HBASE-9704', '2d7c39e50c', '3'],
#  ['HBASE-9704', 'a270d1c0a6', '1'],
#  ['HBASE-9704', '045ee401b3', '2'],
#  ['HBASE-9704', '8f76956cc6', '1'],
#  ['HBASE-9704', '54b2f547c9', '1'],
#  ['HBASE-9704', '84ee3d54d4', '2'],
#  ['HBASE-9704', '94184eb5f8', '1'],
#  ['HBASE-9704', '90c7d0d614', '1'],
#  ['HBASE-9704', 'e475dca13d', '1'],
#  ['HBASE-9704', 'db972590c6', '1'],
#  ['HBASE-9704', 'e216445124', '1'],
#  ['HBASE-9704', 'dcfd369293', '1'],
#  ['HBASE-9704', 'ccc03f50f5', '1'],
#  ['HBASE-9704', 'ff5a191a7b', '1'],
#  ['HBASE-9704', '3b95287866', '1'],
#  ['HBASE-9704', '29a28aa05c', '1'],
#  ['HBASE-9704', 'e6b3951c4d', '4'],
#  ['HBASE-9704', '7d38a444b3', '4'],
#  ['HBASE-9704', '1d351abceb', '2'],
#  ['HBASE-9704', '920e6f1ea5', '3'],
#  ['HBASE-9704', '1aa35bf423', '2'],
#  ['HBASE-9698', '230cb08611', '1'],
#  ['HBASE-9698', '6d0eade8b6', '1'],
#  ['HBASE-9698', '36e4fe8a37', '4'],
#  ['HBASE-9698', 'a07ef888e1', '4'],
#  ['HBASE-968', 'ae27a2bc3f', '2'],
#  ['HBASE-968', 'bf17c35a8f', '2'],
#  ['HBASE-968', 'c18a713726', '2'],
#  ['HBASE-968', 'f609ddabbc', '2'],
#  ['HBASE-9639', '91508fd564', '2'],
#  ['HBASE-9639', '00927d1438', '2'],
#  ['HBASE-9534', '9f11a9d6b6', '1'],
#  ['HBASE-9534', '5e36c8e6dd', '3'],
#  ['HBASE-9534', '4793668c1d', '3'],
#  ['HBASE-9534', '69e56e387d', '3'],
#  ['HBASE-9534', '6bc48464ca', '3'],
#  ['HBASE-9519', '29909882ea', '1'],
#  ['HBASE-9415', 'de186bdb7b', '1'],
#  ['HBASE-9415', 'd0cce3f48d', '2'],
#  ['HBASE-9415', 'd50125a745', '1'],
#  ['HBASE-930', '029b37eade', '2'],
#  ['HBASE-930', 'c3c1c8ddbc', '2'],
#  ['HBASE-930', 'a0cffd6f12', '1'],
#  ['HBASE-930', '50ad3e6d12', '1'],
#  ['HBASE-930', '44b55114b4', '1'],
#  ['HBASE-930', 'f84bf5c8a1', '1'],
#  ['HBASE-930', 'ca07a6f30b', '2'],
#  ['HBASE-930', 'a1a6b437e0', '2'],
#  ['HBASE-930', '1f66d54b5d', '2'],
#  ['HBASE-930', '8dcc95d790', '1'],
#  ['HBASE-930', 'f69423a1d9', '6'],
#  ['HBASE-930', '3de18d1763', '6'],
#  ['HBASE-930', '06d1a00f83', '5'],
#  ['HBASE-927', 'cfb9cb2946', '14'],
#  ['HBASE-927', '838b238999', '2'],
#  ['HBASE-927', '55d0467c75', '2'],
#  ['HBASE-927', '78165487d9', '13'],
#  ['HBASE-927', '9950dd24de', '13'],
#  ['HBASE-927', '69cbc5d27c', '1'],
#  ['HBASE-927', '748842b131', '1'],
#  ['HBASE-927', '400e183da5', '2'],
#  ['HBASE-927', 'ad707c4f60', '2'],
#  ['HBASE-9238', '0c9f543e1c', '1'],
#  ['HBASE-9232', '7773da0cb4', '3'],
#  ['HBASE-9232', '58ee2bbf24', '3'],
#  ['HBASE-9219', '8a9f332ac0', '2'],
#  ['HBASE-9205', '48c1e7aff3', '2'],
#  ['HBASE-9205', 'f651b6a820', '1'],
#  ['HBASE-9164', '4dd82c9b1c', '26'],
#  ['HBASE-9164', 'd7d0398713', '26'],
#  ['HBASE-9158', '2c80ed63b0', '2'],
#  ['HBASE-9158', 'e7657c930b', '2'],
#  ['HBASE-9158', 'bd3acd05d4', '2'],
#  ['HBASE-9158', '3bc9e2c95c', '2'],
#  ['HBASE-9151', '87c2b88576', '4'],
#  ['HBASE-9151', '57a307487f', '4'],
#  ['HBASE-9151', '8d7ed731a9', '4'],
#  ['HBASE-9115', 'dc795cca20', '2'],
#  ['HBASE-9115', 'd272cf1727', '2'],
#  ['HBASE-9115', '2036dbb763', '2'],
#  ['HBASE-9115', 'dfb7778d1a', '2'],
#  ['HBASE-9115', 'b77483f695', '2'],
#  ['HBASE-9115', '5b89721c1e', '2'],
#  ['HBASE-9114', '9f592ea0b4', '1'],
#  ['HBASE-9085', 'cea837fa8f', '1'],
#  ['HBASE-9085', 'ee48ceb820', '1'],
#  ['HBASE-9085', '08235fca23', '1'],
#  ['HBASE-9003', 'b2d1b154bb', '3'],
#  ['HBASE-9003', 'a71dd16a70', '3'],
#  ['HBASE-9003', 'bf2144fe60', '2'],
#  ['HBASE-9001', 'd06aa724b0', '2'],
#  ['HBASE-9001', 'ff84a7ae16', '2'],
#  ['HBASE-9001', '5dc4727113', '1'],
#  ['HBASE-9001', '2fb6b8b7f3', '1'],
#  ['HBASE-8942', 'f14f42ec5b', '1'],
#  ['HBASE-8942', '5f47f7b6a8', '1'],
#  ['HBASE-8942', '8d3133aa0f', '1'],
#  ['HBASE-8942', 'e97a20f8b1', '1'],
#  ['HBASE-8942', 'a30d3f5c23', '1'],
#  ['HBASE-8942', 'b0c406da07', '1'],
#  ['HBASE-8942', '45e7540347', '1'],
#  ['HBASE-8930', 'e15deb5cf1', '7'],
#  ['HBASE-8930', 'df4784be5a', '7'],
#  ['HBASE-8930', 'da4167c42b', '7'],
#  ['HBASE-8930', '6905ddc2e1', '7'],
#  ['HBASE-8930', '30eb01f496', '7'],
#  ['HBASE-8930', '633369205f', '7'],
#  ['HBASE-8930', '41b9c58f96', '7'],
#  ['HBASE-8930', '4f05fc60d5', '7'],
#  ['HBASE-8930', '813f88a482', '1'],
#  ['HBASE-8930', 'ee1562dace', '6'],
#  ['HBASE-8919', 'd390841912', '2'],
#  ['HBASE-8919', '299b39532b', '2'],
#  ['HBASE-8917', 'da3e3046ad', '3'],
#  ['HBASE-8856', '6c43cd988b', '1'],
#  ['HBASE-8856', 'afca885131', '1'],
#  ['HBASE-881', '428e685b75', '2'],
#  ['HBASE-881', '16a2c45780', '2'],
#  ['HBASE-881', '87102ae59b', '2'],
#  ['HBASE-8798', '9ccf16db51', '2'],
#  ['HBASE-8706', 'bcf89528dc', '9'],
#  ['HBASE-8706', '8bb177d37f', '9'],
#  ['HBASE-8706', '9763240f35', '9'],
#  ['HBASE-8706', 'ba8801c2ff', '9'],
#  ['HBASE-8664', 'ed65f9bb6e', '3'],
#  ['HBASE-8664', 'd6becac229', '3'],
#  ['HBASE-8627', 'f73a68178f', '2'],
#  ['HBASE-8627', '2581ebb0b2', '2'],
#  ['HBASE-8615', 'dc716a9005', '1'],
#  ['HBASE-8615', '4ec30df08f', '1'],
#  ['HBASE-8615', '8bdcbb67ff', '2'],
#  ['HBASE-8615', '1236068fd0', '2'],
#  ['HBASE-8532', '2eec2f340a', '8'],
#  ['HBASE-8532', '93fab309db', '8'],
#  ['HBASE-8521', 'f2d10f4e9e', '1'],
#  ['HBASE-8521', '49de0f9133', '13'],
#  ['HBASE-8519', '20c4b8a685', '3'],
#  ['HBASE-8519', 'ad6292f86e', '3'],
#  ['HBASE-8519', 'bc4992c0f8', '3'],
#  ['HBASE-8519', 'f729fcd4ec', '3'],
#  ['HBASE-8500', 'b0a03df607', '1'],
#  ['HBASE-8500', '0744c27fc8', '2'],
#  ['HBASE-8500', 'e8b80ba94c', '347'],
#  ['HBASE-8500', 'd2cfd53dc3', '2'],
#  ['HBASE-8500', '0b6039a650', '2'],
#  ['HBASE-8500', '98060a04ac', '1'],
#  ['HBASE-8500', '1977527c57', '2'],
#  ['HBASE-8500', 'c45f2f28f9', '2'],
#  ['HBASE-8500', '04bbd5eaf7', '2'],
#  ['HBASE-8500', '68b1e5c512', '7'],
#  ['HBASE-8467', '415e06f7a1', '1'],
#  ['HBASE-8467', '2e44f61062', '10'],
#  ['HBASE-830', '986f364d03', '4'],
#  ['HBASE-830', '1fb69ec11a', '4'],
#  ['HBASE-830', '9b62798b11', '4'],
#  ['HBASE-826', '19c87a375d', '1'],
#  ['HBASE-826', 'ec8aeab847', '1'],
#  ['HBASE-826', '4dc9c3642c', '1'],
#  ['HBASE-826', '681367f310', '1'],
#  ['HBASE-826', '79d463d658', '1'],
#  ['HBASE-826', 'ed648b7327', '10'],
#  ['HBASE-826', 'd1adcf1629', '6'],
#  ['HBASE-826', '7627490bea', '6'],
#  ['HBASE-8259', 'b9c3497b8b', '1'],
#  ['HBASE-8259', '8af84cb46d', '3'],
#  ['HBASE-8259', 'ca669156cf', '3'],
#  ['HBASE-8259', 'a34f3a364f', '0'],
#  ['HBASE-8259', 'fff96309a6', '1492'],
#  ['HBASE-8259', '0c47666dee', '1'],
#  ['HBASE-8225', 'a79a77aa02', '1'],
#  ['HBASE-8225', 'a96672bec6', '1'],
#  ['HBASE-8225', '0bc9187d46', '1'],
#  ['HBASE-8223', '6605c597bd', '1'],
#  ['HBASE-8216', '635949147f', '1'],
#  ['HBASE-8207', '9e02c52762', '4'],
#  ['HBASE-8207', '92d5967a86', '5'],
#  ['HBASE-8207', '7e26d32349', '2'],
#  ['HBASE-8207', 'ac97504dc5', '2'],
#  ['HBASE-8207', '6930ff607f', '1'],
#  ['HBASE-8207', 'aa851e3b7a', '1'],
#  ['HBASE-8207', 'c5a16ef24c', '1'],
#  ['HBASE-8207', '542b8dcc1f', '4'],
#  ['HBASE-8207', '9087f50a5f', '3'],
#  ['HBASE-8207', '1babc2abbc', '3'],
#  ['HBASE-8206', '38fc69c10c', '2'],
#  ['HBASE-8125', '8e664d8133', '1'],
#  ['HBASE-8125', '2c684ee552', '1'],
#  ['HBASE-8119', '089e876398', '1'],
#  ['HBASE-8119', '77904ce78a', '6'],
#  ['HBASE-8119', 'e21a1ee4ae', '6'],
#  ['HBASE-8111', '9e270796d1', '1'],
#  ['HBASE-811', '0696c139f5', '3'],
#  ['HBASE-811', 'a5a72605cf', '3'],
#  ['HBASE-811', 'dbba69fce5', '3'],
#  ['HBASE-811', 'ca41de9b1b', '4'],
#  ['HBASE-811', '0c3bd478b3', '4'],
#  ['HBASE-811', 'b55027819e', '4'],
#  ['HBASE-8085', 'd004827b82', '4'],
#  ['HBASE-8085', '7465b3d076', '4'],
#  ['HBASE-808', '4456a8f5cf', '1'],
#  ['HBASE-808', 'aabc02c44b', '1'],
#  ['HBASE-808', '4c2a6f66f1', '1'],
#  ['HBASE-808', 'fba07d1808', '6'],
#  ['HBASE-808', '78b53558b8', '5'],
#  ['HBASE-808', 'f85e23cb43', '5'],
#  ['HBASE-8067', '50256d7035', '1'],
#  ['HBASE-8067', '39e7e66ae9', '1'],
#  ['HBASE-8067', '448f2f7902', '1'],
#  ['HBASE-8067', '986c9fbed6', '2'],
#  ['HBASE-8067', '9230c45c7e', '1'],
#  ['HBASE-8067', '770219fccc', '1'],
#  ['HBASE-8067', '302ce0325b', '1'],
#  ['HBASE-8067', '90eaac74d5', '2'],
#  ['HBASE-8067', '95e4f53090', '2'],
#  ['HBASE-8062', '24736e83bb', '1'],
#  ['HBASE-8062', '7181fa35a3', '1'],
#  ['HBASE-8058', 'ddb06ad449', '1'],
#  ['HBASE-8058', '3564568830', '1'],
#  ['HBASE-8050', '579c4eb3b2', '1'],
#  ['HBASE-8044', '41e2c36c82', '1'],
#  ['HBASE-8044', '486b290863', '1'],
#  ['HBASE-8044', '831e3dc59a', '1'],
#  ['HBASE-8044', '16c7c1e769', '1'],
#  ['HBASE-7966', '3a1b53f2fc', '1'],
#  ['HBASE-7966', 'fd45b6fe06', '1'],
#  ['HBASE-7966', '70b1899e88', '2'],
#  ['HBASE-7966', '6f3af86452', '2'],
#  ['HBASE-7966', 'ca1a0ea654', '1'],
#  ['HBASE-7966', '27dd86e0a0', '1'],
#  ['HBASE-7953', '30f12477b2', '1'],
#  ['HBASE-7953', 'cf328edb97', '1'],
#  ['HBASE-7953', 'f7d02a07d8', '1'],
#  ['HBASE-7953', '4742310a5f', '1'],
#  ['HBASE-7920', 'ad99387bfe', '1'],
#  ['HBASE-7920', '66512747bf', '6'],
#  ['HBASE-7920', '3c44b28c94', '1'],
#  ['HBASE-7920', '99a9328680', '6'],
#  ['HBASE-792', '92bd62bf58', '1'],
#  ['HBASE-792', 'e2a146d694', '1'],
#  ['HBASE-792', 'b3bdd512f3', '5'],
#  ['HBASE-792', '9f00684d05', '5'],
#  ['HBASE-7914', '2cccddf35d', '2'],
#  ['HBASE-7914', '195e23fe01', '2'],
#  ['HBASE-790', '942c54cf56', '3'],
#  ['HBASE-790', '0d8ab3cad8', '3'],
#  ['HBASE-790', '165e2ed915', '1'],
#  ['HBASE-790', 'a9aef2181d', '1'],
#  ['HBASE-790', 'b3bdd512f3', '5'],
#  ['HBASE-790', '9f00684d05', '5'],
#  ['HBASE-7878', 'c565b2f13a', '3'],
#  ['HBASE-7878', '1aa9c548fc', '2'],
#  ['HBASE-7878', 'c5d6b90eb8', '4'],
#  ['HBASE-7878', '57a4c03bbb', '4'],
#  ['HBASE-7878', 'ed9a0a5091', '4'],
#  ['HBASE-7878', '030628c553', '2'],
#  ['HBASE-7878', 'b3647fec74', '1'],
#  ['HBASE-7878', '3b4b9b3c7a', '1'],
#  ['HBASE-7878', '7850fda086', '2'],
#  ['HBASE-7878', '17c662c46c', '1'],
#  ['HBASE-7878', '28cfad9739', '1'],
#  ['HBASE-7878', '31c1c9e7e6', '4'],
#  ['HBASE-7878', '708669b53f', '4'],
#  ['HBASE-7878', 'e253150cf3', '4'],
#  ['HBASE-7878', '6722e26df1', '4'],
#  ['HBASE-7878', 'dc470e0be7', '2'],
#  ['HBASE-7878', 'bfbc70a68a', '2'],
#  ['HBASE-7878', '46db70556e', '2'],
#  ['HBASE-7878', '21eda243ad', '1'],
#  ['HBASE-7878', '33f7a4d7ff', '1'],
#  ['HBASE-7878', '50a47a9023', '1'],
#  ['HBASE-7878', '539ff195e8', '1'],
#  ['HBASE-7878', '3b923a92c5', '2'],
#  ['HBASE-7878', '41208aa44f', '2'],
#  ['HBASE-7878', '2e2d95af14', '2'],
#  ['HBASE-7852', '2f1579e92e', '1'],
#  ['HBASE-7852', '1bafc48511', '1'],
#  ['HBASE-7817', '77df789608', '3'],
#  ['HBASE-7817', 'ff3ae92d1f', '3'],
#  ['HBASE-7817', '5ca140fe2f', '3'],
#  ['HBASE-7725', '5068650101', '10'],
#  ['HBASE-7725', '43edd93495', '10'],
#  ['HBASE-7725', 'f66bbf1ca4', '3'],
#  ['HBASE-7725', '1a766c42a1', '12'],
#  ['HBASE-7682', 'a3f0aea354', '1'],
#  ['HBASE-7669', '479232c610', '1'],
#  ['HBASE-7669', 'e9f14f1073', '1'],
#  ['HBASE-7669', '4d7b2824be', '1'],
#  ['HBASE-7669', '898f661663', '1'],
#  ['HBASE-7601', 'b96d60d659', '8'],
#  ['HBASE-7595', '28b79e1214', '1'],
#  ['HBASE-7588', 'f60b8246e7', '1'],
#  ['HBASE-7588', 'c3e140cd14', '1'],
#  ['HBASE-7588', '3b345cd684', '1'],
#  ['HBASE-7587', '152ec1cc7f', '1'],
#  ['HBASE-7587', '05934d7405', '1'],
#  ['HBASE-7587', 'bda467aeca', '1'],
#  ['HBASE-7586', '5c8c3d0a8c', '2'],
#  ['HBASE-7521', '837f89bd79', '2'],
#  ['HBASE-7521', 'efead793d4', '12'],
#  ['HBASE-7521', '6ab7671f08', '2'],
#  ['HBASE-7521', '883ec67336', '12'],
#  ['HBASE-7517', '24e4df74ea', '2'],
#  ['HBASE-7517', '69cbc81e5c', '6'],
#  ['HBASE-7517', '8eee0f17ba', '1'],
#  ['HBASE-7517', '233dc24e3d', '1'],
#  ['HBASE-7508', '4e0af48fe4', '20'],
#  ['HBASE-7491', 'c739366d73', '2'],
#  ['HBASE-7443', '4409ba741c', '1'],
#  ['HBASE-7443', '92c98a76d1', '17'],
#  ['HBASE-7435', '9ead77761f', '1'],
#  ['HBASE-7435', '8e664d8133', '1'],
#  ['HBASE-7435', '2c684ee552', '1'],
#  ['HBASE-7435', '5640731663', '1'],
#  ['HBASE-7435', 'f356d580c5', '1'],
#  ['HBASE-7417', 'b8784b73e5', '2'],
#  ['HBASE-7417', '65d764e979', '1'],
#  ['HBASE-7417', '85d9f6b709', '2'],
#  ['HBASE-7390', 'deeb84ae5a', '12'],
#  ['HBASE-7275', '289ab6b87c', '2'],
#  ['HBASE-7198', '3b980dda5c', '2'],
#  ['HBASE-7083', '75682c0c5b', '1'],
#  ['HBASE-7002', 'f065232db0', '4'],
#  ['HBASE-6991', 'd004827b82', '4'],
#  ['HBASE-6991', '7465b3d076', '4'],
#  ['HBASE-6991', '9b3e63dcb7', '4'],
#  ['HBASE-697', '1371c33e8d', '2'],
#  ['HBASE-697', 'e522b64665', '2'],
#  ['HBASE-697', '0023b81e82', '3'],
#  ['HBASE-697', 'fddd62e6c5', '2'],
#  ['HBASE-697', '83c1c30938', '2'],
#  ['HBASE-697', 'e30ed932bb', '17'],
#  ['HBASE-697', 'c65c58905b', '17'],
#  ['HBASE-697', 'f346a3d85a', '18'],
#  ['HBASE-6943', '0750adf8a2', '2'],
#  ['HBASE-6928', '610ea30534', '1'],
#  ['HBASE-6928', 'e64430e970', '1'],
#  ['HBASE-6920', '12315b8597', '3'],
#  ['HBASE-6920', 'ce9703aa4f', '6'],
#  ['HBASE-6920', '7bfd09e973', '6'],
#  ['HBASE-6920', 'a0344c193f', '1'],
#  ['HBASE-6920', 'bb54590ab5', '1'],
#  ['HBASE-6920', '11496b6f72', '6'],
#  ['HBASE-6920', '205c9b83ac', '6'],
#  ['HBASE-6918', 'd6cca23ed3', '1'],
#  ['HBASE-6871', '2f850f964a', '1'],
#  ['HBASE-6871', '6abd8dec5e', '1'],
#  ['HBASE-6871', 'dd2015d6ad', '2'],
#  ['HBASE-6871', '061a2457b1', '2'],
#  ['HBASE-6871', '9d470279dd', '2'],
#  ['HBASE-6871', '267b941c4c', '2'],
#  ['HBASE-6871', 'e496b61aa1', '1'],
#  ['HBASE-6871', '215d216275', '1'],
#  ['HBASE-6871', 'a4fbfcf640', '1'],
#  ['HBASE-6871', '473dcddb55', '2'],
#  ['HBASE-6871', '79e79ef090', '2'],
#  ['HBASE-6871', 'd02e466bc2', '2'],
#  ['HBASE-6871', 'c0b38e6c57', '2'],
#  ['HBASE-6871', '15e07e8548', '2'],
#  ['HBASE-6858', 'bb563c3603', '1'],
#  ['HBASE-6858', '3a0b571d7b', '1'],
#  ['HBASE-6858', 'e30829d8c1', '1'],
#  ['HBASE-6858', '9712f25f8f', '1'],
#  ['HBASE-6858', '9526aeb2a8', '1'],
#  ['HBASE-6858', '9b789a9d67', '1'],
#  ['HBASE-6858', '6bee1177a2', '1'],
#  ['HBASE-6858', '529807b0e5', '1'],
#  ['HBASE-6846', 'd487401613', '2'],
#  ['HBASE-6846', '3ab7fe3e6e', '2'],
#  ['HBASE-6846', 'f4923b98a6', '2'],
#  ['HBASE-6838', '4ca039e4e3', '1'],
#  ['HBASE-6838', '17a2e1663a', '1'],
#  ['HBASE-681', '80fa33698f', '11'],
#  ['HBASE-681', 'f02a98da07', '11'],
#  ['HBASE-681', '767d2765b5', '2'],
#  ['HBASE-6748', '2cccddf35d', '2'],
#  ['HBASE-6748', '195e23fe01', '2'],
#  ['HBASE-6748', '10c1bceda4', '2'],
#  ['HBASE-6741', '72aba5f19e', '2'],
#  ['HBASE-6741', 'dbcad94d43', '6'],
#  ['HBASE-6728', 'db380918a4', '1'],
#  ['HBASE-6728', '5754b24e57', '5'],
#  ['HBASE-6728', '770605db8c', '5'],
#  ['HBASE-6728', '1a32bfed45', '5'],
#  ['HBASE-6728', '1048d15c6a', '5'],
#  ['HBASE-6728', '649126bdc5', '5'],
#  ['HBASE-6710', '4c7a465b00', '7'],
#  ['HBASE-6710', '58f3f30cb3', '7'],
#  ['HBASE-6710', '802f264f4e', '5'],
#  ['HBASE-6710', 'baa5d4675a', '9'],
#  ['HBASE-6710', '6c4e39dcae', '9'],
#  ['HBASE-6697', '55fb6632b9', '2'],
#  ['HBASE-6619', '6f8104a966', '1'],
#  ['HBASE-6590', '564fc2e7c3', '16'],
#  ['HBASE-6590', '1673fee154', '1'],
#  ['HBASE-6590', 'dec419003a', '10'],
#  ['HBASE-6583', '4606107e1d', '1'],
#  ['HBASE-6583', '510cb9f71d', '1'],
#  ['HBASE-6583', '7e02b67d30', '1'],
#  ['HBASE-6583', '3e2399a7b1', '1'],
#  ['HBASE-656', 'f328681e00', '13'],
#  ['HBASE-656', 'c7165b1e30', '13'],
#  ['HBASE-649', 'f328681e00', '13'],
#  ['HBASE-649', 'c7165b1e30', '13'],
#  ['HBASE-6460', '7c16621e1b', '1'],
#  ['HBASE-6460', '78b3ca68c1', '1'],
#  ['HBASE-6460', '936caf1b39', '1'],
#  ['HBASE-6460', '9734a67ab4', '2'],
#  ['HBASE-6460', '4d726189eb', '2'],
#  ['HBASE-6421', 'd90f009688', '2'],
#  ['HBASE-6389', '505bfe4363', '4'],
#  ['HBASE-6389', '8738056386', '4'],
#  ['HBASE-6389', '6f6f425a31', '6'],
#  ['HBASE-6389', 'c6038306f5', '3'],
#  ['HBASE-6389', '983d08709e', '3'],
#  ['HBASE-6389', '5586daa4de', '3'],
#  ['HBASE-6389', 'd9a7c8cd60', '3'],
#  ['HBASE-6389', 'e0d9503dd7', '3'],
#  ['HBASE-6389', '3a68756704', '3'],
#  ['HBASE-6388', '27c67b8577', '1'],
#  ['HBASE-6388', 'f5b5e66da1', '1'],
#  ['HBASE-6377', '528d95d964', '2'],
#  ['HBASE-6377', 'c3fcaa3560', '2'],
#  ['HBASE-6377', '349c82e0a0', '2'],
#  ['HBASE-6368', '07eb671bc9', '1'],
#  ['HBASE-6368', 'd6ed913ce5', '1'],
#  ['HBASE-6340', '8767127966', '5'],
#  ['HBASE-6340', '7538a94704', '5'],
#  ['HBASE-6340', '3fadfe5958', '4'],
#  ['HBASE-6340', '124d48e61a', '4'],
#  ['HBASE-6340', '23f61b37bb', '1'],
#  ['HBASE-6340', 'a7dde5bb90', '1'],
#  ['HBASE-6340', '4ae9102b28', '3'],
#  ['HBASE-6340', '6be9826a22', '3'],
#  ['HBASE-6284', '003df0419f', '3'],
#  ['HBASE-6284', 'c2afb45db9', '3'],
#  ['HBASE-6284', '2bd71320b2', '1'],
#  ['HBASE-6284', '6505939970', '5'],
#  ['HBASE-6276', 'f4165e27ce', '1'],
#  ['HBASE-6276', 'aae0227054', '1'],
#  ['HBASE-6276', 'a39d417edd', '1'],
#  ['HBASE-6276', '5a676a601e', '1'],
#  ['HBASE-6276', 'c80b254756', '1'],
#  ['HBASE-6200', '62f038308e', '3'],
#  ['HBASE-6200', 'd97099951a', '3'],
#  ['HBASE-6200', '98b05fce1f', '2'],
#  ['HBASE-6200', 'bf3697d750', '2'],
#  ['HBASE-6200', '275bfdcc40', '2'],
#  ['HBASE-6164', 'f727c0d5ec', '7'],
#  ['HBASE-6164', '0c0e5af110', '7'],
#  ['HBASE-6138', '181d2ea889', '1'],
#  ['HBASE-6138', '62154f1a1a', '1'],
#  ['HBASE-613', 'ae97400be0', '3'],
#  ['HBASE-613', '769b0e5c8c', '3'],
#  ['HBASE-613', '193deb330d', '2'],
#  ['HBASE-613', '80fa33698f', '11'],
#  ['HBASE-613', 'f02a98da07', '11'],
#  ['HBASE-613', '4dbb084860', '3'],
#  ['HBASE-6123', '901c3a31ce', '1'],
#  ['HBASE-6121', 'f69428067b', '1'],
#  ['HBASE-6112', '9aa80d2696', '3'],
#  ['HBASE-6112', '4ae26c1246', '2'],
#  ['HBASE-6110', '3fa097b01c', '6'],
#  ['HBASE-6110', '99613b8746', '5'],
#  ['HBASE-6110', 'a113f4c291', '5'],
#  ['HBASE-6088', '1761677cef', '1'],
#  ['HBASE-6088', '1869b424ba', '1'],
#  ['HBASE-6088', '77b446186c', '2'],
#  ['HBASE-6088', '4c5a7bbfb3', '2'],
#  ['HBASE-6088', 'a9a4dbe59c', '2'],
#  ['HBASE-6088', 'ccb9c74400', '2'],
#  ['HBASE-6060', 'efead793d4', '12'],
#  ['HBASE-6060', '883ec67336', '12'],
#  ['HBASE-6060', 'ddb9e96654', '5'],
#  ['HBASE-6059', '4eb48a2043', '6'],
#  ['HBASE-6059', '5144d15ce3', '1'],
#  ['HBASE-6059', '8ea00217ed', '4'],
#  ['HBASE-6059', 'b3ec7ced77', '6'],
#  ['HBASE-5974', '8f9faabf57', '8'],
#  ['HBASE-5974', '624021fb4d', '2'],
#  ['HBASE-5974', 'c9073c4631', '9'],
#  ['HBASE-5919', '7692e2efb7', '3'],
#  ['HBASE-588', '03ce494494', '6'],
#  ['HBASE-588', 'fb2db8cdaa', '1'],
#  ['HBASE-588', '75c73ccbbb', '1'],
#  ['HBASE-588', 'e1da900df8', '10'],
#  ['HBASE-588', '1d199b4b7b', '10'],
#  ['HBASE-586', 'ee27270ee9', '9'],
#  ['HBASE-586', 'cffa3a254e', '12'],
#  ['HBASE-586', '32ce612048', '12'],
#  ['HBASE-5825', '10cada8d0b', '2'],
#  ['HBASE-5825', '183b567f6f', '2'],
#  ['HBASE-5825', 'a0a2674c42', '2'],
#  ['HBASE-5824', 'e05c21c0cb', '3'],
#  ['HBASE-5824', '85842f019e', '3'],
#  ['HBASE-5824', '0b30494edb', '2'],
#  ['HBASE-5805', '5ec931d5c7', '1'],
#  ['HBASE-5805', '0f28bc4b6c', '1'],
#  ['HBASE-5799', '44ec501a2b', '1'],
#  ['HBASE-5781', '8db34840c9', '2'],
#  ['HBASE-5781', '711a90655c', '2'],
#  ['HBASE-5781', 'a91b3977f2', '1'],
#  ['HBASE-5781', '7f7bc2b6b6', '1'],
#  ['HBASE-5781', '44a05d4380', '1'],
#  ['HBASE-5763', '421400c256', '2'],
#  ['HBASE-5763', 'c21266e5b2', '2'],
#  ['HBASE-5744', '00316a4a51', '3'],
#  ['HBASE-5744', '46286a023e', '3'],
#  ['HBASE-5743', '20e281d7e1', '2'],
#  ['HBASE-5730', 'bff42e1d84', '3'],
#  ['HBASE-5727', 'c831d7b512', '1'],
#  ['HBASE-5727', '1044d5e353', '1'],
#  ['HBASE-5727', '66772ce043', '2'],
#  ['HBASE-5727', 'e1449b5538', '1'],
#  ['HBASE-5700', '8764ccd917', '4'],
#  ['HBASE-5611', '1f5e7da87e', '3'],
#  ['HBASE-5611', '1ea241364f', '3'],
#  ['HBASE-5611', '224cfd640d', '3'],
#  ['HBASE-5611', '3f5800a3f1', '3'],
#  ['HBASE-5611', '9f3d9a4283', '1'],
#  ['HBASE-5611', '8c8922da96', '1'],
#  ['HBASE-5611', 'c896b73549', '4'],
#  ['HBASE-5611', 'b6f7573a3b', '3'],
#  ['HBASE-5611', 'b8554c84d4', '3'],
#  ['HBASE-5611', 'b695b64dfa', '3'],
#  ['HBASE-5598', '9fac4877d3', '6'],
#  ['HBASE-5598', '81b15f1907', '1'],
#  ['HBASE-5597', '1629b1a219', '1'],
#  ['HBASE-5597', '3c58fdacf1', '1'],
#  ['HBASE-5597', '5856e90720', '1'],
#  ['HBASE-5596', 'a703e49824', '5'],
#  ['HBASE-5596', '998367baf1', '4'],
#  ['HBASE-5596', 'd5b5fabf14', '4'],
#  ['HBASE-5596', '3fd6997380', '4'],
#  ['HBASE-5567', 'df97e219c4', '1'],
#  ['HBASE-5567', 'ab2b1acced', '1'],
#  ['HBASE-5567', '2314945b8b', '1'],
#  ['HBASE-5566', '04c6066df8', '8'],
#  ['HBASE-5562', '63bd5eae5b', '1'],
#  ['HBASE-5562', '0ae06d72b6', '1'],
#  ['HBASE-5562', 'd04201683a', '1'],
#  ['HBASE-554', 'a00fd30d8a', '1'],
#  ['HBASE-554', '48899525e5', '1'],
#  ['HBASE-554', '53563c5586', '1'],
#  ['HBASE-554', '5a43af4b99', '1'],
#  ['HBASE-552', 'de57a6f401', '3'],
#  ['HBASE-552', 'a1f8ee8ac1', '3'],
#  ['HBASE-552', 'c729049956', '3'],
#  ['HBASE-552', '425a522a45', '4'],
#  ['HBASE-5499', '624b0a51b2', '1'],
#  ['HBASE-5499', '6783a4cd96', '1'],
#  ['HBASE-5499', 'ffa518256f', '1'],
#  ['HBASE-5470', '85c90d9274', '1'],
#  ['HBASE-5470', 'ded2006ec9', '1'],
#  ['HBASE-5437', 'b0d4403059', '3'],
#  ['HBASE-5437', 'e7cfa2da58', '3'],
#  ['HBASE-5387', 'e4e8c9dc5b', '4'],
#  ['HBASE-5387', 'b50714c043', '4'],
#  ['HBASE-5387', 'a148490496', '4'],
#  ['HBASE-532', '03ce494494', '6'],
#  ['HBASE-532', 'fb2db8cdaa', '1'],
#  ['HBASE-532', '75c73ccbbb', '1'],
#  ['HBASE-532', 'e1da900df8', '10'],
#  ['HBASE-532', '1d199b4b7b', '10'],
#  ['HBASE-532', '26c2702c12', '4'],
#  ['HBASE-532', 'ef5bb6f316', '4'],
#  ['HBASE-532', '7475ce01fa', '4'],
#  ['HBASE-532', '373761483f', '7'],
#  ['HBASE-532', '64e3f031ea', '7'],
#  ['HBASE-5286', '3d906ed52b', '3'],
#  ['HBASE-5286', 'eb42e72b89', '2'],
#  ['HBASE-5286', '84c103829e', '2'],
#  ['HBASE-5286', '0132176084', '1'],
#  ['HBASE-5286', '180b41f518', '1'],
#  ['HBASE-5286', '11446b1bd6', '1'],
#  ['HBASE-5286', 'abaad0bec9', '1'],
#  ['HBASE-5204', '0abb51186a', '4'],
#  ['HBASE-5204', 'e20aa2b3a6', '3'],
#  ['HBASE-5204', '35cd894356', '3'],
#  ['HBASE-5137', '051c8981c0', '1'],
#  ['HBASE-5137', 'abe549d38e', '2'],
#  ['HBASE-5137', '17af5827a5', '2'],
#  ['HBASE-5137', 'e06aaf4ecc', '2'],
#  ['HBASE-5137', '0820fbddd3', '2'],
#  ['HBASE-5104', 'd2ca6bfe63', '9'],
#  ['HBASE-5104', 'e83952f9af', '4'],
#  ['HBASE-5085', '8edf120cf7', '1'],
#  ['HBASE-5085', '31b10cd5f2', '1'],
#  ['HBASE-5081', 'cb8e30ae17', '7'],
#  ['HBASE-5081', 'ff3cf1aeda', '7'],
#  ['HBASE-5081', '00a846ff20', '7'],
#  ['HBASE-5081', '6b39d23401', '7'],
#  ['HBASE-5081', '04d9afead2', '3'],
#  ['HBASE-5081', '7569cea558', '3'],
#  ['HBASE-5081', '436e064a2c', '3'],
#  ['HBASE-5081', '6c97552ee1', '3'],
#  ['HBASE-5081', 'eb9f9a9e78', '3'],
#  ['HBASE-5081', 'fd27501c1c', '3'],
#  ['HBASE-5081', '3e92ac2ddb', '3'],
#  ['HBASE-5081', 'fa979ebab2', '3'],
#  ['HBASE-5081', 'b8c423408a', '3'],
#  ['HBASE-5081', '72c1f6c8c7', '3'],
#  ['HBASE-5081', '69a45fe909', '3'],
#  ['HBASE-5081', '9f986b0dca', '3'],
#  ['HBASE-5077', '482a460546', '1'],
#  ['HBASE-5077', 'c5b874fff0', '1'],
#  ['HBASE-5077', '26de3b2c74', '1'],
#  ['HBASE-5077', '04dd71214a', '2'],
#  ['HBASE-5077', 'e76a78e103', '2'],
#  ['HBASE-5077', 'bcde7a436f', '2'],
#  ['HBASE-505', 'f15048d4d0', '5'],
#  ['HBASE-505', 'b104b3235b', '5'],
#  ['HBASE-505', '90e3cb13ca', '5'],
#  ['HBASE-5029', '0766dd12f2', '3'],
#  ['HBASE-5029', '1222383f1d', '2'],
#  ['HBASE-5029', '48f3c24dc6', '2'],
#  ['HBASE-5029', '48ccb28e81', '1'],
#  ['HBASE-5029', '4c2c89a9d0', '1'],
#  ['HBASE-5029', '185c0c7dd7', '1'],
#  ['HBASE-5029', 'cd8b64fb38', '3'],
#  ['HBASE-5029', 'a157c07ead', '3'],
#  ['HBASE-5029', '86a3830175', '1'],
#  ['HBASE-5029', '203d2828be', '1'],
#  ['HBASE-5029', '3cad85bc77', '1'],
#  ['HBASE-5029', 'badab7888f', '1'],
#  ['HBASE-5029', 'e4c0fd9231', '2'],
#  ['HBASE-501', '4ea64897fe', '1'],
#  ['HBASE-501', '1e27f603a1', '1'],
#  ['HBASE-501', '277f675af6', '1'],
#  ['HBASE-501', 'c1f974bbee', '10'],
#  ['HBASE-501', '55f01a9863', '10'],
#  ['HBASE-501', 'bba36ce79a', '7'],
#  ['HBASE-500', 'da595915a9', '2'],
#  ['HBASE-4997', 'bcaabd9105', '1'],
#  ['HBASE-4997', '4b8eb16ea9', '1'],
#  ['HBASE-4997', '76a2db4d50', '1'],
#  ['HBASE-4997', '9a74916dae', '2'],
#  ['HBASE-4927', 'bb7f82ac71', '2'],
#  ['HBASE-4927', '925c25fdda', '2'],
#  ['HBASE-4927', '61683142da', '2'],
#  ['HBASE-4927', 'e8123d2b21', '4'],
#  ['HBASE-4927', '1f176022fe', '4'],
#  ['HBASE-4927', 'e1855a9344', '4'],
#  ['HBASE-4890', '0f7285a81a', '1'],
#  ['HBASE-4890', '3c7cd28524', '1'],
#  ['HBASE-4890', 'c5570926a2', '1'],
#  ['HBASE-4890', 'c5354bf129', '2'],
#  ['HBASE-4883', '8ed781ada7', '1'],
#  ['HBASE-4883', 'ea764bd727', '1'],
#  ['HBASE-4883', '01c389c879', '1'],
#  ['HBASE-4883', '625889c281', '1'],
#  ['HBASE-4823', '0d2aab190e', '2'],
#  ['HBASE-4799', 'c991dba669', '3'],
#  ['HBASE-4799', 'ea3484ecea', '1'],
#  ['HBASE-4799', 'f7099fa5c7', '2'],
#  ['HBASE-4799', 'c9d5a838d0', '2'],
#  ['HBASE-4799', '04b1c45b94', '2'],
#  ['HBASE-4758', '2235988874', '1'],
#  ['HBASE-4722', '451303c3cb', '2'],
#  ['HBASE-4722', '2ce1d7c97c', '2'],
#  ['HBASE-4722', 'ec1c5835ec', '2'],
#  ['HBASE-4722', '3fab67a8b5', '1'],
#  ['HBASE-4722', 'b0a61e290e', '1'],
#  ['HBASE-4686', '1c7d82cdad', '6'],
#  ['HBASE-4645', '6e0c0ec263', '2'],
#  ['HBASE-4645', '770cc7d5d2', '3'],
#  ['HBASE-4645', 'aa2c97b3b7', '3'],
#  ['HBASE-4645', '9ffe7cb666', '3'],
#  ['HBASE-4589', 'af700ae33e', '9'],
#  ['HBASE-4589', 'cbfd640aab', '11'],
#  ['HBASE-4589', '4d776c28b9', '11'],
#  ['HBASE-4589', 'efa951b6ab', '11'],
#  ['HBASE-4540', '0a98312a9e', '2'],
#  ['HBASE-4540', '5cd3b9979b', '9'],
#  ['HBASE-4540', '5331d83421', '6'],
#  ['HBASE-4540', '3d50077db1', '6'],
#  ['HBASE-4540', 'bd06d43d93', '6'],
#  ['HBASE-4539', '5331d83421', '6'],
#  ['HBASE-4539', '3d50077db1', '6'],
#  ['HBASE-4539', 'bd06d43d93', '6'],
#  ['HBASE-4531', '1f2f565409', '1'],
#  ['HBASE-4531', '6232eae926', '1'],
#  ['HBASE-4531', '82c9209931', '1'],
#  ['HBASE-4531', 'ef24e43470', '2'],
#  ['HBASE-4531', 'cb845c04d8', '2'],
#  ['HBASE-4531', '6ae7807237', '2'],
#  ['HBASE-4505', '435fea6d79', '1'],
#  ['HBASE-4505', '0db9b9b148', '1'],
#  ['HBASE-4400', 'aa6d6c7a9e', '1'],
#  ['HBASE-4400', 'e866d8091d', '1'],
#  ['HBASE-4400', '034215f247', '1'],
#  ['HBASE-4400', 'ab404d8f36', '1'],
#  ['HBASE-4400', '89b5c7bf10', '4'],
#  ['HBASE-4400', '3cc7e62571', '4'],
#  ['HBASE-4400', 'e282e25dac', '4'],
#  ['HBASE-4367', '3dc7b7f69b', '29'],
#  ['HBASE-4367', '9570f3c907', '15'],
#  ['HBASE-4367', '7c56111aaa', '15'],
#  ['HBASE-4367', '0aafb370ce', '15'],
#  ['HBASE-4350', 'b043d60317', '1'],
#  ['HBASE-4350', '2077f41f18', '1'],
#  ['HBASE-4350', '76b123052e', '3'],
#  ['HBASE-4350', '9f3c81e87d', '3'],
#  ['HBASE-4153', '0b9498a53c', '2'],
#  ['HBASE-4153', '083d104243', '2'],
#  ['HBASE-4153', 'a7318c7969', '2'],
#  ['HBASE-4153', '1ad63afb70', '1'],
#  ['HBASE-4153', '9ab414f1dc', '1'],
#  ['HBASE-4153', '2786fd5863', '1'],
#  ['HBASE-4153', '83da96047e', '8'],
#  ['HBASE-4153', '08d56e35e4', '1'],
#  ['HBASE-4153', 'bf8af69d8d', '1'],
#  ['HBASE-4153', '76ba002ef7', '8'],
#  ['HBASE-4153', 'a36c666a87', '8'],
#  ['HBASE-4153', 'd098ab3b2c', '8'],
#  ['HBASE-4153', '7e6a6538b4', '8'],
#  ['HBASE-4153', 'bd372dcea7', '8'],
#  ['HBASE-4150', '738f80c221', '2'],
#  ['HBASE-4150', 'd453688d1a', '2'],
#  ['HBASE-4150', '4b84ea5a0a', '4'],
#  ['HBASE-4150', '061f1bcd73', '4'],
#  ['HBASE-4150', '2c772a97ab', '2'],
#  ['HBASE-4150', '0aa723c2a3', '2'],
#  ['HBASE-4150', 'a9031452f7', '2'],
#  ['HBASE-4150', '6acdab46a1', '2'],
#  ['HBASE-4149', '026b437eff', '1'],
#  ['HBASE-4149', 'b2d802611f', '1'],
#  ['HBASE-4138', '5cae3a6b66', '1'],
#  ['HBASE-4138', '2889431d93', '1'],
#  ['HBASE-4138', '1c5e23f215', '1'],
#  ['HBASE-4138', 'b993a611e1', '1'],
#  ['HBASE-4138', '5e4f28c289', '12'],
#  ['HBASE-4138', 'd1cb273b2f', '12'],
#  ['HBASE-4078', 'df9b82c082', '3'],
#  ['HBASE-4078', '98cad6e708', '3'],
#  ['HBASE-4078', 'fa26da20db', '3'],
#  ['HBASE-4078', '790feddf2d', '5'],
#  ['HBASE-4075', '3314b87804', '2'],
#  ['HBASE-4075', 'df9c2fdc30', '2'],
#  ['HBASE-4075', 'd69b198ba9', '2'],
#  ['HBASE-4020', 'a9e7b929e7', '2'],
#  ['HBASE-4020', '1a5251661e', '2'],
#  ['HBASE-4020', '829cdddeec', '2'],
#  ['HBASE-4005', '2851a9dfe3', '3'],
#  ['HBASE-4005', '7e87980347', '4'],
#  ['HBASE-4005', '170bed8651', '4'],
#  ['HBASE-3987', '73cb88aef3', '1'],
#  ['HBASE-3987', '3f59c6a0e5', '2'],
#  ['HBASE-3987', '6f09e358e0', '2'],
#  ['HBASE-3987', '949f7a68db', '2'],
#  ['HBASE-3979', 'c98dc2c4b4', '4'],
#  ['HBASE-3979', '7ccbc3bbb1', '4'],
#  ['HBASE-3939', 'ae0dccc833', '2'],
#  ['HBASE-3939', '7ccda81373', '14'],
#  ['HBASE-3939', '7d8d42d01b', '16'],
#  ['HBASE-3939', '2e678eaab6', '16'],
#  ['HBASE-3912', 'e341eb76cb', '1'],
#  ['HBASE-3912', '60d7a81833', '1'],
#  ['HBASE-3912', '7d86a5998b', '1'],
#  ['HBASE-3912', '1c6a02a046', '2'],
#  ['HBASE-3912', '981f414cd3', '2'],
#  ['HBASE-3912', 'cd8f643954', '2'],
#  ['HBASE-3904', 'edf2b7901a', '1'],
#  ['HBASE-3904', 'd37e6eb390', '1'],
#  ['HBASE-3904', 'de919df41a', '1'],
#  ['HBASE-3904', '04e89f8ae4', '1'],
#  ['HBASE-3904', '1add4cc5d2', '1'],
#  ['HBASE-3904', 'abccc7fd9f', '1'],
#  ['HBASE-3904', '7fa7d15daf', '1'],
#  ['HBASE-3904', '1f3a4fefb8', '1'],
#  ['HBASE-3904', '46924a1dc2', '1'],
#  ['HBASE-3904', '521141cdc6', '1'],
#  ['HBASE-3904', '18987b9d4d', '1'],
#  ['HBASE-3904', 'a4482ae1ac', '2'],
#  ['HBASE-3904', 'e3f8560143', '2'],
#  ['HBASE-3904', '24c18ac1e9', '2'],
#  ['HBASE-3872', '6fd573c3b0', '9'],
#  ['HBASE-3872', 'f54803aac2', '1'],
#  ['HBASE-3872', '185e57e58c', '1'],
#  ['HBASE-3872', '0a0ce9f1ae', '1'],
#  ['HBASE-3872', '5872ef811b', '1'],
#  ['HBASE-3872', '7f10f29425', '10'],
#  ['HBASE-3872', 'ca7452b4b6', '10'],
#  ['HBASE-3832', 'c80200bded', '4'],
#  ['HBASE-3832', '097edf7bc4', '4'],
#  ['HBASE-3821', 'ce20845951', '1'],
#  ['HBASE-3821', '81e9be2518', '3'],
#  ['HBASE-3821', '724ddc58bf', '3'],
#  ['HBASE-3821', '8e0e63e0a8', '3'],
#  ['HBASE-3819', '95a45d1341', '2'],
#  ['HBASE-3819', '2e84b07763', '2'],
#  ['HBASE-3819', 'e01e57ff92', '2'],
#  ['HBASE-3819', '599b7e6f7d', '2'],
#  ['HBASE-3813', '8ffaac2003', '2'],
#  ['HBASE-3813', '1162a81b92', '2'],
#  ['HBASE-3813', 'e56c8db56e', '2'],
#  ['HBASE-3793', '7656d7568a', '1'],
#  ['HBASE-3793', '243c222ccd', '1'],
#  ['HBASE-3793', '76a743e8f0', '3'],
#  ['HBASE-3793', 'f0b1b298c7', '3'],
#  ['HBASE-3762', 'f616c0c709', '1'],
#  ['HBASE-3762', '07353b5618', '1'],
#  ['HBASE-3762', 'a7f8453d50', '6'],
#  ['HBASE-3762', '02659a4882', '6'],
#  ['HBASE-3750', '7eddae4687', '1'],
#  ['HBASE-3750', '9fe4b7c5bc', '1'],
#  ['HBASE-3750', '1b438175a3', '1'],
#  ['HBASE-3750', 'c81146580a', '2'],
#  ['HBASE-3750', '56b76bd434', '2'],
#  ['HBASE-3750', '13bc223d04', '2'],
#  ['HBASE-3741', '4219e2accb', '9'],
#  ['HBASE-3741', '0e29fbf876', '9'],
#  ['HBASE-3741', 'afea4ede2a', '1'],
#  ['HBASE-3741', 'a5863ce0e7', '8'],
#  ['HBASE-3708', 'b634180d5c', '1'],
#  ['HBASE-3708', '7f90ea5860', '2'],
#  ['HBASE-3708', '6aa734ee92', '2'],
#  ['HBASE-3708', 'b10bacf1e8', '2'],
#  ['HBASE-3690', '04afdf9633', '4'],
#  ['HBASE-3690', 'c40efc3887', '4'],
#  ['HBASE-3674', '992bf057e7', '1'],
#  ['HBASE-3674', '45e341b8b7', '1'],
#  ['HBASE-3674', '7437b11bec', '1'],
#  ['HBASE-3674', 'dded2af3e0', '1'],
#  ['HBASE-3674', '5125ae04fb', '2'],
#  ['HBASE-3674', '53a031f00c', '2'],
#  ['HBASE-3674', '8070b53b13', '2'],
#  ['HBASE-3671', '05c9826cba', '1'],
#  ['HBASE-3671', '1889d7ed5c', '1'],
#  ['HBASE-3671', '56aeaec832', '1'],
#  ['HBASE-3671', '23916d541d', '1'],
#  ['HBASE-3671', 'f56380f1ce', '1'],
#  ['HBASE-3671', '33f7f5525b', '1'],
#  ['HBASE-3671', '2e41ea820e', '2'],
#  ['HBASE-3671', '3579bdf84b', '2'],
#  ['HBASE-3671', '2ea5d45bb0', '2'],
#  ['HBASE-3669', '86e9f5f8c9', '1'],
#  ['HBASE-3669', '237bc82af2', '1'],
#  ['HBASE-3669', 'bd688ffaae', '1'],
#  ['HBASE-3636', '32d4618caf', '3'],
#  ['HBASE-3636', '856065dee8', '3'],
#  ['HBASE-3636', '129ced5a3d', '3'],
#  ['HBASE-3627', '23606d0645', '3'],
#  ['HBASE-3627', '79b522db0c', '6'],
#  ['HBASE-3627', '89794648e6', '1'],
#  ['HBASE-3627', '16bb3bb633', '1'],
#  ['HBASE-3627', 'cf3284dfb9', '7'],
#  ['HBASE-3627', '833fd0095e', '7'],
#  ['HBASE-3622', 'c38558e545', '1'],
#  ['HBASE-3622', '42b7a92450', '1'],
#  ['HBASE-3515', '930eb49759', '1'],
#  ['HBASE-3515', '346aa36b77', '1'],
#  ['HBASE-3515', 'cb9e52fe6b', '5'],
#  ['HBASE-3515', '08a9170236', '3'],
#  ['HBASE-3515', 'fa8dcedb56', '3'],
#  ['HBASE-3515', 'd051203938', '3'],
#  ['HBASE-3515', '1aaaac0c92', '3'],
#  ['HBASE-3515', 'c9449f0598', '3'],
#  ['HBASE-3515', 'ef29cac094', '2'],
#  ['HBASE-3515', '2b7560b147', '2'],
#  ['HBASE-3515', '01af2a830e', '2'],
#  ['HBASE-3481', 'fa81c75aed', '1'],
#  ['HBASE-3421', 'e3acd1dd77', '1'],
#  ['HBASE-3421', '15a396c926', '1'],
#  ['HBASE-3421', 'd9158b505e', '1'],
#  ['HBASE-3421', 'a8536b787c', '1'],
#  ['HBASE-3421', '61249dc5f3', '1'],
#  ['HBASE-3421', 'ba305551e1', '2'],
#  ['HBASE-3421', '7efe1dbbce', '2'],
#  ['HBASE-3421', 'bcaecda371', '2'],
#  ['HBASE-3421', '1244c9108f', '2'],
#  ['HBASE-3416', '9937c30304', '4'],
#  ['HBASE-3416', 'feda42e474', '3'],
#  ['HBASE-3416', 'a3a2ce9215', '3'],
#  ['HBASE-3416', '410d70fca7', '3'],
#  ['HBASE-3374', 'a59bd1030b', '10'],
#  ['HBASE-3374', 'e787973338', '10'],
#  ['HBASE-3374', 'ec8f0ad428', '10'],
#  ['HBASE-3337', 'c0c723f660', '7'],
#  ['HBASE-3337', '092bdbbea6', '7'],
#  ['HBASE-3337', '97adaad945', '7'],
#  ['HBASE-3315', 'ef50ac96c4', '2'],
#  ['HBASE-3315', 'd547429a14', '2'],
#  ['HBASE-3315', 'b9c34cf91a', '2'],
#  ['HBASE-3311', 'b1a82279a1', '6'],
#  ['HBASE-3311', '5441eaa83d', '6'],
#  ['HBASE-3311', 'ce3139a30e', '6'],
#  ['HBASE-3298', 'b1a82279a1', '6'],
#  ['HBASE-3298', '5441eaa83d', '6'],
#  ['HBASE-3298', 'ce3139a30e', '6'],
#  ['HBASE-3298', 'be91a5326f', '1'],
#  ['HBASE-3298', 'a3127bd6cd', '1'],
#  ['HBASE-3298', '0427950746', '1'],
#  ['HBASE-3298', '61fb4c2d77', '1'],
#  ['HBASE-3298', 'd960ee49cb', '1'],
#  ['HBASE-3298', 'b6a5c4189f', '1'],
#  ['HBASE-3298', 'f6b7e8c6c3', '7'],
#  ['HBASE-3298', 'fe2e720318', '7'],
#  ['HBASE-3298', '633c049091', '7'],
#  ['HBASE-3275', 'cb85bf2e0a', '2'],
#  ['HBASE-3275', '182e82fa62', '2'],
#  ['HBASE-3275', '79a2cf9f3a', '2'],
#  ['HBASE-3275', '446c403dc4', '2'],
#  ['HBASE-3275', '429fc09852', '2'],
#  ['HBASE-3275', '9b45d9996f', '2'],
#  ['HBASE-3275', 'de0ab29132', '2'],
#  ['HBASE-3264', '84134f360a', '1'],
#  ['HBASE-3264', '2778fced75', '1'],
#  ['HBASE-3264', 'c0e4ac3571', '1'],
#  ['HBASE-3264', '307dafacfe', '1'],
#  ['HBASE-3264', '272806891a', '1'],
#  ['HBASE-3264', 'e9b54394cb', '1'],
#  ['HBASE-3264', 'a7b528a712', '4'],
#  ['HBASE-3264', '4ff0e7ac89', '4'],
#  ['HBASE-3264', '4122dc1fe5', '4'],
#  ['HBASE-3241', 'd68e62c6b8', '1'],
#  ['HBASE-3241', '4a6d4ff453', '2'],
#  ['HBASE-3241', '3027f23030', '2'],
#  ['HBASE-3241', '1c76849d3d', '2'],
#  ['HBASE-3239', 'd68e62c6b8', '1'],
#  ['HBASE-3239', '4a6d4ff453', '2'],
#  ['HBASE-3239', '3027f23030', '2'],
#  ['HBASE-3239', '1c76849d3d', '2'],
#  ['HBASE-3232', '3093d81540', '11'],
#  ['HBASE-3232', '571e8f8520', '11'],
#  ['HBASE-3232', '3fd0eedcdf', '11'],
#  ['HBASE-3232', 'a3e56bb694', '5'],
#  ['HBASE-3232', 'a14cd5950c', '7'],
#  ['HBASE-3232', '069fecaeb7', '7'],
#  ['HBASE-3232', '717fee6602', '7'],
#  ['HBASE-3199', 'f102ec2722', '5'],
#  ['HBASE-3199', '0cb9652dd1', '6'],
#  ['HBASE-3199', 'ea9618df63', '6'],
#  ['HBASE-3183', '053141a64f', '1'],
#  ['HBASE-3183', '2fbceee800', '1'],
#  ['HBASE-3183', '9009d8e489', '1'],
#  ['HBASE-3179', '18a78fef4d', '3'],
#  ['HBASE-3179', '10e1d0d6fc', '3'],
#  ['HBASE-3159', '3523b66eec', '13'],
#  ['HBASE-3159', '289ca8adae', '13'],
#  ['HBASE-3114', '0f27ee880c', '4'],
#  ['HBASE-3114', '13d8b4fdad', '4'],
#  ['HBASE-3113', 'dcbcd4f2d4', '3'],
#  ['HBASE-3113', '02d9066f9e', '3'],
#  ['HBASE-3113', '509beae1e2', '4'],
#  ['HBASE-3113', '0d2dcd023c', '4'],
#  ['HBASE-3113', 'e20615b917', '3'],
#  ['HBASE-3113', '98edfa4ba1', '3'],
#  ['HBASE-3113', 'bcaa2dea49', '1'],
#  ['HBASE-3113', 'c0be59b731', '1'],
#  ['HBASE-3111', '954efa6e76', '6'],
#  ['HBASE-3111', 'e334903b44', '6'],
#  ['HBASE-3111', 'cd2bfd5b6a', '1'],
#  ['HBASE-3111', '2379ca5a68', '1'],
#  ['HBASE-3110', 'a01b4c5576', '1'],
#  ['HBASE-3110', '095b37ecdf', '1'],
#  ['HBASE-3110', '3d75d323e5', '1'],
#  ['HBASE-3110', '14554236ef', '1'],
#  ['HBASE-3100', '0fcd520eb3', '1'],
#  ...]

# %%
with open(analyze_dir + "02_extracting_commitid/numberof_file_in_candidatebugfix_commitid.csv", "w") as csvfile:
    fields = ['bug_id', 'candidate_bugfix_commitID', 'number_of_files']
    writers = csv.writer(csvfile, delimiter = ",")
    writers.writerow(fields)
    for n in file_num:
        writers.writerow(n)
print("File numberof_file_in_candidatebugfix_commitid.csv has been created")
# Out:
# File numberof_file_in_candidatebugfix_commitid.csv has been created

# %%
df_filenum = pd.read_csv(analyze_dir + "02_extracting_commitid/numberof_file_in_candidatebugfix_commitid.csv")
df_filenum = df_filenum[fields]
df_filenum
# Out:
#            bug_id candidate_bugfix_commitID  number_of_files
# 0      HBASE-9971                8a6291a896                1
# 1      HBASE-9961                1e7fdb06b2                1
# 2      HBASE-9961                560f000424                1
# 3      HBASE-9961                e5946ba799                2
# 4      HBASE-9961                18e018b3d9                2
# 5      HBASE-9958                8a6291a896                1
# 6      HBASE-9958                4b84160b37                5
# 7      HBASE-9958                c5a3048fec                5
# 8      HBASE-9908                f224e4721f                1
# 9      HBASE-9908                16b799dae5                1
# 10     HBASE-9908                61120fb62c               11
# 11     HBASE-9908                ff78f217fa               11
# 12     HBASE-9893                c5fc5b993e                2
# 13     HBASE-9893                da89846cf7                2
# 14     HBASE-9856                13e9eda3e7                2
# 15      HBASE-985                e3659aa246                2
# 16      HBASE-985                894c99bdb3                2
# 17     HBASE-9843                6dd52d7ed3                7
# 18     HBASE-9843                53bb2f6be7                7
# 19      HBASE-984                f78f944026                3
# 20      HBASE-984                963c1104dd                3
# 21     HBASE-9786                230cb08611                1
# 22     HBASE-9786                6d0eade8b6                1
# 23      HBASE-977                5418547132                4
# 24      HBASE-977                1b49c9b6c4                4
# 25     HBASE-9747                201c67a7d8                1
# 26     HBASE-9747                3f496372bf                1
# 27     HBASE-9747                b4df85d6b0                1
# 28     HBASE-9747                fc15e1ae39                1
# 29     HBASE-9747                a2a3071256                1
# ...           ...                       ...              ...
# 2503  HBASE-10397                b5d161c513                1
# 2504  HBASE-10370                5645d48eac                1
# 2505  HBASE-10370                bebb59dc10                1
# 2506  HBASE-10370                3b9b0e1bc8                1
# 2507  HBASE-10370                c27bfd6acc                2
# 2508  HBASE-10370                1abfabaaa4                2
# 2509  HBASE-10370                9b10589954                1
# 2510  HBASE-10370                e7c36e7822                2
# 2511  HBASE-10370                868f9e4b38                2
# 2512   HBASE-1013                05a11e7fcc                4
# 2513   HBASE-1013                dfd2d6af99                4
# 2514  HBASE-10079                d6e86d0524                1
# 2515  HBASE-10079                8eca550e02                1
# 2516  HBASE-10079                584793fb6f                1
# 2517  HBASE-10079                3fb88f10af                2
# 2518  HBASE-10079                6873efa5a2                2
# 2519  HBASE-10079                923becd6c0                2
# 2520  HBASE-10011                22f54af029                1
# 2521  HBASE-10011                100cfded38                7
# 2522  HBASE-10011                35cea57fe5                7
# 2523  HBASE-10004                e0c324f9d5                3
# 2524   HBASE-9778                ca8b80433e                1
# 2525   HBASE-9778                a772c4110d                6
# 2526   HBASE-9778                9ffe4843dd                6
# 2527   HBASE-9778                d2eac30d68                6
# 2528   HBASE-9778                330a8e1fc3                6
# 2529   HBASE-3015                d16d6257e6                1
# 2530   HBASE-3015                7daffb3a42                2
# 2531   HBASE-3015                0d53298953                2
# 2532  HBASE-15195                9955118995                1
#
# [2533 rows x 3 columns]

# %%
summ = 0
for z in range(0, len(df_filenum)):
    summ = summ + df_filenum.iloc[z][2]
print ("Total number of files for all candidate bug-fix commit id: %i" %summ)
# Out:
# Total number of files for all candidate bug-fix commit id: 13179
